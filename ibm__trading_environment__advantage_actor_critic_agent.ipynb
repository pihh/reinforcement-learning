# %%
import shutup
shutup.please()

import gym
import src.environments.continuous.stock_trading  

import numpy as np
import pandas as pd 

from tqdm.notebook import trange, tqdm

# %% [markdown]
# ### Train the agent
# * Run it until he has a running average above the success_threshold
# * Use a large number of episodes for the running average ( 1000+ ) so if even it falls into a privileged sample, it wont be prone to error

# %%
def environment():
    env = gym.make('StockTradingEnvironment-v0',
        ticker="IBM",
        use_technical_indicators= [
        "macd",
        "boll_ub",
        "boll_lb",
        "rsi_30",
        "cci_30",
        "dx_30",
        "close_30_sma",
        "close_60_sma",
    ])
    print('original threshold',env.success_threshold)
    
    env.success_threshold =0.25 # 25%
    
    print('current threshold',env.success_threshold)
    return env

# from src.environments.continuous.trading import environment

# %%
from src.agents.actor_critic.a2c import A2CAgent

# %%
agent=A2CAgent(environment, epochs=1, actor_learning_rate=0.000025,critic_learning_rate=0.000025,policy="CNN")
agent.load()
# Out:
# 0.03489889871905054
# [Errno 2] Unable to open file (unable to open file: name = 'storage/environments/IbmStockTradingEnvironment-v0/2ec9feb00c05a2de76418e3bcb711337/models/a2c-actor.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
#
# [Errno 2] Unable to open file (unable to open file: name = 'storage/environments/IbmStockTradingEnvironment-v0/2ec9feb00c05a2de76418e3bcb711337/models/a2c-critic.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
#
#
# 0.03489889871905054
# 0.25

# %%
agent.env.mode = "train"
agent.learning_log.episodes = 0
agent.learn(
    timesteps=-1, 
    log_every=100,
    success_threshold_lookback=1000,
    success_strict=True,
)

print('A2C + CNN + 0.25 threshold -> Executed in 1h 1m 4s, finished 18:43:51 2022-08-08')
# Out:
# Episode * 100 * Moving Avg Reward is ==> 0.00168 * Last Reward was ==> -0.01097
# Episode * 200 * Moving Avg Reward is ==> 0.00540 * Last Reward was ==> 0.01132
# Episode * 300 * Moving Avg Reward is ==> 0.00596 * Last Reward was ==> -0.01821
# Episode * 400 * Moving Avg Reward is ==> 0.00924 * Last Reward was ==> 0.08276
# Episode * 500 * Moving Avg Reward is ==> 0.01044 * Last Reward was ==> 0.01026
# Episode * 600 * Moving Avg Reward is ==> 0.01196 * Last Reward was ==> 0.01050
# Episode * 700 * Moving Avg Reward is ==> 0.01424 * Last Reward was ==> 0.03462
# Episode * 800 * Moving Avg Reward is ==> 0.01755 * Last Reward was ==> 0.03666
# Episode * 900 * Moving Avg Reward is ==> 0.02131 * Last Reward was ==> 0.03930
# Episode * 1000 * Moving Avg Reward is ==> 0.02496 * Last Reward was ==> 0.06020
# * Models saved *
#
# New historical moving average record: 0.02505
#
# * Models saved *
#
# New historical moving average record: 0.02514
#
# * Models saved *
#
# New historical moving average record: 0.02514
#
# * Models saved *
#
# New historical moving average record: 0.02515
#
# * Models saved *
#
# New historical moving average record: 0.02518
#
# * Models saved *
#
# New historical moving average record: 0.02530
#
# * Models saved *
#
# New historical moving average record: 0.02534
#
# * Models saved *
#
# New historical moving average record: 0.02539
#
# * Models saved *
#
# New historical moving average record: 0.02545
#
# * Models saved *
#
# New historical moving average record: 0.02558
#
# * Models saved *
#
# New historical moving average record: 0.02559
#
# * Models saved *
#
# New historical moving average record: 0.02565
#
# * Models saved *
#
# New historical moving average record: 0.02567
#
# * Models saved *
#
# New historical moving average record: 0.02574
#
# * Models saved *
#
# New historical moving average record: 0.02586
#
# * Models saved *
#
# New historical moving average record: 0.02589
#
# * Models saved *
#
# New historical moving average record: 0.02598
#
# * Models saved *
#
# New historical moving average record: 0.02603
#
# * Models saved *
#
# New historical moving average record: 0.02607
#
# * Models saved *
#
# New historical moving average record: 0.02612
#
# * Models saved *
#
# New historical moving average record: 0.02615
#
# * Models saved *
#
# New historical moving average record: 0.02625
#
# * Models saved *
#
# New historical moving average record: 0.02629
#
# * Models saved *
#
# New historical moving average record: 0.02634
#
# * Models saved *
#
# New historical moving average record: 0.02642
#
# * Models saved *
#
# New historical moving average record: 0.02648
#
# * Models saved *
#
# New historical moving average record: 0.02655
#
# * Models saved *
#
# New historical moving average record: 0.02658
#
# * Models saved *
#
# New historical moving average record: 0.02666
#
# * Models saved *
#
# New historical moving average record: 0.02676
#
# * Models saved *
#
# New historical moving average record: 0.02683
#
# * Models saved *
#
# New historical moving average record: 0.02687
#
# * Models saved *
#
# New historical moving average record: 0.02692
#
# * Models saved *
#
# New historical moving average record: 0.02696
#
# * Models saved *
#
# New historical moving average record: 0.02704
#
# * Models saved *
#
# New historical moving average record: 0.02710
#
# * Models saved *
#
# New historical moving average record: 0.02714
#
# * Models saved *
#
# New historical moving average record: 0.02716
#
# * Models saved *
#
# New historical moving average record: 0.02722
#
# * Models saved *
#
# New historical moving average record: 0.02725
#
# * Models saved *
#
# New historical moving average record: 0.02728
#
# * Models saved *
#
# New historical moving average record: 0.02733
#
# * Models saved *
#
# New historical moving average record: 0.02746
#
# * Models saved *
#
# New historical moving average record: 0.02751
#
# * Models saved *
#
# New historical moving average record: 0.02760
#
# * Models saved *
#
# New historical moving average record: 0.02769
#
# * Models saved *
#
# New historical moving average record: 0.02773
#
# * Models saved *
#
# New historical moving average record: 0.02778
#
# * Models saved *
#
# New historical moving average record: 0.02784
#
# * Models saved *
#
# New historical moving average record: 0.02790
#
# * Models saved *
#
# New historical moving average record: 0.02792
#
# * Models saved *
#
# New historical moving average record: 0.02793
#
# * Models saved *
#
# New historical moving average record: 0.02802
#
# * Models saved *
#
# New historical moving average record: 0.02809
#
# * Models saved *
#
# New historical moving average record: 0.02821
#
# * Models saved *
#
# New historical moving average record: 0.02825
#
# * Models saved *
#
# New historical moving average record: 0.02830
#
# * Models saved *
#
# New historical moving average record: 0.02837
#
# * Models saved *
#
# New historical moving average record: 0.02843
#
# * Models saved *
#
# New historical moving average record: 0.02854
#
# * Models saved *
#
# New historical moving average record: 0.02855
#
# * Models saved *
#
# New historical moving average record: 0.02863
#
# * Models saved *
#
# New historical moving average record: 0.02868
#
# * Models saved *
#
# New historical moving average record: 0.02874
#
# * Models saved *
#
# New historical moving average record: 0.02882
#
# * Models saved *
#
# New historical moving average record: 0.02889
#
# * Models saved *
#
# New historical moving average record: 0.02899
#
# * Models saved *
#
# New historical moving average record: 0.02914
#
# * Models saved *
#
# New historical moving average record: 0.02920
#
# * Models saved *
#
# New historical moving average record: 0.02926
#
# * Models saved *
#
# New historical moving average record: 0.02930
#
# * Models saved *
#
# New historical moving average record: 0.02943
#
# * Models saved *
#
# New historical moving average record: 0.02954
#
# * Models saved *
#
# New historical moving average record: 0.02955
#
# * Models saved *
#
# New historical moving average record: 0.02963
#
# * Models saved *
#
# New historical moving average record: 0.02972
#
# * Models saved *
#
# New historical moving average record: 0.02982
#
# * Models saved *
#
# New historical moving average record: 0.02990
#
# * Models saved *
#
# New historical moving average record: 0.02990
#
# * Models saved *
#
# New historical moving average record: 0.02996
#
# * Models saved *
#
# New historical moving average record: 0.03007
#
# * Models saved *
#
# New historical moving average record: 0.03021
#
# * Models saved *
#
# New historical moving average record: 0.03037
#
# * Models saved *
#
# New historical moving average record: 0.03043
#
# * Models saved *
#
# New historical moving average record: 0.03046
#
# * Models saved *
#
# New historical moving average record: 0.03048
#
# * Models saved *
#
# New historical moving average record: 0.03052
#
# * Models saved *
#
# New historical moving average record: 0.03062
#
# * Models saved *
#
# New historical moving average record: 0.03068
#
# * Models saved *
#
# New historical moving average record: 0.03077
#
# * Models saved *
#
# New historical moving average record: 0.03077
#
# * Models saved *
#
# New historical moving average record: 0.03085
#
# * Models saved *
#
# New historical moving average record: 0.03093
#
# * Models saved *
#
# New historical moving average record: 0.03100
#
# * Models saved *
#
# New historical moving average record: 0.03104
#
# Episode * 1100 * Moving Avg Reward is ==> 0.03113 * Last Reward was ==> 0.07540
# * Models saved *
#
# New historical moving average record: 0.03113
#
# * Models saved *
#
# New historical moving average record: 0.03117
#
# * Models saved *
#
# New historical moving average record: 0.03128
#
# * Models saved *
#
# New historical moving average record: 0.03136
#
# * Models saved *
#
# New historical moving average record: 0.03136
#
# * Models saved *
#
# New historical moving average record: 0.03137
#
# * Models saved *
#
# New historical moving average record: 0.03142
#
# * Models saved *
#
# New historical moving average record: 0.03149
#
# * Models saved *
#
# New historical moving average record: 0.03162
#
# * Models saved *
#
# New historical moving average record: 0.03173
#
# * Models saved *
#
# New historical moving average record: 0.03177
#
# * Models saved *
#
# New historical moving average record: 0.03183
#
# * Models saved *
#
# New historical moving average record: 0.03189
#
# * Models saved *
#
# New historical moving average record: 0.03196
#
# * Models saved *
#
# New historical moving average record: 0.03205
#
# * Models saved *
#
# New historical moving average record: 0.03213
#
# * Models saved *
#
# New historical moving average record: 0.03219
#
# * Models saved *
#
# New historical moving average record: 0.03226
# * Models saved *
#
# New historical moving average record: 0.03235
#
# * Models saved *
#
# New historical moving average record: 0.03246
#
# * Models saved *
#
# New historical moving average record: 0.03256
#
# * Models saved *
#
# New historical moving average record: 0.03264
#
# * Models saved *
#
# New historical moving average record: 0.03272
#
# * Models saved *
#
# New historical moving average record: 0.03278
#
# * Models saved *
#
# New historical moving average record: 0.03285
#
# * Models saved *
#
# New historical moving average record: 0.03293
#
# * Models saved *
#
# New historical moving average record: 0.03300
#
# * Models saved *
#
# New historical moving average record: 0.03301
#
# * Models saved *
#
# New historical moving average record: 0.03307
#
# * Models saved *
#
# New historical moving average record: 0.03322
#
# * Models saved *
#
# New historical moving average record: 0.03336
#
# * Models saved *
#
# New historical moving average record: 0.03337
#
# * Models saved *
#
# New historical moving average record: 0.03343
#
# * Models saved *
#
# New historical moving average record: 0.03345
#
# * Models saved *
#
# New historical moving average record: 0.03352
#
# * Models saved *
#
# New historical moving average record: 0.03356
#
# * Models saved *
#
# New historical moving average record: 0.03357
#
# * Models saved *
#
# New historical moving average record: 0.03372
#
# * Models saved *
#
# New historical moving average record: 0.03381
#
# * Models saved *
#
# New historical moving average record: 0.03389
#
# * Models saved *
#
# New historical moving average record: 0.03394
#
# * Models saved *
#
# New historical moving average record: 0.03398
#
# * Models saved *
#
# New historical moving average record: 0.03404
#
# * Models saved *
#
# New historical moving average record: 0.03413
#
# * Models saved *
#
# New historical moving average record: 0.03417
#
# * Models saved *
#
# New historical moving average record: 0.03426
#
# * Models saved *
#
# New historical moving average record: 0.03440
#
# * Models saved *
#
# New historical moving average record: 0.03444
#
# * Models saved *
#
# New historical moving average record: 0.03450
#
# * Models saved *
#
# New historical moving average record: 0.03458
#
# * Models saved *
#
# New historical moving average record: 0.03471
#
# * Models saved *
#
# New historical moving average record: 0.03476
#
# * Models saved *
#
# New historical moving average record: 0.03477
#
# * Models saved *
#
# New historical moving average record: 0.03481
#
# * Models saved *
#
# New historical moving average record: 0.03486
#
# * Models saved *
#
# New historical moving average record: 0.03488
#
# * Models saved *
#
# New historical moving average record: 0.03496
#
# * Models saved *
#
# New historical moving average record: 0.03510
#
# * Models saved *
#
# New historical moving average record: 0.03513
#
# * Models saved *
#
# New historical moving average record: 0.03518
#
# * Models saved *
#
# New historical moving average record: 0.03527
#
# * Models saved *
#
# New historical moving average record: 0.03532
#
# * Models saved *
#
# New historical moving average record: 0.03542
#
# * Models saved *
#
# New historical moving average record: 0.03554
#
# * Models saved *
#
# New historical moving average record: 0.03564
#
# * Models saved *
#
# New historical moving average record: 0.03577
#
# * Models saved *
#
# New historical moving average record: 0.03583
#
# * Models saved *
#
# New historical moving average record: 0.03595
#
# * Models saved *
#
# New historical moving average record: 0.03604
#
# * Models saved *
#
# New historical moving average record: 0.03611
#
# * Models saved *
#
# New historical moving average record: 0.03620
#
# * Models saved *
#
# New historical moving average record: 0.03623
#
# * Models saved *
#
# New historical moving average record: 0.03624
#
# * Models saved *
#
# New historical moving average record: 0.03638
#
# * Models saved *
#
# New historical moving average record: 0.03646
#
# * Models saved *
#
# New historical moving average record: 0.03657
#
# * Models saved *
#
# New historical moving average record: 0.03668
#
# * Models saved *
#
# New historical moving average record: 0.03678
#
# * Models saved *
#
# New historical moving average record: 0.03688
#
# * Models saved *
#
# New historical moving average record: 0.03702
#
# * Models saved *
#
# New historical moving average record: 0.03713
#
# * Models saved *
#
# New historical moving average record: 0.03715
#
# * Models saved *
#
# New historical moving average record: 0.03722
#
# * Models saved *
#
# New historical moving average record: 0.03731
#
# * Models saved *
#
# New historical moving average record: 0.03733
#
# * Models saved *
#
# New historical moving average record: 0.03739
#
# * Models saved *
#
# New historical moving average record: 0.03746
#
# * Models saved *
#
# New historical moving average record: 0.03759
#
# * Models saved *
#
# New historical moving average record: 0.03769
#
# * Models saved *
#
# New historical moving average record: 0.03771
#
# * Models saved *
#
# New historical moving average record: 0.03775
#
# * Models saved *
#
# New historical moving average record: 0.03778
#
# * Models saved *
#
# New historical moving average record: 0.03789
#
# Episode * 1200 * Moving Avg Reward is ==> 0.03798 * Last Reward was ==> 0.10560
# * Models saved *
#
# New historical moving average record: 0.03798
#
# * Models saved *
#
# New historical moving average record: 0.03799
#
# * Models saved *
#
# New historical moving average record: 0.03802
#
# * Models saved *
#
# New historical moving average record: 0.03808
#
# * Models saved *
#
# New historical moving average record: 0.03824
#
# * Models saved *
#
# New historical moving average record: 0.03831
#
# * Models saved *
#
# New historical moving average record: 0.03839
#
# * Models saved *
#
# New historical moving average record: 0.03849
#
# * Models saved *
#
# New historical moving average record: 0.03852
#
# * Models saved *
#
# New historical moving average record: 0.03859
#
# * Models saved *
#
# New historical moving average record: 0.03871
#
# * Models saved *
#
# New historical moving average record: 0.03878
#
# * Models saved *
#
# New historical moving average record: 0.03886
#
# * Models saved *
#
# New historical moving average record: 0.03903
#
# * Models saved *
#
# New historical moving average record: 0.03913
#
# * Models saved *
#
# New historical moving average record: 0.03919
#
# * Models saved *
#
# New historical moving average record: 0.03927
#
# * Models saved *
#
# New historical moving average record: 0.03932
#
# * Models saved *
#
# New historical moving average record: 0.03942
#
# * Models saved *
#
# New historical moving average record: 0.03952
#
# * Models saved *
#
# New historical moving average record: 0.03956
#
# * Models saved *
#
# New historical moving average record: 0.03964
#
# * Models saved *
#
# New historical moving average record: 0.03971
#
# * Models saved *
#
# New historical moving average record: 0.03974
#
# * Models saved *
#
# New historical moving average record: 0.03982
#
# * Models saved *
#
# New historical moving average record: 0.03984
#
# * Models saved *
#
# New historical moving average record: 0.03994
#
# * Models saved *
#
# New historical moving average record: 0.03998
#
# * Models saved *
#
# New historical moving average record: 0.04006
#
# * Models saved *
#
# New historical moving average record: 0.04014
#
# * Models saved *
#
# New historical moving average record: 0.04019
#
# * Models saved *
#
# New historical moving average record: 0.04023
#
# * Models saved *
#
# New historical moving average record: 0.04036
#
# * Models saved *
#
# New historical moving average record: 0.04050
#
# * Models saved *
#
# New historical moving average record: 0.04055
#
# * Models saved *
#
# New historical moving average record: 0.04064
#
# * Models saved *
#
# New historical moving average record: 0.04071
#
# * Models saved *
#
# New historical moving average record: 0.04079
#
# * Models saved *
#
# New historical moving average record: 0.04092
#
# * Models saved *
#
# New historical moving average record: 0.04106
#
# * Models saved *
#
# New historical moving average record: 0.04115
#
# * Models saved *
#
# New historical moving average record: 0.04125
#
# * Models saved *
#
# New historical moving average record: 0.04134
#
# * Models saved *
#
# New historical moving average record: 0.04144
#
# * Models saved *
#
# New historical moving average record: 0.04149
#
# * Models saved *
#
# New historical moving average record: 0.04154
#
# * Models saved *
#
# New historical moving average record: 0.04170
#
# * Models saved *
#
# New historical moving average record: 0.04176
#
# * Models saved *
#
# New historical moving average record: 0.04190
#
# * Models saved *
#
# New historical moving average record: 0.04196
# * Models saved *
#
# New historical moving average record: 0.04200
#
# * Models saved *
#
# New historical moving average record: 0.04207
#
# * Models saved *
#
# New historical moving average record: 0.04212
#
# * Models saved *
#
# New historical moving average record: 0.04215
#
# * Models saved *
#
# New historical moving average record: 0.04219
#
# * Models saved *
#
# New historical moving average record: 0.04221
#
# * Models saved *
#
# New historical moving average record: 0.04226
#
# * Models saved *
#
# New historical moving average record: 0.04242
#
# * Models saved *
#
# New historical moving average record: 0.04245
#
# * Models saved *
#
# New historical moving average record: 0.04251
#
# * Models saved *
#
# New historical moving average record: 0.04260
#
# * Models saved *
#
# New historical moving average record: 0.04269
#
# * Models saved *
#
# New historical moving average record: 0.04283
#
# * Models saved *
#
# New historical moving average record: 0.04289
#
# * Models saved *
#
# New historical moving average record: 0.04292
#
# * Models saved *
#
# New historical moving average record: 0.04300
#
# * Models saved *
#
# New historical moving average record: 0.04314
#
# * Models saved *
#
# New historical moving average record: 0.04326
#
# * Models saved *
#
# New historical moving average record: 0.04344
#
# * Models saved *
#
# New historical moving average record: 0.04348
#
# * Models saved *
#
# New historical moving average record: 0.04348
#
# * Models saved *
#
# New historical moving average record: 0.04357
#
# * Models saved *
#
# New historical moving average record: 0.04365
#
# * Models saved *
#
# New historical moving average record: 0.04370
#
# * Models saved *
#
# New historical moving average record: 0.04376
#
# * Models saved *
#
# New historical moving average record: 0.04385
#
# * Models saved *
#
# New historical moving average record: 0.04392
#
# * Models saved *
#
# New historical moving average record: 0.04399
#
# * Models saved *
#
# New historical moving average record: 0.04406
#
# * Models saved *
#
# New historical moving average record: 0.04411
#
# * Models saved *
#
# New historical moving average record: 0.04420
#
# * Models saved *
#
# New historical moving average record: 0.04431
#
# * Models saved *
#
# New historical moving average record: 0.04437
#
# * Models saved *
#
# New historical moving average record: 0.04447
#
# * Models saved *
#
# New historical moving average record: 0.04459
#
# * Models saved *
#
# New historical moving average record: 0.04471
#
# * Models saved *
#
# New historical moving average record: 0.04474
#
# Episode * 1300 * Moving Avg Reward is ==> 0.04487 * Last Reward was ==> 0.11712
# * Models saved *
#
# New historical moving average record: 0.04487
#
# * Models saved *
#
# New historical moving average record: 0.04499
#
# * Models saved *
#
# New historical moving average record: 0.04509
#
# * Models saved *
#
# New historical moving average record: 0.04510
#
# * Models saved *
#
# New historical moving average record: 0.04514
#
# * Models saved *
#
# New historical moving average record: 0.04516
#
# * Models saved *
#
# New historical moving average record: 0.04519
#
# * Models saved *
#
# New historical moving average record: 0.04523
#
# * Models saved *
#
# New historical moving average record: 0.04542
#
# * Models saved *
#
# New historical moving average record: 0.04545
#
# * Models saved *
#
# New historical moving average record: 0.04551
#
# * Models saved *
#
# New historical moving average record: 0.04554
#
# * Models saved *
#
# New historical moving average record: 0.04566
#
# * Models saved *
#
# New historical moving average record: 0.04573
#
# * Models saved *
#
# New historical moving average record: 0.04578
#
# * Models saved *
#
# New historical moving average record: 0.04588
#
# * Models saved *
#
# New historical moving average record: 0.04594
#
# * Models saved *
#
# New historical moving average record: 0.04613
#
# * Models saved *
#
# New historical moving average record: 0.04622
#
# * Models saved *
#
# New historical moving average record: 0.04638
#
# * Models saved *
#
# New historical moving average record: 0.04640
#
# * Models saved *
#
# New historical moving average record: 0.04646
#
# * Models saved *
#
# New historical moving average record: 0.04648
#
# * Models saved *
#
# New historical moving average record: 0.04657
#
# * Models saved *
#
# New historical moving average record: 0.04663
#
# * Models saved *
#
# New historical moving average record: 0.04678
#
# * Models saved *
#
# New historical moving average record: 0.04685
#
# * Models saved *
#
# New historical moving average record: 0.04686
#
# * Models saved *
#
# New historical moving average record: 0.04695
#
# * Models saved *
#
# New historical moving average record: 0.04702
#
# * Models saved *
#
# New historical moving average record: 0.04712
#
# * Models saved *
#
# New historical moving average record: 0.04714
#
# * Models saved *
#
# New historical moving average record: 0.04727
#
# * Models saved *
#
# New historical moving average record: 0.04729
#
# * Models saved *
#
# New historical moving average record: 0.04734
#
# * Models saved *
#
# New historical moving average record: 0.04740
#
# * Models saved *
#
# New historical moving average record: 0.04748
#
# * Models saved *
#
# New historical moving average record: 0.04754
#
# * Models saved *
#
# New historical moving average record: 0.04762
#
# * Models saved *
#
# New historical moving average record: 0.04768
#
# * Models saved *
#
# New historical moving average record: 0.04773
#
# * Models saved *
#
# New historical moving average record: 0.04774
#
# * Models saved *
#
# New historical moving average record: 0.04777
#
# * Models saved *
#
# New historical moving average record: 0.04789
#
# * Models saved *
#
# New historical moving average record: 0.04789
#
# * Models saved *
#
# New historical moving average record: 0.04792
#
# * Models saved *
#
# New historical moving average record: 0.04797
#
# * Models saved *
#
# New historical moving average record: 0.04799
#
# * Models saved *
#
# New historical moving average record: 0.04808
#
# * Models saved *
#
# New historical moving average record: 0.04814
#
# * Models saved *
#
# New historical moving average record: 0.04823
#
# * Models saved *
#
# New historical moving average record: 0.04826
#
# * Models saved *
#
# New historical moving average record: 0.04829
#
# * Models saved *
#
# New historical moving average record: 0.04834
#
# * Models saved *
#
# New historical moving average record: 0.04834
#
# * Models saved *
#
# New historical moving average record: 0.04839
#
# * Models saved *
#
# New historical moving average record: 0.04853
#
# * Models saved *
#
# New historical moving average record: 0.04860
#
# * Models saved *
#
# New historical moving average record: 0.04867
#
# * Models saved *
#
# New historical moving average record: 0.04873
#
# * Models saved *
#
# New historical moving average record: 0.04882
#
# * Models saved *
#
# New historical moving average record: 0.04885
#
# * Models saved *
#
# New historical moving average record: 0.04890
#
# * Models saved *
#
# New historical moving average record: 0.04894
#
# * Models saved *
#
# New historical moving average record: 0.04904
#
# * Models saved *
#
# New historical moving average record: 0.04909
#
# * Models saved *
#
# New historical moving average record: 0.04916
#
# * Models saved *
#
# New historical moving average record: 0.04917
#
# * Models saved *
#
# New historical moving average record: 0.04923
#
# * Models saved *
#
# New historical moving average record: 0.04933
#
# * Models saved *
#
# New historical moving average record: 0.04936
#
# * Models saved *
#
# New historical moving average record: 0.04941
#
# * Models saved *
#
# New historical moving average record: 0.04942
#
# * Models saved *
#
# New historical moving average record: 0.04954
#
# * Models saved *
#
# New historical moving average record: 0.04956
#
# * Models saved *
#
# New historical moving average record: 0.04960
#
# * Models saved *
#
# New historical moving average record: 0.04962
#
# * Models saved *
#
# New historical moving average record: 0.04969
#
# * Models saved *
#
# New historical moving average record: 0.04974
#
# * Models saved *
#
# New historical moving average record: 0.04982
#
# * Models saved *
#
# New historical moving average record: 0.04996
#
# * Models saved *
#
# New historical moving average record: 0.04998
#
# * Models saved *
#
# New historical moving average record: 0.05004
#
# * Models saved *
#
# New historical moving average record: 0.05016
#
# * Models saved *
#
# New historical moving average record: 0.05026
#
# * Models saved *
#
# New historical moving average record: 0.05045
#
# * Models saved *
#
# New historical moving average record: 0.05063
#
# * Models saved *
#
# New historical moving average record: 0.05064
# * Models saved *
#
# New historical moving average record: 0.05068
#
# * Models saved *
#
# New historical moving average record: 0.05073
#
# Episode * 1400 * Moving Avg Reward is ==> 0.05069 * Last Reward was ==> 0.04650
# * Models saved *
#
# New historical moving average record: 0.05076
#
# * Models saved *
#
# New historical moving average record: 0.05081
#
# * Models saved *
#
# New historical moving average record: 0.05083
#
# * Models saved *
#
# New historical moving average record: 0.05090
#
# * Models saved *
#
# New historical moving average record: 0.05097
#
# * Models saved *
#
# New historical moving average record: 0.05110
#
# * Models saved *
#
# New historical moving average record: 0.05122
#
# * Models saved *
#
# New historical moving average record: 0.05130
#
# * Models saved *
#
# New historical moving average record: 0.05131
#
# * Models saved *
#
# New historical moving average record: 0.05133
#
# * Models saved *
#
# New historical moving average record: 0.05137
#
# * Models saved *
#
# New historical moving average record: 0.05153
#
# * Models saved *
#
# New historical moving average record: 0.05153
#
# * Models saved *
#
# New historical moving average record: 0.05168
#
# * Models saved *
#
# New historical moving average record: 0.05172
#
# * Models saved *
#
# New historical moving average record: 0.05180
#
# * Models saved *
#
# New historical moving average record: 0.05184
#
# * Models saved *
#
# New historical moving average record: 0.05190
#
# * Models saved *
#
# New historical moving average record: 0.05197
#
# * Models saved *
#
# New historical moving average record: 0.05205
#
# * Models saved *
#
# New historical moving average record: 0.05217
#
# * Models saved *
#
# New historical moving average record: 0.05221
#
# * Models saved *
#
# New historical moving average record: 0.05224
#
# * Models saved *
#
# New historical moving average record: 0.05233
#
# * Models saved *
#
# New historical moving average record: 0.05246
#
# * Models saved *
#
# New historical moving average record: 0.05250
#
# * Models saved *
#
# New historical moving average record: 0.05263
#
# * Models saved *
#
# New historical moving average record: 0.05268
#
# * Models saved *
#
# New historical moving average record: 0.05275
#
# * Models saved *
#
# New historical moving average record: 0.05278
#
# * Models saved *
#
# New historical moving average record: 0.05285
#
# * Models saved *
#
# New historical moving average record: 0.05291
#
# * Models saved *
#
# New historical moving average record: 0.05302
#
# * Models saved *
#
# New historical moving average record: 0.05319
#
# * Models saved *
#
# New historical moving average record: 0.05321
#
# * Models saved *
#
# New historical moving average record: 0.05326
#
# * Models saved *
#
# New historical moving average record: 0.05330
#
# * Models saved *
#
# New historical moving average record: 0.05336
#
# * Models saved *
#
# New historical moving average record: 0.05349
#
# * Models saved *
#
# New historical moving average record: 0.05357
#
# * Models saved *
#
# New historical moving average record: 0.05357
#
# * Models saved *
#
# New historical moving average record: 0.05360
#
# * Models saved *
#
# New historical moving average record: 0.05372
#
# * Models saved *
#
# New historical moving average record: 0.05377
#
# * Models saved *
#
# New historical moving average record: 0.05382
#
# * Models saved *
#
# New historical moving average record: 0.05391
#
# * Models saved *
#
# New historical moving average record: 0.05404
#
# * Models saved *
#
# New historical moving average record: 0.05407
#
# * Models saved *
#
# New historical moving average record: 0.05411
#
# * Models saved *
#
# New historical moving average record: 0.05418
#
# * Models saved *
#
# New historical moving average record: 0.05422
#
# * Models saved *
#
# New historical moving average record: 0.05425
#
# * Models saved *
#
# New historical moving average record: 0.05426
#
# * Models saved *
#
# New historical moving average record: 0.05432
#
# * Models saved *
#
# New historical moving average record: 0.05433
#
# * Models saved *
#
# New historical moving average record: 0.05439
#
# * Models saved *
#
# New historical moving average record: 0.05441
#
# * Models saved *
#
# New historical moving average record: 0.05445
#
# * Models saved *
#
# New historical moving average record: 0.05451
#
# * Models saved *
#
# New historical moving average record: 0.05459
#
# * Models saved *
#
# New historical moving average record: 0.05467
#
# * Models saved *
#
# New historical moving average record: 0.05470
#
# * Models saved *
#
# New historical moving average record: 0.05473
#
# * Models saved *
#
# New historical moving average record: 0.05481
#
# * Models saved *
#
# New historical moving average record: 0.05488
#
# * Models saved *
#
# New historical moving average record: 0.05499
#
# * Models saved *
#
# New historical moving average record: 0.05506
#
# * Models saved *
#
# New historical moving average record: 0.05508
#
# * Models saved *
#
# New historical moving average record: 0.05511
#
# * Models saved *
#
# New historical moving average record: 0.05522
#
# * Models saved *
#
# New historical moving average record: 0.05524
#
# * Models saved *
#
# New historical moving average record: 0.05534
#
# * Models saved *
#
# New historical moving average record: 0.05541
#
# * Models saved *
#
# New historical moving average record: 0.05549
#
# * Models saved *
#
# New historical moving average record: 0.05551
#
# * Models saved *
#
# New historical moving average record: 0.05554
#
# * Models saved *
#
# New historical moving average record: 0.05568
#
# * Models saved *
#
# New historical moving average record: 0.05574
#
# * Models saved *
#
# New historical moving average record: 0.05579
#
# * Models saved *
#
# New historical moving average record: 0.05585
#
# * Models saved *
#
# New historical moving average record: 0.05586
#
# * Models saved *
#
# New historical moving average record: 0.05591
#
# * Models saved *
#
# New historical moving average record: 0.05604
#
# * Models saved *
#
# New historical moving average record: 0.05606
#
# * Models saved *
#
# New historical moving average record: 0.05607
#
# * Models saved *
#
# New historical moving average record: 0.05616
#
# Episode * 1500 * Moving Avg Reward is ==> 0.05624 * Last Reward was ==> 0.10103
# * Models saved *
#
# New historical moving average record: 0.05624
#
# * Models saved *
#
# New historical moving average record: 0.05629
#
# * Models saved *
#
# New historical moving average record: 0.05639
#
# * Models saved *
#
# New historical moving average record: 0.05647
#
# * Models saved *
#
# New historical moving average record: 0.05648
#
# * Models saved *
#
# New historical moving average record: 0.05654
#
# * Models saved *
#
# New historical moving average record: 0.05658
#
# * Models saved *
#
# New historical moving average record: 0.05669
#
# * Models saved *
#
# New historical moving average record: 0.05679
#
# * Models saved *
#
# New historical moving average record: 0.05688
#
# * Models saved *
#
# New historical moving average record: 0.05692
#
# * Models saved *
#
# New historical moving average record: 0.05703
#
# * Models saved *
#
# New historical moving average record: 0.05718
#
# * Models saved *
#
# New historical moving average record: 0.05722
#
# * Models saved *
#
# New historical moving average record: 0.05731
#
# * Models saved *
#
# New historical moving average record: 0.05733
#
# * Models saved *
#
# New historical moving average record: 0.05739
#
# * Models saved *
#
# New historical moving average record: 0.05749
#
# * Models saved *
#
# New historical moving average record: 0.05766
#
# * Models saved *
#
# New historical moving average record: 0.05770
#
# * Models saved *
#
# New historical moving average record: 0.05778
#
# * Models saved *
#
# New historical moving average record: 0.05787
#
# * Models saved *
#
# New historical moving average record: 0.05792
#
# * Models saved *
#
# New historical moving average record: 0.05800
#
# * Models saved *
#
# New historical moving average record: 0.05806
#
# * Models saved *
#
# New historical moving average record: 0.05813
#
# * Models saved *
#
# New historical moving average record: 0.05830
#
# * Models saved *
#
# New historical moving average record: 0.05847
#
# * Models saved *
#
# New historical moving average record: 0.05857
#
# * Models saved *
#
# New historical moving average record: 0.05863
#
# * Models saved *
#
# New historical moving average record: 0.05868
#
# * Models saved *
#
# New historical moving average record: 0.05877
#
# * Models saved *
#
# New historical moving average record: 0.05887
#
# * Models saved *
#
# New historical moving average record: 0.05897
#
# * Models saved *
#
# New historical moving average record: 0.05905
#
# * Models saved *
#
# New historical moving average record: 0.05910
# * Models saved *
#
# New historical moving average record: 0.05914
#
# * Models saved *
#
# New historical moving average record: 0.05922
#
# * Models saved *
#
# New historical moving average record: 0.05932
#
# * Models saved *
#
# New historical moving average record: 0.05936
#
# * Models saved *
#
# New historical moving average record: 0.05941
#
# * Models saved *
#
# New historical moving average record: 0.05947
#
# * Models saved *
#
# New historical moving average record: 0.05948
#
# * Models saved *
#
# New historical moving average record: 0.05952
#
# * Models saved *
#
# New historical moving average record: 0.05962
#
# * Models saved *
#
# New historical moving average record: 0.05965
#
# * Models saved *
#
# New historical moving average record: 0.05967
#
# * Models saved *
#
# New historical moving average record: 0.05970
#
# * Models saved *
#
# New historical moving average record: 0.05981
#
# * Models saved *
#
# New historical moving average record: 0.05986
#
# * Models saved *
#
# New historical moving average record: 0.05996
#
# * Models saved *
#
# New historical moving average record: 0.05996
#
# * Models saved *
#
# New historical moving average record: 0.06004
#
# * Models saved *
#
# New historical moving average record: 0.06005
#
# * Models saved *
#
# New historical moving average record: 0.06008
#
# * Models saved *
#
# New historical moving average record: 0.06018
#
# * Models saved *
#
# New historical moving average record: 0.06027
#
# * Models saved *
#
# New historical moving average record: 0.06031
#
# * Models saved *
#
# New historical moving average record: 0.06036
#
# * Models saved *
#
# New historical moving average record: 0.06046
#
# * Models saved *
#
# New historical moving average record: 0.06058
#
# * Models saved *
#
# New historical moving average record: 0.06070
#
# * Models saved *
#
# New historical moving average record: 0.06071
#
# * Models saved *
#
# New historical moving average record: 0.06078
#
# * Models saved *
#
# New historical moving average record: 0.06092
#
# * Models saved *
#
# New historical moving average record: 0.06097
#
# * Models saved *
#
# New historical moving average record: 0.06104
#
# * Models saved *
#
# New historical moving average record: 0.06111
#
# * Models saved *
#
# New historical moving average record: 0.06118
#
# * Models saved *
#
# New historical moving average record: 0.06129
#
# * Models saved *
#
# New historical moving average record: 0.06130
#
# * Models saved *
#
# New historical moving average record: 0.06130
#
# * Models saved *
#
# New historical moving average record: 0.06140
#
# * Models saved *
#
# New historical moving average record: 0.06143
#
# * Models saved *
#
# New historical moving average record: 0.06143
#
# * Models saved *
#
# New historical moving average record: 0.06152
#
# * Models saved *
#
# New historical moving average record: 0.06158
#
# * Models saved *
#
# New historical moving average record: 0.06164
#
# * Models saved *
#
# New historical moving average record: 0.06171
#
# * Models saved *
#
# New historical moving average record: 0.06176
#
# * Models saved *
#
# New historical moving average record: 0.06179
#
# * Models saved *
#
# New historical moving average record: 0.06182
#
# * Models saved *
#
# New historical moving average record: 0.06192
#
# * Models saved *
#
# New historical moving average record: 0.06202
#
# * Models saved *
#
# New historical moving average record: 0.06209
#
# * Models saved *
#
# New historical moving average record: 0.06212
#
# * Models saved *
#
# New historical moving average record: 0.06225
#
# * Models saved *
#
# New historical moving average record: 0.06233
#
# * Models saved *
#
# New historical moving average record: 0.06241
#
# * Models saved *
#
# New historical moving average record: 0.06245
#
# * Models saved *
#
# New historical moving average record: 0.06252
#
# * Models saved *
#
# New historical moving average record: 0.06269
#
# * Models saved *
#
# New historical moving average record: 0.06273
#
# * Models saved *
#
# New historical moving average record: 0.06279
#
# Episode * 1600 * Moving Avg Reward is ==> 0.06282 * Last Reward was ==> 0.03431
# * Models saved *
#
# New historical moving average record: 0.06282
#
# * Models saved *
#
# New historical moving average record: 0.06286
#
# * Models saved *
#
# New historical moving average record: 0.06298
#
# * Models saved *
#
# New historical moving average record: 0.06302
#
# * Models saved *
#
# New historical moving average record: 0.06309
#
# * Models saved *
#
# New historical moving average record: 0.06319
#
# * Models saved *
#
# New historical moving average record: 0.06332
#
# * Models saved *
#
# New historical moving average record: 0.06341
#
# * Models saved *
#
# New historical moving average record: 0.06349
#
# * Models saved *
#
# New historical moving average record: 0.06362
#
# * Models saved *
#
# New historical moving average record: 0.06367
#
# * Models saved *
#
# New historical moving average record: 0.06378
#
# * Models saved *
#
# New historical moving average record: 0.06398
#
# * Models saved *
#
# New historical moving average record: 0.06403
#
# * Models saved *
#
# New historical moving average record: 0.06409
#
# * Models saved *
#
# New historical moving average record: 0.06414
#
# * Models saved *
#
# New historical moving average record: 0.06426
#
# * Models saved *
#
# New historical moving average record: 0.06435
#
# * Models saved *
#
# New historical moving average record: 0.06441
#
# * Models saved *
#
# New historical moving average record: 0.06444
#
# * Models saved *
#
# New historical moving average record: 0.06453
#
# * Models saved *
#
# New historical moving average record: 0.06454
#
# * Models saved *
#
# New historical moving average record: 0.06464
#
# * Models saved *
#
# New historical moving average record: 0.06467
#
# * Models saved *
#
# New historical moving average record: 0.06470
#
# * Models saved *
#
# New historical moving average record: 0.06480
#
# * Models saved *
#
# New historical moving average record: 0.06480
#
# * Models saved *
#
# New historical moving average record: 0.06485
#
# * Models saved *
#
# New historical moving average record: 0.06486
#
# * Models saved *
#
# New historical moving average record: 0.06500
#
# * Models saved *
#
# New historical moving average record: 0.06501
#
# * Models saved *
#
# New historical moving average record: 0.06513
#
# * Models saved *
#
# New historical moving average record: 0.06523
#
# * Models saved *
#
# New historical moving average record: 0.06532
#
# * Models saved *
#
# New historical moving average record: 0.06541
#
# * Models saved *
#
# New historical moving average record: 0.06550
#
# * Models saved *
#
# New historical moving average record: 0.06555
#
# * Models saved *
#
# New historical moving average record: 0.06565
#
# * Models saved *
#
# New historical moving average record: 0.06573
#
# * Models saved *
#
# New historical moving average record: 0.06574
#
# * Models saved *
#
# New historical moving average record: 0.06577
#
# * Models saved *
#
# New historical moving average record: 0.06584
#
# * Models saved *
#
# New historical moving average record: 0.06589
#
# * Models saved *
#
# New historical moving average record: 0.06591
#
# * Models saved *
#
# New historical moving average record: 0.06597
#
# * Models saved *
#
# New historical moving average record: 0.06608
#
# * Models saved *
#
# New historical moving average record: 0.06614
#
# * Models saved *
#
# New historical moving average record: 0.06618
#
# * Models saved *
#
# New historical moving average record: 0.06630
#
# * Models saved *
#
# New historical moving average record: 0.06637
#
# * Models saved *
#
# New historical moving average record: 0.06650
#
# * Models saved *
#
# New historical moving average record: 0.06662
#
# * Models saved *
#
# New historical moving average record: 0.06666
#
# * Models saved *
#
# New historical moving average record: 0.06681
#
# * Models saved *
#
# New historical moving average record: 0.06685
#
# * Models saved *
#
# New historical moving average record: 0.06689
#
# * Models saved *
#
# New historical moving average record: 0.06704
#
# * Models saved *
#
# New historical moving average record: 0.06712
#
# * Models saved *
#
# New historical moving average record: 0.06717
#
# * Models saved *
#
# New historical moving average record: 0.06734
#
# * Models saved *
#
# New historical moving average record: 0.06749
#
# * Models saved *
#
# New historical moving average record: 0.06753
#
# * Models saved *
#
# New historical moving average record: 0.06763
#
# * Models saved *
#
# New historical moving average record: 0.06770
#
# * Models saved *
#
# New historical moving average record: 0.06784
#
# * Models saved *
#
# New historical moving average record: 0.06800
#
# * Models saved *
#
# New historical moving average record: 0.06800
# * Models saved *
#
# New historical moving average record: 0.06811
#
# * Models saved *
#
# New historical moving average record: 0.06816
#
# * Models saved *
#
# New historical moving average record: 0.06828
#
# * Models saved *
#
# New historical moving average record: 0.06831
#
# * Models saved *
#
# New historical moving average record: 0.06841
#
# * Models saved *
#
# New historical moving average record: 0.06844
#
# * Models saved *
#
# New historical moving average record: 0.06849
#
# * Models saved *
#
# New historical moving average record: 0.06857
#
# * Models saved *
#
# New historical moving average record: 0.06863
#
# * Models saved *
#
# New historical moving average record: 0.06870
#
# * Models saved *
#
# New historical moving average record: 0.06881
#
# * Models saved *
#
# New historical moving average record: 0.06892
#
# * Models saved *
#
# New historical moving average record: 0.06908
#
# * Models saved *
#
# New historical moving average record: 0.06917
#
# * Models saved *
#
# New historical moving average record: 0.06919
#
# * Models saved *
#
# New historical moving average record: 0.06921
#
# * Models saved *
#
# New historical moving average record: 0.06924
#
# * Models saved *
#
# New historical moving average record: 0.06926
#
# Episode * 1700 * Moving Avg Reward is ==> 0.06930 * Last Reward was ==> 0.08204
# * Models saved *
#
# New historical moving average record: 0.06930
#
# * Models saved *
#
# New historical moving average record: 0.06939
#
# * Models saved *
#
# New historical moving average record: 0.06942
#
# * Models saved *
#
# New historical moving average record: 0.06944
#
# * Models saved *
#
# New historical moving average record: 0.06955
#
# * Models saved *
#
# New historical moving average record: 0.06972
#
# * Models saved *
#
# New historical moving average record: 0.06982
#
# * Models saved *
#
# New historical moving average record: 0.06992
#
# * Models saved *
#
# New historical moving average record: 0.06994
#
# * Models saved *
#
# New historical moving average record: 0.07004
#
# * Models saved *
#
# New historical moving average record: 0.07009
#
# * Models saved *
#
# New historical moving average record: 0.07022
#
# * Models saved *
#
# New historical moving average record: 0.07028
#
# * Models saved *
#
# New historical moving average record: 0.07042
#
# * Models saved *
#
# New historical moving average record: 0.07043
#
# * Models saved *
#
# New historical moving average record: 0.07046
#
# * Models saved *
#
# New historical moving average record: 0.07051
#
# * Models saved *
#
# New historical moving average record: 0.07054
#
# * Models saved *
#
# New historical moving average record: 0.07056
#
# * Models saved *
#
# New historical moving average record: 0.07072
#
# * Models saved *
#
# New historical moving average record: 0.07073
#
# * Models saved *
#
# New historical moving average record: 0.07078
#
# * Models saved *
#
# New historical moving average record: 0.07091
#
# * Models saved *
#
# New historical moving average record: 0.07099
#
# * Models saved *
#
# New historical moving average record: 0.07105
#
# * Models saved *
#
# New historical moving average record: 0.07109
#
# * Models saved *
#
# New historical moving average record: 0.07119
#
# * Models saved *
#
# New historical moving average record: 0.07123
#
# * Models saved *
#
# New historical moving average record: 0.07125
#
# * Models saved *
#
# New historical moving average record: 0.07133
#
# * Models saved *
#
# New historical moving average record: 0.07133
#
# * Models saved *
#
# New historical moving average record: 0.07134
#
# * Models saved *
#
# New historical moving average record: 0.07144
#
# * Models saved *
#
# New historical moving average record: 0.07156
#
# * Models saved *
#
# New historical moving average record: 0.07166
#
# * Models saved *
#
# New historical moving average record: 0.07179
#
# * Models saved *
#
# New historical moving average record: 0.07186
#
# * Models saved *
#
# New historical moving average record: 0.07195
#
# * Models saved *
#
# New historical moving average record: 0.07202
#
# * Models saved *
#
# New historical moving average record: 0.07203
#
# * Models saved *
#
# New historical moving average record: 0.07209
#
# * Models saved *
#
# New historical moving average record: 0.07219
#
# * Models saved *
#
# New historical moving average record: 0.07222
#
# * Models saved *
#
# New historical moving average record: 0.07227
#
# * Models saved *
#
# New historical moving average record: 0.07242
#
# * Models saved *
#
# New historical moving average record: 0.07245
#
# * Models saved *
#
# New historical moving average record: 0.07247
#
# * Models saved *
#
# New historical moving average record: 0.07247
#
# * Models saved *
#
# New historical moving average record: 0.07252
#
# * Models saved *
#
# New historical moving average record: 0.07256
#
# * Models saved *
#
# New historical moving average record: 0.07264
#
# * Models saved *
#
# New historical moving average record: 0.07276
#
# * Models saved *
#
# New historical moving average record: 0.07285
#
# * Models saved *
#
# New historical moving average record: 0.07293
#
# * Models saved *
#
# New historical moving average record: 0.07301
#
# * Models saved *
#
# New historical moving average record: 0.07311
#
# * Models saved *
#
# New historical moving average record: 0.07321
#
# * Models saved *
#
# New historical moving average record: 0.07326
#
# * Models saved *
#
# New historical moving average record: 0.07344
#
# * Models saved *
#
# New historical moving average record: 0.07346
#
# * Models saved *
#
# New historical moving average record: 0.07350
#
# * Models saved *
#
# New historical moving average record: 0.07359
#
# * Models saved *
#
# New historical moving average record: 0.07366
#
# * Models saved *
#
# New historical moving average record: 0.07373
#
# * Models saved *
#
# New historical moving average record: 0.07386
#
# * Models saved *
#
# New historical moving average record: 0.07393
#
# * Models saved *
#
# New historical moving average record: 0.07396
#
# * Models saved *
#
# New historical moving average record: 0.07397
#
# * Models saved *
#
# New historical moving average record: 0.07405
#
# * Models saved *
#
# New historical moving average record: 0.07410
#
# * Models saved *
#
# New historical moving average record: 0.07420
#
# * Models saved *
#
# New historical moving average record: 0.07427
#
# * Models saved *
#
# New historical moving average record: 0.07435
#
# * Models saved *
#
# New historical moving average record: 0.07446
#
# * Models saved *
#
# New historical moving average record: 0.07450
#
# * Models saved *
#
# New historical moving average record: 0.07463
#
# * Models saved *
#
# New historical moving average record: 0.07469
#
# * Models saved *
#
# New historical moving average record: 0.07479
#
# * Models saved *
#
# New historical moving average record: 0.07487
#
# * Models saved *
#
# New historical moving average record: 0.07504
#
# * Models saved *
#
# New historical moving average record: 0.07517
#
# * Models saved *
#
# New historical moving average record: 0.07518
#
# * Models saved *
#
# New historical moving average record: 0.07521
#
# * Models saved *
#
# New historical moving average record: 0.07529
#
# * Models saved *
#
# New historical moving average record: 0.07543
#
# * Models saved *
#
# New historical moving average record: 0.07546
#
# Episode * 1800 * Moving Avg Reward is ==> 0.07557 * Last Reward was ==> 0.15498
# * Models saved *
#
# ...
#
# New historical moving average record: 0.17171
#
# * Models saved *
#
# New historical moving average record: 0.17172
#
# * Models saved *
#
# New historical moving average record: 0.17179
#
# * Models saved *
#
# New historical moving average record: 0.17182
#
# * Models saved *
#
# New historical moving average record: 0.17188
#
# * Models saved *
#
# New historical moving average record: 0.17198
#
# * Models saved *
#
# New historical moving average record: 0.17214
#
# * Models saved *
#
# New historical moving average record: 0.17227
# * Models saved *
#
# New historical moving average record: 0.17233
#
# * Models saved *
#
# New historical moving average record: 0.17234
#
# * Models saved *
#
# New historical moving average record: 0.17241
#
# * Models saved *
#
# New historical moving average record: 0.17251
#
# * Models saved *
#
# New historical moving average record: 0.17262
#
# * Models saved *
#
# New historical moving average record: 0.17271
#
# * Models saved *
#
# New historical moving average record: 0.17274
#
# * Models saved *
#
# New historical moving average record: 0.17279
#
# * Models saved *
#
# New historical moving average record: 0.17283
#
# * Models saved *
#
# New historical moving average record: 0.17285
#
# * Models saved *
#
# New historical moving average record: 0.17291
#
# * Models saved *
#
# New historical moving average record: 0.17303
#
# * Models saved *
#
# New historical moving average record: 0.17310
#
# * Models saved *
#
# New historical moving average record: 0.17312
#
# * Models saved *
#
# New historical moving average record: 0.17316
#
# * Models saved *
#
# New historical moving average record: 0.17324
#
# * Models saved *
#
# New historical moving average record: 0.17325
#
# * Models saved *
#
# New historical moving average record: 0.17329
#
# * Models saved *
#
# New historical moving average record: 0.17329
#
# * Models saved *
#
# New historical moving average record: 0.17340
#
# * Models saved *
#
# New historical moving average record: 0.17340
#
# * Models saved *
#
# New historical moving average record: 0.17347
#
# * Models saved *
#
# New historical moving average record: 0.17353
#
# * Models saved *
#
# New historical moving average record: 0.17354
#
# * Models saved *
#
# New historical moving average record: 0.17374
#
# * Models saved *
#
# New historical moving average record: 0.17374
#
# * Models saved *
#
# New historical moving average record: 0.17376
#
# * Models saved *
#
# New historical moving average record: 0.17384
#
# * Models saved *
#
# New historical moving average record: 0.17391
#
# * Models saved *
#
# New historical moving average record: 0.17396
#
# * Models saved *
#
# New historical moving average record: 0.17399
#
# * Models saved *
#
# New historical moving average record: 0.17401
#
# * Models saved *
#
# New historical moving average record: 0.17403
#
# * Models saved *
#
# New historical moving average record: 0.17408
#
# * Models saved *
#
# New historical moving average record: 0.17411
#
# * Models saved *
#
# New historical moving average record: 0.17417
#
# * Models saved *
#
# New historical moving average record: 0.17419
#
# * Models saved *
#
# New historical moving average record: 0.17422
#
# * Models saved *
#
# New historical moving average record: 0.17426
#
# * Models saved *
#
# New historical moving average record: 0.17435
#
# * Models saved *
#
# New historical moving average record: 0.17441
#
# Episode * 5000 * Moving Avg Reward is ==> 0.17439 * Last Reward was ==> 0.15707
# * Models saved *
#
# New historical moving average record: 0.17448
#
# * Models saved *
#
# New historical moving average record: 0.17455
#
# * Models saved *
#
# New historical moving average record: 0.17458
#
# * Models saved *
#
# New historical moving average record: 0.17463
#
# * Models saved *
#
# New historical moving average record: 0.17466
#
# * Models saved *
#
# New historical moving average record: 0.17469
#
# * Models saved *
#
# New historical moving average record: 0.17477
#
# * Models saved *
#
# New historical moving average record: 0.17483
#
# * Models saved *
#
# New historical moving average record: 0.17487
#
# * Models saved *
#
# New historical moving average record: 0.17492
#
# * Models saved *
#
# New historical moving average record: 0.17498
#
# * Models saved *
#
# New historical moving average record: 0.17500
#
# * Models saved *
#
# New historical moving average record: 0.17505
#
# * Models saved *
#
# New historical moving average record: 0.17508
#
# * Models saved *
#
# New historical moving average record: 0.17512
#
# * Models saved *
#
# New historical moving average record: 0.17515
#
# * Models saved *
#
# New historical moving average record: 0.17516
#
# * Models saved *
#
# New historical moving average record: 0.17518
#
# * Models saved *
#
# New historical moving average record: 0.17531
#
# * Models saved *
#
# New historical moving average record: 0.17542
#
# * Models saved *
#
# New historical moving average record: 0.17544
#
# * Models saved *
#
# New historical moving average record: 0.17549
#
# * Models saved *
#
# New historical moving average record: 0.17558
#
# * Models saved *
#
# New historical moving average record: 0.17565
#
# * Models saved *
#
# New historical moving average record: 0.17571
#
# * Models saved *
#
# New historical moving average record: 0.17578
#
# * Models saved *
#
# New historical moving average record: 0.17583
#
# * Models saved *
#
# New historical moving average record: 0.17586
#
# * Models saved *
#
# New historical moving average record: 0.17590
#
# * Models saved *
#
# New historical moving average record: 0.17592
#
# * Models saved *
#
# New historical moving average record: 0.17602
#
# * Models saved *
#
# New historical moving average record: 0.17611
#
# * Models saved *
#
# New historical moving average record: 0.17615
#
# * Models saved *
#
# New historical moving average record: 0.17615
#
# * Models saved *
#
# New historical moving average record: 0.17616
#
# * Models saved *
#
# New historical moving average record: 0.17623
#
# * Models saved *
#
# New historical moving average record: 0.17626
#
# Episode * 5100 * Moving Avg Reward is ==> 0.17600 * Last Reward was ==> 0.13910
# * Models saved *
#
# New historical moving average record: 0.17630
#
# * Models saved *
#
# New historical moving average record: 0.17638
#
# * Models saved *
#
# New historical moving average record: 0.17641
#
# * Models saved *
#
# New historical moving average record: 0.17648
#
# * Models saved *
#
# New historical moving average record: 0.17655
#
# * Models saved *
#
# New historical moving average record: 0.17659
#
# * Models saved *
#
# New historical moving average record: 0.17662
#
# * Models saved *
#
# New historical moving average record: 0.17670
#
# * Models saved *
#
# New historical moving average record: 0.17673
#
# * Models saved *
#
# New historical moving average record: 0.17675
#
# * Models saved *
#
# New historical moving average record: 0.17678
#
# * Models saved *
#
# New historical moving average record: 0.17691
#
# * Models saved *
#
# New historical moving average record: 0.17696
#
# * Models saved *
#
# New historical moving average record: 0.17701
#
# * Models saved *
#
# New historical moving average record: 0.17711
#
# * Models saved *
#
# New historical moving average record: 0.17712
#
# * Models saved *
#
# New historical moving average record: 0.17715
#
# * Models saved *
#
# New historical moving average record: 0.17724
#
# * Models saved *
#
# New historical moving average record: 0.17735
#
# * Models saved *
#
# New historical moving average record: 0.17743
#
# * Models saved *
#
# New historical moving average record: 0.17752
#
# * Models saved *
#
# New historical moving average record: 0.17754
#
# * Models saved *
#
# New historical moving average record: 0.17755
#
# * Models saved *
#
# New historical moving average record: 0.17759
#
# * Models saved *
#
# New historical moving average record: 0.17762
#
# * Models saved *
#
# New historical moving average record: 0.17765
#
# * Models saved *
#
# New historical moving average record: 0.17768
#
# * Models saved *
#
# New historical moving average record: 0.17769
#
# * Models saved *
#
# New historical moving average record: 0.17775
#
# * Models saved *
#
# New historical moving average record: 0.17778
#
# * Models saved *
#
# New historical moving average record: 0.17797
#
# * Models saved *
#
# New historical moving average record: 0.17807
#
# * Models saved *
#
# New historical moving average record: 0.17809
#
# * Models saved *
#
# New historical moving average record: 0.17815
#
# * Models saved *
#
# New historical moving average record: 0.17824
#
# * Models saved *
#
# New historical moving average record: 0.17833
#
# * Models saved *
#
# New historical moving average record: 0.17837
#
# * Models saved *
#
# New historical moving average record: 0.17840
#
# * Models saved *
#
# New historical moving average record: 0.17849
#
# * Models saved *
#
# New historical moving average record: 0.17859
#
# * Models saved *
#
# New historical moving average record: 0.17861
#
# * Models saved *
#
# New historical moving average record: 0.17865
#
# Episode * 5200 * Moving Avg Reward is ==> 0.17852 * Last Reward was ==> 0.17800
# * Models saved *
#
# New historical moving average record: 0.17890
#
# * Models saved *
#
# New historical moving average record: 0.17891
#
# * Models saved *
#
# New historical moving average record: 0.17893
# * Models saved *
#
# New historical moving average record: 0.17893
#
# * Models saved *
#
# New historical moving average record: 0.17895
#
# * Models saved *
#
# New historical moving average record: 0.17899
#
# * Models saved *
#
# New historical moving average record: 0.17899
#
# * Models saved *
#
# New historical moving average record: 0.17902
#
# * Models saved *
#
# New historical moving average record: 0.17903
#
# * Models saved *
#
# New historical moving average record: 0.17908
#
# * Models saved *
#
# New historical moving average record: 0.17912
#
# * Models saved *
#
# New historical moving average record: 0.17912
#
# * Models saved *
#
# New historical moving average record: 0.17929
#
# * Models saved *
#
# New historical moving average record: 0.17936
#
# * Models saved *
#
# New historical moving average record: 0.17941
#
# * Models saved *
#
# New historical moving average record: 0.17946
#
# * Models saved *
#
# New historical moving average record: 0.17947
#
# * Models saved *
#
# New historical moving average record: 0.17953
#
# Episode * 5300 * Moving Avg Reward is ==> 0.17940 * Last Reward was ==> 0.15482
# * Models saved *
#
# New historical moving average record: 0.17960
#
# * Models saved *
#
# New historical moving average record: 0.17970
#
# * Models saved *
#
# New historical moving average record: 0.17979
#
# * Models saved *
#
# New historical moving average record: 0.17988
#
# * Models saved *
#
# New historical moving average record: 0.17996
#
# * Models saved *
#
# New historical moving average record: 0.17996
#
# * Models saved *
#
# New historical moving average record: 0.17998
#
# * Models saved *
#
# New historical moving average record: 0.18002
#
# * Models saved *
#
# New historical moving average record: 0.18007
#
# * Models saved *
#
# New historical moving average record: 0.18010
#
# * Models saved *
#
# New historical moving average record: 0.18013
#
# * Models saved *
#
# New historical moving average record: 0.18020
#
# * Models saved *
#
# New historical moving average record: 0.18029
#
# * Models saved *
#
# New historical moving average record: 0.18040
#
# * Models saved *
#
# New historical moving average record: 0.18051
#
# * Models saved *
#
# New historical moving average record: 0.18052
#
# * Models saved *
#
# New historical moving average record: 0.18062
#
# * Models saved *
#
# New historical moving average record: 0.18071
#
# * Models saved *
#
# New historical moving average record: 0.18072
#
# * Models saved *
#
# New historical moving average record: 0.18073
#
# * Models saved *
#
# New historical moving average record: 0.18077
#
# * Models saved *
#
# New historical moving average record: 0.18085
#
# * Models saved *
#
# New historical moving average record: 0.18089
#
# * Models saved *
#
# New historical moving average record: 0.18099
#
# * Models saved *
#
# New historical moving average record: 0.18108
#
# * Models saved *
#
# New historical moving average record: 0.18110
#
# * Models saved *
#
# New historical moving average record: 0.18113
#
# * Models saved *
#
# New historical moving average record: 0.18116
#
# * Models saved *
#
# New historical moving average record: 0.18124
#
# * Models saved *
#
# New historical moving average record: 0.18127
#
# * Models saved *
#
# New historical moving average record: 0.18131
#
# * Models saved *
#
# New historical moving average record: 0.18142
#
# * Models saved *
#
# New historical moving average record: 0.18143
#
# * Models saved *
#
# New historical moving average record: 0.18147
#
# * Models saved *
#
# New historical moving average record: 0.18153
#
# * Models saved *
#
# New historical moving average record: 0.18160
#
# * Models saved *
#
# New historical moving average record: 0.18163
#
# Episode * 5400 * Moving Avg Reward is ==> 0.18165 * Last Reward was ==> 0.23160
# * Models saved *
#
# New historical moving average record: 0.18165
#
# * Models saved *
#
# New historical moving average record: 0.18169
#
# * Models saved *
#
# New historical moving average record: 0.18175
#
# * Models saved *
#
# New historical moving average record: 0.18178
#
# * Models saved *
#
# New historical moving average record: 0.18181
#
# * Models saved *
#
# New historical moving average record: 0.18187
#
# * Models saved *
#
# New historical moving average record: 0.18190
#
# * Models saved *
#
# New historical moving average record: 0.18193
#
# * Models saved *
#
# New historical moving average record: 0.18195
#
# * Models saved *
#
# New historical moving average record: 0.18197
#
# * Models saved *
#
# New historical moving average record: 0.18204
#
# * Models saved *
#
# New historical moving average record: 0.18209
#
# * Models saved *
#
# New historical moving average record: 0.18210
#
# * Models saved *
#
# New historical moving average record: 0.18214
#
# * Models saved *
#
# New historical moving average record: 0.18217
#
# * Models saved *
#
# New historical moving average record: 0.18220
#
# * Models saved *
#
# New historical moving average record: 0.18230
#
# * Models saved *
#
# New historical moving average record: 0.18231
#
# * Models saved *
#
# New historical moving average record: 0.18231
#
# * Models saved *
#
# New historical moving average record: 0.18234
#
# * Models saved *
#
# New historical moving average record: 0.18237
#
# * Models saved *
#
# New historical moving average record: 0.18243
#
# * Models saved *
#
# New historical moving average record: 0.18259
#
# * Models saved *
#
# New historical moving average record: 0.18265
#
# * Models saved *
#
# New historical moving average record: 0.18271
#
# * Models saved *
#
# New historical moving average record: 0.18274
#
# * Models saved *
#
# New historical moving average record: 0.18278
#
# * Models saved *
#
# New historical moving average record: 0.18282
#
# * Models saved *
#
# New historical moving average record: 0.18282
#
# * Models saved *
#
# New historical moving average record: 0.18284
#
# * Models saved *
#
# New historical moving average record: 0.18288
#
# Episode * 5500 * Moving Avg Reward is ==> 0.18284 * Last Reward was ==> 0.16684
# * Models saved *
#
# New historical moving average record: 0.18294
#
# * Models saved *
#
# New historical moving average record: 0.18294
#
# * Models saved *
#
# New historical moving average record: 0.18301
#
# * Models saved *
#
# New historical moving average record: 0.18310
#
# * Models saved *
#
# New historical moving average record: 0.18310
#
# * Models saved *
#
# New historical moving average record: 0.18319
#
# * Models saved *
#
# New historical moving average record: 0.18329
#
# * Models saved *
#
# New historical moving average record: 0.18344
#
# * Models saved *
#
# New historical moving average record: 0.18349
#
# * Models saved *
#
# New historical moving average record: 0.18356
#
# * Models saved *
#
# New historical moving average record: 0.18359
#
# * Models saved *
#
# New historical moving average record: 0.18360
#
# * Models saved *
#
# New historical moving average record: 0.18363
#
# * Models saved *
#
# New historical moving average record: 0.18366
#
# * Models saved *
#
# New historical moving average record: 0.18367
#
# * Models saved *
#
# New historical moving average record: 0.18371
#
# * Models saved *
#
# New historical moving average record: 0.18372
#
# * Models saved *
#
# New historical moving average record: 0.18374
#
# * Models saved *
#
# New historical moving average record: 0.18381
#
# * Models saved *
#
# New historical moving average record: 0.18385
#
# * Models saved *
#
# New historical moving average record: 0.18404
#
# All episodes are returning positive profits.Agent solved environment at the episode 5553
# All episodes are returning positive profits.Agent solved environment at the episode 5553
# A2C + CNN + 0.25 threshold -> Executed in 1h 1m 4s, finished 18:43:51 2022-08-08

# %%
agent.env.initial_investment
# Out:
# 1391.873779296875

# %% [markdown]
# ### Test the results
# * Runs a set of episodes with **unseen data**
# * Stores the results in a csv file for later consulting

# %%
success = 0
n_tests = 10000

scores = []
targets = []
portfolio_target_ratios = []
initial_investments = []

for i in trange(n_tests):
    state = agent.env.reset(visualize=False,mode="test")
    step = 0
    score = 0
    reward = 0
    done = False
    
    targets.append((agent.env.episode_target-agent.env.initial_investment)/agent.env.initial_investment)
    initial_investments.append(agent.env.initial_investment)

    while not done:
        agent.env.render()
        
        # Select action
        action, action_onehot, prediction = agent.act(state)
        
        # Retrieve new state, reward, and whether the state is terminal
        next_state, reward, done, info = agent.env.step(action)
        
        # End of episode, track scores here
        if done :
            if agent.env.portfolio_value > agent.env.initial_investment:
                success +=1

        step+=1
        state = next_state
        score += reward
    
    # Track scores and ratios
    scores.append(score)
    portfolio_target_ratios.append(info["portfolio_value"]/info["episode_target"] -1)
    
    
test_results_dataframe = pd.DataFrame([[
    n_tests,
    str(round(np.mean(scores)*100,3))+'%',
    str(round(np.mean(targets)*100,3))+'%',
    str(round(np.mean(portfolio_target_ratios)*100,3))+'%',
    str(round(min(scores)*100,3))+'%',
    str(round(max(scores)*100,3))+'%',
    str(round((success/n_tests)*100,3)) +'%'
]],
    columns=[
        '# Blind tests',
        '% Average portfolio return', 
        '% Desired portfolio return', 
        'Portfolio/Target rate',
        '% Historical minimum return',
        '% Historical maximum return', 
        '% Episodes concluded with positive outcome'
    ]
)


agent.results_writer.store_test_results(agent,test_results_dataframe)

test_results_dataframe.T
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]

# %% [markdown]
# ### Visual test
# * Runs a set of episodes with **unseen data**
# * See the evolution in real time

# %%
success = 0
n_tests = 10

scores = []
targets = []


for i in trange(n_tests):
    state = agent.env.reset(visualize=True,mode="test")
    step = 0
    score = 0
    reward = 0
    done = False
    targets.append((agent.env.episode_target-agent.env.initial_investment)/agent.env.initial_investment)
    initial_portfolio = agent.env.portfolio_value

    while not done:
        agent.env.render()
        
        # Select desired action
        action, action_onehot, prediction = agent.act(state)

        # Retrieve new state, reward, and whether the state is terminal
        next_state, reward, done, _ = agent.env.step(action)

        # End of episode, track scores here
        if done :
            if agent.env.portfolio_value > agent.env.initial_investment:
                success +=1

        step+=1
        state = next_state
        score += reward
    
    scores.append(score)

agent.env.close()

# %% [markdown]
# ### Transactions profit
# * Track how much the agent gained by doing purchases and sales
# * Doesn't track the portfolio value
# * Already has the fees discounted

# %%
success = 0
n_tests = 10000

test_results_data = []
test_results_columns = [
    'dataset id',
    'episode start date', 
    'episode end date',
    'episode working days',
    'total transactions',
    'total transaction profit',
    "dataframe hash",
    "agent hash"
]

print('NOTE: This test only tracks the transactions profit. ')

for i in trange(n_tests):
    trading_history = []
    state = agent.env.reset(visualize=False,mode="test")
    step = 0
    score = 0
    reward = 0
    done = False
    #targets.append((agent.env.episode_target-agent.env.initial_investment)/agent.env.initial_investment)
    #initial_portfolio = agent.env.portfolio_value
    
    j = 0
    num_stocks = 0
    while not done:
        agent.env.render()
        
        # Select desired action
        action, action_onehot, prediction = agent.act(state)
        current_price = agent.env.df.iloc[agent.env.current_step -1]['close']
        
        if action == agent.env.ACTIONS.BUY:
            discounted_price = current_price * (1+agent.env.fees.BUY) 
            if agent.env.stock_held < agent.env.maximum_stocks_held and agent.env.cash_in_hand >= discounted_price:
                num_stocks +=1
                trading_history.append(['buy', discounted_price])
        elif action == agent.env.ACTIONS.SELL:
            if agent.env.stock_held > 0:
                discounted_price = current_price * (1-agent.env.fees.SELL) 
                trading_history.append(['sell', discounted_price])
                num_stocks =0
                
        # Retrieve new state, reward, and whether the state is terminal
        next_state, reward, done, _ = agent.env.step(action)

        # Update current state
        if done :
            if agent.env.portfolio_value > agent.env.initial_investment:
                success +=1
                
            profits = []
            purchases = []
            for e in trading_history:
                if e[0] == 'buy':
                    purchases.append(e[1])
                else:
                    profits.append((e[1]* len(purchases) - sum(purchases)) / sum(purchases))
                    purchases.clear() 
                    
            test_results_data.append([
                agent.env.dataset_idx,
                agent.env.df.iloc[agent.env.lookback].name,
                agent.env.df.iloc[-1].name,
                agent.env.window_size,
                len(profits),
                sum(profits)*100,
                agent.env.df_name,
                agent.hash
            ])


        step+=1
        state = next_state
        score += reward
    

agent.env.close()


pd.DataFrame(test_results_data,columns=test_results_columns)

# %%
transaction_results_df = pd.DataFrame(test_results_data,columns=test_results_columns)

# %%
transaction_results_df.sort_values(by="dataset id")

# %%
transaction_results_df[transaction_results_df['total transaction profit'] <= 0]

# %%
failed_episodes_df = transaction_results_df[transaction_results_df['total transaction profit'] <= 0]
failed_episodes_idx = failed_episodes_df['dataset id'].unique()
failed_episodes_idx.sort()

# %%
len(transaction_results_df[transaction_results_df['total transaction profit'] <= 0]['dataset id'].unique()),len(transaction_results_df[transaction_results_df['total transaction profit'] > 0]['dataset id'].unique())

# %%
import matplotlib.pyplot as plt 

for idx in failed_episodes_idx:
    plt.figure(figsize=(16,4))
    plt.plot(agent.env.df['close'])
    plt.title('#'+str(idx)+' - ' + str(len(failed_episodes_df[failed_episodes_df['dataset id'] == idx])) +'/' + str(len(transaction_results_df[transaction_results_df['dataset id'] == idx])))
