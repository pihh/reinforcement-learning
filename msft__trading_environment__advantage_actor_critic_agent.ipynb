# %%
import shutup
shutup.please()

import gym
import src.environments.continuous.stock_trading  

import numpy as np
import pandas as pd 

from tqdm.notebook import trange, tqdm

# %% [markdown]
# ### Train the agent
# * Run it until he has a running average above the success_threshold
# * Use a large number of episodes for the running average ( 1000+ ) so if even it falls into a privileged sample, it wont be prone to error

# %%
def environment():
    env = gym.make('StockTradingEnvironment-v0',
        ticker="MSFT",
        use_technical_indicators= [
        "macd",
        "boll_ub",
        "boll_lb",
        "rsi_30",
        "cci_30",
        "dx_30",
        "close_30_sma",
        "close_60_sma",
    ])
    
    poc_threshold = 0.1 # 10% 
    print('* Original success threshold', env.success_threshold)
    
    print('* POC success threshold', poc_threshold)
    print()
    
    env.success_threshold = poc_threshold


# from src.environments.continuous.trading import environment

# %%
from src.agents.actor_critic.a2c import A2CAgent

# %%
agent=A2CAgent(environment, epochs=1, actor_learning_rate=0.000025,critic_learning_rate=0.000025,policy="CNN")
agent.load()
# Out:
# original threshold 0.0379506553185424
# current threshold 0.25
# @TODO Agent._load_agent_configuration()
#
# original threshold 0.0379506553185424
# current threshold 0.25
# 0.25

# %%
# agent.hash

# %%
agent.env.mode = "train"
agent.learning_log.episodes = 0
agent.learn(
    timesteps=-1, 
    log_every=100,
    success_threshold_lookback=1000,
    success_strict=True,
)

print('A2C + CNN + 0.25 threshold -> Executed in 1h 1m 4s, finished 18:43:51 2022-08-08')
# Out:
# Episode * 100 * Moving Avg Reward is ==> 0.15209 * Last Reward was ==> 0.16841
# Episode * 200 * Moving Avg Reward is ==> 0.14486 * Last Reward was ==> 0.30797
# Episode * 300 * Moving Avg Reward is ==> 0.14418 * Last Reward was ==> 0.20598
# Episode * 400 * Moving Avg Reward is ==> 0.14686 * Last Reward was ==> 0.20006
# Episode * 500 * Moving Avg Reward is ==> 0.14407 * Last Reward was ==> 0.19182
# Episode * 600 * Moving Avg Reward is ==> 0.14381 * Last Reward was ==> 0.22664
# Episode * 700 * Moving Avg Reward is ==> 0.14428 * Last Reward was ==> 0.24821
# Episode * 800 * Moving Avg Reward is ==> 0.14153 * Last Reward was ==> 0.17768
# Episode * 900 * Moving Avg Reward is ==> 0.14114 * Last Reward was ==> 0.12915
# Episode * 1000 * Moving Avg Reward is ==> 0.13939 * Last Reward was ==> 0.00247
# * Models saved *
#
# New historical moving average record: 0.13920
#
# * Models saved *
#
# New historical moving average record: 0.13936
#
# * Models saved *
#
# New historical moving average record: 0.13945
#
# Episode * 1100 * Moving Avg Reward is ==> 0.13883 * Last Reward was ==> 0.02250
# Episode * 1200 * Moving Avg Reward is ==> 0.13738 * Last Reward was ==> 0.03843
# Episode * 1300 * Moving Avg Reward is ==> 0.13644 * Last Reward was ==> 0.03038
# Episode * 1400 * Moving Avg Reward is ==> 0.13585 * Last Reward was ==> 0.07473
# Episode * 1500 * Moving Avg Reward is ==> 0.13616 * Last Reward was ==> 0.08667
# Episode * 1600 * Moving Avg Reward is ==> 0.13418 * Last Reward was ==> 0.17843
# Episode * 1700 * Moving Avg Reward is ==> 0.13296 * Last Reward was ==> 0.13607
# Episode * 1800 * Moving Avg Reward is ==> 0.13500 * Last Reward was ==> 0.17628
# Episode * 1900 * Moving Avg Reward is ==> 0.13511 * Last Reward was ==> 0.19321
# Episode * 2000 * Moving Avg Reward is ==> 0.13637 * Last Reward was ==> -0.01828
# Episode * 2100 * Moving Avg Reward is ==> 0.13550 * Last Reward was ==> -0.01828
# Episode * 2200 * Moving Avg Reward is ==> 0.13733 * Last Reward was ==> 0.12573
# Episode * 2300 * Moving Avg Reward is ==> 0.13711 * Last Reward was ==> -0.04326
# Episode * 2400 * Moving Avg Reward is ==> 0.13646 * Last Reward was ==> 0.00247
# Episode * 2500 * Moving Avg Reward is ==> 0.13680 * Last Reward was ==> 0.01691
# Episode * 2600 * Moving Avg Reward is ==> 0.13930 * Last Reward was ==> 0.23953
# * Models saved *
#
# New historical moving average record: 0.13946
#
# * Models saved *
#
# New historical moving average record: 0.13948
#
# * Models saved *
#
# New historical moving average record: 0.13950
#
# * Models saved *
#
# New historical moving average record: 0.13950
#
# * Models saved *
#
# New historical moving average record: 0.13952
#
# * Models saved *
#
# New historical moving average record: 0.13953
#
# * Models saved *
#
# New historical moving average record: 0.13957
#
# * Models saved *
#
# New historical moving average record: 0.13966
#
# * Models saved *
#
# New historical moving average record: 0.13968
#
# * Models saved *
#
# New historical moving average record: 0.13976
#
# * Models saved *
#
# New historical moving average record: 0.13989
#
# Episode * 2700 * Moving Avg Reward is ==> 0.13877 * Last Reward was ==> 0.08209
# * Models saved *
#
# New historical moving average record: 0.13992
#
# * Models saved *
#
# New historical moving average record: 0.14001
#
# * Models saved *
#
# New historical moving average record: 0.14008
#
# * Models saved *
#
# New historical moving average record: 0.14024
#
# * Models saved *
#
# New historical moving average record: 0.14033
#
# * Models saved *
#
# New historical moving average record: 0.14038
#
# * Models saved *
#
# New historical moving average record: 0.14046
#
# * Models saved *
#
# New historical moving average record: 0.14069
#
# * Models saved *
#
# New historical moving average record: 0.14080
#
# Episode * 2800 * Moving Avg Reward is ==> 0.13931 * Last Reward was ==> 0.01455
# Episode * 2900 * Moving Avg Reward is ==> 0.13936 * Last Reward was ==> 0.15160
# * Models saved *
#
# New historical moving average record: 0.14100
#
# * Models saved *
#
# New historical moving average record: 0.14112
#
# * Models saved *
#
# New historical moving average record: 0.14128
#
# * Models saved *
#
# New historical moving average record: 0.14147
#
# * Models saved *
#
# New historical moving average record: 0.14154
#
# * Models saved *
#
# New historical moving average record: 0.14182
#
# * Models saved *
#
# New historical moving average record: 0.14185
#
# * Models saved *
#
# New historical moving average record: 0.14192
#
# Episode * 3000 * Moving Avg Reward is ==> 0.14095 * Last Reward was ==> -0.02053
# Episode * 3100 * Moving Avg Reward is ==> 0.14045 * Last Reward was ==> 0.02131
# Episode * 3200 * Moving Avg Reward is ==> 0.14051 * Last Reward was ==> 0.34003
# Episode * 3300 * Moving Avg Reward is ==> 0.14093 * Last Reward was ==> 0.19182
# * Models saved *
#
# New historical moving average record: 0.14215
#
# * Models saved *
#
# New historical moving average record: 0.14227
#
# * Models saved *
#
# New historical moving average record: 0.14231
#
# * Models saved *
#
# New historical moving average record: 0.14233
#
# * Models saved *
#
# New historical moving average record: 0.14238
#
# * Models saved *
#
# New historical moving average record: 0.14239
#
# * Models saved *
#
# New historical moving average record: 0.14250
#
# * Models saved *
#
# New historical moving average record: 0.14266
#
# * Models saved *
#
# New historical moving average record: 0.14282
#
# * Models saved *
#
# New historical moving average record: 0.14289
#
# * Models saved *
#
# New historical moving average record: 0.14307
#
# * Models saved *
#
# New historical moving average record: 0.14314
#
# * Models saved *
#
# New historical moving average record: 0.14319
#
# * Models saved *
#
# New historical moving average record: 0.14334
#
# * Models saved *
#
# New historical moving average record: 0.14336
#
# Episode * 3400 * Moving Avg Reward is ==> 0.14256 * Last Reward was ==> 0.14719
# * Models saved *
#
# New historical moving average record: 0.14339
#
# * Models saved *
#
# New historical moving average record: 0.14361
#
# * Models saved *
#
# New historical moving average record: 0.14373
#
# * Models saved *
#
# New historical moving average record: 0.14379
#
# * Models saved *
#
# New historical moving average record: 0.14406
#
# * Models saved *
#
# New historical moving average record: 0.14410
#
# * Models saved *
#
# New historical moving average record: 0.14415
#
# * Models saved *
#
# New historical moving average record: 0.14428
#
# * Models saved *
#
# New historical moving average record: 0.14433
#
# * Models saved *
#
# New historical moving average record: 0.14440
#
# * Models saved *
#
# New historical moving average record: 0.14449
#
# Episode * 3500 * Moving Avg Reward is ==> 0.14358 * Last Reward was ==> 0.07639
# * Models saved *
#
# New historical moving average record: 0.14463
#
# * Models saved *
#
# New historical moving average record: 0.14477
#
# * Models saved *
#
# New historical moving average record: 0.14496
#
# * Models saved *
#
# New historical moving average record: 0.14517
#
# * Models saved *
#
# New historical moving average record: 0.14526
#
# * Models saved *
#
# New historical moving average record: 0.14558
#
# Episode * 3600 * Moving Avg Reward is ==> 0.14485 * Last Reward was ==> 0.02637
# * Models saved *
#
# New historical moving average record: 0.14571
#
# * Models saved *
#
# New historical moving average record: 0.14581
#
# * Models saved *
#
# New historical moving average record: 0.14592
#
# * Models saved *
#
# New historical moving average record: 0.14596
#
# * Models saved *
#
# New historical moving average record: 0.14599
#
# * Models saved *
#
# New historical moving average record: 0.14600
#
# * Models saved *
#
# New historical moving average record: 0.14601
#
# * Models saved *
#
# New historical moving average record: 0.14610
#
# * Models saved *
#
# New historical moving average record: 0.14632
#
# * Models saved *
#
# New historical moving average record: 0.14634
#
# * Models saved *
#
# New historical moving average record: 0.14650
#
# * Models saved *
#
# New historical moving average record: 0.14666
#
# * Models saved *
#
# New historical moving average record: 0.14675
#
# Episode * 3700 * Moving Avg Reward is ==> 0.14578 * Last Reward was ==> 0.04346
# Episode * 3800 * Moving Avg Reward is ==> 0.14510 * Last Reward was ==> 0.18785
# Episode * 3900 * Moving Avg Reward is ==> 0.14632 * Last Reward was ==> 0.30349
# * Models saved *
#
# New historical moving average record: 0.14687
#
# * Models saved *
#
# New historical moving average record: 0.14693
#
# Episode * 4000 * Moving Avg Reward is ==> 0.14504 * Last Reward was ==> 0.02410
# Episode * 4100 * Moving Avg Reward is ==> 0.14420 * Last Reward was ==> 0.22029
# Episode * 4200 * Moving Avg Reward is ==> 0.14361 * Last Reward was ==> 0.32015
# Episode * 4300 * Moving Avg Reward is ==> 0.14401 * Last Reward was ==> 0.02272
# Episode * 4400 * Moving Avg Reward is ==> 0.14102 * Last Reward was ==> -0.00074
# Episode * 4500 * Moving Avg Reward is ==> 0.13990 * Last Reward was ==> 0.27998
# Episode * 4600 * Moving Avg Reward is ==> 0.13819 * Last Reward was ==> 0.05650
# Episode * 4700 * Moving Avg Reward is ==> 0.13713 * Last Reward was ==> 0.01167
# Episode * 4800 * Moving Avg Reward is ==> 0.13850 * Last Reward was ==> 0.04091
# Episode * 4900 * Moving Avg Reward is ==> 0.13583 * Last Reward was ==> 0.08799
# Episode * 5000 * Moving Avg Reward is ==> 0.13650 * Last Reward was ==> 0.18099
# Episode * 5100 * Moving Avg Reward is ==> 0.13511 * Last Reward was ==> 0.21377
# Episode * 5200 * Moving Avg Reward is ==> 0.13565 * Last Reward was ==> 0.17768
# Episode * 5300 * Moving Avg Reward is ==> 0.13601 * Last Reward was ==> 0.05129
# Episode * 5400 * Moving Avg Reward is ==> 0.13601 * Last Reward was ==> 0.09389
# Episode * 5500 * Moving Avg Reward is ==> 0.13614 * Last Reward was ==> 0.12625
# Episode * 5600 * Moving Avg Reward is ==> 0.13642 * Last Reward was ==> -0.02053
# Episode * 5700 * Moving Avg Reward is ==> 0.13905 * Last Reward was ==> 0.29475
# Episode * 5800 * Moving Avg Reward is ==> 0.13727 * Last Reward was ==> 0.15913
# Episode * 5900 * Moving Avg Reward is ==> 0.13963 * Last Reward was ==> 0.17795
# Episode * 6000 * Moving Avg Reward is ==> 0.13873 * Last Reward was ==> 0.18824
# Episode * 6100 * Moving Avg Reward is ==> 0.14215 * Last Reward was ==> 0.02328
# Episode * 6200 * Moving Avg Reward is ==> 0.14136 * Last Reward was ==> 0.00875
# Episode * 6300 * Moving Avg Reward is ==> 0.14139 * Last Reward was ==> 0.21778
# Episode * 6400 * Moving Avg Reward is ==> 0.14230 * Last Reward was ==> 0.14128
# Episode * 6500 * Moving Avg Reward is ==> 0.14026 * Last Reward was ==> -0.01775
# Episode * 6600 * Moving Avg Reward is ==> 0.13966 * Last Reward was ==> -0.00963
# Episode * 6700 * Moving Avg Reward is ==> 0.13690 * Last Reward was ==> 0.16247
# Episode * 6800 * Moving Avg Reward is ==> 0.13699 * Last Reward was ==> 0.09588
# Episode * 6900 * Moving Avg Reward is ==> 0.13504 * Last Reward was ==> 0.12387
# Episode * 7000 * Moving Avg Reward is ==> 0.13444 * Last Reward was ==> 0.16424
# Episode * 7100 * Moving Avg Reward is ==> 0.13315 * Last Reward was ==> 0.00247
# Episode * 7200 * Moving Avg Reward is ==> 0.13460 * Last Reward was ==> 0.18718
# Episode * 7300 * Moving Avg Reward is ==> 0.13367 * Last Reward was ==> 0.12746
# Episode * 7400 * Moving Avg Reward is ==> 0.13246 * Last Reward was ==> 0.08004
# Episode * 7500 * Moving Avg Reward is ==> 0.13596 * Last Reward was ==> 0.21609
# Episode * 7600 * Moving Avg Reward is ==> 0.13542 * Last Reward was ==> 0.14798
# Episode * 7700 * Moving Avg Reward is ==> 0.13580 * Last Reward was ==> 0.18424
# Episode * 7800 * Moving Avg Reward is ==> 0.13691 * Last Reward was ==> 0.16181
# Episode * 7900 * Moving Avg Reward is ==> 0.13694 * Last Reward was ==> 0.09896
# Episode * 8000 * Moving Avg Reward is ==> 0.13653 * Last Reward was ==> 0.01786
# Episode * 8100 * Moving Avg Reward is ==> 0.13784 * Last Reward was ==> 0.28838
# Episode * 8200 * Moving Avg Reward is ==> 0.13706 * Last Reward was ==> 0.14312
# Episode * 8300 * Moving Avg Reward is ==> 0.13681 * Last Reward was ==> 0.11698
# Episode * 8400 * Moving Avg Reward is ==> 0.13778 * Last Reward was ==> 0.28525
# Episode * 8500 * Moving Avg Reward is ==> 0.13734 * Last Reward was ==> -0.01995
# Episode * 8600 * Moving Avg Reward is ==> 0.13799 * Last Reward was ==> 0.03190
# Episode * 8700 * Moving Avg Reward is ==> 0.13811 * Last Reward was ==> 0.27093
# Episode * 8800 * Moving Avg Reward is ==> 0.13825 * Last Reward was ==> 0.00112
# Episode * 8900 * Moving Avg Reward is ==> 0.13784 * Last Reward was ==> 0.21029
# Episode * 9000 * Moving Avg Reward is ==> 0.13866 * Last Reward was ==> 0.23157
# Episode * 9100 * Moving Avg Reward is ==> 0.13840 * Last Reward was ==> 0.22601
# Episode * 9200 * Moving Avg Reward is ==> 0.13886 * Last Reward was ==> 0.28701
# Episode * 9300 * Moving Avg Reward is ==> 0.13905 * Last Reward was ==> 0.19747
# Episode * 9400 * Moving Avg Reward is ==> 0.13964 * Last Reward was ==> 0.00191
# Episode * 9500 * Moving Avg Reward is ==> 0.13706 * Last Reward was ==> 0.09203
# Episode * 9600 * Moving Avg Reward is ==> 0.13701 * Last Reward was ==> 0.03954
# Episode * 9700 * Moving Avg Reward is ==> 0.13745 * Last Reward was ==> 0.27385
# Episode * 9800 * Moving Avg Reward is ==> 0.13658 * Last Reward was ==> 0.19906
# Episode * 9900 * Moving Avg Reward is ==> 0.13897 * Last Reward was ==> 0.28883
# Episode * 10000 * Moving Avg Reward is ==> 0.13911 * Last Reward was ==> 0.22317
# Episode * 10100 * Moving Avg Reward is ==> 0.13820 * Last Reward was ==> 0.18129
# Episode * 10200 * Moving Avg Reward is ==> 0.13658 * Last Reward was ==> 0.17585
# Episode * 10300 * Moving Avg Reward is ==> 0.13592 * Last Reward was ==> 0.15913
# Episode * 10400 * Moving Avg Reward is ==> 0.13811 * Last Reward was ==> 0.03843
# Episode * 10500 * Moving Avg Reward is ==> 0.13892 * Last Reward was ==> 0.16140
# Episode * 10600 * Moving Avg Reward is ==> 0.13883 * Last Reward was ==> 0.15226
# Episode * 10700 * Moving Avg Reward is ==> 0.13993 * Last Reward was ==> -0.00074
# Episode * 10800 * Moving Avg Reward is ==> 0.13904 * Last Reward was ==> 0.14042
# Episode * 10900 * Moving Avg Reward is ==> 0.13870 * Last Reward was ==> 0.19199
# Episode * 11000 * Moving Avg Reward is ==> 0.13884 * Last Reward was ==> 0.04379
# Episode * 11100 * Moving Avg Reward is ==> 0.13992 * Last Reward was ==> 0.15765
# Episode * 11200 * Moving Avg Reward is ==> 0.14116 * Last Reward was ==> 0.32258
# Episode * 11300 * Moving Avg Reward is ==> 0.14105 * Last Reward was ==> 0.19906
# Episode * 11400 * Moving Avg Reward is ==> 0.13806 * Last Reward was ==> 0.28875
# Episode * 11500 * Moving Avg Reward is ==> 0.13839 * Last Reward was ==> 0.17854
# Episode * 11600 * Moving Avg Reward is ==> 0.13905 * Last Reward was ==> 0.12855
# Episode * 11700 * Moving Avg Reward is ==> 0.13931 * Last Reward was ==> 0.32015
# Episode * 11800 * Moving Avg Reward is ==> 0.13951 * Last Reward was ==> 0.04316
# Episode * 11900 * Moving Avg Reward is ==> 0.13780 * Last Reward was ==> 0.18990
# Episode * 12000 * Moving Avg Reward is ==> 0.13723 * Last Reward was ==> 0.14719
# Episode * 12100 * Moving Avg Reward is ==> 0.13574 * Last Reward was ==> 0.00875
# Episode * 12200 * Moving Avg Reward is ==> 0.13560 * Last Reward was ==> 0.20925
# Episode * 12300 * Moving Avg Reward is ==> 0.13605 * Last Reward was ==> 0.14459
# Episode * 12400 * Moving Avg Reward is ==> 0.13583 * Last Reward was ==> 0.24534
# Episode * 12500 * Moving Avg Reward is ==> 0.13765 * Last Reward was ==> 0.22251
# Episode * 12600 * Moving Avg Reward is ==> 0.13734 * Last Reward was ==> 0.12108
# Episode * 12700 * Moving Avg Reward is ==> 0.13679 * Last Reward was ==> 0.16085
# Episode * 12800 * Moving Avg Reward is ==> 0.13602 * Last Reward was ==> 0.11132
# Episode * 12900 * Moving Avg Reward is ==> 0.13745 * Last Reward was ==> 0.13704
# Episode * 13000 * Moving Avg Reward is ==> 0.13823 * Last Reward was ==> 0.26630
# Episode * 13100 * Moving Avg Reward is ==> 0.13961 * Last Reward was ==> 0.26445
# Episode * 13200 * Moving Avg Reward is ==> 0.13875 * Last Reward was ==> 0.13244
# Episode * 13300 * Moving Avg Reward is ==> 0.13954 * Last Reward was ==> 0.35311
# Episode * 13400 * Moving Avg Reward is ==> 0.14094 * Last Reward was ==> 0.24478
# Episode * 13500 * Moving Avg Reward is ==> 0.13872 * Last Reward was ==> -0.00772
# Episode * 13600 * Moving Avg Reward is ==> 0.13730 * Last Reward was ==> 0.20767
# Episode * 13700 * Moving Avg Reward is ==> 0.13777 * Last Reward was ==> 0.32258
# Episode * 13800 * Moving Avg Reward is ==> 0.13785 * Last Reward was ==> 0.21332
# Episode * 13900 * Moving Avg Reward is ==> 0.13851 * Last Reward was ==> 0.32258
# Episode * 14000 * Moving Avg Reward is ==> 0.13843 * Last Reward was ==> 0.14903
# Episode * 14100 * Moving Avg Reward is ==> 0.13824 * Last Reward was ==> 0.01183
# Episode * 14200 * Moving Avg Reward is ==> 0.13958 * Last Reward was ==> 0.20992
# Episode * 14300 * Moving Avg Reward is ==> 0.13998 * Last Reward was ==> -0.00097
# Episode * 14400 * Moving Avg Reward is ==> 0.13741 * Last Reward was ==> 0.19182
# Episode * 14500 * Moving Avg Reward is ==> 0.13687 * Last Reward was ==> 0.14204
# Episode * 14600 * Moving Avg Reward is ==> 0.13811 * Last Reward was ==> 0.20960
# Episode * 14700 * Moving Avg Reward is ==> 0.13680 * Last Reward was ==> 0.32448
# Episode * 14800 * Moving Avg Reward is ==> 0.13966 * Last Reward was ==> 0.11628
# Episode * 14900 * Moving Avg Reward is ==> 0.13996 * Last Reward was ==> 0.28567
# Episode * 15000 * Moving Avg Reward is ==> 0.13980 * Last Reward was ==> 0.17419
# Episode * 15100 * Moving Avg Reward is ==> 0.13922 * Last Reward was ==> 0.17795
# Episode * 15200 * Moving Avg Reward is ==> 0.13796 * Last Reward was ==> 0.19537
# Episode * 15300 * Moving Avg Reward is ==> 0.13652 * Last Reward was ==> 0.11798
# Episode * 15400 * Moving Avg Reward is ==> 0.13711 * Last Reward was ==> 0.20875
# Episode * 15500 * Moving Avg Reward is ==> 0.13827 * Last Reward was ==> 0.20767
# Episode * 15600 * Moving Avg Reward is ==> 0.13805 * Last Reward was ==> -0.00772
# Episode * 15700 * Moving Avg Reward is ==> 0.13730 * Last Reward was ==> 0.28883
# Episode * 15800 * Moving Avg Reward is ==> 0.13676 * Last Reward was ==> 0.28044
# Episode * 15900 * Moving Avg Reward is ==> 0.13552 * Last Reward was ==> 0.28719
# Episode * 16000 * Moving Avg Reward is ==> 0.13491 * Last Reward was ==> 0.28996
# Episode * 16100 * Moving Avg Reward is ==> 0.13536 * Last Reward was ==> 0.13605
# Episode * 16200 * Moving Avg Reward is ==> 0.13487 * Last Reward was ==> 0.33763
# Episode * 16300 * Moving Avg Reward is ==> 0.13639 * Last Reward was ==> 0.22245
# Episode * 16400 * Moving Avg Reward is ==> 0.13784 * Last Reward was ==> 0.16179
# Episode * 16500 * Moving Avg Reward is ==> 0.13879 * Last Reward was ==> 0.02820
# Episode * 16600 * Moving Avg Reward is ==> 0.13869 * Last Reward was ==> 0.30453
# Episode * 16700 * Moving Avg Reward is ==> 0.13907 * Last Reward was ==> 0.18875
# Episode * 16800 * Moving Avg Reward is ==> 0.13860 * Last Reward was ==> 0.15226
# Episode * 16900 * Moving Avg Reward is ==> 0.13727 * Last Reward was ==> 0.22856
# Episode * 17000 * Moving Avg Reward is ==> 0.13807 * Last Reward was ==> 0.10289
# Episode * 17100 * Moving Avg Reward is ==> 0.13861 * Last Reward was ==> 0.22084
# Episode * 17200 * Moving Avg Reward is ==> 0.13783 * Last Reward was ==> -0.02053
# Episode * 17300 * Moving Avg Reward is ==> 0.13492 * Last Reward was ==> 0.03190
# Episode * 17400 * Moving Avg Reward is ==> 0.13563 * Last Reward was ==> 0.05129
# Episode * 17500 * Moving Avg Reward is ==> 0.13504 * Last Reward was ==> 0.00297
# Episode * 17600 * Moving Avg Reward is ==> 0.13373 * Last Reward was ==> 0.20453
# Episode * 17700 * Moving Avg Reward is ==> 0.13452 * Last Reward was ==> 0.27272
# Episode * 17800 * Moving Avg Reward is ==> 0.13304 * Last Reward was ==> 0.16181
# Episode * 17900 * Moving Avg Reward is ==> 0.13409 * Last Reward was ==> 0.08898
# Episode * 18000 * Moving Avg Reward is ==> 0.13523 * Last Reward was ==> 0.19086
# Episode * 18100 * Moving Avg Reward is ==> 0.13374 * Last Reward was ==> 0.00468
# Episode * 18200 * Moving Avg Reward is ==> 0.13719 * Last Reward was ==> 0.02637
# Episode * 18300 * Moving Avg Reward is ==> 0.14161 * Last Reward was ==> 0.30594
# Episode * 18400 * Moving Avg Reward is ==> 0.14201 * Last Reward was ==> 0.29346
# Episode * 18500 * Moving Avg Reward is ==> 0.14386 * Last Reward was ==> 0.10251
# Episode * 18600 * Moving Avg Reward is ==> 0.14593 * Last Reward was ==> 0.07163
# Episode * 18700 * Moving Avg Reward is ==> 0.14489 * Last Reward was ==> 0.06969
# Episode * 18800 * Moving Avg Reward is ==> 0.14521 * Last Reward was ==> 0.09203
# Episode * 18900 * Moving Avg Reward is ==> 0.14482 * Last Reward was ==> 0.21421
# Episode * 19000 * Moving Avg Reward is ==> 0.14344 * Last Reward was ==> 0.00191
# Episode * 19100 * Moving Avg Reward is ==> 0.14504 * Last Reward was ==> 0.31640
# Episode * 19200 * Moving Avg Reward is ==> 0.14420 * Last Reward was ==> 0.12915
# Episode * 19300 * Moving Avg Reward is ==> 0.14483 * Last Reward was ==> 0.13879
# Episode * 19400 * Moving Avg Reward is ==> 0.14361 * Last Reward was ==> 0.18530
# Episode * 19500 * Moving Avg Reward is ==> 0.14195 * Last Reward was ==> 0.22433
# Episode * 19600 * Moving Avg Reward is ==> 0.14212 * Last Reward was ==> 0.19906
# Episode * 19700 * Moving Avg Reward is ==> 0.14406 * Last Reward was ==> 0.31138
# Episode * 19800 * Moving Avg Reward is ==> 0.14520 * Last Reward was ==> 0.15109
# Episode * 19900 * Moving Avg Reward is ==> 0.14606 * Last Reward was ==> 0.19351
# Episode * 20000 * Moving Avg Reward is ==> 0.14579 * Last Reward was ==> 0.10146
# Episode * 20100 * Moving Avg Reward is ==> 0.14613 * Last Reward was ==> 0.21879
# * Models saved *
#
# New historical moving average record: 0.14693
#
# * Models saved *
#
# New historical moving average record: 0.14707
#
# Episode * 20200 * Moving Avg Reward is ==> 0.14666 * Last Reward was ==> 0.33736
# Episode * 20300 * Moving Avg Reward is ==> 0.14248 * Last Reward was ==> 0.10540
# Episode * 20400 * Moving Avg Reward is ==> 0.14009 * Last Reward was ==> 0.24533
# Episode * 20500 * Moving Avg Reward is ==> 0.13950 * Last Reward was ==> 0.14259
# Episode * 20600 * Moving Avg Reward is ==> 0.13949 * Last Reward was ==> 0.32406
# Episode * 20700 * Moving Avg Reward is ==> 0.13797 * Last Reward was ==> 0.03018
# Episode * 20800 * Moving Avg Reward is ==> 0.13833 * Last Reward was ==> 0.14190
# Episode * 20900 * Moving Avg Reward is ==> 0.13739 * Last Reward was ==> -0.02399
# Episode * 21000 * Moving Avg Reward is ==> 0.13763 * Last Reward was ==> 0.16204
# Episode * 21100 * Moving Avg Reward is ==> 0.13631 * Last Reward was ==> 0.17043
# Episode * 21200 * Moving Avg Reward is ==> 0.13474 * Last Reward was ==> 0.03257
# Episode * 21300 * Moving Avg Reward is ==> 0.13439 * Last Reward was ==> 0.03843
# Episode * 21400 * Moving Avg Reward is ==> 0.13716 * Last Reward was ==> 0.00490
# Episode * 21500 * Moving Avg Reward is ==> 0.13755 * Last Reward was ==> 0.02521
# Episode * 21600 * Moving Avg Reward is ==> 0.13710 * Last Reward was ==> 0.20412
# Episode * 21700 * Moving Avg Reward is ==> 0.13613 * Last Reward was ==> 0.04091
# Episode * 21800 * Moving Avg Reward is ==> 0.13617 * Last Reward was ==> 0.31452
# Episode * 21900 * Moving Avg Reward is ==> 0.13635 * Last Reward was ==> 0.28701
# Episode * 22000 * Moving Avg Reward is ==> 0.13646 * Last Reward was ==> 0.00944
# Episode * 22100 * Moving Avg Reward is ==> 0.13901 * Last Reward was ==> 0.02985
# Episode * 22200 * Moving Avg Reward is ==> 0.13969 * Last Reward was ==> 0.25277
# Episode * 22300 * Moving Avg Reward is ==> 0.14136 * Last Reward was ==> 0.27235
# Episode * 22400 * Moving Avg Reward is ==> 0.14196 * Last Reward was ==> 0.15433
# Episode * 22500 * Moving Avg Reward is ==> 0.14163 * Last Reward was ==> -0.00360
# Episode * 22600 * Moving Avg Reward is ==> 0.14025 * Last Reward was ==> 0.14820
# Episode * 22700 * Moving Avg Reward is ==> 0.14086 * Last Reward was ==> 0.12806
# Episode * 22800 * Moving Avg Reward is ==> 0.14026 * Last Reward was ==> 0.16687
# Episode * 22900 * Moving Avg Reward is ==> 0.14114 * Last Reward was ==> 0.09588
# Episode * 23000 * Moving Avg Reward is ==> 0.13910 * Last Reward was ==> -0.01041
# Episode * 23100 * Moving Avg Reward is ==> 0.13433 * Last Reward was ==> 0.14204
# Episode * 23200 * Moving Avg Reward is ==> 0.13341 * Last Reward was ==> 0.09360
# Episode * 23300 * Moving Avg Reward is ==> 0.13478 * Last Reward was ==> 0.12915
# Episode * 23400 * Moving Avg Reward is ==> 0.13531 * Last Reward was ==> 0.31138
# Episode * 23500 * Moving Avg Reward is ==> 0.13533 * Last Reward was ==> 0.02200
# Episode * 23600 * Moving Avg Reward is ==> 0.13681 * Last Reward was ==> 0.04653
# Episode * 23700 * Moving Avg Reward is ==> 0.13749 * Last Reward was ==> 0.22827
# Episode * 23800 * Moving Avg Reward is ==> 0.13732 * Last Reward was ==> 0.12822
# Episode * 23900 * Moving Avg Reward is ==> 0.13715 * Last Reward was ==> 0.06958
# Episode * 24000 * Moving Avg Reward is ==> 0.13717 * Last Reward was ==> 0.01448
# Episode * 24100 * Moving Avg Reward is ==> 0.13917 * Last Reward was ==> 0.02635
# Episode * 24200 * Moving Avg Reward is ==> 0.13882 * Last Reward was ==> 0.21627
# Episode * 24300 * Moving Avg Reward is ==> 0.13850 * Last Reward was ==> 0.15554
# Episode * 24400 * Moving Avg Reward is ==> 0.13998 * Last Reward was ==> 0.24999
# Episode * 24500 * Moving Avg Reward is ==> 0.13867 * Last Reward was ==> 0.20432
# Episode * 24600 * Moving Avg Reward is ==> 0.13806 * Last Reward was ==> 0.31065
# Episode * 24700 * Moving Avg Reward is ==> 0.13777 * Last Reward was ==> 0.06969
# Episode * 24800 * Moving Avg Reward is ==> 0.13728 * Last Reward was ==> 0.22245
# Episode * 24900 * Moving Avg Reward is ==> 0.13667 * Last Reward was ==> 0.23343
# Episode * 25000 * Moving Avg Reward is ==> 0.13865 * Last Reward was ==> 0.30798
# Episode * 25100 * Moving Avg Reward is ==> 0.13903 * Last Reward was ==> 0.03499
# Episode * 25200 * Moving Avg Reward is ==> 0.13821 * Last Reward was ==> 0.10012
# Episode * 25300 * Moving Avg Reward is ==> 0.13677 * Last Reward was ==> 0.22730
# Episode * 25400 * Moving Avg Reward is ==> 0.13418 * Last Reward was ==> -0.11292
# Episode * 25500 * Moving Avg Reward is ==> 0.13568 * Last Reward was ==> 0.17094
# Episode * 25600 * Moving Avg Reward is ==> 0.13570 * Last Reward was ==> 0.31138
# Episode * 25700 * Moving Avg Reward is ==> 0.13626 * Last Reward was ==> 0.16687
# Episode * 25800 * Moving Avg Reward is ==> 0.13643 * Last Reward was ==> 0.09860
# Episode * 25900 * Moving Avg Reward is ==> 0.13726 * Last Reward was ==> 0.21385
# Episode * 26000 * Moving Avg Reward is ==> 0.13710 * Last Reward was ==> 0.02833
# Episode * 26100 * Moving Avg Reward is ==> 0.13730 * Last Reward was ==> 0.13713
# Episode * 26200 * Moving Avg Reward is ==> 0.13764 * Last Reward was ==> 0.18596
# Episode * 26300 * Moving Avg Reward is ==> 0.14006 * Last Reward was ==> -0.00360
# Episode * 26400 * Moving Avg Reward is ==> 0.13954 * Last Reward was ==> 0.02926
# Episode * 26500 * Moving Avg Reward is ==> 0.13949 * Last Reward was ==> 0.04379
# Episode * 26600 * Moving Avg Reward is ==> 0.13698 * Last Reward was ==> 0.22516
# Episode * 26700 * Moving Avg Reward is ==> 0.13764 * Last Reward was ==> 0.03190
# Episode * 26800 * Moving Avg Reward is ==> 0.13814 * Last Reward was ==> 0.27998
# Episode * 26900 * Moving Avg Reward is ==> 0.13685 * Last Reward was ==> 0.03976
# Episode * 27000 * Moving Avg Reward is ==> 0.13717 * Last Reward was ==> 0.14869
# Episode * 27100 * Moving Avg Reward is ==> 0.13518 * Last Reward was ==> 0.15433
# Episode * 27200 * Moving Avg Reward is ==> 0.13649 * Last Reward was ==> -0.04587
# Episode * 27300 * Moving Avg Reward is ==> 0.13612 * Last Reward was ==> 0.14887
# Episode * 27400 * Moving Avg Reward is ==> 0.13540 * Last Reward was ==> 0.14204
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [6], in <cell line: 3>()
#       1 agent.env.mode = "train"
#       2 agent.learning_log.episodes = 0
# ----> 3 agent.learn(
#       4     timesteps=-1,
#       5     log_every=100,
#       6     success_threshold_lookback=1000,
#       7     success_strict=True,
#       8 )
#      10 print('A2C + CNN + 0.25 threshold -> Executed in 1h 1m 4s, finished 18:43:51 2022-08-08')
#
# File ~\Development\GIT\tmp\reinforcement-learning\src\agents\actor_critic\a2c.py:276, in A2CAgent.learn(self, timesteps, plot_results, reset, success_threshold, log_level, log_every, success_threshold_lookback, success_strict)
#     273 action, action_onehot, prediction = self.choose_action(state,deterministic=False)
#     275 # Retrieve new state, reward, and whether the state is terminal
# --> 276 next_state, reward, done, _ = self.env.step(action)
#     278 # Memorize (state, action, reward) for training
#     279 self.buffer.remember(np.expand_dims(state, axis=0), action_onehot, reward)
#
# File ~\anaconda3\envs\ai_4\lib\site-packages\gym\wrappers\order_enforcing.py:13, in OrderEnforcing.step(self, action)
#      11 def step(self, action):
#      12     assert self._has_reset, "Cannot call env.step() before calling reset()"
# ---> 13     observation, reward, done, info = self.env.step(action)
#      14     return observation, reward, done, info
#
# File ~\Development\GIT\tmp\reinforcement-learning\src\environments\continuous\stock_trading\v0.py:788, in step(self, action)
#     786 def calculate_initial_investment(self,idx):
#     787     if self.auto_investment:
# --> 788         return self.initial_investments[idx]
#     789     else:
#     790         return self.initial_investment
#
# File ~\Development\GIT\tmp\reinforcement-learning\src\environments\continuous\stock_trading\v0.py:618, in _next_state(self)
#     615         self.cash_in_hand -= discounted_price
#     617     else:
# --> 618         amount = 0
#     620 elif action == self.actions.SELL:
#     621     # Sells all in a row
#     622     position = 'sell'
#
# File ~\Development\GIT\tmp\reinforcement-learning\src\environments\continuous\stock_trading\v0.py:585, in _state(self)
#     582 def execute_trade(self,action,amount):
#     583     """
#     584     Trade action
# --> 585     --------------------
#     586     """
#     588     # Track what we have done in this episode
#     589     self.stock_bought = 0
#
# File <__array_function__ internals>:180, in concatenate(*args, **kwargs)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Test the results
# * Runs a set of episodes with **unseen data**
# * Stores the results in a csv file for later consulting

# %%
success = 0
n_tests = 10000

scores = []
targets = []
portfolio_target_ratios = []
initial_investments = []

for i in trange(n_tests):
    state = agent.env.reset(visualize=False,mode="test")
    step = 0
    score = 0
    reward = 0
    done = False
    
    targets.append((agent.env.episode_target-agent.env.initial_investment)/agent.env.initial_investment)
    initial_investments.append(agent.env.initial_investment)

    while not done:
        agent.env.render()
        
        # Select action
        action, action_onehot, prediction = agent.choose_action(state)
        
        # Retrieve new state, reward, and whether the state is terminal
        next_state, reward, done, info = agent.env.step(action)
        
        # End of episode, track scores here
        if done :
            if agent.env.portfolio_value > agent.env.initial_investment:
                success +=1

        step+=1
        state = next_state
        score += reward
    
    # Track scores and ratios
    scores.append(score)
    portfolio_target_ratios.append(info["portfolio_value"]/info["episode_target"] -1)
    
    
test_results_dataframe = pd.DataFrame([[
    n_tests,
    str(round(np.mean(scores)*100,3))+'%',
    str(round(np.mean(targets)*100,3))+'%',
    str(round(np.mean(portfolio_target_ratios)*100,3))+'%',
    str(round(min(scores)*100,3))+'%',
    str(round(max(scores)*100,3))+'%',
    str(round((success/n_tests)*100,3)) +'%'
]],
    columns=[
        '# Blind tests',
        '% Average portfolio return', 
        '% Desired portfolio return', 
        'Portfolio/Target rate',
        '% Historical minimum return',
        '% Historical maximum return', 
        '% Episodes concluded with positive outcome'
    ]
)


agent.results_writer.store_test_results(agent,test_results_dataframe)

test_results_dataframe.T

# %% [markdown]
# ### Visual test
# * Runs a set of episodes with **unseen data**
# * See the evolution in real time

# %%
success = 0
n_tests = 10

scores = []
targets = []


for i in trange(n_tests):
    state = agent.env.reset(visualize=True,mode="test")
    step = 0
    score = 0
    reward = 0
    done = False
    targets.append((agent.env.episode_target-agent.env.initial_investment)/agent.env.initial_investment)
    initial_portfolio = agent.env.portfolio_value

    while not done:
        agent.env.render()
        
        # Select desired action
        action, action_onehot, prediction = agent.choose_action(state)

        # Retrieve new state, reward, and whether the state is terminal
        next_state, reward, done, _ = agent.env.step(action)

        # Update current state
        if done :
            if agent.env.portfolio_value > agent.env.initial_investment:
                success +=1

        step+=1
        state = next_state
        score += reward
    
    scores.append(score)

agent.env.close()

# %% [markdown]
# ### Transactions profit
# * Track how much the agent gained by doing purchases and sales
# * Doesn't track the portfolio value
# * Already has the fees discounted

# %%
success = 0
n_tests = 10000

test_results_data = []
test_results_columns = [
    'dataset id',
    'episode start date', 
    'episode end date',
    'episode working days',
    'total transactions',
    'total transaction profit',
    "dataframe hash",
    "agent hash"
]

print('NOTE: This test only tracks the transactions profit. ')

for i in trange(n_tests):
    trading_history = []
    state = agent.env.reset(visualize=False,mode="test")
    step = 0
    score = 0
    reward = 0
    done = False
    #targets.append((agent.env.episode_target-agent.env.initial_investment)/agent.env.initial_investment)
    #initial_portfolio = agent.env.portfolio_value
    
    j = 0
    num_stocks = 0
    while not done:
        agent.env.render()
        
        # Select desired action
        action, action_onehot, prediction = agent.choose_action(state)
        current_price = agent.env.df.iloc[agent.env.current_step -1]['close']
        
        if action == agent.env.ACTIONS.BUY:
            discounted_price = current_price * (1+agent.env.fees.BUY) 
            if agent.env.stock_held < agent.env.maximum_stocks_held and agent.env.cash_in_hand >= discounted_price:
                num_stocks +=1
                trading_history.append(['buy', discounted_price])
        elif action == agent.env.ACTIONS.SELL:
            if agent.env.stock_held > 0:
                discounted_price = current_price * (1-agent.env.fees.SELL) 
                trading_history.append(['sell', discounted_price])
                num_stocks =0
                
        # Retrieve new state, reward, and whether the state is terminal
        next_state, reward, done, _ = agent.env.step(action)

        # Update current state
        if done :
            if agent.env.portfolio_value > agent.env.initial_investment:
                success +=1
                
            profits = []
            purchases = []
            for e in trading_history:
                if e[0] == 'buy':
                    purchases.append(e[1])
                else:
                    profits.append((e[1]* len(purchases) - sum(purchases)) / sum(purchases))
                    purchases.clear() 
                    
            test_results_data.append([
                agent.env.dataset_idx,
                agent.env.df.iloc[agent.env.lookback].name,
                agent.env.df.iloc[-1].name,
                agent.env.window_size,
                len(profits),
                sum(profits)*100,
                agent.env.df_name,
                agent.hash
            ])


        step+=1
        state = next_state
        score += reward
    

agent.env.close()


pd.DataFrame(test_results_data,columns=test_results_columns)

# %%
transaction_results_df = pd.DataFrame(test_results_data,columns=test_results_columns)

# %%
transaction_results_df.sort_values(by="dataset id")

# %%
transaction_results_df[transaction_results_df['total transaction profit'] <= 0]

# %%
failed_episodes_df = transaction_results_df[transaction_results_df['total transaction profit'] <= 0]
failed_episodes_idx = failed_episodes_df['dataset id'].unique()
failed_episodes_idx.sort()

# %%
len(transaction_results_df[transaction_results_df['total transaction profit'] <= 0]['dataset id'].unique()),len(transaction_results_df[transaction_results_df['total transaction profit'] > 0]['dataset id'].unique())

# %%
import matplotlib.pyplot as plt 

for idx in failed_episodes_idx:
    plt.figure(figsize=(16,4))
    plt.plot(agent.env.df['close'])
    plt.title('#'+str(idx)+' - ' + str(len(failed_episodes_df[failed_episodes_df['dataset id'] == idx])) +'/' + str(len(transaction_results_df[transaction_results_df['dataset id'] == idx])))

# %%
import time
n=10000
time_format = time.strftime("%H:%M:%S", time.gmtime(n))
print("Time in preferred format :-",time_format)

# %%
0>float(-np.inf)

# %%
a = time.time()

# %%
b = time.time()

# %%
a

# %%
b

# %%
b-a

# %%
time.strftime("%H:%M:%S", time.gmtime(b-a))

# %%
import os
directory = agent.writer_log_directory+'/plots'
number_of_files = len(os.listdir(directory))
print(number_of_files)

# %%
agent.writer_log_directory
