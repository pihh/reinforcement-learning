# %%
import shutup
shutup.please()

import gym
import src.environments.continuous.stock_trading  

import numpy as np
import pandas as pd 

from tqdm.notebook import trange, tqdm

# %% [markdown]
# ### Train the agent
# * Run it until he has a running average above the success_threshold
# * Use a large number of episodes for the running average ( 1000+ ) so if even it falls into a privileged sample, it wont be prone to error

# %%
def environment():
    env = gym.make('StockTradingEnvironment-v0',
        ticker="MSFT",
        use_technical_indicators= [
        "macd",
        "boll_ub",
        "boll_lb",
        "rsi_30",
        "cci_30",
        "dx_30",
        "close_30_sma",
        "close_60_sma",
    ])
    
    print('original threshold',env.success_threshold)
    
    env.success_threshold =0.25 # 25%
    
    print('current threshold',env.success_threshold)
    
    return env

# from src.environments.continuous.trading import environment

# %%
from src.agents.actor_critic.a2c import A2CAgent

# %%
agent=A2CAgent(environment, epochs=1, actor_learning_rate=0.000025,critic_learning_rate=0.000025,policy="CNN")
agent.load()
environment().success_threshold
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\filip\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# boll_lb
# boll_ub
# cci_30
# close_30_sma
# close_60_sma
# dx_30
# macd
# rsi_30
# boll_lb close
# boll_ub close
# cci_30 259
# close_30_sma close
# close_60_sma close
# dx_30 100
# macd close
# macd close
# rsi_30 100
#
# original threshold 0.0379506553185424
# current threshold 0.25
# [Errno 2] Unable to open file (unable to open file: name = 'storage/environments/MsftStockTradingEnvironment-v0/5561205d123bbaecd2b98785760fa4f7/models/a2c-actor.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
#
# [Errno 2] Unable to open file (unable to open file: name = 'storage/environments/MsftStockTradingEnvironment-v0/5561205d123bbaecd2b98785760fa4f7/models/a2c-critic.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
#
#
# original threshold 0.0379506553185424
# current threshold 0.25
# 0.25

# %%
# agent.hash

# %%
agent.env.mode = "train"
agent.learning_log.episodes = 0
agent.learn(
    timesteps=-1, 
    log_every=100,
    success_threshold_lookback=1000,
    success_strict=True,
)

print('A2C + CNN + 0.25 threshold -> Executed in 1h 1m 4s, finished 18:43:51 2022-08-08')
# Out:
# Episode * 100 * Moving Avg Reward is ==> 0.00433 * Last Reward was ==> 0.02179
# Episode * 200 * Moving Avg Reward is ==> 0.00777 * Last Reward was ==> -0.04268
# Episode * 300 * Moving Avg Reward is ==> 0.01218 * Last Reward was ==> 0.00708
# Episode * 400 * Moving Avg Reward is ==> 0.01755 * Last Reward was ==> 0.14570
# Episode * 500 * Moving Avg Reward is ==> 0.03131 * Last Reward was ==> 0.19985
# Episode * 600 * Moving Avg Reward is ==> 0.04344 * Last Reward was ==> 0.18987
# Episode * 700 * Moving Avg Reward is ==> 0.05364 * Last Reward was ==> 0.15287
# Episode * 800 * Moving Avg Reward is ==> 0.06385 * Last Reward was ==> 0.13923
# Episode * 900 * Moving Avg Reward is ==> 0.07012 * Last Reward was ==> 0.08392
# Episode * 1000 * Moving Avg Reward is ==> 0.07852 * Last Reward was ==> 0.03243
# * Models saved *
#
# New historical moving average record: 0.07862
#
# * Models saved *
#
# New historical moving average record: 0.07890
#
# * Models saved *
#
# New historical moving average record: 0.07895
#
# * Models saved *
#
# New historical moving average record: 0.07903
#
# * Models saved *
#
# New historical moving average record: 0.07916
#
# * Models saved *
#
# New historical moving average record: 0.07934
#
# * Models saved *
#
# New historical moving average record: 0.07937
#
# * Models saved *
#
# New historical moving average record: 0.07963
#
# * Models saved *
#
# New historical moving average record: 0.07988
#
# * Models saved *
#
# New historical moving average record: 0.08003
#
# * Models saved *
#
# New historical moving average record: 0.08004
#
# * Models saved *
#
# New historical moving average record: 0.08016
#
# * Models saved *
#
# New historical moving average record: 0.08030
#
# * Models saved *
#
# New historical moving average record: 0.08046
#
# * Models saved *
#
# New historical moving average record: 0.08074
#
# * Models saved *
#
# New historical moving average record: 0.08090
#
# * Models saved *
#
# New historical moving average record: 0.08094
#
# * Models saved *
#
# New historical moving average record: 0.08120
#
# * Models saved *
#
# New historical moving average record: 0.08147
#
# * Models saved *
#
# New historical moving average record: 0.08171
#
# * Models saved *
#
# New historical moving average record: 0.08204
#
# * Models saved *
#
# New historical moving average record: 0.08210
#
# * Models saved *
#
# New historical moving average record: 0.08228
#
# * Models saved *
#
# New historical moving average record: 0.08230
#
# * Models saved *
#
# New historical moving average record: 0.08239
#
# * Models saved *
#
# New historical moving average record: 0.08245
#
# * Models saved *
#
# New historical moving average record: 0.08247
#
# * Models saved *
#
# New historical moving average record: 0.08264
#
# * Models saved *
#
# New historical moving average record: 0.08269
#
# * Models saved *
#
# New historical moving average record: 0.08292
#
# * Models saved *
#
# New historical moving average record: 0.08297
#
# * Models saved *
#
# New historical moving average record: 0.08303
#
# * Models saved *
#
# New historical moving average record: 0.08316
#
# * Models saved *
#
# New historical moving average record: 0.08342
#
# * Models saved *
#
# New historical moving average record: 0.08355
#
# * Models saved *
#
# New historical moving average record: 0.08362
#
# * Models saved *
#
# New historical moving average record: 0.08364
#
# * Models saved *
#
# New historical moving average record: 0.08367
#
# * Models saved *
#
# New historical moving average record: 0.08401
#
# * Models saved *
#
# New historical moving average record: 0.08418
#
# * Models saved *
#
# New historical moving average record: 0.08430
#
# * Models saved *
#
# New historical moving average record: 0.08434
#
# * Models saved *
#
# New historical moving average record: 0.08464
#
# * Models saved *
#
# New historical moving average record: 0.08478
#
# * Models saved *
#
# New historical moving average record: 0.08496
#
# * Models saved *
#
# New historical moving average record: 0.08497
#
# * Models saved *
#
# New historical moving average record: 0.08524
#
# * Models saved *
#
# New historical moving average record: 0.08542
#
# * Models saved *
#
# New historical moving average record: 0.08565
#
# * Models saved *
#
# New historical moving average record: 0.08576
#
# * Models saved *
#
# New historical moving average record: 0.08587
#
# * Models saved *
#
# New historical moving average record: 0.08590
#
# * Models saved *
#
# New historical moving average record: 0.08607
#
# * Models saved *
#
# New historical moving average record: 0.08636
#
# * Models saved *
#
# New historical moving average record: 0.08647
#
# * Models saved *
#
# New historical moving average record: 0.08649
#
# * Models saved *
#
# New historical moving average record: 0.08663
#
# * Models saved *
#
# New historical moving average record: 0.08684
#
# * Models saved *
#
# New historical moving average record: 0.08688
#
# * Models saved *
#
# New historical moving average record: 0.08696
#
# * Models saved *
#
# New historical moving average record: 0.08711
#
# * Models saved *
#
# New historical moving average record: 0.08731
#
# * Models saved *
#
# New historical moving average record: 0.08754
#
# * Models saved *
#
# New historical moving average record: 0.08773
#
# * Models saved *
#
# New historical moving average record: 0.08790
#
# * Models saved *
#
# New historical moving average record: 0.08819
#
# * Models saved *
#
# New historical moving average record: 0.08835
#
# * Models saved *
#
# New historical moving average record: 0.08851
#
# * Models saved *
#
# New historical moving average record: 0.08855
#
# * Models saved *
#
# New historical moving average record: 0.08868
#
# * Models saved *
#
# New historical moving average record: 0.08898
#
# * Models saved *
#
# New historical moving average record: 0.08927
#
# * Models saved *
#
# New historical moving average record: 0.08951
#
# * Models saved *
#
# New historical moving average record: 0.08983
#
# * Models saved *
#
# New historical moving average record: 0.09000
#
# * Models saved *
#
# New historical moving average record: 0.09017
#
# * Models saved *
#
# New historical moving average record: 0.09039
#
# * Models saved *
#
# New historical moving average record: 0.09060
#
# * Models saved *
#
# New historical moving average record: 0.09067
#
# * Models saved *
#
# New historical moving average record: 0.09090
#
# * Models saved *
#
# New historical moving average record: 0.09120
#
# * Models saved *
#
# New historical moving average record: 0.09152
#
# * Models saved *
#
# New historical moving average record: 0.09165
#
# * Models saved *
#
# New historical moving average record: 0.09182
#
# * Models saved *
#
# New historical moving average record: 0.09211
#
# * Models saved *
#
# New historical moving average record: 0.09227
#
# Episode * 1100 * Moving Avg Reward is ==> 0.09257 * Last Reward was ==> 0.32448
# * Models saved *
#
# New historical moving average record: 0.09257
#
# * Models saved *
#
# New historical moving average record: 0.09276
#
# * Models saved *
#
# New historical moving average record: 0.09310
#
# * Models saved *
#
# New historical moving average record: 0.09329
#
# * Models saved *
#
# New historical moving average record: 0.09361
#
# * Models saved *
#
# New historical moving average record: 0.09378
#
# * Models saved *
#
# New historical moving average record: 0.09395
#
# * Models saved *
#
# New historical moving average record: 0.09409
#
# * Models saved *
#
# New historical moving average record: 0.09412
#
# * Models saved *
#
# New historical moving average record: 0.09430
#
# * Models saved *
#
# New historical moving average record: 0.09446
#
# * Models saved *
#
# New historical moving average record: 0.09453
#
# * Models saved *
#
# New historical moving average record: 0.09477
#
# * Models saved *
#
# New historical moving average record: 0.09487
#
# * Models saved *
#
# New historical moving average record: 0.09507
#
# * Models saved *
#
# New historical moving average record: 0.09509
#
# * Models saved *
#
# New historical moving average record: 0.09522
#
# * Models saved *
#
# New historical moving average record: 0.09534
#
# * Models saved *
#
# New historical moving average record: 0.09542
#
# * Models saved *
#
# New historical moving average record: 0.09557
#
# * Models saved *
#
# New historical moving average record: 0.09559
#
# * Models saved *
#
# New historical moving average record: 0.09568
#
# * Models saved *
#
# New historical moving average record: 0.09569
#
# * Models saved *
#
# New historical moving average record: 0.09585
#
# * Models saved *
#
# New historical moving average record: 0.09607
#
# * Models saved *
#
# New historical moving average record: 0.09610
#
# * Models saved *
#
# New historical moving average record: 0.09624
# * Models saved *
#
# New historical moving average record: 0.09637
#
# * Models saved *
#
# New historical moving average record: 0.09646
#
# * Models saved *
#
# New historical moving average record: 0.09647
#
# * Models saved *
#
# New historical moving average record: 0.09651
#
# * Models saved *
#
# New historical moving average record: 0.09671
#
# * Models saved *
#
# New historical moving average record: 0.09674
#
# * Models saved *
#
# New historical moving average record: 0.09685
#
# * Models saved *
#
# New historical moving average record: 0.09711
#
# * Models saved *
#
# New historical moving average record: 0.09739
#
# * Models saved *
#
# New historical moving average record: 0.09761
#
# * Models saved *
#
# New historical moving average record: 0.09782
#
# * Models saved *
#
# New historical moving average record: 0.09783
#
# * Models saved *
#
# New historical moving average record: 0.09802
#
# * Models saved *
#
# New historical moving average record: 0.09811
#
# * Models saved *
#
# New historical moving average record: 0.09832
#
# * Models saved *
#
# New historical moving average record: 0.09852
#
# * Models saved *
#
# New historical moving average record: 0.09864
#
# * Models saved *
#
# New historical moving average record: 0.09874
#
# * Models saved *
#
# New historical moving average record: 0.09904
#
# * Models saved *
#
# New historical moving average record: 0.09911
#
# * Models saved *
#
# New historical moving average record: 0.09931
#
# * Models saved *
#
# New historical moving average record: 0.09948
#
# * Models saved *
#
# New historical moving average record: 0.09963
#
# * Models saved *
#
# New historical moving average record: 0.09982
#
# * Models saved *
#
# New historical moving average record: 0.09993
#
# * Models saved *
#
# New historical moving average record: 0.10002
#
# * Models saved *
#
# New historical moving average record: 0.10006
#
# * Models saved *
#
# New historical moving average record: 0.10008
#
# * Models saved *
#
# New historical moving average record: 0.10011
#
# * Models saved *
#
# New historical moving average record: 0.10036
#
# * Models saved *
#
# New historical moving average record: 0.10044
#
# * Models saved *
#
# New historical moving average record: 0.10056
#
# * Models saved *
#
# New historical moving average record: 0.10058
#
# * Models saved *
#
# New historical moving average record: 0.10066
#
# * Models saved *
#
# New historical moving average record: 0.10075
#
# * Models saved *
#
# New historical moving average record: 0.10077
#
# * Models saved *
#
# New historical moving average record: 0.10077
#
# * Models saved *
#
# New historical moving average record: 0.10088
#
# * Models saved *
#
# New historical moving average record: 0.10111
#
# * Models saved *
#
# New historical moving average record: 0.10133
#
# * Models saved *
#
# New historical moving average record: 0.10150
#
# * Models saved *
#
# New historical moving average record: 0.10170
#
# * Models saved *
#
# New historical moving average record: 0.10187
#
# * Models saved *
#
# New historical moving average record: 0.10194
#
# * Models saved *
#
# New historical moving average record: 0.10216
#
# * Models saved *
#
# New historical moving average record: 0.10224
#
# * Models saved *
#
# New historical moving average record: 0.10236
#
# * Models saved *
#
# New historical moving average record: 0.10261
#
# * Models saved *
#
# New historical moving average record: 0.10278
#
# * Models saved *
#
# New historical moving average record: 0.10297
#
# * Models saved *
#
# New historical moving average record: 0.10301
#
# * Models saved *
#
# New historical moving average record: 0.10320
#
# * Models saved *
#
# New historical moving average record: 0.10348
#
# * Models saved *
#
# New historical moving average record: 0.10369
#
# * Models saved *
#
# New historical moving average record: 0.10377
#
# * Models saved *
#
# New historical moving average record: 0.10391
#
# * Models saved *
#
# New historical moving average record: 0.10416
#
# * Models saved *
#
# New historical moving average record: 0.10432
#
# Episode * 1200 * Moving Avg Reward is ==> 0.10438 * Last Reward was ==> 0.02094
# * Models saved *
#
# New historical moving average record: 0.10438
#
# * Models saved *
#
# New historical moving average record: 0.10444
#
# * Models saved *
#
# New historical moving average record: 0.10451
#
# * Models saved *
#
# New historical moving average record: 0.10478
#
# * Models saved *
#
# New historical moving average record: 0.10486
#
# * Models saved *
#
# New historical moving average record: 0.10514
#
# * Models saved *
#
# New historical moving average record: 0.10518
#
# * Models saved *
#
# New historical moving average record: 0.10528
#
# * Models saved *
#
# New historical moving average record: 0.10542
#
# * Models saved *
#
# New historical moving average record: 0.10557
#
# * Models saved *
#
# New historical moving average record: 0.10581
#
# * Models saved *
#
# New historical moving average record: 0.10608
#
# * Models saved *
#
# New historical moving average record: 0.10635
#
# * Models saved *
#
# New historical moving average record: 0.10645
#
# * Models saved *
#
# New historical moving average record: 0.10650
#
# * Models saved *
#
# New historical moving average record: 0.10676
#
# * Models saved *
#
# New historical moving average record: 0.10698
#
# * Models saved *
#
# New historical moving average record: 0.10700
#
# * Models saved *
#
# New historical moving average record: 0.10728
#
# * Models saved *
#
# New historical moving average record: 0.10756
#
# * Models saved *
#
# New historical moving average record: 0.10759
#
# * Models saved *
#
# New historical moving average record: 0.10780
#
# * Models saved *
#
# New historical moving average record: 0.10789
#
# * Models saved *
#
# New historical moving average record: 0.10796
#
# * Models saved *
#
# New historical moving average record: 0.10805
#
# * Models saved *
#
# New historical moving average record: 0.10821
#
# * Models saved *
#
# New historical moving average record: 0.10826
#
# * Models saved *
#
# New historical moving average record: 0.10842
#
# * Models saved *
#
# New historical moving average record: 0.10868
#
# * Models saved *
#
# New historical moving average record: 0.10891
#
# * Models saved *
#
# New historical moving average record: 0.10915
#
# * Models saved *
#
# New historical moving average record: 0.10931
#
# * Models saved *
#
# New historical moving average record: 0.10935
#
# * Models saved *
#
# New historical moving average record: 0.10957
#
# * Models saved *
#
# New historical moving average record: 0.10971
#
# * Models saved *
#
# New historical moving average record: 0.10999
#
# * Models saved *
#
# New historical moving average record: 0.11031
#
# * Models saved *
#
# New historical moving average record: 0.11031
#
# * Models saved *
#
# New historical moving average record: 0.11042
#
# * Models saved *
#
# New historical moving average record: 0.11058
#
# * Models saved *
#
# New historical moving average record: 0.11071
#
# * Models saved *
#
# New historical moving average record: 0.11093
#
# * Models saved *
#
# New historical moving average record: 0.11108
#
# * Models saved *
#
# New historical moving average record: 0.11126
#
# * Models saved *
#
# New historical moving average record: 0.11144
#
# * Models saved *
#
# New historical moving average record: 0.11173
#
# * Models saved *
#
# New historical moving average record: 0.11184
#
# * Models saved *
#
# New historical moving average record: 0.11220
#
# * Models saved *
#
# New historical moving average record: 0.11244
#
# * Models saved *
#
# New historical moving average record: 0.11254
#
# * Models saved *
#
# New historical moving average record: 0.11259
#
# * Models saved *
#
# New historical moving average record: 0.11260
#
# * Models saved *
#
# New historical moving average record: 0.11274
#
# * Models saved *
#
# New historical moving average record: 0.11295
#
# * Models saved *
#
# New historical moving average record: 0.11305
#
# * Models saved *
#
# New historical moving average record: 0.11319
#
# * Models saved *
#
# New historical moving average record: 0.11327
#
# * Models saved *
#
# New historical moving average record: 0.11346
#
# * Models saved *
#
# New historical moving average record: 0.11376
#
# * Models saved *
#
# New historical moving average record: 0.11397
#
# * Models saved *
#
# New historical moving average record: 0.11414
#
# * Models saved *
#
# New historical moving average record: 0.11419
#
# * Models saved *
#
# New historical moving average record: 0.11425
#
# * Models saved *
#
# New historical moving average record: 0.11441
#
# * Models saved *
#
# New historical moving average record: 0.11456
#
# * Models saved *
#
# New historical moving average record: 0.11457
#
# * Models saved *
#
# New historical moving average record: 0.11466
# * Models saved *
#
# New historical moving average record: 0.11473
#
# * Models saved *
#
# New historical moving average record: 0.11498
#
# * Models saved *
#
# New historical moving average record: 0.11506
#
# * Models saved *
#
# New historical moving average record: 0.11532
#
# * Models saved *
#
# New historical moving average record: 0.11548
#
# * Models saved *
#
# New historical moving average record: 0.11572
#
# * Models saved *
#
# New historical moving average record: 0.11574
#
# * Models saved *
#
# New historical moving average record: 0.11586
#
# * Models saved *
#
# New historical moving average record: 0.11598
#
# * Models saved *
#
# New historical moving average record: 0.11619
#
# * Models saved *
#
# New historical moving average record: 0.11637
#
# * Models saved *
#
# New historical moving average record: 0.11646
#
# * Models saved *
#
# New historical moving average record: 0.11658
#
# Episode * 1300 * Moving Avg Reward is ==> 0.11654 * Last Reward was ==> -0.03420
# * Models saved *
#
# New historical moving average record: 0.11674
#
# * Models saved *
#
# New historical moving average record: 0.11706
#
# * Models saved *
#
# New historical moving average record: 0.11712
#
# * Models saved *
#
# New historical moving average record: 0.11726
#
# * Models saved *
#
# New historical moving average record: 0.11744
#
# * Models saved *
#
# New historical moving average record: 0.11763
#
# * Models saved *
#
# New historical moving average record: 0.11779
#
# * Models saved *
#
# New historical moving average record: 0.11791
#
# * Models saved *
#
# New historical moving average record: 0.11801
#
# * Models saved *
#
# New historical moving average record: 0.11819
#
# * Models saved *
#
# New historical moving average record: 0.11833
#
# * Models saved *
#
# New historical moving average record: 0.11857
#
# * Models saved *
#
# New historical moving average record: 0.11877
#
# * Models saved *
#
# New historical moving average record: 0.11890
#
# * Models saved *
#
# New historical moving average record: 0.11895
#
# * Models saved *
#
# New historical moving average record: 0.11911
#
# * Models saved *
#
# New historical moving average record: 0.11916
#
# * Models saved *
#
# New historical moving average record: 0.11922
#
# * Models saved *
#
# New historical moving average record: 0.11926
#
# * Models saved *
#
# New historical moving average record: 0.11927
#
# * Models saved *
#
# New historical moving average record: 0.11930
#
# * Models saved *
#
# New historical moving average record: 0.11954
#
# * Models saved *
#
# New historical moving average record: 0.11975
#
# * Models saved *
#
# New historical moving average record: 0.11995
#
# * Models saved *
#
# New historical moving average record: 0.12014
#
# * Models saved *
#
# New historical moving average record: 0.12027
#
# * Models saved *
#
# New historical moving average record: 0.12038
#
# * Models saved *
#
# New historical moving average record: 0.12057
#
# * Models saved *
#
# New historical moving average record: 0.12073
#
# * Models saved *
#
# New historical moving average record: 0.12090
#
# * Models saved *
#
# New historical moving average record: 0.12096
#
# * Models saved *
#
# New historical moving average record: 0.12110
#
# * Models saved *
#
# New historical moving average record: 0.12138
#
# * Models saved *
#
# New historical moving average record: 0.12154
#
# * Models saved *
#
# New historical moving average record: 0.12160
#
# * Models saved *
#
# New historical moving average record: 0.12172
#
# * Models saved *
#
# New historical moving average record: 0.12196
#
# * Models saved *
#
# New historical moving average record: 0.12216
#
# * Models saved *
#
# New historical moving average record: 0.12246
#
# * Models saved *
#
# New historical moving average record: 0.12250
#
# * Models saved *
#
# New historical moving average record: 0.12272
#
# * Models saved *
#
# New historical moving average record: 0.12294
#
# * Models saved *
#
# New historical moving average record: 0.12308
#
# * Models saved *
#
# New historical moving average record: 0.12319
#
# * Models saved *
#
# New historical moving average record: 0.12347
#
# * Models saved *
#
# New historical moving average record: 0.12355
#
# * Models saved *
#
# New historical moving average record: 0.12361
#
# * Models saved *
#
# New historical moving average record: 0.12371
#
# * Models saved *
#
# New historical moving average record: 0.12382
#
# * Models saved *
#
# New historical moving average record: 0.12416
#
# * Models saved *
#
# New historical moving average record: 0.12435
#
# * Models saved *
#
# New historical moving average record: 0.12468
#
# * Models saved *
#
# New historical moving average record: 0.12473
#
# * Models saved *
#
# New historical moving average record: 0.12489
#
# * Models saved *
#
# New historical moving average record: 0.12495
#
# * Models saved *
#
# New historical moving average record: 0.12498
#
# * Models saved *
#
# New historical moving average record: 0.12506
#
# * Models saved *
#
# New historical moving average record: 0.12518
#
# * Models saved *
#
# New historical moving average record: 0.12524
#
# * Models saved *
#
# New historical moving average record: 0.12537
#
# * Models saved *
#
# New historical moving average record: 0.12547
#
# * Models saved *
#
# New historical moving average record: 0.12574
#
# * Models saved *
#
# New historical moving average record: 0.12584
#
# * Models saved *
#
# New historical moving average record: 0.12595
#
# * Models saved *
#
# New historical moving average record: 0.12606
#
# * Models saved *
#
# New historical moving average record: 0.12614
#
# * Models saved *
#
# New historical moving average record: 0.12641
#
# * Models saved *
#
# New historical moving average record: 0.12664
#
# * Models saved *
#
# New historical moving average record: 0.12680
#
# * Models saved *
#
# New historical moving average record: 0.12719
#
# * Models saved *
#
# New historical moving average record: 0.12732
#
# * Models saved *
#
# New historical moving average record: 0.12759
#
# * Models saved *
#
# New historical moving average record: 0.12776
#
# * Models saved *
#
# New historical moving average record: 0.12804
#
# * Models saved *
#
# New historical moving average record: 0.12823
#
# * Models saved *
#
# New historical moving average record: 0.12831
#
# * Models saved *
#
# New historical moving average record: 0.12833
#
# * Models saved *
#
# New historical moving average record: 0.12839
#
# Episode * 1400 * Moving Avg Reward is ==> 0.12824 * Last Reward was ==> -0.00181
# * Models saved *
#
# New historical moving average record: 0.12842
#
# * Models saved *
#
# New historical moving average record: 0.12851
#
# * Models saved *
#
# New historical moving average record: 0.12862
#
# * Models saved *
#
# New historical moving average record: 0.12877
#
# * Models saved *
#
# New historical moving average record: 0.12887
#
# * Models saved *
#
# New historical moving average record: 0.12891
#
# * Models saved *
#
# New historical moving average record: 0.12902
#
# * Models saved *
#
# New historical moving average record: 0.12904
#
# * Models saved *
#
# New historical moving average record: 0.12908
#
# * Models saved *
#
# New historical moving average record: 0.12913
#
# * Models saved *
#
# New historical moving average record: 0.12924
#
# * Models saved *
#
# New historical moving average record: 0.12932
#
# * Models saved *
#
# New historical moving average record: 0.12934
#
# * Models saved *
#
# New historical moving average record: 0.12935
#
# * Models saved *
#
# New historical moving average record: 0.12945
#
# * Models saved *
#
# New historical moving average record: 0.12964
#
# * Models saved *
#
# New historical moving average record: 0.12988
#
# * Models saved *
#
# New historical moving average record: 0.13000
#
# * Models saved *
#
# New historical moving average record: 0.13003
#
# * Models saved *
#
# New historical moving average record: 0.13020
#
# * Models saved *
#
# New historical moving average record: 0.13050
#
# * Models saved *
#
# New historical moving average record: 0.13056
#
# * Models saved *
#
# New historical moving average record: 0.13059
#
# * Models saved *
#
# New historical moving average record: 0.13076
#
# * Models saved *
#
# New historical moving average record: 0.13092
#
# * Models saved *
#
# New historical moving average record: 0.13094
#
# * Models saved *
#
# New historical moving average record: 0.13125
#
# * Models saved *
#
# New historical moving average record: 0.13131
#
# * Models saved *
#
# New historical moving average record: 0.13158
#
# * Models saved *
#
# New historical moving average record: 0.13184
#
# * Models saved *
#
# New historical moving average record: 0.13218
#
# * Models saved *
#
# New historical moving average record: 0.13228
#
# * Models saved *
#
# New historical moving average record: 0.13232
# * Models saved *
#
# New historical moving average record: 0.13257
#
# * Models saved *
#
# New historical moving average record: 0.13271
#
# * Models saved *
#
# New historical moving average record: 0.13290
#
# * Models saved *
#
# New historical moving average record: 0.13304
#
# * Models saved *
#
# New historical moving average record: 0.13329
#
# * Models saved *
#
# New historical moving average record: 0.13359
#
# * Models saved *
#
# New historical moving average record: 0.13371
#
# * Models saved *
#
# New historical moving average record: 0.13407
#
# * Models saved *
#
# New historical moving average record: 0.13429
#
# Episode * 1500 * Moving Avg Reward is ==> 0.13405 * Last Reward was ==> 0.05129
# * Models saved *
#
# New historical moving average record: 0.13435
#
# * Models saved *
#
# New historical moving average record: 0.13446
#
# * Models saved *
#
# New historical moving average record: 0.13472
#
# * Models saved *
#
# New historical moving average record: 0.13487
#
# * Models saved *
#
# New historical moving average record: 0.13504
#
# * Models saved *
#
# New historical moving average record: 0.13520
#
# * Models saved *
#
# New historical moving average record: 0.13540
#
# * Models saved *
#
# New historical moving average record: 0.13541
#
# * Models saved *
#
# New historical moving average record: 0.13552
#
# * Models saved *
#
# New historical moving average record: 0.13554
#
# * Models saved *
#
# New historical moving average record: 0.13561
#
# * Models saved *
#
# New historical moving average record: 0.13571
#
# * Models saved *
#
# New historical moving average record: 0.13588
#
# * Models saved *
#
# New historical moving average record: 0.13599
#
# * Models saved *
#
# New historical moving average record: 0.13606
#
# * Models saved *
#
# New historical moving average record: 0.13606
#
# * Models saved *
#
# New historical moving average record: 0.13609
#
# * Models saved *
#
# New historical moving average record: 0.13617
#
# * Models saved *
#
# New historical moving average record: 0.13618
#
# * Models saved *
#
# New historical moving average record: 0.13640
#
# * Models saved *
#
# New historical moving average record: 0.13659
#
# * Models saved *
#
# New historical moving average record: 0.13674
#
# * Models saved *
#
# New historical moving average record: 0.13678
#
# * Models saved *
#
# New historical moving average record: 0.13679
#
# * Models saved *
#
# New historical moving average record: 0.13681
#
# * Models saved *
#
# New historical moving average record: 0.13685
#
# * Models saved *
#
# New historical moving average record: 0.13706
#
# Episode * 1600 * Moving Avg Reward is ==> 0.13682 * Last Reward was ==> 0.07596
# * Models saved *
#
# New historical moving average record: 0.13712
#
# * Models saved *
#
# New historical moving average record: 0.13722
#
# * Models saved *
#
# New historical moving average record: 0.13740
#
# * Models saved *
#
# New historical moving average record: 0.13743
#
# * Models saved *
#
# New historical moving average record: 0.13752
#
# * Models saved *
#
# New historical moving average record: 0.13762
#
# * Models saved *
#
# New historical moving average record: 0.13792
#
# * Models saved *
#
# New historical moving average record: 0.13794
#
# * Models saved *
#
# New historical moving average record: 0.13814
#
# * Models saved *
#
# New historical moving average record: 0.13823
#
# * Models saved *
#
# New historical moving average record: 0.13839
#
# * Models saved *
#
# New historical moving average record: 0.13859
#
# * Models saved *
#
# New historical moving average record: 0.13872
#
# * Models saved *
#
# New historical moving average record: 0.13879
#
# * Models saved *
#
# New historical moving average record: 0.13888
#
# * Models saved *
#
# New historical moving average record: 0.13901
#
# * Models saved *
#
# New historical moving average record: 0.13910
#
# * Models saved *
#
# New historical moving average record: 0.13928
#
# * Models saved *
#
# New historical moving average record: 0.13938
#
# * Models saved *
#
# New historical moving average record: 0.13939
#
# * Models saved *
#
# New historical moving average record: 0.13956
#
# * Models saved *
#
# New historical moving average record: 0.13959
#
# * Models saved *
#
# New historical moving average record: 0.13980
#
# * Models saved *
#
# New historical moving average record: 0.13983
#
# * Models saved *
#
# New historical moving average record: 0.14001
#
# * Models saved *
#
# New historical moving average record: 0.14007
#
# * Models saved *
#
# New historical moving average record: 0.14017
#
# * Models saved *
#
# New historical moving average record: 0.14020
#
# * Models saved *
#
# New historical moving average record: 0.14023
#
# Episode * 1700 * Moving Avg Reward is ==> 0.13978 * Last Reward was ==> 0.03499
# * Models saved *
#
# New historical moving average record: 0.14030
#
# * Models saved *
#
# New historical moving average record: 0.14036
#
# * Models saved *
#
# New historical moving average record: 0.14055
#
# * Models saved *
#
# New historical moving average record: 0.14058
#
# * Models saved *
#
# New historical moving average record: 0.14065
#
# * Models saved *
#
# New historical moving average record: 0.14073
#
# * Models saved *
#
# New historical moving average record: 0.14075
#
# * Models saved *
#
# New historical moving average record: 0.14084
#
# * Models saved *
#
# New historical moving average record: 0.14105
#
# * Models saved *
#
# New historical moving average record: 0.14111
#
# * Models saved *
#
# New historical moving average record: 0.14118
#
# * Models saved *
#
# New historical moving average record: 0.14121
#
# * Models saved *
#
# New historical moving average record: 0.14139
#
# * Models saved *
#
# New historical moving average record: 0.14147
#
# * Models saved *
#
# New historical moving average record: 0.14165
#
# * Models saved *
#
# New historical moving average record: 0.14172
#
# * Models saved *
#
# New historical moving average record: 0.14175
#
# Episode * 1800 * Moving Avg Reward is ==> 0.14135 * Last Reward was ==> 0.00879
# * Models saved *
#
# New historical moving average record: 0.14181
#
# * Models saved *
#
# New historical moving average record: 0.14182
#
# * Models saved *
#
# New historical moving average record: 0.14185
#
# * Models saved *
#
# New historical moving average record: 0.14191
#
# * Models saved *
#
# New historical moving average record: 0.14198
#
# * Models saved *
#
# New historical moving average record: 0.14226
#
# * Models saved *
#
# New historical moving average record: 0.14247
#
# * Models saved *
#
# New historical moving average record: 0.14257
#
# * Models saved *
#
# New historical moving average record: 0.14260
#
# * Models saved *
#
# New historical moving average record: 0.14261
#
# * Models saved *
#
# New historical moving average record: 0.14273
#
# * Models saved *
#
# New historical moving average record: 0.14274
#
# * Models saved *
#
# New historical moving average record: 0.14298
#
# * Models saved *
#
# New historical moving average record: 0.14304
#
# * Models saved *
#
# New historical moving average record: 0.14326
#
# * Models saved *
#
# New historical moving average record: 0.14331
#
# * Models saved *
#
# New historical moving average record: 0.14332
#
# * Models saved *
#
# New historical moving average record: 0.14334
#
# * Models saved *
#
# New historical moving average record: 0.14350
#
# * Models saved *
#
# New historical moving average record: 0.14367
#
# * Models saved *
#
# New historical moving average record: 0.14378
#
# * Models saved *
#
# New historical moving average record: 0.14387
#
# * Models saved *
#
# New historical moving average record: 0.14401
#
# * Models saved *
#
# New historical moving average record: 0.14409
#
# * Models saved *
#
# New historical moving average record: 0.14413
#
# Episode * 1900 * Moving Avg Reward is ==> 0.14278 * Last Reward was ==> -0.01828
# Episode * 2000 * Moving Avg Reward is ==> 0.13913 * Last Reward was ==> 0.05659
# Episode * 2100 * Moving Avg Reward is ==> 0.13798 * Last Reward was ==> 0.20767
# Episode * 2200 * Moving Avg Reward is ==> 0.13724 * Last Reward was ==> 0.00932
# Episode * 2300 * Moving Avg Reward is ==> 0.13649 * Last Reward was ==> 0.05086
# Episode * 2400 * Moving Avg Reward is ==> 0.13451 * Last Reward was ==> 0.32015
# Episode * 2500 * Moving Avg Reward is ==> 0.13470 * Last Reward was ==> 0.05301
# Episode * 2600 * Moving Avg Reward is ==> 0.13451 * Last Reward was ==> 0.18129
# Episode * 2700 * Moving Avg Reward is ==> 0.13267 * Last Reward was ==> 0.19770
# Episode * 2800 * Moving Avg Reward is ==> 0.13098 * Last Reward was ==> 0.03843
# Episode * 2900 * Moving Avg Reward is ==> 0.12943 * Last Reward was ==> 0.00875
# Episode * 3000 * Moving Avg Reward is ==> 0.13163 * Last Reward was ==> 0.00216
# Episode * 3100 * Moving Avg Reward is ==> 0.13209 * Last Reward was ==> 0.20408
# Episode * 3200 * Moving Avg Reward is ==> 0.13302 * Last Reward was ==> 0.20842
# Episode * 3300 * Moving Avg Reward is ==> 0.13444 * Last Reward was ==> 0.08667
# Episode * 3400 * Moving Avg Reward is ==> 0.13543 * Last Reward was ==> -0.01921
# Episode * 3500 * Moving Avg Reward is ==> 0.13396 * Last Reward was ==> 0.10251
# Episode * 3600 * Moving Avg Reward is ==> 0.13292 * Last Reward was ==> 0.13839
# Episode * 3700 * Moving Avg Reward is ==> 0.13410 * Last Reward was ==> 0.04316
# Episode * 3800 * Moving Avg Reward is ==> 0.13480 * Last Reward was ==> -0.02427
# Episode * 3900 * Moving Avg Reward is ==> 0.13697 * Last Reward was ==> 0.34221
# Episode * 4000 * Moving Avg Reward is ==> 0.13494 * Last Reward was ==> 0.04346
# Episode * 4100 * Moving Avg Reward is ==> 0.13510 * Last Reward was ==> 0.33735
# Episode * 4200 * Moving Avg Reward is ==> 0.13590 * Last Reward was ==> 0.16687
# Episode * 4300 * Moving Avg Reward is ==> 0.13528 * Last Reward was ==> 0.33072
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [6], in <cell line: 3>()
#       1 agent.env.mode = "train"
#       2 agent.learning_log.episodes = 0
# ----> 3 agent.learn(
#       4     timesteps=-1,
#       5     log_every=100,
#       6     success_threshold_lookback=1000,
#       7     success_strict=True,
#       8 )
#      10 print('A2C + CNN + 0.25 threshold -> Executed in 1h 1m 4s, finished 18:43:51 2022-08-08')
#
# File ~\Development\GIT\tmp\reinforcement-learning\src\agents\actor_critic\a2c.py:273, in A2CAgent.learn(self, timesteps, plot_results, reset, success_threshold, log_level, log_every, success_threshold_lookback, success_strict)
#     268 done = False
#     270 while not done:
#     271
#     272     #state = np.expand_dims(state, axis=0)
# --> 273     action, action_onehot, prediction = self.act(state,deterministic=False)
#     275     # Retrieve new state, reward, and whether the state is terminal
#     276     next_state, reward, done, _ = self.env.step(action)
#
# File ~\Development\GIT\tmp\reinforcement-learning\src\agents\actor_critic\a2c.py:240, in A2CAgent.act(self, state, deterministic)
#     239 def act(self,state,deterministic=True):
# --> 240     action, action_onehot, prediction = self.actor.act(state,deterministic=deterministic)
#     241     return action, action_onehot, prediction
#
# File ~\Development\GIT\tmp\reinforcement-learning\src\agents\actor_critic\a2c.py:92, in ActorNetwork.act(self, state, deterministic)
#      90 state = np.expand_dims(state, axis=0)
#      91 if self.action_space_mode == "discrete":
# ---> 92     prediction = self.model.predict(state)[0]
#      93     if deterministic:
#      94         action = np.argmax(prediction)
#
# File ~\anaconda3\envs\ai_4\lib\site-packages\keras\engine\training_v1.py:970, in Model.predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#     967 self._check_call_args('predict')
#     969 func = self._select_training_loop(x)
# --> 970 return func.predict(
#     971     self,
#     972     x=x,
#     973     batch_size=batch_size,
#     974     verbose=verbose,
#     975     steps=steps,
#     976     callbacks=callbacks,
#     977     max_queue_size=max_queue_size,
#     978     workers=workers,
#     979     use_multiprocessing=use_multiprocessing)
#
# File ~\anaconda3\envs\ai_4\lib\site-packages\keras\engine\training_arrays_v1.py:700, in ArrayLikeTrainingLoop.predict(self, model, x, batch_size, verbose, steps, callbacks, **kwargs)
#     697 batch_size = model._validate_or_infer_batch_size(batch_size, steps, x)
#     698 x, _, _ = model._standardize_user_data(
#     699     x, check_steps=True, steps_name='steps', steps=steps)
# --> 700 return predict_loop(
#     701     model,
#     702     x,
#     703     batch_size=batch_size,
#     704     verbose=verbose,
#     705     steps=steps,
#     706     callbacks=callbacks)
#
# File ~\anaconda3\envs\ai_4\lib\site-packages\keras\engine\training_arrays_v1.py:377, in model_iteration(model, inputs, targets, sample_weights, batch_size, epochs, verbose, callbacks, val_inputs, val_targets, val_sample_weights, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq, mode, validation_in_fit, prepared_feed_values_from_dataset, steps_name, **kwargs)
#     374 callbacks._call_batch_hook(mode, 'begin', batch_index, batch_logs)
#     376 # Get outputs.
# --> 377 batch_outs = f(ins_batch)
#     378 if not isinstance(batch_outs, list):
#     379   batch_outs = [batch_outs]
#
# File ~\anaconda3\envs\ai_4\lib\site-packages\keras\backend.py:4275, in GraphExecutionFunction.__call__(self, inputs)
#    4269 if (self._callable_fn is None or feed_arrays != self._feed_arrays or
#    4270     symbol_vals != self._symbol_vals or
#    4271     feed_symbols != self._feed_symbols or self.fetches != self._fetches or
#    4272     session != self._session):
#    4273   self._make_callable(feed_arrays, feed_symbols, symbol_vals, session)
# -> 4275 fetched = self._callable_fn(*array_vals,
#    4276                             run_metadata=self.run_metadata)
#    4277 self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    4278 output_structure = tf.nest.pack_sequence_as(
#    4279     self._outputs_structure,
#    4280     fetched[:len(self.outputs)],
#    4281     expand_composites=True)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\client\session.py:1480, in BaseSession._Callable.__call__(self, *args, **kwargs)
#    1478 try:
#    1479   run_metadata_ptr = tf_session.TF_NewBuffer() if run_metadata else None
# -> 1480   ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1481                                          self._handle, args,
#    1482                                          run_metadata_ptr)
#    1483   if run_metadata:
#    1484     proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
# agent.env.df_norm.columns

# %%
# agent.env.df.describe().T

# %%
# agent.env.df.describe().T

# %%
# close_30_sma= agent.env.df.close_30_sma/agent.env.df.close

# %%
# close_30_sma.max()

# %%
# import pandas as pd
# pd.read_csv('src/environments/continuous/stock_trading/datasets/466050e5494591d46c7d5ae81f468b29/raw_dataframe.csv').close_30_sma.describe().T

# %%
# import pandas as pd
# pd.read_csv('src/environments/continuous/stock_trading/datasets/466050e5494591d46c7d5ae81f468b29/norm_dataframe.csv').close_30_sma.describe().T

# %%
# close_30 = pd.read_csv('src/environments/continuous/stock_trading/datasets/466050e5494591d46c7d5ae81f468b29/raw_dataframe.csv').close_30_sma
# close = pd.read_csv('src/environments/continuous/stock_trading/datasets/466050e5494591d46c7d5ae81f468b29/raw_dataframe.csv').close

# %%
# norm = close_30/close
# norm.describe()

# %% [markdown]
# ### Test the results
# * Runs a set of episodes with **unseen data**
# * Stores the results in a csv file for later consulting

# %%
success = 0
n_tests = 10000

scores = []
targets = []
portfolio_target_ratios = []
initial_investments = []

for i in trange(n_tests):
    state = agent.env.reset(visualize=False,mode="test")
    step = 0
    score = 0
    reward = 0
    done = False
    
    targets.append((agent.env.episode_target-agent.env.initial_investment)/agent.env.initial_investment)
    initial_investments.append(agent.env.initial_investment)

    while not done:
        agent.env.render()
        
        # Select action
        action, action_onehot, prediction = agent.choose_action(state)
        
        # Retrieve new state, reward, and whether the state is terminal
        next_state, reward, done, info = agent.env.step(action)
        
        # End of episode, track scores here
        if done :
            if agent.env.portfolio_value > agent.env.initial_investment:
                success +=1

        step+=1
        state = next_state
        score += reward
    
    # Track scores and ratios
    scores.append(score)
    portfolio_target_ratios.append(info["portfolio_value"]/info["episode_target"] -1)
    
    
test_results_dataframe = pd.DataFrame([[
    n_tests,
    str(round(np.mean(scores)*100,3))+'%',
    str(round(np.mean(targets)*100,3))+'%',
    str(round(np.mean(portfolio_target_ratios)*100,3))+'%',
    str(round(min(scores)*100,3))+'%',
    str(round(max(scores)*100,3))+'%',
    str(round((success/n_tests)*100,3)) +'%'
]],
    columns=[
        '# Blind tests',
        '% Average portfolio return', 
        '% Desired portfolio return', 
        'Portfolio/Target rate',
        '% Historical minimum return',
        '% Historical maximum return', 
        '% Episodes concluded with positive outcome'
    ]
)


agent.results_writer.store_test_results(agent,test_results_dataframe)

test_results_dataframe.T

# %% [markdown]
# ### Visual test
# * Runs a set of episodes with **unseen data**
# * See the evolution in real time

# %%
success = 0
n_tests = 10

scores = []
targets = []


for i in trange(n_tests):
    state = agent.env.reset(visualize=True,mode="test")
    step = 0
    score = 0
    reward = 0
    done = False
    targets.append((agent.env.episode_target-agent.env.initial_investment)/agent.env.initial_investment)
    initial_portfolio = agent.env.portfolio_value

    while not done:
        agent.env.render()
        
        # Select desired action
        action, action_onehot, prediction = agent.choose_action(state)

        # Retrieve new state, reward, and whether the state is terminal
        next_state, reward, done, _ = agent.env.step(action)

        # Update current state
        if done :
            if agent.env.portfolio_value > agent.env.initial_investment:
                success +=1

        step+=1
        state = next_state
        score += reward
    
    scores.append(score)

agent.env.close()

# %% [markdown]
# ### Transactions profit
# * Track how much the agent gained by doing purchases and sales
# * Doesn't track the portfolio value
# * Already has the fees discounted

# %%
success = 0
n_tests = 10000

test_results_data = []
test_results_columns = [
    'dataset id',
    'episode start date', 
    'episode end date',
    'episode working days',
    'total transactions',
    'total transaction profit',
    "dataframe hash",
    "agent hash"
]

print('NOTE: This test only tracks the transactions profit. ')

for i in trange(n_tests):
    trading_history = []
    state = agent.env.reset(visualize=False,mode="test")
    step = 0
    score = 0
    reward = 0
    done = False
    #targets.append((agent.env.episode_target-agent.env.initial_investment)/agent.env.initial_investment)
    #initial_portfolio = agent.env.portfolio_value
    
    j = 0
    num_stocks = 0
    while not done:
        agent.env.render()
        
        # Select desired action
        action, action_onehot, prediction = agent.choose_action(state)
        current_price = agent.env.df.iloc[agent.env.current_step -1]['close']
        
        if action == agent.env.ACTIONS.BUY:
            discounted_price = current_price * (1+agent.env.fees.BUY) 
            if agent.env.stock_held < agent.env.maximum_stocks_held and agent.env.cash_in_hand >= discounted_price:
                num_stocks +=1
                trading_history.append(['buy', discounted_price])
        elif action == agent.env.ACTIONS.SELL:
            if agent.env.stock_held > 0:
                discounted_price = current_price * (1-agent.env.fees.SELL) 
                trading_history.append(['sell', discounted_price])
                num_stocks =0
                
        # Retrieve new state, reward, and whether the state is terminal
        next_state, reward, done, _ = agent.env.step(action)

        # Update current state
        if done :
            if agent.env.portfolio_value > agent.env.initial_investment:
                success +=1
                
            profits = []
            purchases = []
            for e in trading_history:
                if e[0] == 'buy':
                    purchases.append(e[1])
                else:
                    profits.append((e[1]* len(purchases) - sum(purchases)) / sum(purchases))
                    purchases.clear() 
                    
            test_results_data.append([
                agent.env.dataset_idx,
                agent.env.df.iloc[agent.env.lookback].name,
                agent.env.df.iloc[-1].name,
                agent.env.window_size,
                len(profits),
                sum(profits)*100,
                agent.env.df_name,
                agent.hash
            ])


        step+=1
        state = next_state
        score += reward
    

agent.env.close()


pd.DataFrame(test_results_data,columns=test_results_columns)

# %%
transaction_results_df = pd.DataFrame(test_results_data,columns=test_results_columns)

# %%
transaction_results_df.sort_values(by="dataset id")

# %%
transaction_results_df[transaction_results_df['total transaction profit'] <= 0]

# %%
failed_episodes_df = transaction_results_df[transaction_results_df['total transaction profit'] <= 0]
failed_episodes_idx = failed_episodes_df['dataset id'].unique()
failed_episodes_idx.sort()

# %%
len(transaction_results_df[transaction_results_df['total transaction profit'] <= 0]['dataset id'].unique()),len(transaction_results_df[transaction_results_df['total transaction profit'] > 0]['dataset id'].unique())

# %%
import matplotlib.pyplot as plt 

for idx in failed_episodes_idx:
    plt.figure(figsize=(16,4))
    plt.plot(agent.env.df['close'])
    plt.title('#'+str(idx)+' - ' + str(len(failed_episodes_df[failed_episodes_df['dataset id'] == idx])) +'/' + str(len(transaction_results_df[transaction_results_df['dataset id'] == idx])))

# %%
import time
n=10000
time_format = time.strftime("%H:%M:%S", time.gmtime(n))
print("Time in preferred format :-",time_format)
# Out:
# Time in preferred format :- 02:46:40

# %%
0>float(-np.inf)
# Out:
# True

# %%
a = time.time()

# %%
b = time.time()

# %%
a
# Out:
# 1660112281.3073773

# %%
b
# Out:
# 1660112288.4904172

# %%
b-a
# Out:
# 7.183039903640747

# %%
time.strftime("%H:%M:%S", time.gmtime(b-a))
# Out:
# '00:00:07'

# %%
import os
directory = agent.writer_log_directory+'/plots'
number_of_files = len(os.listdir(directory))
print(number_of_files)
# Out:
# 2

# %%
agent.writer_log_directory
# Out:
# 'storage/environments/MsftStockTradingEnvironment-v0/5561205d123bbaecd2b98785760fa4f7'
