# %%
import shutup
shutup.please()

import gym
import src.environments.continuous.stock_trading  

import numpy as np
import pandas as pd

# %%
env = gym.make('StockTradingEnvironment-v0', use_technical_indicators= [
    "macd",
    "boll_ub",
    "boll_lb",
    "rsi_30",
    "cci_30",
    "dx_30",
    "close_30_sma",
    "close_60_sma",
])

# %%
pd.read_csv('src/environments/continuous/stock_trading/datasets/67b906a1ca1d5e7e03dd20f0c89fd03c/targets.csv').targets.iloc[0]
# Out:
# 6.936458988189692

# %%
env.train_dataframe_id_range,env.test_dataframe_id_range
# Out:
# ([0, 315], [316, 395])

# %%
env.load_dataset_by_index(0)
env.df
# Out:
#                  open       high        low      close     volume  day  \
# date
# 2018-01-08  43.587502  43.902500  43.482498  41.573772   82271200    0
# 2018-01-09  43.637501  43.764999  43.352501  41.569000   86336000    1
# 2018-01-11  43.647499  43.872501  43.622501  41.795528   74670800    3
# 2018-01-12  44.044998  44.340000  43.912498  42.227123  101672400    4
# 2018-01-16  44.474998  44.847500  44.035000  42.012512  118263600    1
# ...               ...        ...        ...        ...        ...  ...
# 2018-04-30  40.532501  41.814999  40.459999  39.566917  169709600    0
# 2018-05-01  41.602501  42.299999  41.317501  40.486298  214277600    1
# 2018-05-02  43.807499  44.437500  43.450001  42.274780  266157600    2
# 2018-05-03  43.970001  44.375000  43.610001  42.351402  136272800    3
# 2018-05-04  44.562500  46.062500  44.542500  44.012989  224805200    4
#
#                vix  turbulence      macd    boll_ub  ...  neg_title  \
# date                                                 ...
# 2018-01-08  0.0952    0.061082 -0.003477  41.870444  ...   0.000000
# 2018-01-09  0.1008    0.060920 -0.004579  41.805620  ...   0.000000
# 2018-01-11  0.0988    0.061166  0.003795  41.864027  ...   0.244000
# 2018-01-12  0.1016    0.071771  0.027654  42.256032  ...   0.000000
# 2018-01-16  0.1166    0.177656  0.032756  42.292433  ...   0.000000
# ...            ...         ...       ...        ...  ...        ...
# 2018-04-30  0.1593    0.219233 -0.531165  43.128501  ...   0.000000
# 2018-05-01  0.1549    0.087350 -0.454444  43.132534  ...   0.000000
# 2018-05-02  0.1597    0.129608 -0.246744  43.287283  ...   0.040364
# 2018-05-03  0.1590    0.045915 -0.075106  43.422290  ...   0.080706
# 2018-05-04  0.1477    0.068189  0.192563  43.958449  ...   0.092333
#
#             neu_title  pos_title  compound_title  neg_body  neu_body  \
# date
# 2018-01-08   1.000000   0.000000        0.000000  0.008000  0.934000
# 2018-01-09   0.946800   0.053200        0.088080  0.026400  0.919000
# 2018-01-11   0.756000   0.000000       -0.296525  0.041000  0.863750
# 2018-01-12   1.000000   0.000000        0.000000  0.126000  0.874000
# 2018-01-16   0.931667   0.068333        0.067433  0.030000  0.849333
# ...               ...        ...             ...       ...       ...
# 2018-04-30   1.000000   0.000000        0.000000  0.022500  0.877500
# 2018-05-01   1.000000   0.000000        0.000000  0.000000  0.962000
# 2018-05-02   0.826455   0.133182        0.110127  0.063545  0.853364
# 2018-05-03   0.836706   0.082588        0.003965  0.077765  0.838176
# 2018-05-04   0.907667   0.000000       -0.116867  0.066333  0.829000
#
#             pos_body  compound_body      aapl  fear greed
# date
# 2018-01-08  0.058000       0.963700  0.395833        0.75
# 2018-01-09  0.055000       0.684980  0.397083        0.75
# 2018-01-11  0.095250       0.636025  0.379167        0.77
# 2018-01-12  0.000000      -0.893400  0.371667        0.79
# 2018-01-16  0.120667       0.729800  0.378333        0.75
# ...              ...            ...       ...         ...
# 2018-04-30  0.100500       0.939450  0.418333        0.42
# 2018-05-01  0.038000       0.381800  0.450417        0.38
# 2018-05-02  0.083091       0.339791  0.431250        0.39
# 2018-05-03  0.084235       0.158376  0.411667        0.32
# 2018-05-04  0.104333      -0.184567  0.415833        0.40
#
# [76 rows x 26 columns]

# %%
env.success_threshold
# Out:
# 0.019395275953202087

# %%
import pandas as pd
episode_targets = []
for i in range(env.n_dataframes):
    env.load_dataset_by_index(i)
    raw_slice = env.df 
    episode_targets.append([
                    env.get_episode_target(raw_slice),
                    raw_slice.iloc[env.lookback-1].open,
                    raw_slice.iloc[env.lookback-1].low,
                    raw_slice.iloc[env.lookback-1].high,
                    raw_slice.iloc[env.lookback-1].close,
                    raw_slice.iloc[env.lookback-1].volume,
                ])




pd.DataFrame(episode_targets,columns=['targets','open','low','high','close','volume']).to_csv(env.df_path+'/targets.csv', index=False)

# %%
episode_columns = ['targets','close','open','high','low','volume']

#pd.DataFrame([[1,2],[1,2]],columns=['a','b'])
#np.array(episode_targets).shape ,=['targets','close','open','high','low','volume']).
pd.DataFrame(episode_targets,columns=episode_columns)
# Out:
#        targets      close       open       high        low       volume
# 0     6.936459  44.325001  44.205002  44.860001  42.215191  130756400.0
# 1     7.254576  44.312500  43.299999  44.325001  41.542770  204420400.0
# 2     7.467441  43.627499  42.632500  43.737499  40.801189  166116000.0
# 3     7.780771  42.540001  41.767502  42.540001  40.050072  202561600.0
# 4     8.421785  41.382500  41.174999  41.842499  39.814007  184192800.0
# ..         ...        ...        ...        ...        ...          ...
# 390  19.266792  54.432499  54.389999  55.032501  53.860348   84632400.0
# 391  19.333063  54.990002  54.779999  55.205002  54.056297   73274800.0
# 392  19.861558  55.264999  54.860001  55.712502  54.563301  101360000.0
# 393  18.858794  55.502499  55.092499  55.939999  54.119972   88242400.0
# 394  19.035732  55.345001  54.367500  55.639999  53.328846  221652400.0
#
# [395 rows x 6 columns]

# %%
state = env.reset()

# %%
state
# Out:
# array([[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          1.00000000e+00,  1.00000000e+00,  0.00000000e+00,
#          1.00000000e+00,  3.04355512e-02,  3.73061101e-02,
#          2.37007706e-02,  3.84526284e-02,  1.12959500e-01,
#          5.00000000e-01,  1.84899998e-01,  1.47049882e-01,
#         -1.69386843e+03,  1.40796758e+03,  1.02934054e+03,
#          3.99145129e-01, -4.17636697e-01,  4.16148277e-01,
#          1.26752228e+03,  1.33156021e+03,  5.80000000e-02,
#          8.40333333e-01,  1.01666667e-01,  7.33166667e-02,
#          3.25000000e-02,  8.85333333e-01,  8.21666667e-02,
#          9.35883333e-01,  4.05416667e-01,  2.10000000e-01],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          1.00000000e+00,  1.00000000e+00,  0.00000000e+00,
#          1.00000000e+00, -1.56681066e-02, -1.02882354e-03,
#          3.64155055e-03, -2.17599668e-03, -8.02493416e-02,
#          2.50000000e-01,  1.90200005e-01,  4.16769199e-02,
#         -5.55054098e+05, -2.51136393e+04, -1.83083761e+04,
#          3.61759125e-01, -5.64988600e-01,  6.09905443e-01,
#         -2.25486557e+04, -2.36167967e+04,  1.88571429e-01,
#          6.96285714e-01,  1.15285714e-01, -1.22800000e-01,
#          7.78571429e-02,  8.39428571e-01,  8.24285714e-02,
#          3.09185714e-01,  4.50000000e-01,  1.90000000e-01],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          1.00000000e+00,  1.00000000e+00,  0.00000000e+00,
#          1.00000000e+00, -4.00135440e-03, -9.34319988e-03,
#         -1.06915255e-02,  1.35235443e-02,  9.04779038e-01,
#          0.00000000e+00,  1.88999996e-01,  5.32746120e-02,
#         -1.41212371e+04,  4.05908573e+03,  2.99439171e+03,
#          3.62997345e-01, -6.28216951e-01,  6.09905443e-01,
#          3.65344907e+03,  3.81573380e+03,  0.00000000e+00,
#          1.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          4.50000000e-02,  8.87000000e-01,  6.75000000e-02,
#          3.96700000e-01,  5.03333333e-01,  1.70000000e-01],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          1.00000000e+00,  1.00000000e+00,  0.00000000e+00,
#          1.00000000e+00, -2.66510510e-02, -2.03583407e-02,
#         -2.52053065e-02, -2.53986544e-02, -2.40976475e-01,
#          1.00000000e+00,  2.15200005e-01,  4.70657573e-02,
#         -3.86953189e+03, -2.17236696e+03, -1.62226688e+03,
#          3.49805768e-01, -6.94828788e-01,  5.96262943e-01,
#         -1.96012286e+03, -2.03957397e+03,  2.68000000e-01,
#          7.32000000e-01,  0.00000000e+00, -2.96000000e-01,
#          0.00000000e+00,  9.52000000e-01,  4.80000000e-02,
#          2.50000000e-01,  6.13750000e-01,  9.00000000e-02],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          1.00000000e+00,  1.00000000e+00,  0.00000000e+00,
#          1.00000000e+00,  7.62460418e-03, -6.61264639e-03,
#          5.92563716e-03, -1.13004111e-03, -5.41111563e-01,
#          5.00000000e-01,  2.07999992e-01,  6.37330826e-02,
#         -1.79501990e+06, -4.89800464e+04, -3.73088321e+04,
#          3.63841586e-01, -6.98975379e-01,  5.61573586e-01,
#         -4.43511297e+04, -4.60193716e+04,  0.00000000e+00,
#          1.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          3.50000000e-03,  9.79500000e-01,  1.70000000e-02,
#          4.29550000e-01,  4.57083333e-01,  1.30000000e-01],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          1.00000000e+00,  1.00000000e+00,  0.00000000e+00,
#          1.00000000e+00, -6.12105520e-02, -4.84006076e-02,
#         -5.12460712e-02, -4.77780914e-02,  6.17763021e-01,
#          2.50000000e-01,  2.24799995e-01,  1.13983810e-01,
#         -9.23969009e+02, -1.15756321e+03, -9.02357829e+02,
#          3.64471274e-01, -7.94357109e-01,  5.61573586e-01,
#         -1.05554340e+03, -1.09200328e+03,  0.00000000e+00,
#          9.35400000e-01,  6.46000000e-02,  7.51800000e-02,
#          3.84000000e-02,  8.52400000e-01,  1.09200000e-01,
#          8.36060000e-01,  4.13750000e-01,  7.00000000e-02],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          1.00000000e+00,  1.00000000e+00,  0.00000000e+00,
#          1.00000000e+00, -2.62467192e-03, -2.19008270e-02,
#         -2.35933762e-02, -3.96320825e-02,  1.35316275e-01,
#          0.00000000e+00,  2.01000004e-01,  1.25616634e-01,
#         -1.17769569e+03, -1.39733950e+03, -1.11344551e+03,
#          3.93717578e-01, -6.48337466e-01,  4.77949388e-01,
#         -1.28249584e+03, -1.32054635e+03,  0.00000000e+00,
#          7.00000000e-01,  3.00000000e-01,  4.58800000e-01,
#          0.00000000e+00,  9.10000000e-01,  9.00000000e-02,
#          9.42300000e-01,  3.94166667e-01,  8.00000000e-02],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          1.00000000e+00,  1.00000000e+00,  0.00000000e+00,
#          1.00000000e+00,  1.12001731e-02,  1.56274417e-02,
#          1.36972333e-02,  1.10756177e-02, -2.05480778e-01,
#          1.00000000e+00,  1.81399994e-01,  7.93841138e-02,
#         -1.39454087e+04,  5.01281668e+03,  4.04591883e+03,
#          4.21990281e-01, -5.70296400e-01,  4.29992507e-01,
#          4.61622550e+03,  4.73609658e+03,  0.00000000e+00,
#          8.81500000e-01,  1.18500000e-01,  2.10750000e-01,
#          3.35000000e-02,  8.65500000e-01,  1.01000000e-01,
#          9.27950000e-01,  4.47916667e-01,  1.00000000e-01],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          1.00000000e+00,  1.00000000e+00,  0.00000000e+00,
#          1.00000000e+00, -2.84166822e-02, -1.29061835e-02,
#          5.21702393e-03,  2.46788601e-02, -2.35558626e-01,
#          7.50000000e-01,  1.99799995e-01,  1.51930078e-01,
#         -2.78667876e+03,  2.25758874e+03,  1.83241329e+03,
#          4.10683333e-01, -7.21384816e-01,  5.17515331e-01,
#          2.08151503e+03,  2.12897821e+03,  5.88333333e-02,
#          8.68666667e-01,  7.25000000e-02,  6.07833333e-02,
#          3.66666667e-02,  8.58833333e-01,  1.04666667e-01,
#          9.80100000e-01,  4.35416667e-01,  1.00000000e-01],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          1.00000000e+00,  1.00000000e+00,  0.00000000e+00,
#          1.00000000e+00,  1.18456868e-02, -1.36930574e-02,
#         -2.88326161e-02, -2.82475240e-02,  2.96869434e-01,
#          5.00000000e-01,  2.12500000e-01,  6.11255262e-02,
#         -2.00910384e+03, -1.97074710e+03, -1.62298535e+03,
#          3.85411253e-01, -8.51142379e-01,  5.17515331e-01,
#         -1.82876693e+03, -1.86328186e+03,  0.00000000e+00,
#          8.63000000e-01,  1.37000000e-01,  2.33733333e-01,
#          2.86666667e-02,  8.65333333e-01,  1.06333333e-01,
#          5.66900000e-01,  4.40416667e-01,  7.00000000e-02]])

# %%
next_state = env.step([1])
next_state
# Out:
# (array([[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           1.00000000e+00,  1.00000000e+00,  0.00000000e+00,
#           1.00000000e+00, -1.56681066e-02, -1.02882354e-03,
#           3.64155055e-03, -2.17599668e-03, -8.02493416e-02,
#           2.50000000e-01,  1.90200005e-01,  4.16769199e-02,
#          -5.55054098e+05, -2.51136393e+04, -1.83083761e+04,
#           3.61759125e-01, -5.64988600e-01,  6.09905443e-01,
#          -2.25486557e+04, -2.36167967e+04,  1.88571429e-01,
#           6.96285714e-01,  1.15285714e-01, -1.22800000e-01,
#           7.78571429e-02,  8.39428571e-01,  8.24285714e-02,
#           3.09185714e-01,  4.50000000e-01,  1.90000000e-01],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           1.00000000e+00,  1.00000000e+00,  0.00000000e+00,
#           1.00000000e+00, -4.00135440e-03, -9.34319988e-03,
#          -1.06915255e-02,  1.35235443e-02,  9.04779038e-01,
#           0.00000000e+00,  1.88999996e-01,  5.32746120e-02,
#          -1.41212371e+04,  4.05908573e+03,  2.99439171e+03,
#           3.62997345e-01, -6.28216951e-01,  6.09905443e-01,
#           3.65344907e+03,  3.81573380e+03,  0.00000000e+00,
#           1.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           4.50000000e-02,  8.87000000e-01,  6.75000000e-02,
#           3.96700000e-01,  5.03333333e-01,  1.70000000e-01],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           1.00000000e+00,  1.00000000e+00,  0.00000000e+00,
#           1.00000000e+00, -2.66510510e-02, -2.03583407e-02,
#          -2.52053065e-02, -2.53986544e-02, -2.40976475e-01,
#           1.00000000e+00,  2.15200005e-01,  4.70657573e-02,
#          -3.86953189e+03, -2.17236696e+03, -1.62226688e+03,
#           3.49805768e-01, -6.94828788e-01,  5.96262943e-01,
#          -1.96012286e+03, -2.03957397e+03,  2.68000000e-01,
#           7.32000000e-01,  0.00000000e+00, -2.96000000e-01,
#           0.00000000e+00,  9.52000000e-01,  4.80000000e-02,
#           2.50000000e-01,  6.13750000e-01,  9.00000000e-02],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           1.00000000e+00,  1.00000000e+00,  0.00000000e+00,
#           1.00000000e+00,  7.62460418e-03, -6.61264639e-03,
#           5.92563716e-03, -1.13004111e-03, -5.41111563e-01,
#           5.00000000e-01,  2.07999992e-01,  6.37330826e-02,
#          -1.79501990e+06, -4.89800464e+04, -3.73088321e+04,
#           3.63841586e-01, -6.98975379e-01,  5.61573586e-01,
#          -4.43511297e+04, -4.60193716e+04,  0.00000000e+00,
#           1.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           3.50000000e-03,  9.79500000e-01,  1.70000000e-02,
#           4.29550000e-01,  4.57083333e-01,  1.30000000e-01],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           1.00000000e+00,  1.00000000e+00,  0.00000000e+00,
#           1.00000000e+00, -6.12105520e-02, -4.84006076e-02,
#          -5.12460712e-02, -4.77780914e-02,  6.17763021e-01,
#           2.50000000e-01,  2.24799995e-01,  1.13983810e-01,
#          -9.23969009e+02, -1.15756321e+03, -9.02357829e+02,
#           3.64471274e-01, -7.94357109e-01,  5.61573586e-01,
#          -1.05554340e+03, -1.09200328e+03,  0.00000000e+00,
#           9.35400000e-01,  6.46000000e-02,  7.51800000e-02,
#           3.84000000e-02,  8.52400000e-01,  1.09200000e-01,
#           8.36060000e-01,  4.13750000e-01,  7.00000000e-02],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           1.00000000e+00,  1.00000000e+00,  0.00000000e+00,
#           1.00000000e+00, -2.62467192e-03, -2.19008270e-02,
#          -2.35933762e-02, -3.96320825e-02,  1.35316275e-01,
#           0.00000000e+00,  2.01000004e-01,  1.25616634e-01,
#          -1.17769569e+03, -1.39733950e+03, -1.11344551e+03,
#           3.93717578e-01, -6.48337466e-01,  4.77949388e-01,
#          -1.28249584e+03, -1.32054635e+03,  0.00000000e+00,
#           7.00000000e-01,  3.00000000e-01,  4.58800000e-01,
#           0.00000000e+00,  9.10000000e-01,  9.00000000e-02,
#           9.42300000e-01,  3.94166667e-01,  8.00000000e-02],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           1.00000000e+00,  1.00000000e+00,  0.00000000e+00,
#           1.00000000e+00,  1.12001731e-02,  1.56274417e-02,
#           1.36972333e-02,  1.10756177e-02, -2.05480778e-01,
#           1.00000000e+00,  1.81399994e-01,  7.93841138e-02,
#          -1.39454087e+04,  5.01281668e+03,  4.04591883e+03,
#           4.21990281e-01, -5.70296400e-01,  4.29992507e-01,
#           4.61622550e+03,  4.73609658e+03,  0.00000000e+00,
#           8.81500000e-01,  1.18500000e-01,  2.10750000e-01,
#           3.35000000e-02,  8.65500000e-01,  1.01000000e-01,
#           9.27950000e-01,  4.47916667e-01,  1.00000000e-01],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           1.00000000e+00,  1.00000000e+00,  0.00000000e+00,
#           1.00000000e+00, -2.84166822e-02, -1.29061835e-02,
#           5.21702393e-03,  2.46788601e-02, -2.35558626e-01,
#           7.50000000e-01,  1.99799995e-01,  1.51930078e-01,
#          -2.78667876e+03,  2.25758874e+03,  1.83241329e+03,
#           4.10683333e-01, -7.21384816e-01,  5.17515331e-01,
#           2.08151503e+03,  2.12897821e+03,  5.88333333e-02,
#           8.68666667e-01,  7.25000000e-02,  6.07833333e-02,
#           3.66666667e-02,  8.58833333e-01,  1.04666667e-01,
#           9.80100000e-01,  4.35416667e-01,  1.00000000e-01],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           1.00000000e+00,  1.00000000e+00,  0.00000000e+00,
#           1.00000000e+00,  1.18456868e-02, -1.36930574e-02,
#          -2.88326161e-02, -2.82475240e-02,  2.96869434e-01,
#           5.00000000e-01,  2.12500000e-01,  6.11255262e-02,
#          -2.00910384e+03, -1.97074710e+03, -1.62298535e+03,
#           3.85411253e-01, -8.51142379e-01,  5.17515331e-01,
#          -1.82876693e+03, -1.86328186e+03,  0.00000000e+00,
#           8.63000000e-01,  1.37000000e-01,  2.33733333e-01,
#           2.86666667e-02,  8.65333333e-01,  1.06333333e-01,
#           5.66900000e-01,  4.40416667e-01,  7.00000000e-02],
#         [ 1.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           1.00000000e+00,  1.00000000e+00,  0.00000000e+00,
#           1.00000000e+00,  3.04355512e-02,  3.73061101e-02,
#           2.37007706e-02,  3.84526284e-02,  1.12959500e-01,
#           5.00000000e-01,  1.84899998e-01,  1.47049882e-01,
#          -1.69386843e+03,  1.40796758e+03,  1.02934054e+03,
#           3.99145129e-01, -4.17636697e-01,  4.16148277e-01,
#           1.26752228e+03,  1.33156021e+03,  5.80000000e-02,
#           8.40333333e-01,  1.01666667e-01,  7.33166667e-02,
#           3.25000000e-02,  8.85333333e-01,  8.21666667e-02,
#           9.35883333e-01,  4.05416667e-01,  2.10000000e-01]]),
#  0.0,
#  False,
#  {})

# %%
next_state[0][0] == state[1]
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True])

# %%
# env.reset()
# for i in range(100):
#     next_state, reward, done, _ = env.step(0)
#     print(i, reward,done)#,next_state[-1])
#     if done:
#         break

# %%
len(env.df),env.window_size, env.lookback, env.window_size+ env.lookback
# Out:
# (76, 66, 10, 76)

# %%
# prices = [5,2,1,7,0,6,3]

# """
# # mins = min de inicio até i inclusive 
#     0 - 5
#     1 - 2
#     2 - 2
#     3 - 2
# # maxs = max de i até fim inclusive
#     0 - 6
#     1 - 6
#     2 - 6
#     3 - 3
# """

# mins = [] #[5,2,2,2]
# maxs = [] #[6,6,6,3]

# ### MINS
# # i = 0 -> prices [0 -> 1] [0:1]
# # mins.append(min(prices[0:1]))
# ### MAXS
# # i = 0 -> prices[0:]
# # i = 1 -> prices[1:]
# # prices[3:]

# for i in range(len(prices)):
#     mins.append(min(prices[0:i+1]))
#     maxs.append(max(prices[i:]))
    
# #mins,maxs
# global_max_single_trade_profit = 0
# for i in range(len(prices)):
#     _min = mins[i]
#     _max = maxs[i]
    
#     print('At {} could have bought at {} and sold at {} so it had {} profit'.format(
#         i,
#         _min,
#         _max,
#         _max-_min
#     ))
#     local_max_single_trade_profit = _max-_min
#     if local_max_single_trade_profit > global_max_single_trade_profit:
#         global_max_single_trade_profit = local_max_single_trade_profit

# print()
# print('Best case scenario would have a profit of {}'.format(global_max_single_trade_profit))

# %%
# for i in range(len(prices)):
#     mins.append(min(prices[0:i+1]))
#     maxs.append(max(prices[i:]))
    
# #mins,maxs
# global_max_single_trade_profit = 0
# for i in range(len(prices)):
#     _min = mins[i]
#     _max = maxs[i]
    
#     print('At {} could have bought at {} and sold at {} so it had {} profit'.format(
#         i,
#         _min,
#         _max,
#         _max-_min
#     ))
#     local_max_single_trade_profit = _max-_min
#     if local_max_single_trade_profit > global_max_single_trade_profit:
#         global_max_single_trade_profit = local_max_single_trade_profit

# print()
# print('Best case scenario would have a profit of {}'.format(global_max_single_trade_profit))

# %%
# prices = env.df.close.values

# mins = [] 
# maxs = [] 

# for i in range(len(prices)):
#     mins.append(min(prices[0:i+1]))
#     maxs.append(max(prices[i:]))
# #     
# #mins,maxs
# global_max_single_trade_profit = 0
# for i in range(len(prices)):
#     _min = mins[i]
#     _max = maxs[i]
    
#     print('At {} could have bought at {} and sold at {} so it had {} profit'.format(
#         i,
#         _min,
#         _max,
#         _max-_min
#     ))
#     local_max_single_trade_profit = _max-_min
#     if local_max_single_trade_profit > global_max_single_trade_profit:
#         global_max_single_trade_profit = local_max_single_trade_profit

# print()
# print('Best case scenario would have a profit of {}'.format(global_max_single_trade_profit))

# %%
#prices * (0.5)
#env.fees['BUY']

# %%
# env.n_dataframes

# %%
# targets = []
# for i in range(env.n_dataframes):
#     env.load_dataset_by_index(i)
#     target = env.calculate_episode_target(env.df)
#     targets.append(target)
    
# targets

# %%
# import pandas as pd
# pd.DataFrame(targets,columns=['targets']).to_csv(env.df_path+'/targets.csv', index=False)

# %%
#pd.read_csv(env.df_path+'/targets.csv')

# %%
from src.agents.actor_critic.a2c import A2CAgent

# %%
def environment():
    env = gym.make('StockTradingEnvironment-v0',
                   use_technical_indicators= [
    "macd",
    "boll_ub",
    "boll_lb",
    "rsi_30",
    "cci_30",
    "dx_30",
    "close_30_sma",
    "close_60_sma",
    ])
    
    
    return env

# %%
agent=A2CAgent(environment,batch_size=5000, epochs=1, actor_learning_rate=0.00003,critic_learning_rate=0.00005)
environment().success_threshold
# Out:
# 0.019395275953202087

# %%
agent.learning_log.episodes
# Out:
# 0

# %%
agent.env.mode = "train"
agent.learning_log.episodes = 0
agent.learn(timesteps=-1, log_every=100,success_threshold_lookback=600)

# %%
agent.env.mode = "test"
scores = []
success = 0

for i in range(100):
    state = agent.env.reset()
    score = 0
    reward = 0
    done = False
    initial_portfolio = agent.env.portfolio_value
    step = 0
    while not done:
                
        #state = np.expand_dims(state, axis=0)
        action, action_onehot, prediction = agent.act(state)
        # Retrieve new state, reward, and whether the state is terminal
        next_state, reward, done, _ = agent.env.step(action)
        #print(action, reward, agent.env.portfolio_value)
        # Memorize (state, action, reward) for training
        #self.buffer.remember(np.expand_dims(state, axis=0), action_onehot, reward)
        # Update current state
        if done :
            if step < 65:
                success +=1
        step+=1
        state = next_state
        score += reward
    
    #print(score,initial_portfolio, agent.env.portfolio_value)
    scores.append(score)
    
print(np.mean(scores))
print(min(scores))
print(max(scores))
print(success)
