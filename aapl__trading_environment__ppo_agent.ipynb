# %%
import shutup
shutup.please()

import gym
import src.environments.continuous.stock_trading  

import numpy as np
import pandas as pd 

from tqdm.notebook import trange, tqdm

# %% [markdown]
# ### Train the agent
# * Run it until he has a running average above the success_threshold
# * Use a large number of episodes for the running average ( 1000+ ) so if even it falls into a privileged sample, it wont be prone to error

# %%
from src.agents.ppo import PpoAgent

# %%
def environment(describe=True):
    env = gym.make('StockTradingEnvironment-v0',
            use_technical_indicators= [
            "macd",
            "boll_ub",
            "boll_lb",
            "rsi_30",
            "cci_30",
            "dx_30",
            "close_30_sma",
            "close_60_sma",
        ])
    
    poc_threshold = 0.5 # 10% 
    print('* Original success threshold', env.success_threshold)
    
    print('* POC success threshold', poc_threshold)
    print()
    
    env.success_threshold = poc_threshold
    
    return env

# %%
agent=PpoAgent(
        environment,
        actor_learning_rate=0.000025,
        critic_learning_rate=0.000025,
        policy="CNN",
        epochs=10,
        n_workers=8)

agent.load()
    
agent.learn(
        timesteps=-1, 
        log_every=100,
        success_threshold_lookback=1000,
        success_strict=False,
    )
# Out:
# * Original success threshold 0.1374562110867307
# * POC success threshold 0.5
#
# @TODO Agent._load_agent_configuration()
#
# * Could not load the following models: ['ppo-actor', 'ppo-critic'] *
#
# * Booting worker 0
#
# * Original success threshold 0.1374562110867307
# * POC success threshold 0.5
#
# * Booting worker 1
#
# * Original success threshold 0.1374562110867307
# * POC success threshold 0.5
#
# * Booting worker 2
#
# * Original success threshold 0.1374562110867307
# * POC success threshold 0.5
#
# * Booting worker 3
#
# * Original success threshold 0.1374562110867307
# * POC success threshold 0.5
#
# * Booting worker 4
#
# * Original success threshold 0.1374562110867307
# * POC success threshold 0.5
#
# * Booting worker 5
#
# * Original success threshold 0.1374562110867307
# * POC success threshold 0.5
#
# * Booting worker 6
#
# * Original success threshold 0.1374562110867307
# * POC success threshold 0.5
#
# * Booting worker 7
#
# * Original success threshold 0.1374562110867307
# * POC success threshold 0.5
#
# Episode * 100 * Worker #3 * Moving Avg Reward is ==> -0.01064 * Last Reward was ==> 0.02817
# Episode * 200 * Worker #7 * Moving Avg Reward is ==> -0.00763 * Last Reward was ==> 0.02549
#
# * Will replay
# * Worker 0 finnished learning phase
# * Worker 1 finnished learning phase
# * Worker 2 finnished learning phase
# * Worker 3 finnished learning phase
# * Worker 4 finnished learning phase
# * Worker 5 finnished learning phase
# * Worker 6 finnished learning phase
# * Worker 7 finnished learning phase
# * Will resume
#
# Episode * 300 * Worker #3 * Moving Avg Reward is ==> -0.00694 * Last Reward was ==> -0.01448
# Episode * 400 * Worker #7 * Moving Avg Reward is ==> -0.00714 * Last Reward was ==> -0.02690
# Episode * 500 * Worker #3 * Moving Avg Reward is ==> -0.00583 * Last Reward was ==> -0.00090
#
# * Will replay
# * Worker 0 finnished learning phase
# * Worker 1 finnished learning phase
# * Worker 2 finnished learning phase
# * Worker 3 finnished learning phase
# * Worker 4 finnished learning phase
# * Worker 5 finnished learning phase
# * Worker 6 finnished learning phase
# * Worker 7 finnished learning phase
# * Will resume
#
# Episode * 600 * Worker #7 * Moving Avg Reward is ==> -0.00415 * Last Reward was ==> -0.03261
# Episode * 700 * Worker #3 * Moving Avg Reward is ==> -0.00325 * Last Reward was ==> 0.04218
#
# * Will replay
# * Worker 0 finnished learning phase
# * Worker 1 finnished learning phase
# * Worker 2 finnished learning phase
# * Worker 3 finnished learning phase
# * Worker 4 finnished learning phase
# * Worker 5 finnished learning phase
# * Worker 6 finnished learning phase
# * Worker 7 finnished learning phase
# * Will resume
#
# Episode * 800 * Worker #7 * Moving Avg Reward is ==> -0.00193 * Last Reward was ==> 0.02960
# Episode * 900 * Worker #3 * Moving Avg Reward is ==> 0.00037 * Last Reward was ==> 0.04501
# Episode * 1000 * Worker #7 * Moving Avg Reward is ==> 0.00242 * Last Reward was ==> 0.00815
# * Models saved *
#
# New historical moving average record: 0.00248
#
# * Models saved *
#
# New historical moving average record: 0.00251
#
#
# * Will replay
# * Worker 0 finnished learning phase
# * Worker 1 finnished learning phase
# * Worker 2 finnished learning phase
# * Worker 3 finnished learning phase
# * Worker 4 finnished learning phase
# * Worker 5 finnished learning phase
# * Worker 6 finnished learning phase
# * Worker 7 finnished learning phase
# * Will resume
#
# * Models saved *
#
# New historical moving average record: 0.00254
#
# * Models saved *
#
# New historical moving average record: 0.00255
#
# * Models saved *
#
# New historical moving average record: 0.00260
#
# * Models saved *
#
# New historical moving average record: 0.00270
#
# * Models saved *
#
# New historical moving average record: 0.00273
#
# * Models saved *
#
# New historical moving average record: 0.00275
#
# * Models saved *
#
# New historical moving average record: 0.00283
#
# * Models saved *
#
# New historical moving average record: 0.00287
#
# * Models saved *
#
# New historical moving average record: 0.00289
#
# * Models saved *
#
# New historical moving average record: 0.00296
#
# * Models saved *
#
# New historical moving average record: 0.00306
#
# * Models saved *
#
# New historical moving average record: 0.00310
#
# * Models saved *
#
# New historical moving average record: 0.00318
#
# * Models saved *
#
# New historical moving average record: 0.00321
#
# * Models saved *
#
# New historical moving average record: 0.00333
#
# * Models saved *
#
# New historical moving average record: 0.00341
#
# * Models saved *
#
# New historical moving average record: 0.00352
#
# * Models saved *
#
# New historical moving average record: 0.00365
#
# * Models saved *
#
# New historical moving average record: 0.00371
#
# * Models saved *
#
# New historical moving average record: 0.00374
#
# * Models saved *
#
# New historical moving average record: 0.00383
#
# * Models saved *
#
# New historical moving average record: 0.00389
#
# * Models saved *
#
# New historical moving average record: 0.00401
#
# * Models saved *
#
# New historical moving average record: 0.00405
#
# * Models saved *
#
# New historical moving average record: 0.00417
#
# * Models saved *
#
# New historical moving average record: 0.00430
#
# * Models saved *
#
# New historical moving average record: 0.00441
#
# * Models saved *
#
# New historical moving average record: 0.00444
#
# * Models saved *
#
# New historical moving average record: 0.00450
#
# * Models saved *
#
# New historical moving average record: 0.00451
#
# * Models saved *
#
# New historical moving average record: 0.00467
#
# * Models saved *
#
# New historical moving average record: 0.00470
#
# * Models saved *
#
# New historical moving average record: 0.00476
#
# * Models saved *
#
# New historical moving average record: 0.00483
#
# * Models saved *
#
# New historical moving average record: 0.00490
#
# * Models saved *
#
# New historical moving average record: 0.00494
#
# * Models saved *
#
# New historical moving average record: 0.00495
#
# * Models saved *
#
# New historical moving average record: 0.00503
#
# * Models saved *
#
# New historical moving average record: 0.00507
#
# * Models saved *
#
# New historical moving average record: 0.00513
#
# * Models saved *
#
# New historical moving average record: 0.00514
#
# * Models saved *
#
# New historical moving average record: 0.00516
#
# * Models saved *
#
# New historical moving average record: 0.00522
#
# * Models saved *
#
# New historical moving average record: 0.00530
#
# * Models saved *
#
# New historical moving average record: 0.00536
#
# * Models saved *
#
# New historical moving average record: 0.00537
#
# * Models saved *
#
# New historical moving average record: 0.00538
#
# * Models saved *
#
# New historical moving average record: 0.00545
#
# * Models saved *
#
# New historical moving average record: 0.00550
#
# * Models saved *
#
# New historical moving average record: 0.00555
#
# * Models saved *
#
# New historical moving average record: 0.00562
#
# * Models saved *
#
# New historical moving average record: 0.00563
#
# * Models saved *
#
# New historical moving average record: 0.00563
#
# * Models saved *
#
# New historical moving average record: 0.00571
#
# * Models saved *
#
# New historical moving average record: 0.00584
#
# * Models saved *
#
# New historical moving average record: 0.00597
#
# * Models saved *
#
# New historical moving average record: 0.00602
#
# * Models saved *
#
# New historical moving average record: 0.00625
#
# * Models saved *
#
# New historical moving average record: 0.00633
#
# * Models saved *
#
# New historical moving average record: 0.00637
#
# * Models saved *
#
# New historical moving average record: 0.00641
#
# * Models saved *
#
# New historical moving average record: 0.00648
#
# * Models saved *
#
# New historical moving average record: 0.00659
#
# * Models saved *
#
# New historical moving average record: 0.00665
#
# * Models saved *
#
# New historical moving average record: 0.00666
#
# * Models saved *
#
# New historical moving average record: 0.00684
#
# * Models saved *
#
# New historical moving average record: 0.00689
#
# * Models saved *
#
# New historical moving average record: 0.00689
#
# * Models saved *
#
# New historical moving average record: 0.00698
#
# * Models saved *
#
# New historical moving average record: 0.00700
#
# * Models saved *
#
# New historical moving average record: 0.00716
#
# Episode * 1100 * Worker #3 * Moving Avg Reward is ==> 0.00715 * Last Reward was ==> 0.01789
# * Models saved *
#
# New historical moving average record: 0.00718
#
# * Models saved *
#
# New historical moving average record: 0.00725
#
# * Models saved *
#
# New historical moving average record: 0.00727
#
# * Models saved *
#
# New historical moving average record: 0.00732
# * Models saved *
#
# New historical moving average record: 0.00739
#
# * Models saved *
#
# New historical moving average record: 0.00740
#
# * Models saved *
#
# New historical moving average record: 0.00744
#
# * Models saved *
#
# New historical moving average record: 0.00752
#
# * Models saved *
#
# New historical moving average record: 0.00762
#
# * Models saved *
#
# New historical moving average record: 0.00766
#
# * Models saved *
#
# New historical moving average record: 0.00773
#
# * Models saved *
#
# New historical moving average record: 0.00777
#
# * Models saved *
#
# New historical moving average record: 0.00780
#
# * Models saved *
#
# New historical moving average record: 0.00787
#
# * Models saved *
#
# New historical moving average record: 0.00791
#
# * Models saved *
#
# New historical moving average record: 0.00797
#
# * Models saved *
#
# New historical moving average record: 0.00799
#
# * Models saved *
#
# New historical moving average record: 0.00805
#
# * Models saved *
#
# New historical moving average record: 0.00806
#
# * Models saved *
#
# New historical moving average record: 0.00813
#
# * Models saved *
#
# New historical moving average record: 0.00819
#
# * Models saved *
#
# New historical moving average record: 0.00829
#
# * Models saved *
#
# New historical moving average record: 0.00837
#
# * Models saved *
#
# New historical moving average record: 0.00849
#
# * Models saved *
#
# New historical moving average record: 0.00857
#
# * Models saved *
#
# New historical moving average record: 0.00858
#
# * Models saved *
#
# New historical moving average record: 0.00865
#
# * Models saved *
#
# New historical moving average record: 0.00870
#
# * Models saved *
#
# New historical moving average record: 0.00873
#
# * Models saved *
#
# New historical moving average record: 0.00877
#
# * Models saved *
#
# New historical moving average record: 0.00879
#
# * Models saved *
#
# New historical moving average record: 0.00882
#
# * Models saved *
#
# New historical moving average record: 0.00885
#
# * Models saved *
#
# New historical moving average record: 0.00893
#
# * Models saved *
#
# New historical moving average record: 0.00897
#
# * Models saved *
#
# New historical moving average record: 0.00918
#
# * Models saved *
#
# New historical moving average record: 0.00921
#
# * Models saved *
#
# New historical moving average record: 0.00926
#
# * Models saved *
#
# New historical moving average record: 0.00935
#
# * Models saved *
#
# New historical moving average record: 0.00942
#
# * Models saved *
#
# New historical moving average record: 0.00945
#
# * Models saved *
#
# New historical moving average record: 0.00956
#
# * Models saved *
#
# New historical moving average record: 0.00956
#
# * Models saved *
#
# New historical moving average record: 0.00957
#
# * Models saved *
#
# New historical moving average record: 0.00973
#
# * Models saved *
#
# New historical moving average record: 0.00973
#
# * Models saved *
#
# New historical moving average record: 0.00976
#
# * Models saved *
#
# New historical moving average record: 0.00977
#
# * Models saved *
#
# New historical moving average record: 0.00988
#
# * Models saved *
#
# New historical moving average record: 0.00992
#
# * Models saved *
#
# New historical moving average record: 0.00993
#
# * Models saved *
#
# New historical moving average record: 0.00995
#
# * Models saved *
#
# New historical moving average record: 0.01000
#
# * Models saved *
#
# New historical moving average record: 0.01003
#
# * Models saved *
#
# New historical moving average record: 0.01008
#
# * Models saved *
#
# New historical moving average record: 0.01009
#
# * Models saved *
#
# New historical moving average record: 0.01020
#
# * Models saved *
#
# New historical moving average record: 0.01030
#
# * Models saved *
#
# New historical moving average record: 0.01040
#
# * Models saved *
#
# New historical moving average record: 0.01057
#
# * Models saved *
#
# New historical moving average record: 0.01066
#
# * Models saved *
#
# New historical moving average record: 0.01071
#
# * Models saved *
#
# New historical moving average record: 0.01072
#
# * Models saved *
#
# New historical moving average record: 0.01077
#
# * Models saved *
#
# New historical moving average record: 0.01081
#
# * Models saved *
#
# New historical moving average record: 0.01089
#
# * Models saved *
#
# New historical moving average record: 0.01098
#
# * Models saved *
#
# New historical moving average record: 0.01106
#
# * Models saved *
#
# New historical moving average record: 0.01110
#
# * Models saved *
#
# New historical moving average record: 0.01112
#
# * Models saved *
#
# New historical moving average record: 0.01118
#
# * Models saved *
#
# New historical moving average record: 0.01127
#
# * Models saved *
#
# New historical moving average record: 0.01131
#
# * Models saved *
#
# New historical moving average record: 0.01143
#
# * Models saved *
#
# New historical moving average record: 0.01146
#
# * Models saved *
#
# New historical moving average record: 0.01156
#
# * Models saved *
#
# New historical moving average record: 0.01159
#
# * Models saved *
#
# New historical moving average record: 0.01162
#
# * Models saved *
#
# New historical moving average record: 0.01167
#
# * Models saved *
#
# New historical moving average record: 0.01174
#
# * Models saved *
#
# New historical moving average record: 0.01182
#
# * Models saved *
#
# New historical moving average record: 0.01187
#
# * Models saved *
#
# New historical moving average record: 0.01197
#
# * Models saved *
#
# New historical moving average record: 0.01206
#
# * Models saved *
#
# New historical moving average record: 0.01207
#
# * Models saved *
#
# New historical moving average record: 0.01211
#
# Episode * 1200 * Worker #7 * Moving Avg Reward is ==> 0.01209 * Last Reward was ==> 0.01340
# * Models saved *
#
# New historical moving average record: 0.01222
#
# * Models saved *
#
# New historical moving average record: 0.01224
#
# * Models saved *
#
# New historical moving average record: 0.01234
#
# * Models saved *
#
# New historical moving average record: 0.01242
#
# * Models saved *
#
# New historical moving average record: 0.01247
#
# * Models saved *
#
# New historical moving average record: 0.01249
#
# * Models saved *
#
# New historical moving average record: 0.01256
#
# * Models saved *
#
# New historical moving average record: 0.01264
#
# * Models saved *
#
# New historical moving average record: 0.01267
#
# * Models saved *
#
# New historical moving average record: 0.01269
#
# * Models saved *
#
# New historical moving average record: 0.01279
#
# * Models saved *
#
# New historical moving average record: 0.01289
#
# * Models saved *
#
# New historical moving average record: 0.01293
#
# * Models saved *
#
# New historical moving average record: 0.01298
#
# * Models saved *
#
# New historical moving average record: 0.01303
#
# * Models saved *
#
# New historical moving average record: 0.01307
#
# * Models saved *
#
# New historical moving average record: 0.01315
#
# * Models saved *
#
# New historical moving average record: 0.01318
#
# * Models saved *
#
# New historical moving average record: 0.01321
#
# * Models saved *
#
# New historical moving average record: 0.01326
#
# * Models saved *
#
# New historical moving average record: 0.01336
#
# * Models saved *
#
# New historical moving average record: 0.01344
#
# * Models saved *
#
# New historical moving average record: 0.01349
#
# * Models saved *
#
# New historical moving average record: 0.01351
#
# * Models saved *
#
# New historical moving average record: 0.01355
#
# * Models saved *
#
# New historical moving average record: 0.01365
#
# * Models saved *
#
# New historical moving average record: 0.01381
#
# * Models saved *
#
# New historical moving average record: 0.01387
#
# * Models saved *
#
# New historical moving average record: 0.01396
#
# * Models saved *
#
# New historical moving average record: 0.01406
#
# * Models saved *
#
# New historical moving average record: 0.01409
#
# * Models saved *
#
# New historical moving average record: 0.01422
#
# * Models saved *
#
# New historical moving average record: 0.01429
#
# * Models saved *
#
# New historical moving average record: 0.01433
#
# * Models saved *
#
# New historical moving average record: 0.01441
#
# * Models saved *
#
# New historical moving average record: 0.01451
#
# * Models saved *
#
# New historical moving average record: 0.01454
#
# * Models saved *
#
# New historical moving average record: 0.01464
#
# * Models saved *
#
# New historical moving average record: 0.01469
#
# * Models saved *
#
# New historical moving average record: 0.01473
#
# * Models saved *
#
# New historical moving average record: 0.01479
#
# * Models saved *
#
# New historical moving average record: 0.01487
#
# * Models saved *
#
# New historical moving average record: 0.01492
#
# * Models saved *
#
# New historical moving average record: 0.01497
#
# * Models saved *
#
# New historical moving average record: 0.01510
#
# * Models saved *
#
# New historical moving average record: 0.01513
#
# * Models saved *
#
# New historical moving average record: 0.01523
#
# * Models saved *
#
# New historical moving average record: 0.01524
#
# * Models saved *
#
# New historical moving average record: 0.01526
# * Models saved *
#
# New historical moving average record: 0.01540
#
# * Models saved *
#
# New historical moving average record: 0.01546
#
# * Models saved *
#
# New historical moving average record: 0.01547
#
# * Models saved *
#
# New historical moving average record: 0.01548
#
# * Models saved *
#
# New historical moving average record: 0.01549
#
# * Models saved *
#
# New historical moving average record: 0.01550
#
#
# * Will replay
# * Worker 0 finnished learning phase
# * Worker 1 finnished learning phase
# * Worker 2 finnished learning phase
# * Worker 3 finnished learning phase
# * Worker 4 finnished learning phase
# * Worker 5 finnished learning phase
# * Worker 6 finnished learning phase
# * Worker 7 finnished learning phase
# * Will resume
#
# * Models saved *
#
# New historical moving average record: 0.01555
#
# * Models saved *
#
# New historical moving average record: 0.01565
#
# * Models saved *
#
# New historical moving average record: 0.01567
#
# * Models saved *
#
# New historical moving average record: 0.01574
#
# * Models saved *
#
# New historical moving average record: 0.01587
#
# * Models saved *
#
# New historical moving average record: 0.01598
#
# * Models saved *
#
# New historical moving average record: 0.01612
#
# * Models saved *
#
# New historical moving average record: 0.01617
#
# * Models saved *
#
# New historical moving average record: 0.01639
#
# * Models saved *
#
# New historical moving average record: 0.01647
#
# * Models saved *
#
# New historical moving average record: 0.01649
#
# * Models saved *
#
# New historical moving average record: 0.01661
#
# * Models saved *
#
# New historical moving average record: 0.01676
#
# * Models saved *
#
# New historical moving average record: 0.01679
#
# * Models saved *
#
# New historical moving average record: 0.01687
#
# * Models saved *
#
# New historical moving average record: 0.01708
#
# * Models saved *
#
# New historical moving average record: 0.01711
#
# * Models saved *
#
# New historical moving average record: 0.01719
#
# * Models saved *
#
# New historical moving average record: 0.01719
#
# * Models saved *
#
# New historical moving average record: 0.01724
#
# * Models saved *
#
# New historical moving average record: 0.01731
#
# * Models saved *
#
# New historical moving average record: 0.01736
#
# * Models saved *
#
# New historical moving average record: 0.01740
#
# * Models saved *
#
# New historical moving average record: 0.01751
#
# * Models saved *
#
# New historical moving average record: 0.01758
#
# * Models saved *
#
# New historical moving average record: 0.01760
#
# * Models saved *
#
# New historical moving average record: 0.01767
#
# * Models saved *
#
# New historical moving average record: 0.01781
#
# Episode * 1300 * Worker #3 * Moving Avg Reward is ==> 0.01787 * Last Reward was ==> 0.05419
# * Models saved *
#
# New historical moving average record: 0.01787
#
# * Models saved *
#
# New historical moving average record: 0.01793
#
# * Models saved *
#
# New historical moving average record: 0.01796
#
# * Models saved *
#
# New historical moving average record: 0.01811
#
# * Models saved *
#
# New historical moving average record: 0.01820
#
# * Models saved *
#
# New historical moving average record: 0.01824
#
# * Models saved *
#
# New historical moving average record: 0.01838
#
# * Models saved *
#
# New historical moving average record: 0.01846
#
# * Models saved *
#
# New historical moving average record: 0.01847
#
# * Models saved *
#
# New historical moving average record: 0.01859
#
# * Models saved *
#
# New historical moving average record: 0.01872
#
# * Models saved *
#
# New historical moving average record: 0.01878
#
# * Models saved *
#
# New historical moving average record: 0.01882
#
# * Models saved *
#
# New historical moving average record: 0.01901
#
# * Models saved *
#
# New historical moving average record: 0.01912
#
# * Models saved *
#
# New historical moving average record: 0.01921
#
# * Models saved *
#
# New historical moving average record: 0.01930
#
# * Models saved *
#
# New historical moving average record: 0.01936
#
# * Models saved *
#
# New historical moving average record: 0.01944
#
# * Models saved *
#
# New historical moving average record: 0.01950
#
# * Models saved *
#
# New historical moving average record: 0.01958
#
# * Models saved *
#
# New historical moving average record: 0.01961
#
# * Models saved *
#
# New historical moving average record: 0.01968
#
# * Models saved *
#
# New historical moving average record: 0.01981
#
# * Models saved *
#
# New historical moving average record: 0.01994
#
# * Models saved *
#
# New historical moving average record: 0.01996
#
# * Models saved *
#
# New historical moving average record: 0.02003
#
# * Models saved *
#
# New historical moving average record: 0.02015
#
# * Models saved *
#
# New historical moving average record: 0.02029
#
# * Models saved *
#
# New historical moving average record: 0.02030
#
# * Models saved *
#
# New historical moving average record: 0.02045
#
# * Models saved *
#
# New historical moving average record: 0.02053
#
# * Models saved *
#
# New historical moving average record: 0.02064
#
# * Models saved *
#
# New historical moving average record: 0.02067
#
# * Models saved *
#
# New historical moving average record: 0.02076
#
# * Models saved *
#
# New historical moving average record: 0.02085
#
# * Models saved *
#
# New historical moving average record: 0.02094
#
# * Models saved *
#
# New historical moving average record: 0.02102
#
# * Models saved *
#
# New historical moving average record: 0.02127
#
# * Models saved *
#
# New historical moving average record: 0.02136
#
# * Models saved *
#
# New historical moving average record: 0.02142
#
# * Models saved *
#
# New historical moving average record: 0.02160
#
# * Models saved *
#
# New historical moving average record: 0.02177
#
# * Models saved *
#
# New historical moving average record: 0.02181
#
# * Models saved *
#
# New historical moving average record: 0.02192
#
# * Models saved *
#
# New historical moving average record: 0.02211
#
# * Models saved *
#
# New historical moving average record: 0.02229
#
# * Models saved *
#
# New historical moving average record: 0.02231
#
# * Models saved *
#
# New historical moving average record: 0.02239
#
# * Models saved *
#
# New historical moving average record: 0.02244
#
# * Models saved *
#
# New historical moving average record: 0.02256
#
# * Models saved *
#
# New historical moving average record: 0.02266
#
# * Models saved *
#
# New historical moving average record: 0.02270
#
# * Models saved *
#
# New historical moving average record: 0.02301
#
# * Models saved *
#
# New historical moving average record: 0.02309
#
# * Models saved *
#
# New historical moving average record: 0.02312
#
# * Models saved *
#
# New historical moving average record: 0.02318
#
# * Models saved *
#
# New historical moving average record: 0.02328
#
# * Models saved *
#
# New historical moving average record: 0.02333
#
# * Models saved *
#
# New historical moving average record: 0.02336
#
# * Models saved *
#
# New historical moving average record: 0.02341
#
# * Models saved *
#
# New historical moving average record: 0.02344
#
# * Models saved *
#
# New historical moving average record: 0.02353
#
# * Models saved *
#
# New historical moving average record: 0.02361
#
# * Models saved *
#
# New historical moving average record: 0.02375
#
# * Models saved *
#
# New historical moving average record: 0.02382
#
# * Models saved *
#
# New historical moving average record: 0.02394
#
# * Models saved *
#
# New historical moving average record: 0.02405
#
# * Models saved *
#
# New historical moving average record: 0.02413
#
# * Models saved *
#
# New historical moving average record: 0.02419
#
# * Models saved *
#
# New historical moving average record: 0.02429
#
# * Models saved *
#
# New historical moving average record: 0.02432
#
# * Models saved *
#
# New historical moving average record: 0.02434
#
# * Models saved *
#
# New historical moving average record: 0.02441
#
# * Models saved *
#
# New historical moving average record: 0.02445
#
# * Models saved *
#
# New historical moving average record: 0.02465
#
# * Models saved *
#
# New historical moving average record: 0.02477
#
# * Models saved *
#
# New historical moving average record: 0.02483
#
# * Models saved *
#
# New historical moving average record: 0.02491
#
# * Models saved *
#
# New historical moving average record: 0.02497
#
# * Models saved *
#
# New historical moving average record: 0.02518
#
# * Models saved *
#
# New historical moving average record: 0.02525
#
# * Models saved *
#
# New historical moving average record: 0.02531
#
# * Models saved *
#
# New historical moving average record: 0.02541
#
# * Models saved *
#
# New historical moving average record: 0.02547
#
# * Models saved *
#
# New historical moving average record: 0.02552
#
# * Models saved *
#
# New historical moving average record: 0.02566
#
# * Models saved *
#
# New historical moving average record: 0.02568
#
# * Models saved *
#
# New historical moving average record: 0.02589
#
# * Models saved *
#
# New historical moving average record: 0.02595
#
# * Models saved *
#
# New historical moving average record: 0.02603
# * Models saved *
#
# New historical moving average record: 0.02606
#
# * Models saved *
#
# New historical moving average record: 0.02625
#
# * Models saved *
#
# New historical moving average record: 0.02637
#
# * Models saved *
#
# New historical moving average record: 0.02642
#
# * Models saved *
#
# New historical moving average record: 0.02656
#
# * Models saved *
#
# New historical moving average record: 0.02665
#
# * Models saved *
#
# New historical moving average record: 0.02679
#
# Episode * 1400 * Worker #7 * Moving Avg Reward is ==> 0.02697 * Last Reward was ==> 0.15567
# * Models saved *
#
# New historical moving average record: 0.02697
#
# * Models saved *
#
# New historical moving average record: 0.02709
#
# * Models saved *
#
# New historical moving average record: 0.02720
#
# * Models saved *
#
# New historical moving average record: 0.02728
#
# * Models saved *
#
# New historical moving average record: 0.02745
#
# * Models saved *
#
# New historical moving average record: 0.02760
#
# * Models saved *
#
# New historical moving average record: 0.02770
#
# * Models saved *
#
# New historical moving average record: 0.02780
#
# * Models saved *
#
# New historical moving average record: 0.02792
#
# * Models saved *
#
# New historical moving average record: 0.02802
#
# * Models saved *
#
# New historical moving average record: 0.02816
#
# * Models saved *
#
# New historical moving average record: 0.02819
#
# * Models saved *
#
# New historical moving average record: 0.02832
#
# * Models saved *
#
# New historical moving average record: 0.02843
#
# * Models saved *
#
# New historical moving average record: 0.02850
#
# * Models saved *
#
# New historical moving average record: 0.02862
#
# * Models saved *
#
# New historical moving average record: 0.02866
#
# * Models saved *
#
# New historical moving average record: 0.02877
#
# * Models saved *
#
# New historical moving average record: 0.02886
#
# * Models saved *
#
# New historical moving average record: 0.02889
#
# * Models saved *
#
# New historical moving average record: 0.02908
#
# * Models saved *
#
# New historical moving average record: 0.02910
#
# * Models saved *
#
# New historical moving average record: 0.02921
#
# * Models saved *
#
# New historical moving average record: 0.02924
#
# * Models saved *
#
# New historical moving average record: 0.02936
#
# * Models saved *
#
# New historical moving average record: 0.02941
#
# * Models saved *
#
# New historical moving average record: 0.02955
#
# * Models saved *
#
# New historical moving average record: 0.02962
#
# * Models saved *
#
# New historical moving average record: 0.02964
#
# * Models saved *
#
# New historical moving average record: 0.02965
#
# * Models saved *
#
# New historical moving average record: 0.02970
#
# * Models saved *
#
# New historical moving average record: 0.02980
#
# * Models saved *
#
# New historical moving average record: 0.02983
#
# * Models saved *
#
# New historical moving average record: 0.02991
#
# * Models saved *
#
# New historical moving average record: 0.03014
#
# * Models saved *
#
# New historical moving average record: 0.03017
#
# * Models saved *
#
# New historical moving average record: 0.03021
#
# * Models saved *
#
# New historical moving average record: 0.03031
#
# * Models saved *
#
# New historical moving average record: 0.03036
#
# * Models saved *
#
# New historical moving average record: 0.03056
#
# * Models saved *
#
# New historical moving average record: 0.03063
#
# * Models saved *
#
# New historical moving average record: 0.03074
#
# * Models saved *
#
# New historical moving average record: 0.03082
#
# * Models saved *
#
# New historical moving average record: 0.03104
#
# * Models saved *
#
# New historical moving average record: 0.03107
#
# * Models saved *
#
# New historical moving average record: 0.03115
#
# * Models saved *
#
# New historical moving average record: 0.03117
#
# * Models saved *
#
# New historical moving average record: 0.03124
#
# * Models saved *
#
# New historical moving average record: 0.03126
#
# * Models saved *
#
# New historical moving average record: 0.03134
#
# * Models saved *
#
# New historical moving average record: 0.03147
#
# * Models saved *
#
# New historical moving average record: 0.03149
#
# * Models saved *
#
# New historical moving average record: 0.03164
#
# * Models saved *
#
# New historical moving average record: 0.03171
#
# * Models saved *
#
# New historical moving average record: 0.03188
#
# * Models saved *
#
# New historical moving average record: 0.03188
#
# * Models saved *
#
# New historical moving average record: 0.03202
#
# * Models saved *
#
# New historical moving average record: 0.03207
#
# * Models saved *
#
# New historical moving average record: 0.03215
#
# * Models saved *
#
# New historical moving average record: 0.03226
#
# * Models saved *
#
# New historical moving average record: 0.03245
#
# * Models saved *
#
# New historical moving average record: 0.03256
#
# * Models saved *
#
# New historical moving average record: 0.03267
#
# * Models saved *
#
# New historical moving average record: 0.03273
#
# * Models saved *
#
# New historical moving average record: 0.03281
#
# * Models saved *
#
# New historical moving average record: 0.03290
#
# * Models saved *
#
# New historical moving average record: 0.03300
#
# * Models saved *
#
# New historical moving average record: 0.03308
#
# * Models saved *
#
# New historical moving average record: 0.03309
#
# * Models saved *
#
# New historical moving average record: 0.03314
#
# * Models saved *
#
# New historical moving average record: 0.03335
#
# * Models saved *
#
# New historical moving average record: 0.03345
#
# * Models saved *
#
# New historical moving average record: 0.03352
#
# * Models saved *
#
# New historical moving average record: 0.03361
#
# * Models saved *
#
# New historical moving average record: 0.03372
#
# * Models saved *
#
# New historical moving average record: 0.03395
#
# * Models saved *
#
# New historical moving average record: 0.03397
#
# * Models saved *
#
# New historical moving average record: 0.03399
#
# * Models saved *
#
# New historical moving average record: 0.03409
#
# * Models saved *
#
# New historical moving average record: 0.03423
#
# * Models saved *
#
# New historical moving average record: 0.03426
#
# * Models saved *
#
# New historical moving average record: 0.03443
#
# * Models saved *
#
# New historical moving average record: 0.03449
#
# * Models saved *
#
# New historical moving average record: 0.03454
#
# * Models saved *
#
# New historical moving average record: 0.03465
#
# * Models saved *
#
# New historical moving average record: 0.03476
#
# * Models saved *
#
# New historical moving average record: 0.03487
#
# * Models saved *
#
# New historical moving average record: 0.03488
#
# * Models saved *
#
# New historical moving average record: 0.03493
#
# * Models saved *
#
# New historical moving average record: 0.03506
#
# * Models saved *
#
# New historical moving average record: 0.03510
#
# * Models saved *
#
# New historical moving average record: 0.03515
#
# * Models saved *
#
# New historical moving average record: 0.03523
#
# * Models saved *
#
# New historical moving average record: 0.03535
#
# * Models saved *
#
# New historical moving average record: 0.03548
#
# * Models saved *
#
# New historical moving average record: 0.03556
#
# * Models saved *
#
# New historical moving average record: 0.03561
#
# Episode * 1500 * Worker #3 * Moving Avg Reward is ==> 0.03567 * Last Reward was ==> 0.06050
# * Models saved *
#
# New historical moving average record: 0.03567
#
# * Models saved *
#
# New historical moving average record: 0.03574
#
# * Models saved *
#
# New historical moving average record: 0.03587
#
# * Models saved *
#
# New historical moving average record: 0.03594
#
# * Models saved *
#
# New historical moving average record: 0.03604
#
# * Models saved *
#
# New historical moving average record: 0.03609
#
# * Models saved *
#
# New historical moving average record: 0.03615
#
# * Models saved *
#
# New historical moving average record: 0.03627
#
# * Models saved *
#
# New historical moving average record: 0.03641
#
# * Models saved *
#
# New historical moving average record: 0.03644
#
# * Models saved *
#
# New historical moving average record: 0.03653
#
# * Models saved *
#
# New historical moving average record: 0.03657
#
# * Models saved *
#
# New historical moving average record: 0.03663
#
# * Models saved *
#
# New historical moving average record: 0.03673
#
# * Models saved *
#
# New historical moving average record: 0.03676
#
# * Models saved *
#
# New historical moving average record: 0.03689
#
# * Models saved *
#
# New historical moving average record: 0.03695
#
# * Models saved *
#
# New historical moving average record: 0.03711
#
# * Models saved *
#
# New historical moving average record: 0.03722
#
# * Models saved *
#
# New historical moving average record: 0.03727
# * Will replay
# * Worker 0 finnished learning phase
# * Worker 1 finnished learning phase
# * Worker 2 finnished learning phase
# * Worker 3 finnished learning phase
# * Worker 4 finnished learning phase
# * Worker 5 finnished learning phase
# * Worker 6 finnished learning phase
# * Worker 7 finnished learning phase
# * Will resume
#
# * Models saved *
#
# New historical moving average record: 0.03732
#
# * Models saved *
#
# New historical moving average record: 0.03740
#
# * Models saved *
#
# New historical moving average record: 0.03752
#
# * Models saved *
#
# New historical moving average record: 0.03760
#
# * Models saved *
#
# New historical moving average record: 0.03773
#
# * Models saved *
#
# New historical moving average record: 0.03789
#
# * Models saved *
#
# New historical moving average record: 0.03800
#
# * Models saved *
#
# New historical moving average record: 0.03829
#
# * Models saved *
#
# New historical moving average record: 0.03837
#
# * Models saved *
#
# New historical moving average record: 0.03863
#
# * Models saved *
#
# New historical moving average record: 0.03869
#
# * Models saved *
#
# New historical moving average record: 0.03877
#
# * Models saved *
#
# New historical moving average record: 0.03891
#
# * Models saved *
#
# New historical moving average record: 0.03892
#
# * Models saved *
#
# New historical moving average record: 0.03904
#
# * Models saved *
#
# New historical moving average record: 0.03924
#
# * Models saved *
#
# New historical moving average record: 0.03929
#
# * Models saved *
#
# New historical moving average record: 0.03941
#
# * Models saved *
#
# New historical moving average record: 0.03958
#
# * Models saved *
#
# New historical moving average record: 0.03961
#
# * Models saved *
#
# New historical moving average record: 0.03973
#
# * Models saved *
#
# New historical moving average record: 0.03981
#
# * Models saved *
#
# New historical moving average record: 0.03994
#
# * Models saved *
#
# New historical moving average record: 0.04005
#
# * Models saved *
#
# New historical moving average record: 0.04024
#
# * Models saved *
#
# New historical moving average record: 0.04032
#
# * Models saved *
#
# New historical moving average record: 0.04051
#
# * Models saved *
#
# New historical moving average record: 0.04060
#
# * Models saved *
#
# New historical moving average record: 0.04077
#
# * Models saved *
#
# New historical moving average record: 0.04086
#
# * Models saved *
#
# New historical moving average record: 0.04088
#
# * Models saved *
#
# New historical moving average record: 0.04092
#
# * Models saved *
#
# New historical moving average record: 0.04107
#
# * Models saved *
#
# New historical moving average record: 0.04130
#
# * Models saved *
#
# New historical moving average record: 0.04138
#
# * Models saved *
#
# New historical moving average record: 0.04144
#
# * Models saved *
#
# New historical moving average record: 0.04150
#
# * Models saved *
#
# New historical moving average record: 0.04152
#
# * Models saved *
#
# New historical moving average record: 0.04160
#
# * Models saved *
#
# New historical moving average record: 0.04168
#
# * Models saved *
#
# New historical moving average record: 0.04170
#
# * Models saved *
#
# New historical moving average record: 0.04179
#
# * Models saved *
#
# New historical moving average record: 0.04181
#
# * Models saved *
#
# New historical moving average record: 0.04199
#
# * Models saved *
#
# New historical moving average record: 0.04208
#
# * Models saved *
#
# New historical moving average record: 0.04235
#
# * Models saved *
#
# New historical moving average record: 0.04248
#
# * Models saved *
#
# New historical moving average record: 0.04266
#
# * Models saved *
#
# New historical moving average record: 0.04267
#
# * Models saved *
#
# New historical moving average record: 0.04282
#
# * Models saved *
#
# New historical moving average record: 0.04295
#
# * Models saved *
#
# New historical moving average record: 0.04309
#
# * Models saved *
#
# New historical moving average record: 0.04315
#
# * Models saved *
#
# New historical moving average record: 0.04315
#
# * Models saved *
#
# New historical moving average record: 0.04328
#
# * Models saved *
#
# New historical moving average record: 0.04340
#
# * Models saved *
#
# New historical moving average record: 0.04355
#
# * Models saved *
#
# New historical moving average record: 0.04364
#
# * Models saved *
#
# New historical moving average record: 0.04379
#
# * Models saved *
#
# New historical moving average record: 0.04396
#
# * Models saved *
#
# New historical moving average record: 0.04408
#
# * Models saved *
#
# New historical moving average record: 0.04424
#
# * Models saved *
#
# New historical moving average record: 0.04426
#
# * Models saved *
#
# New historical moving average record: 0.04450
#
# * Models saved *
#
# New historical moving average record: 0.04461
#
# * Models saved *
#
# New historical moving average record: 0.04470
#
# * Models saved *
#
# New historical moving average record: 0.04480
#
# * Models saved *
#
# New historical moving average record: 0.04494
#
# * Models saved *
#
# New historical moving average record: 0.04503
#
# * Models saved *
#
# New historical moving average record: 0.04518
#
# * Models saved *
#
# New historical moving average record: 0.04525
#
# * Models saved *
#
# New historical moving average record: 0.04538
#
# * Models saved *
#
# New historical moving average record: 0.04547
#
# * Models saved *
#
# New historical moving average record: 0.04563
#
# * Models saved *
#
# New historical moving average record: 0.04578
#
# * Models saved *
#
# New historical moving average record: 0.04594
#
# Episode * 1600 * Worker #7 * Moving Avg Reward is ==> 0.04603 * Last Reward was ==> 0.05029
# * Models saved *
#
# New historical moving average record: 0.04603
#
# * Models saved *
#
# New historical moving average record: 0.04621
#
# * Models saved *
#
# New historical moving average record: 0.04643
#
# * Models saved *
#
# New historical moving average record: 0.04651
#
# * Models saved *
#
# New historical moving average record: 0.04665
#
# * Models saved *
#
# New historical moving average record: 0.04683
#
# * Models saved *
#
# New historical moving average record: 0.04695
#
# * Models saved *
#
# New historical moving average record: 0.04703
#
# * Models saved *
#
# New historical moving average record: 0.04709
#
# * Models saved *
#
# New historical moving average record: 0.04731
#
# * Models saved *
#
# New historical moving average record: 0.04741
#
# * Models saved *
#
# New historical moving average record: 0.04748
#
# * Models saved *
#
# New historical moving average record: 0.04752
#
# * Models saved *
#
# New historical moving average record: 0.04759
#
# * Models saved *
#
# New historical moving average record: 0.04770
#
# * Models saved *
#
# New historical moving average record: 0.04784
#
# * Models saved *
#
# New historical moving average record: 0.04787
#
# * Models saved *
#
# New historical moving average record: 0.04807
#
# * Models saved *
#
# New historical moving average record: 0.04814
#
# * Models saved *
#
# New historical moving average record: 0.04823
#
# * Models saved *
#
# New historical moving average record: 0.04831
#
# * Models saved *
#
# New historical moving average record: 0.04838
#
# * Models saved *
#
# New historical moving average record: 0.04857
#
# * Models saved *
#
# New historical moving average record: 0.04872
#
# * Models saved *
#
# New historical moving average record: 0.04887
#
# * Models saved *
#
# New historical moving average record: 0.04906
#
# * Models saved *
#
# New historical moving average record: 0.04913
#
# * Models saved *
#
# New historical moving average record: 0.04918
#
# * Models saved *
#
# New historical moving average record: 0.04926
#
# * Models saved *
#
# New historical moving average record: 0.04938
#
# * Models saved *
#
# New historical moving average record: 0.04944
#
# * Models saved *
#
# New historical moving average record: 0.04961
#
# * Models saved *
#
# New historical moving average record: 0.04977
#
# * Models saved *
#
# New historical moving average record: 0.05003
#
# * Models saved *
#
# New historical moving average record: 0.05011
#
# * Models saved *
#
# New historical moving average record: 0.05018
#
# * Models saved *
#
# New historical moving average record: 0.05031
#
# * Models saved *
#
# New historical moving average record: 0.05051
#
# * Models saved *
#
# New historical moving average record: 0.05065
#
# * Models saved *
#
# New historical moving average record: 0.05075
#
# * Models saved *
#
# New historical moving average record: 0.05080
#
# * Models saved *
#
# New historical moving average record: 0.05094
#
# * Models saved *
#
# New historical moving average record: 0.05107
#
# * Models saved *
#
# New historical moving average record: 0.05118
#
# * Models saved *
#
# New historical moving average record: 0.05126
#
# * Models saved *
#
# New historical moving average record: 0.05136
# * Models saved *
#
# New historical moving average record: 0.05144
#
# * Models saved *
#
# New historical moving average record: 0.05158
#
# * Models saved *
#
# New historical moving average record: 0.05171
#
# * Models saved *
#
# New historical moving average record: 0.05172
#
# * Models saved *
#
# New historical moving average record: 0.05182
#
# * Models saved *
#
# New historical moving average record: 0.05202
#
# * Models saved *
#
# New historical moving average record: 0.05211
#
# * Models saved *
#
# New historical moving average record: 0.05211
#
# * Models saved *
#
# New historical moving average record: 0.05229
#
# * Models saved *
#
# New historical moving average record: 0.05237
#
# * Models saved *
#
# New historical moving average record: 0.05247
#
# * Models saved *
#
# New historical moving average record: 0.05253
#
# * Models saved *
#
# New historical moving average record: 0.05262
#
# * Models saved *
#
# New historical moving average record: 0.05263
#
# * Models saved *
#
# New historical moving average record: 0.05274
#
# * Models saved *
#
# New historical moving average record: 0.05290
#
# * Models saved *
#
# New historical moving average record: 0.05299
#
# * Models saved *
#
# New historical moving average record: 0.05309
#
# * Models saved *
#
# New historical moving average record: 0.05324
#
# * Models saved *
#
# New historical moving average record: 0.05340
#
# * Models saved *
#
# New historical moving average record: 0.05343
#
# * Models saved *
#
# New historical moving average record: 0.05346
#
# * Models saved *
#
# New historical moving average record: 0.05347
#
# * Models saved *
#
# New historical moving average record: 0.05377
#
# * Models saved *
#
# New historical moving average record: 0.05385
#
# * Models saved *
#
# New historical moving average record: 0.05405
#
# * Models saved *
#
# New historical moving average record: 0.05421
#
# * Models saved *
#
# New historical moving average record: 0.05435
#
# * Models saved *
#
# New historical moving average record: 0.05441
#
# * Models saved *
#
# New historical moving average record: 0.05448
#
# * Models saved *
#
# New historical moving average record: 0.05453
#
# * Models saved *
#
# New historical moving average record: 0.05460
#
# * Models saved *
#
# New historical moving average record: 0.05466
#
# * Models saved *
#
# New historical moving average record: 0.05475
#
# * Models saved *
#
# New historical moving average record: 0.05491
#
# * Models saved *
#
# New historical moving average record: 0.05498
#
# * Models saved *
#
# New historical moving average record: 0.05510
#
# * Models saved *
#
# New historical moving average record: 0.05510
#
# * Models saved *
#
# New historical moving average record: 0.05512
#
# * Models saved *
#
# New historical moving average record: 0.05521
#
# * Models saved *
#
# New historical moving average record: 0.05531
#
# * Models saved *
#
# New historical moving average record: 0.05546
#
# * Models saved *
#
# New historical moving average record: 0.05562
#
# * Models saved *
#
# New historical moving average record: 0.05577
#
# * Models saved *
#
# New historical moving average record: 0.05601
#
# * Models saved *
#
# New historical moving average record: 0.05624
#
# * Models saved *
#
# New historical moving average record: 0.05633
#
# * Models saved *
#
# New historical moving average record: 0.05641
#
# * Models saved *
#
# New historical moving average record: 0.05651
#
# * Models saved *
#
# New historical moving average record: 0.05654
#
# * Models saved *
#
# New historical moving average record: 0.05660
#
# * Models saved *
#
# New historical moving average record: 0.05677
#
# Episode * 1700 * Worker #3 * Moving Avg Reward is ==> 0.05681 * Last Reward was ==> 0.07976
# * Models saved *
#
# New historical moving average record: 0.05681
#
# * Models saved *
#
# New historical moving average record: 0.05692
#
# * Models saved *
#
# New historical moving average record: 0.05701
#
# * Models saved *
#
# New historical moving average record: 0.05708
#
# * Models saved *
#
# New historical moving average record: 0.05719
#
# * Models saved *
#
# New historical moving average record: 0.05731
#
# * Models saved *
#
# New historical moving average record: 0.05743
#
# * Models saved *
#
# New historical moving average record: 0.05759
#
# * Models saved *
#
# New historical moving average record: 0.05769
#
# * Models saved *
#
# New historical moving average record: 0.05774
#
# * Models saved *
#
# New historical moving average record: 0.05790
#
# * Models saved *
#
# New historical moving average record: 0.05811
#
# * Models saved *
#
# New historical moving average record: 0.05820
#
# * Models saved *
#
# New historical moving average record: 0.05837
#
# * Models saved *
#
# New historical moving average record: 0.05841
#
# * Models saved *
#
# New historical moving average record: 0.05847
#
# * Models saved *
#
# New historical moving average record: 0.05860
#
# * Models saved *
#
# New historical moving average record: 0.05873
#
# * Models saved *
#
# New historical moving average record: 0.05885
#
# * Models saved *
#
# New historical moving average record: 0.05893
#
# * Models saved *
#
# New historical moving average record: 0.05917
#
# * Models saved *
#
# New historical moving average record: 0.05924
#
# * Models saved *
#
# New historical moving average record: 0.05938
#
# * Models saved *
#
# New historical moving average record: 0.05952
#
# * Models saved *
#
# New historical moving average record: 0.05963
#
# * Models saved *
#
# New historical moving average record: 0.05977
#
# * Models saved *
#
# New historical moving average record: 0.05992
#
# * Models saved *
#
# New historical moving average record: 0.06002
#
# * Models saved *
#
# New historical moving average record: 0.06009
#
# * Models saved *
#
# New historical moving average record: 0.06021
#
# * Models saved *
#
# New historical moving average record: 0.06037
#
# * Models saved *
#
# New historical moving average record: 0.06051
#
# * Models saved *
#
# New historical moving average record: 0.06060
#
# * Models saved *
#
# New historical moving average record: 0.06063
#
# * Models saved *
#
# New historical moving average record: 0.06079
#
# * Models saved *
#
# New historical moving average record: 0.06081
#
# * Models saved *
#
# New historical moving average record: 0.06091
#
# * Models saved *
#
# New historical moving average record: 0.06098
#
# * Models saved *
#
# New historical moving average record: 0.06113
#
# ...
# * Worker 1 finnished learning phase
# * Worker 2 finnished learning phase
# * Worker 3 finnished learning phase
# * Worker 4 finnished learning phase
# * Worker 5 finnished learning phase
# * Worker 6 finnished learning phase
# * Worker 7 finnished learning phase
# * Will resume
#
# Episode * 146300 * Worker #3 * Moving Avg Reward is ==> 0.40168 * Last Reward was ==> 0.48889
# Episode * 146400 * Worker #7 * Moving Avg Reward is ==> 0.40312 * Last Reward was ==> 0.34530
# Episode * 146500 * Worker #3 * Moving Avg Reward is ==> 0.40679 * Last Reward was ==> 0.46782
#
# * Will replay
# * Worker 0 finnished learning phase
# * Worker 1 finnished learning phase
# * Worker 2 finnished learning phase
# * Worker 3 finnished learning phase
# * Worker 4 finnished learning phase
# * Worker 5 finnished learning phase
# * Worker 6 finnished learning phase
# * Worker 7 finnished learning phase
# * Will resume
#
# Episode * 146600 * Worker #7 * Moving Avg Reward is ==> 0.40658 * Last Reward was ==> 0.46917
# Episode * 146700 * Worker #3 * Moving Avg Reward is ==> 0.40766 * Last Reward was ==> 0.34716
#
# * Will replay
# * Worker 0 finnished learning phase
# * Worker 1 finnished learning phase
# * Worker 2 finnished learning phase
# * Worker 3 finnished learning phase
# * Worker 4 finnished learning phase
# * Worker 5 finnished learning phase
# * Worker 6 finnished learning phase
# * Worker 7 finnished learning phase
# * Will resume
#
# Episode * 146800 * Worker #7 * Moving Avg Reward is ==> 0.40809 * Last Reward was ==> 0.35465
# Episode * 146900 * Worker #3 * Moving Avg Reward is ==> 0.40828 * Last Reward was ==> 0.49958
# Episode * 147000 * Worker #7 * Moving Avg Reward is ==> 0.40751 * Last Reward was ==> 0.31602
#
# * Will replay
# * Worker 0 finnished learning phase
# * Worker 1 finnished learning phase
# * Worker 2 finnished learning phase
# * Worker 3 finnished learning phase
# * Worker 4 finnished learning phase
# * Worker 5 finnished learning phase
# * Worker 6 finnished learning phase
# * Worker 7 finnished learning phase
# * Will resume
#
# Episode * 147100 * Worker #3 * Moving Avg Reward is ==> 0.40915 * Last Reward was ==> 0.47568
# Episode * 147200 * Worker #7 * Moving Avg Reward is ==> 0.40916 * Last Reward was ==> 0.27890
#
# * Will replay
# * Worker 0 finnished learning phase
# * Worker 1 finnished learning phase
# * Worker 2 finnished learning phase
# * Worker 3 finnished learning phase
# * Worker 4 finnished learning phase
# * Worker 5 finnished learning phase
# * Worker 6 finnished learning phase
# * Worker 7 finnished learning phase
# * Will resume
#
# Episode * 147300 * Worker #3 * Moving Avg Reward is ==> 0.40955 * Last Reward was ==> 0.33595
# Episode * 147400 * Worker #7 * Moving Avg Reward is ==> 0.40915 * Last Reward was ==> 0.25173
# Episode * 147500 * Worker #3 * Moving Avg Reward is ==> 0.40911 * Last Reward was ==> 0.27652
#
# * Will replay
# * Worker 0 finnished learning phase
# * Worker 1 finnished learning phase
# * Worker 2 finnished learning phase
# * Worker 3 finnished learning phase
# * Worker 4 finnished learning phase
# * Worker 5 finnished learning phase
# * Worker 6 finnished learning phase
# * Worker 7 finnished learning phase
# * Will resume
#
# Episode * 147600 * Worker #7 * Moving Avg Reward is ==> 0.40844 * Last Reward was ==> 0.37868
# Episode * 147700 * Worker #3 * Moving Avg Reward is ==> 0.40828 * Last Reward was ==> 0.45538
# Episode * 147800 * Worker #7 * Moving Avg Reward is ==> 0.40737 * Last Reward was ==> 0.57848
#
# * Will replay
# * Worker 0 finnished learning phase
# * Worker 1 finnished learning phase
# * Worker 2 finnished learning phase
# * Worker 3 finnished learning phase
# * Worker 4 finnished learning phase
# * Worker 5 finnished learning phase
# * Worker 6 finnished learning phase
# * Worker 7 finnished learning phase
# * Will resume
#
# Episode * 147900 * Worker #3 * Moving Avg Reward is ==> 0.40638 * Last Reward was ==> 0.54429
# Episode * 148000 * Worker #7 * Moving Avg Reward is ==> 0.40698 * Last Reward was ==> 0.36774
#
# * Will replay
# * Worker 0 finnished learning phase
# * Worker 1 finnished learning phase
# * Worker 2 finnished learning phase
# * Worker 3 finnished learning phase
# * Worker 4 finnished learning phase
# * Worker 5 finnished learning phase
# * Worker 6 finnished learning phase
# * Worker 7 finnished learning phase
# * Will resume
#
# Episode * 148100 * Worker #3 * Moving Avg Reward is ==> 0.40675 * Last Reward was ==> 0.53368
# Episode * 148200 * Worker #7 * Moving Avg Reward is ==> 0.40588 * Last Reward was ==> 0.47083
# Episode * 148300 * Worker #3 * Moving Avg Reward is ==> 0.40601 * Last Reward was ==> 0.46469
#
# * Will replay
# * Worker 0 finnished learning phase
# * Worker 1 finnished learning phase
# * Worker 2 finnished learning phase
# * Worker 3 finnished learning phase
# * Worker 4 finnished learning phase
# * Worker 5 finnished learning phase
# * Worker 6 finnished learning phase
# * Worker 7 finnished learning phase
# * Will resume
#
# Episode * 148400 * Worker #7 * Moving Avg Reward is ==> 0.40562 * Last Reward was ==> 0.31399
# Episode * 148500 * Worker #3 * Moving Avg Reward is ==> 0.40261 * Last Reward was ==> 0.37409
#
# * Will replay
# * Worker 0 finnished learning phase
# * Worker 1 finnished learning phase
# * Worker 2 finnished learning phase
# * Worker 3 finnished learning phase
# * Worker 4 finnished learning phase
# * Worker 5 finnished learning phase
# * Worker 6 finnished learning phase
# * Worker 7 finnished learning phase
# * Will resume
#
# Episode * 148600 * Worker #7 * Moving Avg Reward is ==> 0.40335 * Last Reward was ==> 0.32134
# Episode * 148700 * Worker #3 * Moving Avg Reward is ==> 0.40361 * Last Reward was ==> 0.34273
# Episode * 148800 * Worker #7 * Moving Avg Reward is ==> 0.40391 * Last Reward was ==> 0.31977
#
# * Will replay
# * Worker 0 finnished learning phase
# * Worker 1 finnished learning phase
# * Worker 2 finnished learning phase
# * Worker 3 finnished learning phase
# * Worker 4 finnished learning phase
# * Worker 5 finnished learning phase
# * Worker 6 finnished learning phase
# * Worker 7 finnished learning phase
# * Will resume
#
# Episode * 148900 * Worker #3 * Moving Avg Reward is ==> 0.40376 * Last Reward was ==> 0.49735
# Episode * 149000 * Worker #7 * Moving Avg Reward is ==> 0.40657 * Last Reward was ==> 0.35953
#
# * Will replay
# * Worker 0 finnished learning phase
# * Worker 1 finnished learning phase
# * Worker 2 finnished learning phase
# * Worker 3 finnished learning phase
# * Worker 4 finnished learning phase
# * Worker 5 finnished learning phase
# * Worker 6 finnished learning phase
# * Worker 7 finnished learning phase
# * Will resume
#
# Episode * 149100 * Worker #3 * Moving Avg Reward is ==> 0.40786 * Last Reward was ==> 0.33941
# Episode * 149200 * Worker #7 * Moving Avg Reward is ==> 0.40886 * Last Reward was ==> 0.26210
# Episode * 149300 * Worker #3 * Moving Avg Reward is ==> 0.40838 * Last Reward was ==> 0.37501
#
# * Will replay
# * Worker 0 finnished learning phase
# * Worker 1 finnished learning phase
# * Worker 2 finnished learning phase
# * Worker 3 finnished learning phase
# * Worker 4 finnished learning phase
# * Worker 5 finnished learning phase
# * Worker 6 finnished learning phase
# * Worker 7 finnished learning phase
# * Will resume
#
# Episode * 149400 * Worker #7 * Moving Avg Reward is ==> 0.40793 * Last Reward was ==> 0.51148
# Episode * 149500 * Worker #3 * Moving Avg Reward is ==> 0.40938 * Last Reward was ==> 0.41635
#
# * Will replay
# * Worker 0 finnished learning phase
# * Worker 1 finnished learning phase
# * Worker 2 finnished learning phase
# * Worker 3 finnished learning phase
# * Worker 4 finnished learning phase
# * Worker 5 finnished learning phase
# * Worker 6 finnished learning phase
# * Worker 7 finnished learning phase
# * Will resume
#
# Episode * 149600 * Worker #7 * Moving Avg Reward is ==> 0.40775 * Last Reward was ==> 0.37621
# Episode * 149700 * Worker #3 * Moving Avg Reward is ==> 0.40770 * Last Reward was ==> 0.47081
# Episode * 149800 * Worker #7 * Moving Avg Reward is ==> 0.40712 * Last Reward was ==> 0.42465
#
# * Will replay
# * Worker 0 finnished learning phase
# * Worker 1 finnished learning phase
# * Worker 2 finnished learning phase
# * Worker 3 finnished learning phase
# * Worker 4 finnished learning phase
# * Worker 5 finnished learning phase
# * Worker 6 finnished learning phase
# * Worker 7 finnished learning phase
# * Will resume
#
# Episode * 149900 * Worker #3 * Moving Avg Reward is ==> 0.40821 * Last Reward was ==> 0.40088
# Episode * 150000 * Worker #7 * Moving Avg Reward is ==> 0.40520 * Last Reward was ==> 0.45605
#
# * Will replay
# * Worker 0 finnished learning phase
# * Worker 1 finnished learning phase
# * Worker 2 finnished learning phase
# * Worker 3 finnished learning phase
# * Worker 4 finnished learning phase
# * Worker 5 finnished learning phase
# * Worker 6 finnished learning phase
# * Worker 7 finnished learning phase
# * Will resume
#
# Episode * 150100 * Worker #3 * Moving Avg Reward is ==> 0.40456 * Last Reward was ==> 0.36548
# Episode * 150200 * Worker #7 * Moving Avg Reward is ==> 0.40470 * Last Reward was ==> 0.33644
# Episode * 150300 * Worker #3 * Moving Avg Reward is ==> 0.40436 * Last Reward was ==> 0.50797
#
# * Will replay
# * Worker 0 finnished learning phase
# * Worker 1 finnished learning phase
# * Worker 2 finnished learning phase
# * Worker 3 finnished learning phase
# * Worker 4 finnished learning phase
# * Worker 5 finnished learning phase
# * Worker 6 finnished learning phase
# * Worker 7 finnished learning phase
# * Will resume
#
# Episode * 150400 * Worker #7 * Moving Avg Reward is ==> 0.40610 * Last Reward was ==> 0.49351
# Episode * 150500 * Worker #3 * Moving Avg Reward is ==> 0.40572 * Last Reward was ==> 0.45825
# Episode * 150600 * Worker #7 * Moving Avg Reward is ==> 0.40731 * Last Reward was ==> 0.25813
#
# * Will replay
# * Worker 0 finnished learning phase
# * Worker 1 finnished learning phase
# * Worker 2 finnished learning phase
# * Worker 3 finnished learning phase
# * Worker 4 finnished learning phase
# * Worker 5 finnished learning phase
# * Worker 6 finnished learning phase
# * Worker 7 finnished learning phase
# * Will resume
#
# Episode * 150700 * Worker #3 * Moving Avg Reward is ==> 0.40761 * Last Reward was ==> 0.36201
# Episode * 150800 * Worker #7 * Moving Avg Reward is ==> 0.40821 * Last Reward was ==> 0.37783
#
# * Will replay
# * Worker 0 finnished learning phase
# * Worker 1 finnished learning phase
# * Worker 2 finnished learning phase
# * Worker 3 finnished learning phase
# * Worker 4 finnished learning phase
# * Worker 5 finnished learning phase
# * Worker 6 finnished learning phase
# * Worker 7 finnished learning phase
# * Will resume
#
# Episode * 150900 * Worker #3 * Moving Avg Reward is ==> 0.40947 * Last Reward was ==> 0.38009
# Episode * 151000 * Worker #7 * Moving Avg Reward is ==> 0.41173 * Last Reward was ==> 0.38675
# Episode * 151100 * Worker #3 * Moving Avg Reward is ==> 0.41238 * Last Reward was ==> 0.46118
#
# * Will replay
# * Worker 0 finnished learning phase
# * Worker 1 finnished learning phase
# * Worker 2 finnished learning phase
# * Worker 3 finnished learning phase
# * Worker 4 finnished learning phase
# * Worker 5 finnished learning phase
# * Worker 6 finnished learning phase
# * Worker 7 finnished learning phase
# * Will resume
#
# Episode * 151200 * Worker #7 * Moving Avg Reward is ==> 0.41328 * Last Reward was ==> 0.47816
# Episode * 151300 * Worker #3 * Moving Avg Reward is ==> 0.41423 * Last Reward was ==> 0.47030
#
# * Will replay
# * Worker 0 finnished learning phase
# * Worker 1 finnished learning phase
# * Worker 2 finnished learning phase
# * Worker 3 finnished learning phase
# * Worker 4 finnished learning phase
# * Worker 5 finnished learning phase
# * Worker 6 finnished learning phase
# * Worker 7 finnished learning phase
# * Will resume
#
# Episode * 151400 * Worker #7 * Moving Avg Reward is ==> 0.41434 * Last Reward was ==> 0.34279
# * Models saved *
#
# New historical moving average record: 0.41622
#
# * Models saved *
#
# New historical moving average record: 0.41623
#
# * Models saved *
#
# New historical moving average record: 0.41633
#
# * Models saved *
#
# New historical moving average record: 0.41645
#
# * Models saved *
#
# New historical moving average record: 0.41653
#
# Episode * 151500 * Worker #3 * Moving Avg Reward is ==> 0.41614 * Last Reward was ==> 0.36403
# * Models saved *
#
# New historical moving average record: 0.41658
#
# * Models saved *
#
# New historical moving average record: 0.41674
#
# * Models saved *
#
# New historical moving average record: 0.41677
#
# Episode * 151600 * Worker #7 * Moving Avg Reward is ==> 0.41680 * Last Reward was ==> 0.43696
# * Models saved *
#
# New historical moving average record: 0.41680
#
# * Models saved *
#
# New historical moving average record: 0.41701
#
# * Models saved *
#
# New historical moving average record: 0.41723
#
# * Models saved *
#
# New historical moving average record: 0.41733
#
# * Models saved *
#
# New historical moving average record: 0.41737
#
# * Models saved *
#
# New historical moving average record: 0.41745
#
# * Models saved *
#
# New historical moving average record: 0.41760
#
# * Models saved *
#
# New historical moving average record: 0.41769
#
# * Models saved *
#
# New historical moving average record: 0.41770
#
# * Models saved *
#
# New historical moving average record: 0.41771
#
# * Models saved *
#
# New historical moving average record: 0.41777
#
#
# * Will replay
# * Worker 0 finnished learning phase
# * Worker 1 finnished learning phase
# * Worker 2 finnished learning phase
# * Worker 3 finnished learning phase
# * Worker 4 finnished learning phase
# * Worker 5 finnished learning phase
# * Worker 6 finnished learning phase
# * Worker 7 finnished learning phase
# * Will resume
#
# * Models saved *
#
# New historical moving average record: 0.41792
#
# * Models saved *
#
# New historical moving average record: 0.41796
#
# * Models saved *
#
# New historical moving average record: 0.41797
#
# * Models saved *
#
# New historical moving average record: 0.41798
#
# Episode * 151700 * Worker #3 * Moving Avg Reward is ==> 0.41553 * Last Reward was ==> 0.48492
# Episode * 151800 * Worker #7 * Moving Avg Reward is ==> 0.41725 * Last Reward was ==> 0.48733
#
# * Will replay
# * Worker 0 finnished learning phase
# * Worker 1 finnished learning phase
# * Worker 2 finnished learning phase
# * Worker 3 finnished learning phase
# * Worker 4 finnished learning phase
# * Worker 5 finnished learning phase
# * Worker 6 finnished learning phase
# * Worker 7 finnished learning phase
# * Will resume
#
# Episode * 151900 * Worker #3 * Moving Avg Reward is ==> 0.41586 * Last Reward was ==> 0.46413
# Episode * 152000 * Worker #7 * Moving Avg Reward is ==> 0.41508 * Last Reward was ==> 0.50315
# Episode * 152100 * Worker #3 * Moving Avg Reward is ==> 0.41400 * Last Reward was ==> 0.50007
#
# * Will replay
# * Worker 0 finnished learning phase
# * Worker 1 finnished learning phase
# * Worker 2 finnished learning phase
# * Worker 3 finnished learning phase
# * Worker 4 finnished learning phase
# * Worker 5 finnished learning phase
# * Worker 6 finnished learning phase
# * Worker 7 finnished learning phase
# * Will resume
#
# Episode * 152200 * Worker #7 * Moving Avg Reward is ==> 0.41301 * Last Reward was ==> 0.35831
# Episode * 152300 * Worker #3 * Moving Avg Reward is ==> 0.41168 * Last Reward was ==> 0.46741
#
# * Will replay
# * Worker 0 finnished learning phase
# * Worker 1 finnished learning phase
# * Worker 2 finnished learning phase
# * Worker 3 finnished learning phase
# * Worker 4 finnished learning phase
# * Worker 5 finnished learning phase
# * Worker 6 finnished learning phase
# * Worker 7 finnished learning phase
# * Will resume
#
# Episode * 152400 * Worker #7 * Moving Avg Reward is ==> 0.41059 * Last Reward was ==> 0.37201
# Episode * 152500 * Worker #3 * Moving Avg Reward is ==> 0.40834 * Last Reward was ==> 0.38278
# Episode * 152600 * Worker #7 * Moving Avg Reward is ==> 0.40878 * Last Reward was ==> 0.55338
#
# * Will replay
# * Worker 0 finnished learning phase
# * Worker 1 finnished learning phase
# * Worker 2 finnished learning phase
# * Worker 3 finnished learning phase
# * Worker 4 finnished learning phase
# * Worker 5 finnished learning phase
# * Worker 6 finnished learning phase
# * Worker 7 finnished learning phase
# * Will resume
#
# Episode * 152700 * Worker #3 * Moving Avg Reward is ==> 0.41007 * Last Reward was ==> 0.55375
# Episode * 152800 * Worker #7 * Moving Avg Reward is ==> 0.40902 * Last Reward was ==> 0.57779

# %%
xxxxxxxxxxxxx

# %%
agent.training_duration

# %% [markdown]
# ### Test the results
# * Runs a set of episodes with unseen data
# * Stores the results in a csv file for later consulting

# %%
success = 0
n_tests = 10000

scores = []
targets = []
portfolio_target_ratios = []
initial_investments = []

for i in trange(n_tests):
    state = agent.env.reset(visualize=False,mode="test")
    step = 0
    score = 0
    reward = 0
    done = False
    
    targets.append((agent.env.episode_target-agent.env.initial_investment)/agent.env.initial_investment)
    initial_investments.append(agent.env.initial_investment)

    while not done:
        state = agent.reshape_state(state)
        agent.env.render()
        #state = np.expand_dims(state, axis=0)
        action, action_onehot, prediction = agent.choose_action(state)
        # Retrieve new state, reward, and whether the state is terminal
        next_state, reward, done, info = agent.env.step(action)
        #print(action, reward, agent.env.portfolio_value)
        # Memorize (state, action, reward) for training
        #self.buffer.remember(np.expand_dims(state, axis=0), action_onehot, reward)
        # Update current state
        if done :
            if agent.env.portfolio_value > agent.env.initial_investment:
                success +=1

        step+=1
        state = next_state
        score += reward
    
    # Track scores and ratios
    scores.append(score)
    portfolio_target_ratios.append(info["portfolio_value"]/info["episode_target"] -1)
    
    
test_results_dataframe = pd.DataFrame([[
    n_tests,
    str(round(np.mean(scores)*100,3))+'%',
    str(round(np.mean(targets)*100,3))+'%',
    str(round(np.mean(portfolio_target_ratios)*100,3))+'%',
    str(round(min(scores)*100,3))+'%',
    str(round(max(scores)*100,3))+'%',
    str(round((success/n_tests)*100,3)) +'%'
]],
    columns=[
        '# Blind tests',
        '% Average portfolio return', 
        '% Desired portfolio return', 
        'Portfolio/Target rate',
        '% Historical minimum return',
        '% Historical maximum return', 
        '% Episodes concluded with positive outcome'
    ]
)



test_results_dataframe.T

# %%
agent.results_writer.store_test_results(agent,test_results_dataframe)

# %% [markdown]
# ### Visual test
# * Runs a set of episodes with unseen data
# * See the evolution in real time

# %%
success = 0
n_tests = 2

scores = []
targets = []


for i in trange(n_tests):
    state = agent.env.reset(visualize=True,mode="test")
    step = 0
    score = 0
    reward = 0
    done = False
    targets.append((agent.env.episode_target-agent.env.initial_investment)/agent.env.initial_investment)
    initial_portfolio = agent.env.portfolio_value

    while not done:
        agent.env.render()
        
        # Shape the state
        state = agent.reshape_state(state)
        # Select a action
        action, action_onehot, prediction = agent.choose_action(state)
        
        # Retrieve new state, reward, and whether the state is terminal
        next_state, reward, done, _ = agent.env.step(action)
        
        # End of episode, track scores here
        if done :
            if agent.env.portfolio_value > agent.env.initial_investment:
                success +=1

        step+=1
        state = next_state
        score += reward
    
    scores.append(score)

agent.env.close()

# %% [markdown]
# ### Transactions profit
# * Track how much the agent gained by doing purchases and sales
# * Doesn't track the portfolio value
# * Already has the fees discounted

# %%
success = 0
n_tests = 10000

test_results_data = []
test_results_columns = [
    'dataset id',
    'episode start date', 
    'episode end date',
    'episode working days',
    'total transactions',
    'total transaction profit',
    "dataframe hash",
    "agent hash"
]

print('NOTE: This test only tracks the transactions profit. ')

for i in trange(n_tests):
    trading_history = []
    state = agent.env.reset(visualize=False,mode="test")
    step = 0
    score = 0
    reward = 0
    done = False
    #targets.append((agent.env.episode_target-agent.env.initial_investment)/agent.env.initial_investment)
    #initial_portfolio = agent.env.portfolio_value
    
    j = 0
    num_stocks = 0
    while not done:
        agent.env.render()
        
        # Select desired action
        state = agent.reshape_state(state)
        action, action_onehot, prediction = agent.choose_action(state)
        current_price = agent.env.df.iloc[agent.env.current_step -1]['close']
        
        if action == agent.env.ACTIONS.BUY:
            discounted_price = current_price * (1+agent.env.fees.BUY) 
            if agent.env.stock_held < agent.env.maximum_stocks_held and agent.env.cash_in_hand >= discounted_price:
                num_stocks +=1
                trading_history.append(['buy', discounted_price])
        elif action == agent.env.ACTIONS.SELL:
            if agent.env.stock_held > 0:
                discounted_price = current_price * (1-agent.env.fees.SELL) 
                trading_history.append(['sell', discounted_price])
                num_stocks =0
                
        # Retrieve new state, reward, and whether the state is terminal
        next_state, reward, done, _ = agent.env.step(action)

        # Update current state
        if done :
            if agent.env.portfolio_value > agent.env.initial_investment:
                success +=1
                
            profits = []
            purchases = []
            for e in trading_history:
                if e[0] == 'buy':
                    purchases.append(e[1])
                else:
                    profits.append((e[1]* len(purchases) - sum(purchases)) / sum(purchases))
                    purchases.clear() 
                    
            test_results_data.append([
                agent.env.dataset_idx,
                agent.env.df.iloc[agent.env.lookback].name,
                agent.env.df.iloc[-1].name,
                agent.env.window_size,
                len(profits),
                sum(profits)*100,
                agent.env.df_name,
                agent.hash
            ])


        step+=1
        state = next_state
        score += reward
    

agent.env.close()


pd.DataFrame(test_results_data,columns=test_results_columns)

# %%
transaction_results_df = pd.DataFrame(test_results_data,columns=test_results_columns)
transaction_results_df.sort_values(by="dataset id")

# %%
failed_episodes_df = transaction_results_df[transaction_results_df['total transaction profit'] <= 0]
failed_episodes_idx = failed_episodes_df['dataset id'].unique()
failed_episodes_idx.sort()

# %%
len(transaction_results_df[transaction_results_df['total transaction profit'] <= 0]['dataset id'].unique()),len(transaction_results_df[transaction_results_df['total transaction profit'] > 0]['dataset id'].unique())

# %%
import matplotlib.pyplot as plt 

for idx in failed_episodes_idx:
    plt.figure(figsize=(16,4))
    plt.plot(agent.env.df['close'])
    plt.title('#'+str(idx)+' - ' + str(len(failed_episodes_df[failed_episodes_df['dataset id'] == idx])) +'/' + str(len(transaction_results_df[transaction_results_df['dataset id'] == idx])))
