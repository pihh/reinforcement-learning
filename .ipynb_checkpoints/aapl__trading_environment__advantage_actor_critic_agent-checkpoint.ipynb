# %%
import shutup
shutup.please()

import gym
import src.environments.continuous.stock_trading  

import numpy as np
import pandas as pd 

from tqdm.notebook import trange, tqdm

# %% [markdown]
# ### Train the agent
# * Run it until he has a running average above the success_threshold
# * Use a large number of episodes for the running average ( 1000+ ) so if even it falls into a privileged sample, it wont be prone to error

# %%
def environment():
    env = gym.make('StockTradingEnvironment-v0',
        use_technical_indicators= [
        "macd",
        "boll_ub",
        "boll_lb",
        "rsi_30",
        "cci_30",
        "dx_30",
        "close_30_sma",
        "close_60_sma",
    ])
    
    poc_threshold = 0.1 # 10% 
    print('* Original success threshold', env.success_threshold)
    
    print('* POC success threshold', poc_threshold)
    print()
    
    env.success_threshold = poc_threshold
    return env

# from src.environments.continuous.trading import environment

# %%
from src.agents.actor_critic.a2c import A2CAgent

# %%
agent=A2CAgent(environment, epochs=1, actor_learning_rate=0.000025,critic_learning_rate=0.000025,policy="CNN")
agent.load()
# Out:
# * Original success threshold 0.044110249488908244
# * POC success threshold 0.1
#
# @TODO Agent._load_agent_configuration()

# %%
agent.env.mode = "train"
agent.learning_log.episodes = 0
agent.learn(
    timesteps=-1, 
    log_every=100,
    success_threshold_lookback=1000,
    success_strict=True,
)

print('A2C + CNN + 0.25 threshold -> Executed in 1h 1m 4s, finished 18:43:51 2022-08-08')
# Out:
# Episode * 100 * Moving Avg Reward is ==> 0.03835 * Last Reward was ==> 0.01318
# Episode * 200 * Moving Avg Reward is ==> 0.05249 * Last Reward was ==> -0.00409
# Episode * 300 * Moving Avg Reward is ==> 0.05765 * Last Reward was ==> 0.28606
# Episode * 400 * Moving Avg Reward is ==> 0.05406 * Last Reward was ==> 0.27998
# Episode * 500 * Moving Avg Reward is ==> 0.05402 * Last Reward was ==> 0.27452
# Episode * 600 * Moving Avg Reward is ==> 0.05010 * Last Reward was ==> 0.18563
# Episode * 700 * Moving Avg Reward is ==> 0.05459 * Last Reward was ==> 0.29643
# Episode * 800 * Moving Avg Reward is ==> 0.05586 * Last Reward was ==> -0.15277
# Episode * 900 * Moving Avg Reward is ==> 0.05655 * Last Reward was ==> 0.14155
# Episode * 1000 * Moving Avg Reward is ==> 0.05670 * Last Reward was ==> 0.10515
# * Models saved *
#
# New historical moving average record: 0.05663
#
# * Models saved *
#
# New historical moving average record: 0.05664
#
# * Models saved *
#
# New historical moving average record: 0.05699
#
# * Models saved *
#
# New historical moving average record: 0.05701
#
# * Models saved *
#
# New historical moving average record: 0.05731
#
# * Models saved *
#
# New historical moving average record: 0.05757
#
# * Models saved *
#
# New historical moving average record: 0.05797
#
# Episode * 1100 * Moving Avg Reward is ==> 0.05573 * Last Reward was ==> -0.15995
# Episode * 1200 * Moving Avg Reward is ==> 0.05391 * Last Reward was ==> -0.03059
# Episode * 1300 * Moving Avg Reward is ==> 0.05430 * Last Reward was ==> 0.25697
# Episode * 1400 * Moving Avg Reward is ==> 0.05558 * Last Reward was ==> 0.05283
# Episode * 1500 * Moving Avg Reward is ==> 0.05457 * Last Reward was ==> -0.16059
# * Models saved *
#
# New historical moving average record: 0.05799
#
# * Models saved *
#
# New historical moving average record: 0.05824
#
# * Models saved *
#
# New historical moving average record: 0.05866
#
# * Models saved *
#
# New historical moving average record: 0.05905
#
# * Models saved *
#
# New historical moving average record: 0.05909
#
# * Models saved *
#
# New historical moving average record: 0.05934
#
# * Models saved *
#
# New historical moving average record: 0.05973
#
# * Models saved *
#
# New historical moving average record: 0.05976
#
# * Models saved *
#
# New historical moving average record: 0.05998
#
# * Models saved *
#
# New historical moving average record: 0.06008
#
# * Models saved *
#
# New historical moving average record: 0.06021
#
# * Models saved *
#
# New historical moving average record: 0.06047
#
# * Models saved *
#
# New historical moving average record: 0.06061
#
# * Models saved *
#
# New historical moving average record: 0.06110
#
# * Models saved *
#
# New historical moving average record: 0.06140
#
# * Models saved *
#
# New historical moving average record: 0.06185
#
# * Models saved *
#
# New historical moving average record: 0.06208
#
# * Models saved *
#
# New historical moving average record: 0.06219
#
# * Models saved *
#
# New historical moving average record: 0.06219
#
# Episode * 1600 * Moving Avg Reward is ==> 0.06202 * Last Reward was ==> 0.03635
# * Models saved *
#
# New historical moving average record: 0.06226
#
# * Models saved *
#
# New historical moving average record: 0.06251
#
# * Models saved *
#
# New historical moving average record: 0.06255
#
# * Models saved *
#
# New historical moving average record: 0.06271
#
# Episode * 1700 * Moving Avg Reward is ==> 0.05943 * Last Reward was ==> 0.29084
# Episode * 1800 * Moving Avg Reward is ==> 0.06051 * Last Reward was ==> 0.23075
# Episode * 1900 * Moving Avg Reward is ==> 0.06152 * Last Reward was ==> 0.25350
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [5], in <cell line: 3>()
#       1 agent.env.mode = "train"
#       2 agent.learning_log.episodes = 0
# ----> 3 agent.learn(
#       4     timesteps=-1,
#       5     log_every=100,
#       6     success_threshold_lookback=1000,
#       7     success_strict=True,
#       8 )
#      10 print('A2C + CNN + 0.25 threshold -> Executed in 1h 1m 4s, finished 18:43:51 2022-08-08')
#
# File ~\Development\GIT\tmp\reinforcement-learning\src\agents\actor_critic\a2c.py:266, in A2CAgent.learn(self, timesteps, plot_results, reset, success_threshold, log_level, log_every, success_threshold_lookback, success_strict)
#     263 episode = 0
#     265 while self.learning_condition(timesteps,timestep):  # Run until solved
# --> 266     state = self.env.reset()
#     267     score = 0
#     268     done = False
#
# File ~\anaconda3\envs\ai_4\lib\site-packages\gym\wrappers\order_enforcing.py:18, in OrderEnforcing.reset(self, **kwargs)
#      16 def reset(self, **kwargs):
#      17     self._has_reset = True
# ---> 18     return self.env.reset(**kwargs)
#
# File ~\Development\GIT\tmp\reinforcement-learning\src\environments\continuous\stock_trading\v0.py:969, in StockTradingEnvironment.reset(self, visualize, dataset_id, mode)
#     966 else:
#     967     self.dataset_idx = dataset_id
# --> 969 self.load_dataset_by_index(self.dataset_idx)
#     971 # Define how much will invest
#     972 self.set_initial_investment(self.dataset_idx)
#
# File ~\Development\GIT\tmp\reinforcement-learning\src\environments\continuous\stock_trading\v0.py:864, in StockTradingEnvironment.load_dataset_by_index(self, idx)
#     861 except:
#     862     pass
# --> 864 df.drop(columns=['ticker'],inplace=True)
#
# File ~\anaconda3\envs\ai_4\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\envs\ai_4\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
#    4816 ):
#    4817     """
#    4818     Drop specified labels from rows or columns.
#    4819
#    (...)
#    4952             weight  1.0     0.8
#    4953     """
# -> 4954     return super().drop(
#    4955         labels=labels,
#    4956         axis=axis,
#    4957         index=index,
#    4958         columns=columns,
#    4959         level=level,
#    4960         inplace=inplace,
#    4961         errors=errors,
#    4962     )
#
# File ~\anaconda3\envs\ai_4\lib\site-packages\pandas\core\generic.py:4267, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265 for axis, labels in axes.items():
#    4266     if labels is not None:
# -> 4267         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4269 if inplace:
#    4270     self._update_inplace(obj)
#
# File ~\anaconda3\envs\ai_4\lib\site-packages\pandas\core\generic.py:4350, in NDFrame._drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4347     new_axis = axis.take(indexer)
#    4349 bm_axis = self.ndim - axis_num - 1
# -> 4350 new_mgr = self._mgr.reindex_indexer(
#    4351     new_axis,
#    4352     indexer,
#    4353     axis=bm_axis,
#    4354     allow_dups=True,
#    4355     consolidate=consolidate,
#    4356     only_slice=only_slice,
#    4357 )
#    4358 result = self._constructor(new_mgr)
#    4359 if self.ndim == 1:
#
# File ~\anaconda3\envs\ai_4\lib\site-packages\pandas\core\internals\managers.py:675, in BaseBlockManager.reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, consolidate, only_slice, use_na_proxy)
#     672     return result
#     674 if consolidate:
# --> 675     self._consolidate_inplace()
#     677 # some axes don't allow reindexing with dups
#     678 if not allow_dups:
#
# File ~\anaconda3\envs\ai_4\lib\site-packages\pandas\core\internals\managers.py:1685, in BlockManager._consolidate_inplace(self)
#    1683 def _consolidate_inplace(self) -> None:
#    1684     if not self.is_consolidated():
# -> 1685         self.blocks = tuple(_consolidate(self.blocks))
#    1686         self._is_consolidated = True
#    1687         self._known_consolidated = True
#
# File ~\anaconda3\envs\ai_4\lib\site-packages\pandas\core\internals\managers.py:2084, in _consolidate(blocks)
#    2082 new_blocks: list[Block] = []
#    2083 for (_can_consolidate, dtype), group_blocks in grouper:
# -> 2084     merged_blocks = _merge_blocks(
#    2085         list(group_blocks), dtype=dtype, can_consolidate=_can_consolidate
#    2086     )
#    2087     new_blocks = extend_blocks(merged_blocks, new_blocks)
#    2088 return new_blocks
#
# File ~\anaconda3\envs\ai_4\lib\site-packages\pandas\core\internals\managers.py:2121, in _merge_blocks(blocks, dtype, can_consolidate)
#    2118     new_values = new_values[argsort]
#    2119     new_mgr_locs = new_mgr_locs[argsort]
# -> 2121     bp = BlockPlacement(new_mgr_locs)
#    2122     return [new_block_2d(new_values, placement=bp)]
#    2124 # can't consolidate --> no merge
#
# KeyboardInterrupt:

# %%
xxxxxxxxxxx

# %% [markdown]
# ### Test the results
# * Runs a set of episodes with **unseen data**
# * Stores the results in a csv file for later consulting

# %%
success = 0
n_tests = 10000

scores = []
targets = []
portfolio_target_ratios = []
initial_investments = []

for i in trange(n_tests):
    state = agent.env.reset(visualize=False,mode="test")
    step = 0
    score = 0
    reward = 0
    done = False
    
    targets.append((agent.env.episode_target-agent.env.initial_investment)/agent.env.initial_investment)
    initial_investments.append(agent.env.initial_investment)

    while not done:
        agent.env.render()
        
        # Select action
        action, action_onehot, prediction = agent.choose_action(state)
        
        # Retrieve new state, reward, and whether the state is terminal
        next_state, reward, done, info = agent.env.step(action)
        
        # End of episode, track scores here
        if done :
            if agent.env.portfolio_value > agent.env.initial_investment:
                success +=1

        step+=1
        state = next_state
        score += reward
    
    # Track scores and ratios
    scores.append(score)
    portfolio_target_ratios.append(info["portfolio_value"]/info["episode_target"] -1)
    
    
test_results_dataframe = pd.DataFrame([[
    n_tests,
    str(round(np.mean(scores)*100,3))+'%',
    str(round(np.mean(targets)*100,3))+'%',
    str(round(np.mean(portfolio_target_ratios)*100,3))+'%',
    str(round(min(scores)*100,3))+'%',
    str(round(max(scores)*100,3))+'%',
    str(round((success/n_tests)*100,3)) +'%'
]],
    columns=[
        '# Blind tests',
        '% Average portfolio return', 
        '% Desired portfolio return', 
        'Portfolio/Target rate',
        '% Historical minimum return',
        '% Historical maximum return', 
        '% Episodes concluded with positive outcome'
    ]
)


agent.results_writer.store_test_results(agent,test_results_dataframe)

test_results_dataframe.T

# %% [markdown]
# ### Visual test
# * Runs a set of episodes with **unseen data**
# * See the evolution in real time

# %%
success = 0
n_tests = 10

scores = []
targets = []


for i in trange(n_tests):
    state = agent.env.reset(visualize=True,mode="test")
    step = 0
    score = 0
    reward = 0
    done = False
    targets.append((agent.env.episode_target-agent.env.initial_investment)/agent.env.initial_investment)
    initial_portfolio = agent.env.portfolio_value

    while not done:
        agent.env.render()
        
        # Select desired action
        action, action_onehot, prediction = agent.choose_action(state)

        # Retrieve new state, reward, and whether the state is terminal
        next_state, reward, done, _ = agent.env.step(action)

        # Update current state
        if done :
            if agent.env.portfolio_value > agent.env.initial_investment:
                success +=1

        step+=1
        state = next_state
        score += reward
    
    scores.append(score)

agent.env.close()

# %% [markdown]
# ### Transactions profit
# * Track how much the agent gained by doing purchases and sales
# * Doesn't track the portfolio value
# * Already has the fees discounted

# %%
success = 0
n_tests = 10000

test_results_data = []
test_results_columns = [
    'dataset id',
    'episode start date', 
    'episode end date',
    'episode working days',
    'total transactions',
    'total transaction profit',
    "dataframe hash",
    "agent hash"
]

print('NOTE: This test only tracks the transactions profit. ')

for i in trange(n_tests):
    trading_history = []
    state = agent.env.reset(visualize=False,mode="test")
    step = 0
    score = 0
    reward = 0
    done = False
    #targets.append((agent.env.episode_target-agent.env.initial_investment)/agent.env.initial_investment)
    #initial_portfolio = agent.env.portfolio_value
    
    j = 0
    num_stocks = 0
    while not done:
        agent.env.render()
        
        # Select desired action
        action, action_onehot, prediction = agent.choose_action(state)
        current_price = agent.env.df.iloc[agent.env.current_step -1]['close']
        
        if action == agent.env.ACTIONS.BUY:
            discounted_price = current_price * (1+agent.env.fees.BUY) 
            if agent.env.stock_held < agent.env.maximum_stocks_held and agent.env.cash_in_hand >= discounted_price:
                num_stocks +=1
                trading_history.append(['buy', discounted_price])
        elif action == agent.env.ACTIONS.SELL:
            if agent.env.stock_held > 0:
                discounted_price = current_price * (1-agent.env.fees.SELL) 
                trading_history.append(['sell', discounted_price])
                num_stocks =0
                
        # Retrieve new state, reward, and whether the state is terminal
        next_state, reward, done, _ = agent.env.step(action)

        # Update current state
        if done :
            if agent.env.portfolio_value > agent.env.initial_investment:
                success +=1
                
            profits = []
            purchases = []
            for e in trading_history:
                if e[0] == 'buy':
                    purchases.append(e[1])
                else:
                    profits.append((e[1]* len(purchases) - sum(purchases)) / sum(purchases))
                    purchases.clear() 
                    
            test_results_data.append([
                agent.env.dataset_idx,
                agent.env.df.iloc[agent.env.lookback].name,
                agent.env.df.iloc[-1].name,
                agent.env.window_size,
                len(profits),
                sum(profits)*100,
                agent.env.df_name,
                agent.hash
            ])


        step+=1
        state = next_state
        score += reward
    

agent.env.close()


pd.DataFrame(test_results_data,columns=test_results_columns)

# %%
transaction_results_df = pd.DataFrame(test_results_data,columns=test_results_columns)

# %%
transaction_results_df.sort_values(by="dataset id")

# %%
transaction_results_df[transaction_results_df['total transaction profit'] <= 0]

# %%
failed_episodes_df = transaction_results_df[transaction_results_df['total transaction profit'] <= 0]
failed_episodes_idx = failed_episodes_df['dataset id'].unique()
failed_episodes_idx.sort()

# %%
len(transaction_results_df[transaction_results_df['total transaction profit'] <= 0]['dataset id'].unique()),len(transaction_results_df[transaction_results_df['total transaction profit'] > 0]['dataset id'].unique())

# %%
import matplotlib.pyplot as plt 

for idx in failed_episodes_idx:
    plt.figure(figsize=(16,4))
    plt.plot(agent.env.df['close'])
    plt.title('#'+str(idx)+' - ' + str(len(failed_episodes_df[failed_episodes_df['dataset id'] == idx])) +'/' + str(len(transaction_results_df[transaction_results_df['dataset id'] == idx])))

# %%
idx

# %%
plt.figure(figsize=(16,4))
plt.plot(agent.env.df['close'])
plt.title('#'+str(idx)+' - ' + str(len(failed_episodes_df[failed_episodes_df['dataset id'] == idx])) +'/' + str(len(transaction_results_df[transaction_results_df['dataset id'] == idx])))

# %%
agent.ten
