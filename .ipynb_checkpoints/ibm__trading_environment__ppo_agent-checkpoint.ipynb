# %%
import shutup
shutup.please()

import gym
import src.environments.continuous.stock_trading  

import numpy as np
import pandas as pd 

from tqdm.notebook import trange, tqdm

# %% [markdown]
# ### Train the agent
# * Run it until he has a running average above the success_threshold
# * Use a large number of episodes for the running average ( 1000+ ) so if even it falls into a privileged sample, it wont be prone to error

# %%
from src.agents.ppo import PpoAgent

# %%
def environment(describe=True):
    env = gym.make('StockTradingEnvironment-v0',
            ticker="IBM",
            use_technical_indicators= [
            "macd",
            "boll_ub",
            "boll_lb",
            "rsi_30",
            "cci_30",
            "dx_30",
            "close_30_sma",
            "close_60_sma",
        ])
    
    poc_threshold = 0.1 # 10% 
    print('* Original success threshold', env.success_threshold)
    
    print('* POC success threshold', poc_threshold)
    print()
    
    env.success_threshold = poc_threshold
    
    return env

# %%
agent=PpoAgent(
        environment,
        actor_learning_rate=0.000025,
        critic_learning_rate=0.000025,
        policy="CNN",
        epochs=10,
        n_workers=8)

agent.load()
    
agent.learn(
        timesteps=-1, 
        log_every=100,
        success_threshold_lookback=1000,
        success_strict=True,
    )
# Out:
# * Original success threshold 0.06430736897477253
# * POC success threshold 0.1
#
# @TODO Agent._load_agent_configuration()
#
# * Could not load the following models: ['ppo-actor', 'ppo-critic'] *
#
# Unable to load previous best score
# * Booting worker 0
#
# * Original success threshold 0.06430736897477253
# * POC success threshold 0.1
#
# * Booting worker 1
#
# * Original success threshold 0.06430736897477253
# * POC success threshold 0.1
#
# * Booting worker 2
#
# * Original success threshold 0.06430736897477253
# * POC success threshold 0.1
#
# * Booting worker 3
#
# * Original success threshold 0.06430736897477253
# * POC success threshold 0.1
#
# * Booting worker 4
#
# * Original success threshold 0.06430736897477253
# * POC success threshold 0.1
#
# * Booting worker 5
#
# * Original success threshold 0.06430736897477253
# * POC success threshold 0.1
#
# * Booting worker 6
#
# * Original success threshold 0.06430736897477253
# * POC success threshold 0.1
#
# * Booting worker 7
#
# * Original success threshold 0.06430736897477253
# * POC success threshold 0.1
#
# Episode * 100 * Worker #3 * Moving Avg Reward is ==> -0.01524 * Last Reward was ==> -0.17842
# Episode * 200 * Worker #7 * Moving Avg Reward is ==> -0.01196 * Last Reward was ==> 0.03804
#
# * Will replay
# * Worker 0 finnished learning phase
# * Worker 1 finnished learning phase
# * Worker 2 finnished learning phase
# * Worker 3 finnished learning phase
# * Worker 4 finnished learning phase
# * Worker 5 finnished learning phase
# * Worker 6 finnished learning phase
# * Worker 7 finnished learning phase
# * Will resume
#
# Episode * 300 * Worker #3 * Moving Avg Reward is ==> -0.01117 * Last Reward was ==> -0.00576
# Episode * 400 * Worker #7 * Moving Avg Reward is ==> -0.00941 * Last Reward was ==> -0.02046
# Episode * 500 * Worker #3 * Moving Avg Reward is ==> -0.00836 * Last Reward was ==> 0.03791
#
# * Will replay
# * Worker 0 finnished learning phase
# * Worker 1 finnished learning phase
# * Worker 2 finnished learning phase
# * Worker 3 finnished learning phase
# * Worker 4 finnished learning phase
# * Worker 5 finnished learning phase
# * Worker 6 finnished learning phase
# * Worker 7 finnished learning phase
# * Will resume
#
# Episode * 600 * Worker #7 * Moving Avg Reward is ==> -0.00515 * Last Reward was ==> 0.01395
# Episode * 700 * Worker #3 * Moving Avg Reward is ==> -0.00313 * Last Reward was ==> 0.04215
#
# * Will replay
# * Worker 0 finnished learning phase
# * Worker 1 finnished learning phase
# * Worker 2 finnished learning phase
# * Worker 3 finnished learning phase
# * Worker 4 finnished learning phase
# * Worker 5 finnished learning phase
# * Worker 6 finnished learning phase
# * Worker 7 finnished learning phase
# * Will resume
#
# Episode * 800 * Worker #7 * Moving Avg Reward is ==> 0.00020 * Last Reward was ==> 0.04950
# Episode * 900 * Worker #3 * Moving Avg Reward is ==> 0.00431 * Last Reward was ==> 0.06613
# Episode * 1000 * Worker #7 * Moving Avg Reward is ==> 0.00759 * Last Reward was ==> 0.03588 * Total episodes ending on loss: 432/1000
# * Models saved *
#
# New historical moving average record: 0.00762
#
# * Models saved *
#
# New historical moving average record: 0.00766
#
# * Models saved *
#
# New historical moving average record: 0.00770
#
# * Models saved *
#
# New historical moving average record: 0.00781
#
# * Models saved *
#
# New historical moving average record: 0.00791
#
# * Models saved *
#
# New historical moving average record: 0.00796
#
# * Models saved *
#
# New historical moving average record: 0.00802
#
# * Models saved *
#
# New historical moving average record: 0.00804
#
#
# * Will replay
# * Worker 0 finnished learning phase
# * Worker 1 finnished learning phase
# * Worker 2 finnished learning phase
# * Worker 3 finnished learning phase
# * Worker 4 finnished learning phase
# * Worker 5 finnished learning phase
# * Worker 6 finnished learning phase
# * Worker 7 finnished learning phase
# * Will resume
#
# * Models saved *
#
# New historical moving average record: 0.00810
#
# * Models saved *
#
# New historical moving average record: 0.00815
#
# * Models saved *
#
# New historical moving average record: 0.00817
#
# * Models saved *
#
# New historical moving average record: 0.00825
#
# * Models saved *
#
# New historical moving average record: 0.00832
#
# * Models saved *
#
# New historical moving average record: 0.00845
#
# * Models saved *
#
# New historical moving average record: 0.00849
#
# * Models saved *
#
# New historical moving average record: 0.00855
#
# * Models saved *
#
# New historical moving average record: 0.00872
#
# * Models saved *
#
# New historical moving average record: 0.00881
#
# * Models saved *
#
# New historical moving average record: 0.00893
#
# * Models saved *
#
# New historical moving average record: 0.00898
#
# * Models saved *
#
# New historical moving average record: 0.00902
#
# * Models saved *
#
# New historical moving average record: 0.00910
#
# * Models saved *
#
# New historical moving average record: 0.00918
#
# * Models saved *
#
# New historical moving average record: 0.00922
#
# * Models saved *
#
# New historical moving average record: 0.00928
#
# * Models saved *
#
# New historical moving average record: 0.00938
#
# * Models saved *
#
# New historical moving average record: 0.00943
#
# * Models saved *
#
# New historical moving average record: 0.00952
#
# * Models saved *
#
# New historical moving average record: 0.00957
#
# * Models saved *
#
# New historical moving average record: 0.00967
#
# * Models saved *
#
# New historical moving average record: 0.00968
#
# * Models saved *
#
# New historical moving average record: 0.00977
#
# * Models saved *
#
# New historical moving average record: 0.00983
#
# * Models saved *
#
# New historical moving average record: 0.00990
#
# * Models saved *
#
# New historical moving average record: 0.00999
#
# * Models saved *
#
# New historical moving average record: 0.01003
#
# * Models saved *
#
# New historical moving average record: 0.01008
#
# * Models saved *
#
# New historical moving average record: 0.01014
#
# * Models saved *
#
# New historical moving average record: 0.01022
#
# * Models saved *
#
# New historical moving average record: 0.01027
#
# * Models saved *
#
# New historical moving average record: 0.01036
#
# * Models saved *
#
# New historical moving average record: 0.01051
#
# * Models saved *
#
# New historical moving average record: 0.01057
#
# * Models saved *
#
# New historical moving average record: 0.01070
#
# * Models saved *
#
# New historical moving average record: 0.01085
#
# * Models saved *
#
# New historical moving average record: 0.01096
#
# * Models saved *
#
# New historical moving average record: 0.01109
#
# * Models saved *
#
# New historical moving average record: 0.01124
#
# * Models saved *
#
# New historical moving average record: 0.01128
#
# * Models saved *
#
# New historical moving average record: 0.01138
#
# * Models saved *
#
# New historical moving average record: 0.01148
#
# * Models saved *
#
# New historical moving average record: 0.01158
#
# * Models saved *
#
# New historical moving average record: 0.01172
#
# * Models saved *
#
# New historical moving average record: 0.01187
#
# * Models saved *
#
# New historical moving average record: 0.01192
#
# * Models saved *
#
# New historical moving average record: 0.01202
#
# * Models saved *
#
# New historical moving average record: 0.01211
#
# * Models saved *
#
# New historical moving average record: 0.01225
#
# * Models saved *
#
# New historical moving average record: 0.01226
#
# * Models saved *
#
# New historical moving average record: 0.01230
#
# * Models saved *
#
# New historical moving average record: 0.01245
#
# * Models saved *
#
# New historical moving average record: 0.01248
#
# * Models saved *
#
# New historical moving average record: 0.01254
#
# * Models saved *
#
# New historical moving average record: 0.01262
#
# * Models saved *
#
# New historical moving average record: 0.01269
#
# * Models saved *
#
# New historical moving average record: 0.01274
#
# * Models saved *
#
# New historical moving average record: 0.01281
#
# * Models saved *
#
# New historical moving average record: 0.01288
#
# * Models saved *
#
# New historical moving average record: 0.01291
#
# * Models saved *
#
# New historical moving average record: 0.01296
#
# * Models saved *
#
# New historical moving average record: 0.01316
#
# * Models saved *
#
# New historical moving average record: 0.01318
#
# * Models saved *
#
# New historical moving average record: 0.01320
#
# * Models saved *
#
# New historical moving average record: 0.01331
#
# * Models saved *
#
# New historical moving average record: 0.01342
#
# * Models saved *
#
# New historical moving average record: 0.01346
#
# * Models saved *
#
# New historical moving average record: 0.01359
#
# * Models saved *
#
# New historical moving average record: 0.01365
#
# * Models saved *
#
# New historical moving average record: 0.01368
#
# * Models saved *
#
# New historical moving average record: 0.01376
#
# * Models saved *
#
# New historical moving average record: 0.01383
#
# * Models saved *
#
# New historical moving average record: 0.01402
# * Models saved *
#
# New historical moving average record: 0.01407
#
# * Models saved *
#
# New historical moving average record: 0.01413
#
# * Models saved *
#
# New historical moving average record: 0.01418
#
# * Models saved *
#
# New historical moving average record: 0.01424
#
# * Models saved *
#
# New historical moving average record: 0.01431
#
# * Models saved *
#
# New historical moving average record: 0.01442
#
# * Models saved *
#
# New historical moving average record: 0.01454
#
# * Models saved *
#
# New historical moving average record: 0.01457
#
# * Models saved *
#
# New historical moving average record: 0.01464
#
# * Models saved *
#
# New historical moving average record: 0.01482
#
# Episode * 1100 * Worker #3 * Moving Avg Reward is ==> 0.01504 * Last Reward was ==> 0.03942 * Total episodes ending on loss: 364/1000
# * Models saved *
#
# New historical moving average record: 0.01504
#
# * Models saved *
#
# New historical moving average record: 0.01507
#
# * Models saved *
#
# New historical moving average record: 0.01507
#
# * Models saved *
#
# New historical moving average record: 0.01512
#
# * Models saved *
#
# New historical moving average record: 0.01530
#
# * Models saved *
#
# New historical moving average record: 0.01534
#
# * Models saved *
#
# New historical moving average record: 0.01540
#
# * Models saved *
#
# New historical moving average record: 0.01548
#
# * Models saved *
#
# New historical moving average record: 0.01551
#
# * Models saved *
#
# New historical moving average record: 0.01554
#
# * Models saved *
#
# New historical moving average record: 0.01570
#
# * Models saved *
#
# New historical moving average record: 0.01573
#
# * Models saved *
#
# New historical moving average record: 0.01582
#
# * Models saved *
#
# New historical moving average record: 0.01590
#
# * Models saved *
#
# New historical moving average record: 0.01596
#
# * Models saved *
#
# New historical moving average record: 0.01613
#
# * Models saved *
#
# New historical moving average record: 0.01615
#
# * Models saved *
#
# New historical moving average record: 0.01631
#
# * Models saved *
#
# New historical moving average record: 0.01644
#
# * Models saved *
#
# New historical moving average record: 0.01646
#
# * Models saved *
#
# New historical moving average record: 0.01651
#
# * Models saved *
#
# New historical moving average record: 0.01662
#
# * Models saved *
#
# New historical moving average record: 0.01668
#
# * Models saved *
#
# New historical moving average record: 0.01674
#
# * Models saved *
#
# New historical moving average record: 0.01686
#
# * Models saved *
#
# New historical moving average record: 0.01688
#
# * Models saved *
#
# New historical moving average record: 0.01693
#
# * Models saved *
#
# New historical moving average record: 0.01698
#
# * Models saved *
#
# New historical moving average record: 0.01706
#
# * Models saved *
#
# New historical moving average record: 0.01710
#
# * Models saved *
#
# New historical moving average record: 0.01715
#
# * Models saved *
#
# New historical moving average record: 0.01726
#
# * Models saved *
#
# New historical moving average record: 0.01736
#
# * Models saved *
#
# New historical moving average record: 0.01738
#
# * Models saved *
#
# New historical moving average record: 0.01742
#
# * Models saved *
#
# New historical moving average record: 0.01749
#
# * Models saved *
#
# New historical moving average record: 0.01757
#
# * Models saved *
#
# New historical moving average record: 0.01763
#
# * Models saved *
#
# New historical moving average record: 0.01776
#
# * Models saved *
#
# New historical moving average record: 0.01792
#
# * Models saved *
#
# New historical moving average record: 0.01810
#
# * Models saved *
#
# New historical moving average record: 0.01813
#
# * Models saved *
#
# New historical moving average record: 0.01830
#
# * Models saved *
#
# New historical moving average record: 0.01838
#
# * Models saved *
#
# New historical moving average record: 0.01840
#
# * Models saved *
#
# New historical moving average record: 0.01850
#
# * Models saved *
#
# New historical moving average record: 0.01859
#
# * Models saved *
#
# New historical moving average record: 0.01861
#
# * Models saved *
#
# New historical moving average record: 0.01867
#
# * Models saved *
#
# New historical moving average record: 0.01879
#
# * Models saved *
#
# New historical moving average record: 0.01883
#
# * Models saved *
#
# New historical moving average record: 0.01890
#
# * Models saved *
#
# New historical moving average record: 0.01897
#
# * Models saved *
#
# New historical moving average record: 0.01901
#
# * Models saved *
#
# New historical moving average record: 0.01913
#
# * Models saved *
#
# New historical moving average record: 0.01920
#
# * Models saved *
#
# New historical moving average record: 0.01932
#
# * Models saved *
#
# New historical moving average record: 0.01937
#
# * Models saved *
#
# New historical moving average record: 0.01953
#
# * Models saved *
#
# New historical moving average record: 0.01961
#
# * Models saved *
#
# New historical moving average record: 0.01964
#
# * Models saved *
#
# New historical moving average record: 0.01980
#
# * Models saved *
#
# New historical moving average record: 0.01994
#
# * Models saved *
#
# New historical moving average record: 0.01998
#
# * Models saved *
#
# New historical moving average record: 0.02009
#
# * Models saved *
#
# New historical moving average record: 0.02019
#
# * Models saved *
#
# New historical moving average record: 0.02025
#
# * Models saved *
#
# New historical moving average record: 0.02032
#
# * Models saved *
#
# New historical moving average record: 0.02034
#
# * Models saved *
#
# New historical moving average record: 0.02044
#
# * Models saved *
#
# New historical moving average record: 0.02047
#
# * Models saved *
#
# New historical moving average record: 0.02054
#
# * Models saved *
#
# New historical moving average record: 0.02058
#
# * Models saved *
#
# New historical moving average record: 0.02075
#
# * Models saved *
#
# New historical moving average record: 0.02084
#
# * Models saved *
#
# New historical moving average record: 0.02093
#
# * Models saved *
#
# New historical moving average record: 0.02097
#
# * Models saved *
#
# New historical moving average record: 0.02102
#
# * Models saved *
#
# New historical moving average record: 0.02107
#
# * Models saved *
#
# New historical moving average record: 0.02118
#
# * Models saved *
#
# New historical moving average record: 0.02128
#
# * Models saved *
#
# New historical moving average record: 0.02137
#
# * Models saved *
#
# New historical moving average record: 0.02145
#
# * Models saved *
#
# New historical moving average record: 0.02155
#
# * Models saved *
#
# New historical moving average record: 0.02163
#
# * Models saved *
#
# New historical moving average record: 0.02173
#
# * Models saved *
#
# New historical moving average record: 0.02180
#
# * Models saved *
#
# New historical moving average record: 0.02185
#
# * Models saved *
#
# New historical moving average record: 0.02193
#
# * Models saved *
#
# New historical moving average record: 0.02197
#
# * Models saved *
#
# New historical moving average record: 0.02210
#
# * Models saved *
#
# New historical moving average record: 0.02222
#
# * Models saved *
#
# New historical moving average record: 0.02230
#
# * Models saved *
#
# New historical moving average record: 0.02239
#
# * Models saved *
#
# New historical moving average record: 0.02243
#
# * Models saved *
#
# New historical moving average record: 0.02250
#
# Episode * 1200 * Worker #7 * Moving Avg Reward is ==> 0.02251 * Last Reward was ==> 0.04942 * Total episodes ending on loss: 303/1000
# * Models saved *
#
# New historical moving average record: 0.02251
#
# * Models saved *
#
# New historical moving average record: 0.02258
#
# * Models saved *
#
# New historical moving average record: 0.02266
#
# * Models saved *
#
# New historical moving average record: 0.02271
#
# * Models saved *
#
# New historical moving average record: 0.02279
#
# * Models saved *
#
# New historical moving average record: 0.02295
#
# * Models saved *
#
# New historical moving average record: 0.02299
#
# * Models saved *
#
# New historical moving average record: 0.02313
#
# * Models saved *
#
# New historical moving average record: 0.02320
#
# * Models saved *
#
# New historical moving average record: 0.02327
#
# * Models saved *
#
# New historical moving average record: 0.02334
#
# * Models saved *
#
# New historical moving average record: 0.02344
#
# * Models saved *
#
# New historical moving average record: 0.02354
#
# * Models saved *
#
# New historical moving average record: 0.02357
#
# * Models saved *
#
# New historical moving average record: 0.02372
#
# * Models saved *
#
# New historical moving average record: 0.02384
#
# * Models saved *
#
# New historical moving average record: 0.02395
# * Models saved *
#
# New historical moving average record: 0.02403
#
# * Models saved *
#
# New historical moving average record: 0.02411
#
# * Models saved *
#
# New historical moving average record: 0.02426
#
# * Models saved *
#
# New historical moving average record: 0.02432
#
# * Models saved *
#
# New historical moving average record: 0.02434
#
# * Models saved *
#
# New historical moving average record: 0.02444
#
# * Models saved *
#
# New historical moving average record: 0.02461
#
# * Models saved *
#
# New historical moving average record: 0.02466
#
# * Models saved *
#
# New historical moving average record: 0.02474
#
# * Models saved *
#
# New historical moving average record: 0.02480
#
# * Models saved *
#
# New historical moving average record: 0.02493
#
# * Models saved *
#
# New historical moving average record: 0.02504
#
# * Models saved *
#
# New historical moving average record: 0.02514
#
# * Models saved *
#
# New historical moving average record: 0.02519
#
# * Models saved *
#
# New historical moving average record: 0.02532
#
# * Models saved *
#
# New historical moving average record: 0.02544
#
# * Models saved *
#
# New historical moving average record: 0.02559
#
# * Models saved *
#
# New historical moving average record: 0.02570
#
# * Models saved *
#
# New historical moving average record: 0.02579
#
# * Models saved *
#
# New historical moving average record: 0.02589
#
# * Models saved *
#
# New historical moving average record: 0.02591
#
# * Models saved *
#
# New historical moving average record: 0.02597
#
# * Models saved *
#
# New historical moving average record: 0.02607
#
# * Models saved *
#
# New historical moving average record: 0.02614
#
# * Models saved *
#
# New historical moving average record: 0.02623
#
# * Models saved *
#
# New historical moving average record: 0.02627
#
# * Models saved *
#
# New historical moving average record: 0.02637
#
# * Models saved *
#
# New historical moving average record: 0.02646
#
# * Models saved *
#
# New historical moving average record: 0.02649
#
# * Models saved *
#
# New historical moving average record: 0.02651
#
# * Models saved *
#
# New historical moving average record: 0.02652
#
# * Models saved *
#
# New historical moving average record: 0.02656
#
# * Models saved *
#
# New historical moving average record: 0.02672
#
# * Models saved *
#
# New historical moving average record: 0.02685
#
# * Models saved *
#
# New historical moving average record: 0.02695
#
# * Models saved *
#
# New historical moving average record: 0.02703
#
# * Models saved *
#
# New historical moving average record: 0.02715
#
# * Models saved *
#
# New historical moving average record: 0.02724
#
# * Models saved *
#
# New historical moving average record: 0.02732
#
# * Models saved *
#
# New historical moving average record: 0.02740
#
# * Models saved *
#
# New historical moving average record: 0.02746
#
# * Models saved *
#
# New historical moving average record: 0.02753
#
# * Models saved *
#
# New historical moving average record: 0.02760
#
# * Models saved *
#
# New historical moving average record: 0.02763
#
# * Models saved *
#
# New historical moving average record: 0.02770
#
#
# * Will replay
# * Worker 0 finnished learning phase
# * Worker 1 finnished learning phase
# * Worker 2 finnished learning phase
# * Worker 3 finnished learning phase
# * Worker 4 finnished learning phase
# * Worker 5 finnished learning phase
# * Worker 6 finnished learning phase
# * Worker 7 finnished learning phase
# * Will resume
#
# * Models saved *
#
# New historical moving average record: 0.02775
#
# * Models saved *
#
# New historical moving average record: 0.02780
#
# * Models saved *
#
# New historical moving average record: 0.02790
#
# * Models saved *
#
# New historical moving average record: 0.02798
#
# * Models saved *
#
# New historical moving average record: 0.02810
#
# * Models saved *
#
# New historical moving average record: 0.02817
#
# * Models saved *
#
# New historical moving average record: 0.02822
#
# * Models saved *
#
# New historical moving average record: 0.02835
#
# * Models saved *
#
# New historical moving average record: 0.02850
#
# * Models saved *
#
# New historical moving average record: 0.02871
#
# * Models saved *
#
# New historical moving average record: 0.02875
#
# * Models saved *
#
# New historical moving average record: 0.02887
#
# * Models saved *
#
# New historical moving average record: 0.02891
#
# * Models saved *
#
# New historical moving average record: 0.02900
#
# * Models saved *
#
# New historical moving average record: 0.02906
#
# * Models saved *
#
# New historical moving average record: 0.02912
#
# * Models saved *
#
# New historical moving average record: 0.02922
#
# * Models saved *
#
# New historical moving average record: 0.02938
#
# * Models saved *
#
# New historical moving average record: 0.02952
#
# * Models saved *
#
# New historical moving average record: 0.02962
#
# * Models saved *
#
# New historical moving average record: 0.02968
#
# * Models saved *
#
# New historical moving average record: 0.02976
#
# * Models saved *
#
# New historical moving average record: 0.02988
#
# * Models saved *
#
# New historical moving average record: 0.02996
#
# * Models saved *
#
# New historical moving average record: 0.03007
#
# * Models saved *
#
# New historical moving average record: 0.03023
#
# * Models saved *
#
# New historical moving average record: 0.03031
#
# * Models saved *
#
# New historical moving average record: 0.03042
#
# * Models saved *
#
# New historical moving average record: 0.03046
#
# * Models saved *
#
# New historical moving average record: 0.03062
#
# * Models saved *
#
# New historical moving average record: 0.03074
#
# * Models saved *
#
# New historical moving average record: 0.03086
#
# * Models saved *
#
# New historical moving average record: 0.03103
#
# * Models saved *
#
# New historical moving average record: 0.03107
#
# Episode * 1300 * Worker #3 * Moving Avg Reward is ==> 0.03123 * Last Reward was ==> 0.15894 * Total episodes ending on loss: 239/1000
# * Models saved *
#
# New historical moving average record: 0.03123
#
# * Models saved *
#
# New historical moving average record: 0.03136
#
# * Models saved *
#
# New historical moving average record: 0.03155
#
# * Models saved *
#
# New historical moving average record: 0.03172
#
# * Models saved *
#
# New historical moving average record: 0.03178
#
# * Models saved *
#
# New historical moving average record: 0.03195
#
# * Models saved *
#
# New historical moving average record: 0.03213
#
# * Models saved *
#
# New historical moving average record: 0.03230
#
# * Models saved *
#
# New historical moving average record: 0.03232
#
# * Models saved *
#
# New historical moving average record: 0.03239
#
# * Models saved *
#
# New historical moving average record: 0.03244
#
# * Models saved *
#
# New historical moving average record: 0.03258
#
# * Models saved *
#
# New historical moving average record: 0.03272
#
# * Models saved *
#
# New historical moving average record: 0.03286
#
# * Models saved *
#
# New historical moving average record: 0.03290
#
# * Models saved *
#
# New historical moving average record: 0.03306
#
# * Models saved *
#
# New historical moving average record: 0.03320
#
# * Models saved *
#
# New historical moving average record: 0.03335
#
# * Models saved *
#
# New historical moving average record: 0.03340
#
# * Models saved *
#
# New historical moving average record: 0.03353
#
# * Models saved *
#
# New historical moving average record: 0.03364
#
# * Models saved *
#
# New historical moving average record: 0.03374
#
# * Models saved *
#
# New historical moving average record: 0.03377
#
# * Models saved *
#
# New historical moving average record: 0.03381
#
# * Models saved *
#
# New historical moving average record: 0.03392
#
# * Models saved *
#
# New historical moving average record: 0.03407
#
# * Models saved *
#
# New historical moving average record: 0.03436
#
# * Models saved *
#
# New historical moving average record: 0.03452
#
# * Models saved *
#
# New historical moving average record: 0.03460
#
# * Models saved *
#
# New historical moving average record: 0.03465
#
# * Models saved *
#
# New historical moving average record: 0.03468
#
# * Models saved *
#
# New historical moving average record: 0.03476
#
# * Models saved *
#
# New historical moving average record: 0.03491
#
# * Models saved *
#
# New historical moving average record: 0.03509
#
# * Models saved *
#
# New historical moving average record: 0.03525
#
# * Models saved *
#
# New historical moving average record: 0.03532
#
# * Models saved *
#
# New historical moving average record: 0.03554
#
# * Models saved *
#
# New historical moving average record: 0.03568
#
# * Models saved *
#
# New historical moving average record: 0.03577
#
# * Models saved *
#
# New historical moving average record: 0.03583
#
# * Models saved *
#
# New historical moving average record: 0.03598
#
# * Models saved *
#
# New historical moving average record: 0.03623
#
# * Models saved *
#
# New historical moving average record: 0.03637
#
# * Models saved *
#
# New historical moving average record: 0.03645
# * Models saved *
#
# New historical moving average record: 0.03656
#
# * Models saved *
#
# New historical moving average record: 0.03669
#
# * Models saved *
#
# New historical moving average record: 0.03674
#
# * Models saved *
#
# New historical moving average record: 0.03682
#
# * Models saved *
#
# New historical moving average record: 0.03690
#
# * Models saved *
#
# New historical moving average record: 0.03711
#
# * Models saved *
#
# New historical moving average record: 0.03736
#
# * Models saved *
#
# New historical moving average record: 0.03747
#
# * Models saved *
#
# New historical moving average record: 0.03754
#
# * Models saved *
#
# New historical moving average record: 0.03759
#
# * Models saved *
#
# New historical moving average record: 0.03777
#
# * Models saved *
#
# New historical moving average record: 0.03788
#
# * Models saved *
#
# New historical moving average record: 0.03802
#
# * Models saved *
#
# New historical moving average record: 0.03812
#
# * Models saved *
#
# New historical moving average record: 0.03827
#
# * Models saved *
#
# New historical moving average record: 0.03839
#
# * Models saved *
#
# New historical moving average record: 0.03847
#
# * Models saved *
#
# New historical moving average record: 0.03858
#
# * Models saved *
#
# New historical moving average record: 0.03869
#
# * Models saved *
#
# New historical moving average record: 0.03882
#
# * Models saved *
#
# New historical moving average record: 0.03886
#
# * Models saved *
#
# New historical moving average record: 0.03889
#
# * Models saved *
#
# New historical moving average record: 0.03903
#
# * Models saved *
#
# New historical moving average record: 0.03915
#
# * Models saved *
#
# New historical moving average record: 0.03935
#
# * Models saved *
#
# New historical moving average record: 0.03945
#
# * Models saved *
#
# New historical moving average record: 0.03957
#
# * Models saved *
#
# New historical moving average record: 0.03965
#
# * Models saved *
#
# New historical moving average record: 0.03981
#
# * Models saved *
#
# New historical moving average record: 0.03989
#
# * Models saved *
#
# New historical moving average record: 0.03994
#
# * Models saved *
#
# New historical moving average record: 0.04003
#
# * Models saved *
#
# New historical moving average record: 0.04008
#
# * Models saved *
#
# New historical moving average record: 0.04022
#
# * Models saved *
#
# New historical moving average record: 0.04039
#
# * Models saved *
#
# New historical moving average record: 0.04047
#
# * Models saved *
#
# New historical moving average record: 0.04054
#
# * Models saved *
#
# New historical moving average record: 0.04075
#
# * Models saved *
#
# New historical moving average record: 0.04080
#
# * Models saved *
#
# New historical moving average record: 0.04085
#
# * Models saved *
#
# New historical moving average record: 0.04097
#
# * Models saved *
#
# New historical moving average record: 0.04103
#
# * Models saved *
#
# New historical moving average record: 0.04111
#
# * Models saved *
#
# New historical moving average record: 0.04123
#
# * Models saved *
#
# New historical moving average record: 0.04137
#
# * Models saved *
#
# New historical moving average record: 0.04145
#
# * Models saved *
#
# New historical moving average record: 0.04160
#
# * Models saved *
#
# New historical moving average record: 0.04181
#
# * Models saved *
#
# New historical moving average record: 0.04195
#
# * Models saved *
#
# New historical moving average record: 0.04211
#
# * Models saved *
#
# New historical moving average record: 0.04226
#
# * Models saved *
#
# New historical moving average record: 0.04227
#
# * Models saved *
#
# New historical moving average record: 0.04242
#
# * Models saved *
#
# New historical moving average record: 0.04255
#
# * Models saved *
#
# New historical moving average record: 0.04269
#
# * Models saved *
#
# New historical moving average record: 0.04284
#
# Episode * 1400 * Worker #7 * Moving Avg Reward is ==> 0.04294 * Last Reward was ==> 0.08027 * Total episodes ending on loss: 186/1000
# * Models saved *
#
# New historical moving average record: 0.04294
#
# * Models saved *
#
# New historical moving average record: 0.04309
#
# * Models saved *
#
# New historical moving average record: 0.04317
#
# * Models saved *
#
# New historical moving average record: 0.04332
#
# * Models saved *
#
# New historical moving average record: 0.04342
#
# * Models saved *
#
# New historical moving average record: 0.04348
#
# * Models saved *
#
# New historical moving average record: 0.04364
#
# * Models saved *
#
# New historical moving average record: 0.04381
#
# * Models saved *
#
# New historical moving average record: 0.04388
#
# * Models saved *
#
# New historical moving average record: 0.04413
#
# * Models saved *
#
# New historical moving average record: 0.04429
#
# * Models saved *
#
# New historical moving average record: 0.04445
#
# * Models saved *
#
# New historical moving average record: 0.04454
#
# * Models saved *
#
# New historical moving average record: 0.04458
#
# * Models saved *
#
# New historical moving average record: 0.04466
#
# * Models saved *
#
# New historical moving average record: 0.04477
#
# * Models saved *
#
# New historical moving average record: 0.04486
#
# * Models saved *
#
# New historical moving average record: 0.04506
#
# * Models saved *
#
# New historical moving average record: 0.04521
#
# * Models saved *
#
# New historical moving average record: 0.04532
#
# * Models saved *
#
# New historical moving average record: 0.04547
#
# * Models saved *
#
# New historical moving average record: 0.04564
#
# * Models saved *
#
# New historical moving average record: 0.04578
#
# * Models saved *
#
# New historical moving average record: 0.04598
#
# * Models saved *
#
# New historical moving average record: 0.04600
#
# * Models saved *
#
# New historical moving average record: 0.04606
#
# * Models saved *
#
# New historical moving average record: 0.04626
#
# * Models saved *
#
# New historical moving average record: 0.04646
#
# * Models saved *
#
# New historical moving average record: 0.04666
#
# * Models saved *
#
# New historical moving average record: 0.04670
#
# * Models saved *
#
# New historical moving average record: 0.04687
#
# * Models saved *
#
# New historical moving average record: 0.04691
#
# * Models saved *
#
# New historical moving average record: 0.04699
#
# * Models saved *
#
# New historical moving average record: 0.04704
#
# * Models saved *
#
# New historical moving average record: 0.04711
#
# * Models saved *
#
# New historical moving average record: 0.04722
#
# * Models saved *
#
# New historical moving average record: 0.04734
#
# * Models saved *
#
# New historical moving average record: 0.04747
#
# * Models saved *
#
# New historical moving average record: 0.04759
#
# * Models saved *
#
# New historical moving average record: 0.04769
#
# * Models saved *
#
# New historical moving average record: 0.04781
#
# * Models saved *
#
# New historical moving average record: 0.04796
#
# * Models saved *
#
# New historical moving average record: 0.04800
#
# * Models saved *
#
# New historical moving average record: 0.04821
#
# * Models saved *
#
# New historical moving average record: 0.04835
#
# * Models saved *
#
# New historical moving average record: 0.04838
#
# * Models saved *
#
# New historical moving average record: 0.04861
#
# * Models saved *
#
# New historical moving average record: 0.04866
#
# * Models saved *
#
# New historical moving average record: 0.04874
#
# * Models saved *
#
# New historical moving average record: 0.04893
#
# * Models saved *
#
# New historical moving average record: 0.04905
#
# * Models saved *
#
# New historical moving average record: 0.04911
#
# * Models saved *
#
# New historical moving average record: 0.04920
#
# * Models saved *
#
# New historical moving average record: 0.04932
#
# * Models saved *
#
# New historical moving average record: 0.04949
#
# * Models saved *
#
# New historical moving average record: 0.04970
#
# * Models saved *
#
# New historical moving average record: 0.04985
#
# * Models saved *
#
# New historical moving average record: 0.05002
#
# * Models saved *
#
# New historical moving average record: 0.05012
#
# * Models saved *
#
# New historical moving average record: 0.05018
#
# * Models saved *
#
# New historical moving average record: 0.05023
#
# * Models saved *
#
# New historical moving average record: 0.05029
#
# * Models saved *
#
# New historical moving average record: 0.05039
#
# * Models saved *
#
# New historical moving average record: 0.05045
#
# * Models saved *
#
# New historical moving average record: 0.05047
#
# * Models saved *
#
# New historical moving average record: 0.05057
#
# * Models saved *
#
# New historical moving average record: 0.05069
#
# * Models saved *
#
# New historical moving average record: 0.05081
#
# * Models saved *
#
# New historical moving average record: 0.05095
#
# * Models saved *
#
# New historical moving average record: 0.05104
#
# * Models saved *
#
# New historical moving average record: 0.05118
#
# * Models saved *
#
# New historical moving average record: 0.05126
# * Models saved *
#
# New historical moving average record: 0.05133
#
# * Models saved *
#
# New historical moving average record: 0.05144
#
# * Models saved *
#
# New historical moving average record: 0.05162
#
# * Models saved *
#
# New historical moving average record: 0.05176
#
# * Models saved *
#
# New historical moving average record: 0.05196
#
# * Models saved *
#
# New historical moving average record: 0.05205
#
# * Models saved *
#
# New historical moving average record: 0.05210
#
# * Models saved *
#
# New historical moving average record: 0.05223
#
# * Models saved *
#
# New historical moving average record: 0.05231
#
# * Models saved *
#
# New historical moving average record: 0.05239
#
# * Models saved *
#
# New historical moving average record: 0.05254
#
# * Models saved *
#
# New historical moving average record: 0.05265
#
# * Models saved *
#
# New historical moving average record: 0.05285
#
# * Models saved *
#
# New historical moving average record: 0.05296
#
# * Models saved *
#
# New historical moving average record: 0.05313
#
# * Models saved *
#
# New historical moving average record: 0.05331
#
# * Models saved *
#
# New historical moving average record: 0.05345
#
# * Models saved *
#
# New historical moving average record: 0.05368
#
# * Models saved *
#
# New historical moving average record: 0.05383
#
# * Models saved *
#
# New historical moving average record: 0.05384
#
# * Models saved *
#
# New historical moving average record: 0.05391
#
# * Models saved *
#
# New historical moving average record: 0.05405
#
# * Models saved *
#
# New historical moving average record: 0.05424
#
# * Models saved *
#
# New historical moving average record: 0.05433
#
# * Models saved *
#
# New historical moving average record: 0.05442
#
# * Models saved *
#
# New historical moving average record: 0.05456
#
# * Models saved *
#
# New historical moving average record: 0.05474
#
# Episode * 1500 * Worker #3 * Moving Avg Reward is ==> 0.05486 * Last Reward was ==> 0.15680 * Total episodes ending on loss: 131/1000
# * Models saved *
#
# New historical moving average record: 0.05486
#
# * Models saved *
#
# New historical moving average record: 0.05495
#
# * Models saved *
#
# New historical moving average record: 0.05505
#
# * Models saved *
#
# New historical moving average record: 0.05513
#
# * Models saved *
#
# New historical moving average record: 0.05528
#
# * Models saved *
#
# New historical moving average record: 0.05546
#
# * Models saved *
#
# New historical moving average record: 0.05560
#
# * Models saved *
#
# New historical moving average record: 0.05573
#
# * Models saved *
#
# New historical moving average record: 0.05582
#
# * Models saved *
#
# New historical moving average record: 0.05599
#
# * Models saved *
#
# New historical moving average record: 0.05610
#
# * Models saved *
#
# New historical moving average record: 0.05621
#
# * Models saved *
#
# New historical moving average record: 0.05636
#
# * Models saved *
#
# New historical moving average record: 0.05650
#
# * Models saved *
#
# New historical moving average record: 0.05656
#
# * Models saved *
#
# New historical moving average record: 0.05664
#
# * Models saved *
#
# New historical moving average record: 0.05678
#
# * Models saved *
#
# New historical moving average record: 0.05697
#
# * Models saved *
#
# New historical moving average record: 0.05713
#
# * Models saved *
#
# New historical moving average record: 0.05716
#
# * Models saved *
#
# New historical moving average record: 0.05736
#
#
# * Will replay
# * Worker 0 finnished learning phase
# * Worker 1 finnished learning phase
# * Worker 2 finnished learning phase
# * Worker 3 finnished learning phase
# * Worker 4 finnished learning phase
# * Worker 5 finnished learning phase
# * Worker 6 finnished learning phase
# * Worker 7 finnished learning phase
# * Will resume
#
# * Models saved *
#
# New historical moving average record: 0.05754
#
# * Models saved *
#
# New historical moving average record: 0.05777
#
# * Models saved *
#
# New historical moving average record: 0.05803
#
# * Models saved *
#
# New historical moving average record: 0.05825
#
# * Models saved *
#
# New historical moving average record: 0.05835
#
# * Models saved *
#
# New historical moving average record: 0.05848
#
# * Models saved *
#
# New historical moving average record: 0.05858
#
# * Models saved *
#
# New historical moving average record: 0.05865
#
# * Models saved *
#
# New historical moving average record: 0.05887
#
# * Models saved *
#
# New historical moving average record: 0.05904
#
# * Models saved *
#
# New historical moving average record: 0.05919
#
# * Models saved *
#
# New historical moving average record: 0.05949
#
# * Models saved *
#
# New historical moving average record: 0.05965
#
# * Models saved *
#
# New historical moving average record: 0.05979
#
# * Models saved *
#
# New historical moving average record: 0.05990
#
# * Models saved *
#
# New historical moving average record: 0.06006
#
# * Models saved *
#
# New historical moving average record: 0.06017
#
# * Models saved *
#
# New historical moving average record: 0.06026
#
# * Models saved *
#
# New historical moving average record: 0.06032
#
# * Models saved *
#
# New historical moving average record: 0.06052
#
# * Models saved *
#
# New historical moving average record: 0.06065
#
# * Models saved *
#
# New historical moving average record: 0.06067
#
# * Models saved *
#
# New historical moving average record: 0.06078
#
# * Models saved *
#
# New historical moving average record: 0.06082
#
# * Models saved *
#
# New historical moving average record: 0.06097
#
# * Models saved *
#
# New historical moving average record: 0.06099
#
# * Models saved *
#
# New historical moving average record: 0.06119
#
# * Models saved *
#
# New historical moving average record: 0.06137
#
# * Models saved *
#
# New historical moving average record: 0.06151
#
# * Models saved *
#
# New historical moving average record: 0.06154
#
# * Models saved *
#
# New historical moving average record: 0.06164
#
# * Models saved *
#
# New historical moving average record: 0.06186
#
# * Models saved *
#
# New historical moving average record: 0.06201
#
# * Models saved *
#
# New historical moving average record: 0.06221
#
# * Models saved *
#
# New historical moving average record: 0.06236
#
# * Models saved *
#
# New historical moving average record: 0.06253
#
# * Models saved *
#
# New historical moving average record: 0.06274
#
# * Models saved *
#
# New historical moving average record: 0.06291
#
# * Models saved *
#
# New historical moving average record: 0.06305
#
# * Models saved *
#
# New historical moving average record: 0.06322
#
# * Models saved *
#
# New historical moving average record: 0.06335
#
# * Models saved *
#
# New historical moving average record: 0.06352
#
# * Models saved *
#
# New historical moving average record: 0.06368
#
# * Models saved *
#
# New historical moving average record: 0.06383
#
# * Models saved *
#
# New historical moving average record: 0.06406
#
# * Models saved *
#
# New historical moving average record: 0.06412
#
# * Models saved *
#
# New historical moving average record: 0.06432
#
# * Models saved *
#
# New historical moving average record: 0.06451
#
# * Models saved *
#
# New historical moving average record: 0.06458
#
# * Models saved *
#
# New historical moving average record: 0.06468
#
# * Models saved *
#
# New historical moving average record: 0.06476
#
# * Models saved *
#
# New historical moving average record: 0.06492
#
# * Models saved *
#
# New historical moving average record: 0.06501
#
# * Models saved *
#
# New historical moving average record: 0.06518
#
# * Models saved *
#
# New historical moving average record: 0.06538
#
# * Models saved *
#
# New historical moving average record: 0.06550
#
# * Models saved *
#
# New historical moving average record: 0.06573
#
# * Models saved *
#
# New historical moving average record: 0.06586
#
# * Models saved *
#
# New historical moving average record: 0.06601
#
# * Models saved *
#
# New historical moving average record: 0.06611
#
# * Models saved *
#
# New historical moving average record: 0.06618
#
# * Models saved *
#
# New historical moving average record: 0.06634
#
# * Models saved *
#
# New historical moving average record: 0.06654
#
# * Models saved *
#
# New historical moving average record: 0.06672
#
# * Models saved *
#
# New historical moving average record: 0.06682
#
# * Models saved *
#
# New historical moving average record: 0.06698
#
# * Models saved *
#
# New historical moving average record: 0.06710
#
# * Models saved *
#
# New historical moving average record: 0.06721
#
# * Models saved *
#
# New historical moving average record: 0.06729
#
# * Models saved *
#
# New historical moving average record: 0.06741
#
# * Models saved *
#
# New historical moving average record: 0.06757
#
# * Models saved *
#
# New historical moving average record: 0.06767
# * Models saved *
#
# New historical moving average record: 0.06782
#
# * Models saved *
#
# New historical moving average record: 0.06800
#
# * Models saved *
#
# New historical moving average record: 0.06807
#
# * Models saved *
#
# New historical moving average record: 0.06817
#
# * Models saved *
#
# New historical moving average record: 0.06834
#
# * Models saved *
#
# New historical moving average record: 0.06859
#
# * Models saved *
#
# New historical moving average record: 0.06874
#
# Episode * 1600 * Worker #7 * Moving Avg Reward is ==> 0.06890 * Last Reward was ==> 0.17429 * Total episodes ending on loss: 95/1000
# * Models saved *
#
# New historical moving average record: 0.06890
#
# * Models saved *
#
# New historical moving average record: 0.06906
#
# * Models saved *
#
# New historical moving average record: 0.06920
#
# * Models saved *
#
# New historical moving average record: 0.06938
#
# * Models saved *
#
# New historical moving average record: 0.06953
#
# * Models saved *
#
# New historical moving average record: 0.06977
#
# * Models saved *
#
# New historical moving average record: 0.06999
#
# * Models saved *
#
# New historical moving average record: 0.07011
#
# * Models saved *
#
# New historical moving average record: 0.07024
#
# * Models saved *
#
# New historical moving average record: 0.07043
#
# * Models saved *
#
# New historical moving average record: 0.07053
#
# * Models saved *
#
# New historical moving average record: 0.07065
#
# * Models saved *
#
# New historical moving average record: 0.07085
#
# * Models saved *
#
# New historical moving average record: 0.07104
#
# * Models saved *
#
# New historical moving average record: 0.07126
#
# * Models saved *
#
# New historical moving average record: 0.07141
#
# * Models saved *
#
# New historical moving average record: 0.07159
#
# * Models saved *
#
# New historical moving average record: 0.07173
#
# * Models saved *
#
# New historical moving average record: 0.07196
#
# * Models saved *
#
# New historical moving average record: 0.07209
#
# * Models saved *
#
# New historical moving average record: 0.07224
#
# * Models saved *
#
# New historical moving average record: 0.07227
#
# * Models saved *
#
# New historical moving average record: 0.07241
#
# * Models saved *
#
# New historical moving average record: 0.07262
#
# * Models saved *
#
# New historical moving average record: 0.07273
#
# * Models saved *
#
# New historical moving average record: 0.07284
#
# * Models saved *
#
# New historical moving average record: 0.07296
#
# * Models saved *
#
# New historical moving average record: 0.07311
#
# * Models saved *
#
# New historical moving average record: 0.07331
#
# * Models saved *
#
# New historical moving average record: 0.07348
#
# * Models saved *
#
# New historical moving average record: 0.07376
#
# * Models saved *
#
# New historical moving average record: 0.07385
#
# * Models saved *
#
# New historical moving average record: 0.07404
#
# * Models saved *
#
# New historical moving average record: 0.07429
#
# * Models saved *
#
# New historical moving average record: 0.07436
#
# * Models saved *
#
# New historical moving average record: 0.07442
#
# * Models saved *
#
# New historical moving average record: 0.07455
#
# * Models saved *
#
# New historical moving average record: 0.07478
#
# * Models saved *
#
# New historical moving average record: 0.07497
#
# * Models saved *
#
# New historical moving average record: 0.07519
#
# * Models saved *
#
# New historical moving average record: 0.07538
#
# * Models saved *
#
# New historical moving average record: 0.07561
#
# * Models saved *
#
# New historical moving average record: 0.07573
#
# * Models saved *
#
# New historical moving average record: 0.07581
#
# * Models saved *
#
# New historical moving average record: 0.07595
#
# * Models saved *
#
# New historical moving average record: 0.07611
#
# * Models saved *
#
# New historical moving average record: 0.07630
#
# * Models saved *
#
# New historical moving average record: 0.07634
#
# * Models saved *
#
# New historical moving average record: 0.07652
#
# * Models saved *
#
# New historical moving average record: 0.07665
#
# * Models saved *
#
# New historical moving average record: 0.07676
#
# * Models saved *
#
# New historical moving average record: 0.07699
#
# * Models saved *
#
# New historical moving average record: 0.07716
#
# * Models saved *
#
# New historical moving average record: 0.07731
#
# * Models saved *
#
# New historical moving average record: 0.07750
#
# * Models saved *
#
# New historical moving average record: 0.07765
#
# * Models saved *
#
# New historical moving average record: 0.07776
#
# * Models saved *
#
# New historical moving average record: 0.07792
#
# * Models saved *
#
# New historical moving average record: 0.07816
#
# * Models saved *
#
# New historical moving average record: 0.07836
#
# * Models saved *
#
# New historical moving average record: 0.07848
#
# * Models saved *
#
# New historical moving average record: 0.07862
#
# * Models saved *
#
# New historical moving average record: 0.07872
#
# * Models saved *
#
# New historical moving average record: 0.07893
#
# * Models saved *
#
# New historical moving average record: 0.07912
#
# * Models saved *
#
# New historical moving average record: 0.07931
#
# * Models saved *
#
# New historical moving average record: 0.07940
#
# * Models saved *
#
# New historical moving average record: 0.07948
#
# * Models saved *
#
# New historical moving average record: 0.07968
#
# * Models saved *
#
# New historical moving average record: 0.07979
#
# * Models saved *
#
# New historical moving average record: 0.08001
#
# * Models saved *
#
# New historical moving average record: 0.08014
#
# * Models saved *
#
# New historical moving average record: 0.08027
#
# * Models saved *
#
# New historical moving average record: 0.08034
#
# * Models saved *
#
# New historical moving average record: 0.08052
#
# * Models saved *
#
# New historical moving average record: 0.08074
#
# * Models saved *
#
# New historical moving average record: 0.08082
#
# * Models saved *
#
# New historical moving average record: 0.08098
#
# * Models saved *
#
# New historical moving average record: 0.08116
#
# * Models saved *
#
# New historical moving average record: 0.08136
#
# * Models saved *
#
# New historical moving average record: 0.08150
#
# * Models saved *
#
# New historical moving average record: 0.08166
#
# * Models saved *
#
# New historical moving average record: 0.08174
#
# * Models saved *
# ...
# * Models saved *
#
# New historical moving average record: 0.11599
#
# Agent solved environment at the episode 1888
# * Models saved *
#
# New historical moving average record: 0.11614
#
# Agent solved environment at the episode 1889
# * Models saved *
#
# New historical moving average record: 0.11632
#
# Agent solved environment at the episode 1890
# * Models saved *
#
# New historical moving average record: 0.11651
#
# Agent solved environment at the episode 1891
# * Models saved *
#
# New historical moving average record: 0.11674
#
# Agent solved environment at the episode 1892
# * Models saved *
#
# New historical moving average record: 0.11702
#
# Agent solved environment at the episode 1893
# * Models saved *
#
# New historical moving average record: 0.11723
#
# Agent solved environment at the episode 1894
# * Models saved *
#
# New historical moving average record: 0.11743
#
# Agent solved environment at the episode 1895
# * Models saved *
#
# New historical moving average record: 0.11765
#
# Agent solved environment at the episode 1896
# * Models saved *
#
# New historical moving average record: 0.11785
#
# Agent solved environment at the episode 1897
# * Models saved *
#
# New historical moving average record: 0.11802
#
# Agent solved environment at the episode 1898
# * Models saved *
#
# New historical moving average record: 0.11823
#
# Agent solved environment at the episode 1899
# Episode * 1900 * Worker #3 * Moving Avg Reward is ==> 0.11840 * Last Reward was ==> 0.23556 * Total episodes ending on loss: 14/1000
# * Models saved *
#
# New historical moving average record: 0.11840
#
# Agent solved environment at the episode 1900
# * Models saved *
#
# New historical moving average record: 0.11856
#
# Agent solved environment at the episode 1901
# * Models saved *
#
# New historical moving average record: 0.11868
#
# Agent solved environment at the episode 1902
# * Models saved *
#
# New historical moving average record: 0.11875
#
# Agent solved environment at the episode 1903
# * Models saved *
#
# New historical moving average record: 0.11905
#
# Agent solved environment at the episode 1904
# * Models saved *
#
# New historical moving average record: 0.11918
#
# Agent solved environment at the episode 1905
# * Models saved *
#
# New historical moving average record: 0.11945
#
# Agent solved environment at the episode 1906
# * Models saved *
#
# New historical moving average record: 0.11959
#
# Agent solved environment at the episode 1907
# * Models saved *
#
# New historical moving average record: 0.11976
#
# Agent solved environment at the episode 1908
# * Models saved *
#
# New historical moving average record: 0.11997
#
# Agent solved environment at the episode 1909
# * Models saved *
#
# New historical moving average record: 0.12021
#
# Agent solved environment at the episode 1910
# * Models saved *
#
# New historical moving average record: 0.12038
#
# Agent solved environment at the episode 1911
# * Models saved *
#
# New historical moving average record: 0.12062
#
# Agent solved environment at the episode 1912
# * Models saved *
#
# New historical moving average record: 0.12075
#
# Agent solved environment at the episode 1913
# * Models saved *
#
# New historical moving average record: 0.12081
#
# Agent solved environment at the episode 1914
# * Models saved *
#
# New historical moving average record: 0.12096
#
# Agent solved environment at the episode 1915
# * Models saved *
#
# New historical moving average record: 0.12108
#
# Agent solved environment at the episode 1916
# * Models saved *
#
# New historical moving average record: 0.12130
#
# Agent solved environment at the episode 1917
# * Models saved *
#
# New historical moving average record: 0.12147
#
# Agent solved environment at the episode 1918
# * Models saved *
#
# New historical moving average record: 0.12168
#
# Agent solved environment at the episode 1919
# * Models saved *
#
# New historical moving average record: 0.12188
#
# Agent solved environment at the episode 1920
# * Models saved *
#
# New historical moving average record: 0.12215
#
# Agent solved environment at the episode 1921
# * Models saved *
#
# New historical moving average record: 0.12224
#
# Agent solved environment at the episode 1922
# * Models saved *
#
# New historical moving average record: 0.12234
#
# Agent solved environment at the episode 1923
# * Models saved *
#
# New historical moving average record: 0.12243
#
# Agent solved environment at the episode 1924
# * Models saved *
#
# New historical moving average record: 0.12263
#
# Agent solved environment at the episode 1925
# * Models saved *
#
# New historical moving average record: 0.12295
#
# Agent solved environment at the episode 1926
# * Models saved *
#
# New historical moving average record: 0.12312
#
# Agent solved environment at the episode 1927
# * Models saved *
#
# New historical moving average record: 0.12336
#
# Agent solved environment at the episode 1928
# * Models saved *
#
# New historical moving average record: 0.12354
#
# Agent solved environment at the episode 1929
# * Models saved *
#
# New historical moving average record: 0.12375
#
# Agent solved environment at the episode 1930
# * Models saved *
#
# New historical moving average record: 0.12396
#
# Agent solved environment at the episode 1931
# * Models saved *
#
# New historical moving average record: 0.12416
#
# Agent solved environment at the episode 1932
# * Models saved *
#
# New historical moving average record: 0.12434
#
# Agent solved environment at the episode 1933
# * Models saved *
#
# New historical moving average record: 0.12449
#
# Agent solved environment at the episode 1934
# * Models saved *
#
# New historical moving average record: 0.12476
#
# Agent solved environment at the episode 1935
# * Models saved *
#
# New historical moving average record: 0.12507
#
# Agent solved environment at the episode 1936
# * Models saved *
#
# New historical moving average record: 0.12518
#
# Agent solved environment at the episode 1937
# * Models saved *
#
# New historical moving average record: 0.12535
#
# Agent solved environment at the episode 1938
# Agent solved environment at the episode 1939
# * Models saved *
#
# New historical moving average record: 0.12546
#
# Agent solved environment at the episode 1940
# * Models saved *
#
# New historical moving average record: 0.12559
#
# Agent solved environment at the episode 1941
# * Models saved *
#
# New historical moving average record: 0.12590
#
# Agent solved environment at the episode 1942
# * Models saved *
#
# New historical moving average record: 0.12612
#
# Agent solved environment at the episode 1943
# * Models saved *
#
# New historical moving average record: 0.12635
#
# Agent solved environment at the episode 1944
# * Models saved *
#
# New historical moving average record: 0.12650
#
# Agent solved environment at the episode 1945
# * Models saved *
#
# New historical moving average record: 0.12668
#
# Agent solved environment at the episode 1946
# * Models saved *
#
# New historical moving average record: 0.12690
#
# Agent solved environment at the episode 1947
# * Models saved *
#
# New historical moving average record: 0.12702
#
# Agent solved environment at the episode 1948
# * Models saved *
#
# New historical moving average record: 0.12722
#
# Agent solved environment at the episode 1949
# * Models saved *
#
# New historical moving average record: 0.12732
#
# Agent solved environment at the episode 1950
# * Models saved *
#
# New historical moving average record: 0.12750
#
# Agent solved environment at the episode 1951
# * Models saved *
#
# New historical moving average record: 0.12780
#
# Agent solved environment at the episode 1952
# * Models saved *
#
# New historical moving average record: 0.12794
#
# Agent solved environment at the episode 1953
# * Models saved *
#
# New historical moving average record: 0.12820
#
# Agent solved environment at the episode 1954
# * Models saved *
#
# New historical moving average record: 0.12844
#
# Agent solved environment at the episode 1955
# * Models saved *
#
# New historical moving average record: 0.12863
#
# Agent solved environment at the episode 1956
# * Models saved *
#
# New historical moving average record: 0.12887
#
# Agent solved environment at the episode 1957
# * Models saved *
#
# New historical moving average record: 0.12900
#
# Agent solved environment at the episode 1958
# * Models saved *
#
# New historical moving average record: 0.12916
#
# Agent solved environment at the episode 1959
# * Models saved *
#
# New historical moving average record: 0.12936
#
# Agent solved environment at the episode 1960
# * Models saved *
#
# New historical moving average record: 0.12958
#
# Agent solved environment at the episode 1961
# * Models saved *
#
# New historical moving average record: 0.12977
#
# Agent solved environment at the episode 1962
# * Models saved *
#
# New historical moving average record: 0.12997
#
# Agent solved environment at the episode 1963
# * Models saved *
#
# New historical moving average record: 0.13016
#
# Agent solved environment at the episode 1964
# * Models saved *
#
# New historical moving average record: 0.13041
#
# Agent solved environment at the episode 1965
# * Models saved *
#
# New historical moving average record: 0.13051
#
# Agent solved environment at the episode 1966
# * Models saved *
#
# New historical moving average record: 0.13072
#
# Agent solved environment at the episode 1967
# * Models saved *
#
# New historical moving average record: 0.13090
#
# Agent solved environment at the episode 1968
# * Models saved *
#
# New historical moving average record: 0.13111
#
# Agent solved environment at the episode 1969
# * Models saved *
#
# New historical moving average record: 0.13128
#
# Agent solved environment at the episode 1970
# * Models saved *
#
# New historical moving average record: 0.13143
#
# Agent solved environment at the episode 1971
# * Models saved *
#
# New historical moving average record: 0.13155
#
# Agent solved environment at the episode 1972
# * Models saved *
#
# New historical moving average record: 0.13173
#
# Agent solved environment at the episode 1973
# * Models saved *
#
# New historical moving average record: 0.13185
#
# Agent solved environment at the episode 1974
# * Models saved *
#
# New historical moving average record: 0.13206
#
# Agent solved environment at the episode 1975
# * Models saved *
#
# New historical moving average record: 0.13207
#
# Agent solved environment at the episode 1976
# * Models saved *
#
# New historical moving average record: 0.13226
#
# Agent solved environment at the episode 1977
# * Models saved *
#
# New historical moving average record: 0.13249
#
# Agent solved environment at the episode 1978
# * Models saved *
#
# New historical moving average record: 0.13262
#
# Agent solved environment at the episode 1979
# * Models saved *
#
# New historical moving average record: 0.13271
#
# Agent solved environment at the episode 1980
# * Models saved *
#
# New historical moving average record: 0.13292
#
# Agent solved environment at the episode 1981
# * Models saved *
#
# New historical moving average record: 0.13307
#
# Agent solved environment at the episode 1982
# * Models saved *
#
# New historical moving average record: 0.13327
#
# Agent solved environment at the episode 1983
# * Models saved *
#
# New historical moving average record: 0.13336
#
# Agent solved environment at the episode 1984
# * Models saved *
#
# New historical moving average record: 0.13362
#
# Agent solved environment at the episode 1985
# * Models saved *
#
# New historical moving average record: 0.13374
#
# Agent solved environment at the episode 1986
# * Models saved *
#
# New historical moving average record: 0.13392
#
# Agent solved environment at the episode 1987
# * Models saved *
#
# New historical moving average record: 0.13413
#
# Agent solved environment at the episode 1988
# * Models saved *
#
# New historical moving average record: 0.13416
#
# Agent solved environment at the episode 1989
# * Models saved *
#
# New historical moving average record: 0.13437
#
# Agent solved environment at the episode 1990
# * Models saved *
#
# New historical moving average record: 0.13453
#
# Agent solved environment at the episode 1991
# * Models saved *
#
# New historical moving average record: 0.13471
#
# Agent solved environment at the episode 1992
# * Models saved *
#
# New historical moving average record: 0.13493
#
# Agent solved environment at the episode 1993
# * Models saved *
#
# New historical moving average record: 0.13510
#
# Agent solved environment at the episode 1994
# * Models saved *
#
# New historical moving average record: 0.13529
#
# Agent solved environment at the episode 1995
# * Models saved *
#
# New historical moving average record: 0.13547
#
# Agent solved environment at the episode 1996
# * Models saved *
#
# New historical moving average record: 0.13562
#
# Agent solved environment at the episode 1997
# * Models saved *
#
# New historical moving average record: 0.13580
#
# Agent solved environment at the episode 1998
# * Models saved *
#
# New historical moving average record: 0.13603
#
# Agent solved environment at the episode 1999
# Episode * 2000 * Worker #7 * Moving Avg Reward is ==> 0.13621 * Last Reward was ==> 0.21393 * Total episodes ending on loss: 5/1000
# * Models saved *
#
# New historical moving average record: 0.13621
#
# Agent solved environment at the episode 2000
# * Models saved *
#
# New historical moving average record: 0.13632
#
# Agent solved environment at the episode 2001
# * Models saved *
#
# New historical moving average record: 0.13654
#
# Agent solved environment at the episode 2002
# * Models saved *
#
# New historical moving average record: 0.13683
#
# Agent solved environment at the episode 2003
# * Models saved *
#
# New historical moving average record: 0.13693
#
# Agent solved environment at the episode 2004
# * Models saved *
#
# New historical moving average record: 0.13716
#
# Agent solved environment at the episode 2005
# * Models saved *
#
# New historical moving average record: 0.13736
#
# Agent solved environment at the episode 2006
# * Models saved *
#
# New historical moving average record: 0.13762
#
# Agent solved environment at the episode 2007
# * Models saved *
#
# New historical moving average record: 0.13775
#
# Agent solved environment at the episode 2008
# * Models saved *
#
# New historical moving average record: 0.13795
#
# Agent solved environment at the episode 2009
# * Models saved *
#
# New historical moving average record: 0.13817
#
# Agent solved environment at the episode 2010
# * Models saved *
#
# New historical moving average record: 0.13832
#
# Agent solved environment at the episode 2011
# * Models saved *
#
# New historical moving average record: 0.13842
#
# Agent solved environment at the episode 2012
# * Models saved *
#
# New historical moving average record: 0.13857
#
# Agent solved environment at the episode 2013
# * Models saved *
#
# New historical moving average record: 0.13879
#
# Agent solved environment at the episode 2014
# * Models saved *
#
# New historical moving average record: 0.13886
#
# Agent solved environment at the episode 2015
# * Models saved *
#
# New historical moving average record: 0.13908
#
# Agent solved environment at the episode 2016
# * Models saved *
#
# New historical moving average record: 0.13922
#
# Agent solved environment at the episode 2017
# * Models saved *
#
# New historical moving average record: 0.13925
#
# Agent solved environment at the episode 2018
# * Models saved *
#
# New historical moving average record: 0.13934
#
# Agent solved environment at the episode 2019
# * Models saved *
#
# New historical moving average record: 0.13947
#
# Agent solved environment at the episode 2020
# * Models saved *
#
# New historical moving average record: 0.13961
#
# Agent solved environment at the episode 2021
# * Models saved *
#
# New historical moving average record: 0.13972
#
# Agent solved environment at the episode 2022
# * Models saved *
#
# New historical moving average record: 0.13992
#
# Agent solved environment at the episode 2023
# * Models saved *
#
# New historical moving average record: 0.13998
#
# Agent solved environment at the episode 2024
# Agent solved environment at the episode 2024
# Worker <Worker name='Worker-1' pid=25476 parent=23516 started> has shut down
# Worker <Worker name='Worker-2' pid=17544 parent=23516 started> has shut down
# Worker <Worker name='Worker-3' pid=17504 parent=23516 started> has shut down
# Worker <Worker name='Worker-4' pid=16836 parent=23516 started> has shut down
# Worker <Worker name='Worker-5' pid=13912 parent=23516 started> has shut down
# Worker <Worker name='Worker-6' pid=2996 parent=23516 started> has shut down
# Worker <Worker name='Worker-7' pid=10264 parent=23516 started> has shut down
# Worker <Worker name='Worker-8' pid=11136 parent=23516 started> has shut down
# * Learning cycle took 00:09:22 to finnish.

# %%
xxxxxxxxxxxxxx
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 xxxxxxxxxxxxxx
#
# NameError: name 'xxxxxxxxxxxxxx' is not defined

# %%
agent.training_duration
# Out:
# '00:09:22'

# %% [markdown]
# ### Test the results
# * Runs a set of episodes with unseen data
# * Stores the results in a csv file for later consulting

# %%
success = 0
n_tests = 10000

scores = []
targets = []
portfolio_target_ratios = []
initial_investments = []

for i in trange(n_tests):
    state = agent.env.reset(visualize=False,mode="test")
    step = 0
    score = 0
    reward = 0
    done = False
    
    targets.append((agent.env.episode_target-agent.env.initial_investment)/agent.env.initial_investment)
    initial_investments.append(agent.env.initial_investment)

    while not done:
        state = agent.reshape_state(state)
        agent.env.render()
        #state = np.expand_dims(state, axis=0)
        action, action_onehot, prediction = agent.choose_action(state)
        # Retrieve new state, reward, and whether the state is terminal
        next_state, reward, done, info = agent.env.step(action)
        #print(action, reward, agent.env.portfolio_value)
        # Memorize (state, action, reward) for training
        #self.buffer.remember(np.expand_dims(state, axis=0), action_onehot, reward)
        # Update current state
        if done :
            if agent.env.portfolio_value > agent.env.initial_investment:
                success +=1

        step+=1
        state = next_state
        score += reward
    
    # Track scores and ratios
    scores.append(score)
    portfolio_target_ratios.append(info["portfolio_value"]/info["episode_target"] -1)
    
    
test_results_dataframe = pd.DataFrame([[
    n_tests,
    str(round(np.mean(scores)*100,3))+'%',
    str(round(np.mean(targets)*100,3))+'%',
    str(round(np.mean(portfolio_target_ratios)*100,3))+'%',
    str(round(min(scores)*100,3))+'%',
    str(round(max(scores)*100,3))+'%',
    str(round((success/n_tests)*100,3)) +'%'
]],
    columns=[
        '# Blind tests',
        '% Average portfolio return', 
        '% Desired portfolio return', 
        'Portfolio/Target rate',
        '% Historical minimum return',
        '% Historical maximum return', 
        '% Episodes concluded with positive outcome'
    ]
)



test_results_dataframe.T

# %%
agent.results_writer.store_test_results(agent,test_results_dataframe)

# %% [markdown]
# ### Visual test
# * Runs a set of episodes with unseen data
# * See the evolution in real time

# %%
success = 0
n_tests = 2

scores = []
targets = []


for i in trange(n_tests):
    state = agent.env.reset(visualize=True,mode="test")
    step = 0
    score = 0
    reward = 0
    done = False
    targets.append((agent.env.episode_target-agent.env.initial_investment)/agent.env.initial_investment)
    initial_portfolio = agent.env.portfolio_value

    while not done:
        agent.env.render()
        
        # Shape the state
        state = agent.reshape_state(state)
        # Select a action
        action, action_onehot, prediction = agent.choose_action(state)
        
        # Retrieve new state, reward, and whether the state is terminal
        next_state, reward, done, _ = agent.env.step(action)
        
        # End of episode, track scores here
        if done :
            if agent.env.portfolio_value > agent.env.initial_investment:
                success +=1

        step+=1
        state = next_state
        score += reward
    
    scores.append(score)

agent.env.close()

# %% [markdown]
# ### Transactions profit
# * Track how much the agent gained by doing purchases and sales
# * Doesn't track the portfolio value
# * Already has the fees discounted

# %%
success = 0
n_tests = 10000

test_results_data = []
test_results_columns = [
    'dataset id',
    'episode start date', 
    'episode end date',
    'episode working days',
    'total transactions',
    'total transaction profit',
    "dataframe hash",
    "agent hash"
]

print('NOTE: This test only tracks the transactions profit. ')

for i in trange(n_tests):
    trading_history = []
    state = agent.env.reset(visualize=False,mode="test")
    step = 0
    score = 0
    reward = 0
    done = False
    #targets.append((agent.env.episode_target-agent.env.initial_investment)/agent.env.initial_investment)
    #initial_portfolio = agent.env.portfolio_value
    
    j = 0
    num_stocks = 0
    while not done:
        agent.env.render()
        
        # Select desired action
        state = agent.reshape_state(state)
        action, action_onehot, prediction = agent.choose_action(state)
        current_price = agent.env.df.iloc[agent.env.current_step -1]['close']
        
        if action == agent.env.ACTIONS.BUY:
            discounted_price = current_price * (1+agent.env.fees.BUY) 
            if agent.env.stock_held < agent.env.maximum_stocks_held and agent.env.cash_in_hand >= discounted_price:
                num_stocks +=1
                trading_history.append(['buy', discounted_price])
        elif action == agent.env.ACTIONS.SELL:
            if agent.env.stock_held > 0:
                discounted_price = current_price * (1-agent.env.fees.SELL) 
                trading_history.append(['sell', discounted_price])
                num_stocks =0
                
        # Retrieve new state, reward, and whether the state is terminal
        next_state, reward, done, _ = agent.env.step(action)

        # Update current state
        if done :
            if agent.env.portfolio_value > agent.env.initial_investment:
                success +=1
                
            profits = []
            purchases = []
            for e in trading_history:
                if e[0] == 'buy':
                    purchases.append(e[1])
                else:
                    profits.append((e[1]* len(purchases) - sum(purchases)) / sum(purchases))
                    purchases.clear() 
                    
            test_results_data.append([
                agent.env.dataset_idx,
                agent.env.df.iloc[agent.env.lookback].name,
                agent.env.df.iloc[-1].name,
                agent.env.window_size,
                len(profits),
                sum(profits)*100,
                agent.env.df_name,
                agent.hash
            ])


        step+=1
        state = next_state
        score += reward
    

agent.env.close()


pd.DataFrame(test_results_data,columns=test_results_columns)

# %%
transaction_results_df = pd.DataFrame(test_results_data,columns=test_results_columns)
transaction_results_df.sort_values(by="dataset id")

# %%
failed_episodes_df = transaction_results_df[transaction_results_df['total transaction profit'] <= 0]
failed_episodes_idx = failed_episodes_df['dataset id'].unique()
failed_episodes_idx.sort()

# %%
len(transaction_results_df[transaction_results_df['total transaction profit'] <= 0]['dataset id'].unique()),len(transaction_results_df[transaction_results_df['total transaction profit'] > 0]['dataset id'].unique())

# %%
import matplotlib.pyplot as plt 

for idx in failed_episodes_idx:
    plt.figure(figsize=(16,4))
    plt.plot(agent.env.df['close'])
    plt.title('#'+str(idx)+' - ' + str(len(failed_episodes_df[failed_episodes_df['dataset id'] == idx])) +'/' + str(len(transaction_results_df[transaction_results_df['dataset id'] == idx])))
