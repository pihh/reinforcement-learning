# %%
import shutup
shutup.please()

import gym
import src.environments.continuous.stock_trading  

import numpy as np
import pandas as pd 

from tqdm.notebook import trange, tqdm

# %% [markdown]
# ### Train the agent
# * Run it until he has a running average above the success_threshold
# * Use a large number of episodes for the running average ( 1000+ ) so if even it falls into a privileged sample, it wont be prone to error

# %%
def environment():
    env = gym.make('StockTradingEnvironment-v0',
        ticker="IBM",
        use_technical_indicators= [
        "macd",
        "boll_ub",
        "boll_lb",
        "rsi_30",
        "cci_30",
        "dx_30",
        "close_30_sma",
        "close_60_sma",
    ])
    
    poc_threshold = 0.1 # 10% 
    print('* Original success threshold', env.success_threshold)
    
    print('* POC success threshold', poc_threshold)
    print()
    
    env.success_threshold = poc_threshold


# from src.environments.continuous.trading import environment

# %%
from src.agents.actor_critic.a2c import A2CAgent

# %%
agent=A2CAgent(environment, epochs=1, actor_learning_rate=0.000025,critic_learning_rate=0.000025,policy="CNN")
agent.load()
# Out:
# [nltk_data] Error loading vader_lexicon: <urlopen error [Errno 11001]
# [nltk_data]     getaddrinfo failed>
# boll_lb
# boll_ub
# cci_30
# close_30_sma
# close_60_sma
# dx_30
# macd
# rsi_30
# boll_lb close
# boll_ub close
# cci_30 259
# close_30_sma close
# close_60_sma close
# dx_30 100
# macd close
# macd close
# rsi_30 100
#
# original threshold 0.03489889871905054
# current threshold 0.25
# @TODO
# @TODO
# * Models successfully loaded *

# %%
agent.env.mode = "train"
agent.learning_log.episodes = 0
agent.learn(
    timesteps=-1, 
    log_every=100,
    success_threshold_lookback=1000,
    success_strict=True,
)

print('A2C + CNN + 0.25 threshold -> Executed in 1h 1m 4s, finished 18:43:51 2022-08-08')
# Out:
# Episode * 100 * Moving Avg Reward is ==> -0.02098 * Last Reward was ==> -0.03791
# Episode * 200 * Moving Avg Reward is ==> -0.01549 * Last Reward was ==> 0.01794
# Episode * 300 * Moving Avg Reward is ==> -0.01175 * Last Reward was ==> -0.05808
# Episode * 400 * Moving Avg Reward is ==> -0.00938 * Last Reward was ==> 0.01416
# Episode * 500 * Moving Avg Reward is ==> -0.00790 * Last Reward was ==> -0.00349
# Episode * 600 * Moving Avg Reward is ==> -0.00705 * Last Reward was ==> 0.00893
# Episode * 700 * Moving Avg Reward is ==> -0.00623 * Last Reward was ==> 0.00062
# Episode * 800 * Moving Avg Reward is ==> -0.00568 * Last Reward was ==> 0.00347
# Episode * 900 * Moving Avg Reward is ==> -0.00509 * Last Reward was ==> -0.00713
# Episode * 1000 * Moving Avg Reward is ==> -0.00463 * Last Reward was ==> -0.00000
# Episode * 1100 * Moving Avg Reward is ==> -0.00253 * Last Reward was ==> 0.00000
# Episode * 1200 * Moving Avg Reward is ==> -0.00155 * Last Reward was ==> 0.00023
# Episode * 1300 * Moving Avg Reward is ==> -0.00111 * Last Reward was ==> 0.00302
# Episode * 1400 * Moving Avg Reward is ==> -0.00090 * Last Reward was ==> 0.00000
# Episode * 1500 * Moving Avg Reward is ==> -0.00069 * Last Reward was ==> 0.00000
# Episode * 1600 * Moving Avg Reward is ==> -0.00042 * Last Reward was ==> -0.00093
# Episode * 1700 * Moving Avg Reward is ==> -0.00029 * Last Reward was ==> 0.00065
# Episode * 1800 * Moving Avg Reward is ==> -0.00010 * Last Reward was ==> 0.00552
# Episode * 1900 * Moving Avg Reward is ==> -0.00007 * Last Reward was ==> 0.00387
# Episode * 2000 * Moving Avg Reward is ==> -0.00005 * Last Reward was ==> 0.00100
# Episode * 2100 * Moving Avg Reward is ==> -0.00006 * Last Reward was ==> 0.00047
# Episode * 2200 * Moving Avg Reward is ==> -0.00002 * Last Reward was ==> 0.00166
# * Models saved *
#
# New historical moving average record: 0.00000
#
# * Models saved *
#
# New historical moving average record: 0.00000
#
# * Models saved *
#
# New historical moving average record: 0.00000
#
# Episode * 2300 * Moving Avg Reward is ==> -0.00003 * Last Reward was ==> 0.00526
# * Models saved *
#
# New historical moving average record: 0.00000
#
# * Models saved *
#
# New historical moving average record: 0.00000
#
# * Models saved *
#
# New historical moving average record: 0.00000
#
# * Models saved *
#
# New historical moving average record: 0.00001
#
# * Models saved *
#
# New historical moving average record: 0.00002
#
# * Models saved *
#
# New historical moving average record: 0.00002
#
# * Models saved *
#
# New historical moving average record: 0.00002
#
# * Models saved *
#
# New historical moving average record: 0.00002
#
# * Models saved *
#
# New historical moving average record: 0.00003
#
# * Models saved *
#
# New historical moving average record: 0.00003
#
# * Models saved *
#
# New historical moving average record: 0.00003
#
# * Models saved *
#
# New historical moving average record: 0.00003
#
# * Models saved *
#
# New historical moving average record: 0.00003
#
# * Models saved *
#
# New historical moving average record: 0.00003
#
# * Models saved *
#
# New historical moving average record: 0.00004
#
# * Models saved *
#
# New historical moving average record: 0.00004
#
# Episode * 2400 * Moving Avg Reward is ==> 0.00004 * Last Reward was ==> 0.00000
# * Models saved *
#
# New historical moving average record: 0.00004
#
# * Models saved *
#
# New historical moving average record: 0.00004
#
# * Models saved *
#
# New historical moving average record: 0.00005
#
# * Models saved *
#
# New historical moving average record: 0.00005
#
# * Models saved *
#
# New historical moving average record: 0.00005
#
# * Models saved *
#
# New historical moving average record: 0.00005
#
# Episode * 2500 * Moving Avg Reward is ==> 0.00001 * Last Reward was ==> 0.00056
# Episode * 2600 * Moving Avg Reward is ==> 0.00004 * Last Reward was ==> -0.00261
# Episode * 2700 * Moving Avg Reward is ==> -0.00000 * Last Reward was ==> 0.00000
# Episode * 2800 * Moving Avg Reward is ==> 0.00001 * Last Reward was ==> 0.00127
# * Models saved *
#
# New historical moving average record: 0.00006
#
# * Models saved *
#
# New historical moving average record: 0.00006
#
# * Models saved *
#
# New historical moving average record: 0.00006
#
# Episode * 2900 * Moving Avg Reward is ==> 0.00005 * Last Reward was ==> 0.00000
# * Models saved *
#
# New historical moving average record: 0.00007
#
# * Models saved *
#
# New historical moving average record: 0.00008
#
# * Models saved *
#
# New historical moving average record: 0.00008
#
# * Models saved *
#
# New historical moving average record: 0.00008
#
# * Models saved *
#
# New historical moving average record: 0.00008
#
# * Models saved *
#
# New historical moving average record: 0.00008
#
# * Models saved *
#
# New historical moving average record: 0.00009
#
# * Models saved *
#
# New historical moving average record: 0.00009
#
# * Models saved *
#
# New historical moving average record: 0.00009
#
# * Models saved *
#
# New historical moving average record: 0.00009
#
# * Models saved *
#
# New historical moving average record: 0.00009
#
# * Models saved *
#
# New historical moving average record: 0.00010
#
# * Models saved *
#
# New historical moving average record: 0.00010
#
# * Models saved *
#
# New historical moving average record: 0.00010
#
# * Models saved *
#
# New historical moving average record: 0.00010
#
# * Models saved *
#
# New historical moving average record: 0.00010
#
# * Models saved *
#
# New historical moving average record: 0.00010
#
# Episode * 3000 * Moving Avg Reward is ==> 0.00008 * Last Reward was ==> -0.00079
# * Models saved *
#
# New historical moving average record: 0.00011
#
# * Models saved *
#
# New historical moving average record: 0.00011
#
# * Models saved *
#
# New historical moving average record: 0.00011
#
# * Models saved *
#
# New historical moving average record: 0.00011
#
# * Models saved *
#
# New historical moving average record: 0.00011
#
# Episode * 3100 * Moving Avg Reward is ==> 0.00011 * Last Reward was ==> 0.00021
# * Models saved *
#
# New historical moving average record: 0.00011
#
# * Models saved *
#
# New historical moving average record: 0.00011
#
# * Models saved *
#
# New historical moving average record: 0.00011
#
# * Models saved *
#
# New historical moving average record: 0.00011
#
# * Models saved *
#
# New historical moving average record: 0.00011
#
# * Models saved *
#
# New historical moving average record: 0.00012
#
# * Models saved *
#
# New historical moving average record: 0.00012
#
# * Models saved *
#
# New historical moving average record: 0.00012
#
# * Models saved *
#
# New historical moving average record: 0.00012
#
# * Models saved *
#
# New historical moving average record: 0.00012
#
# * Models saved *
#
# New historical moving average record: 0.00012
#
# * Models saved *
#
# New historical moving average record: 0.00013
#
# * Models saved *
#
# New historical moving average record: 0.00013
#
# Episode * 3200 * Moving Avg Reward is ==> 0.00008 * Last Reward was ==> 0.00000
# Episode * 3300 * Moving Avg Reward is ==> 0.00007 * Last Reward was ==> 0.00262
# Episode * 3400 * Moving Avg Reward is ==> -0.00002 * Last Reward was ==> -0.00101
# Episode * 3500 * Moving Avg Reward is ==> 0.00008 * Last Reward was ==> 0.00387
# * Models saved *
#
# New historical moving average record: 0.00014
#
# * Models saved *
#
# New historical moving average record: 0.00014
#
# * Models saved *
#
# New historical moving average record: 0.00014
#
# * Models saved *
#
# New historical moving average record: 0.00015
#
# * Models saved *
#
# New historical moving average record: 0.00015
#
# * Models saved *
#
# New historical moving average record: 0.00019
#
# * Models saved *
#
# New historical moving average record: 0.00019
#
# * Models saved *
#
# New historical moving average record: 0.00020
#
# * Models saved *
#
# New historical moving average record: 0.00021
#
# * Models saved *
#
# New historical moving average record: 0.00022
#
# * Models saved *
#
# New historical moving average record: 0.00022
#
# * Models saved *
#
# New historical moving average record: 0.00023
#
# * Models saved *
#
# New historical moving average record: 0.00023
#
# * Models saved *
#
# New historical moving average record: 0.00024
#
# * Models saved *
#
# New historical moving average record: 0.00024
#
# Episode * 3600 * Moving Avg Reward is ==> 0.00024 * Last Reward was ==> 0.00413
# * Models saved *
#
# New historical moving average record: 0.00026
#
# * Models saved *
#
# New historical moving average record: 0.00027
#
# * Models saved *
#
# New historical moving average record: 0.00029
#
# * Models saved *
#
# New historical moving average record: 0.00029
# * Models saved *
#
# New historical moving average record: 0.00029
#
# * Models saved *
#
# New historical moving average record: 0.00029
#
# * Models saved *
#
# New historical moving average record: 0.00030
#
# * Models saved *
#
# New historical moving average record: 0.00030
#
# * Models saved *
#
# New historical moving average record: 0.00030
#
# * Models saved *
#
# New historical moving average record: 0.00031
#
# * Models saved *
#
# New historical moving average record: 0.00032
#
# * Models saved *
#
# New historical moving average record: 0.00032
#
# * Models saved *
#
# New historical moving average record: 0.00032
#
# * Models saved *
#
# New historical moving average record: 0.00032
#
# * Models saved *
#
# New historical moving average record: 0.00032
#
# * Models saved *
#
# New historical moving average record: 0.00032
#
# Episode * 3700 * Moving Avg Reward is ==> 0.00032 * Last Reward was ==> -0.00452
# * Models saved *
#
# New historical moving average record: 0.00032
#
# * Models saved *
#
# New historical moving average record: 0.00033
#
# * Models saved *
#
# New historical moving average record: 0.00033
#
# * Models saved *
#
# New historical moving average record: 0.00034
#
# * Models saved *
#
# New historical moving average record: 0.00034
#
# * Models saved *
#
# New historical moving average record: 0.00034
#
# * Models saved *
#
# New historical moving average record: 0.00035
#
# * Models saved *
#
# New historical moving average record: 0.00036
#
# * Models saved *
#
# New historical moving average record: 0.00037
#
# * Models saved *
#
# New historical moving average record: 0.00037
#
# * Models saved *
#
# New historical moving average record: 0.00042
#
# * Models saved *
#
# New historical moving average record: 0.00042
#
# * Models saved *
#
# New historical moving average record: 0.00042
#
# * Models saved *
#
# New historical moving average record: 0.00043
#
# * Models saved *
#
# New historical moving average record: 0.00044
#
# * Models saved *
#
# New historical moving average record: 0.00044
#
# Episode * 3800 * Moving Avg Reward is ==> 0.00041 * Last Reward was ==> 0.00347
# * Models saved *
#
# New historical moving average record: 0.00044
#
# * Models saved *
#
# New historical moving average record: 0.00045
#
# * Models saved *
#
# New historical moving average record: 0.00046
#
# * Models saved *
#
# New historical moving average record: 0.00051
#
# * Models saved *
#
# New historical moving average record: 0.00051
#
# * Models saved *
#
# New historical moving average record: 0.00051
#
# * Models saved *
#
# New historical moving average record: 0.00051
#
# * Models saved *
#
# New historical moving average record: 0.00053
#
# * Models saved *
#
# New historical moving average record: 0.00053
#
# * Models saved *
#
# New historical moving average record: 0.00053
#
# * Models saved *
#
# New historical moving average record: 0.00054
#
# * Models saved *
#
# New historical moving average record: 0.00055
#
# * Models saved *
#
# New historical moving average record: 0.00057
#
# Episode * 3900 * Moving Avg Reward is ==> 0.00055 * Last Reward was ==> -0.00401
# * Models saved *
#
# New historical moving average record: 0.00058
#
# * Models saved *
#
# New historical moving average record: 0.00059
#
# * Models saved *
#
# New historical moving average record: 0.00059
#
# * Models saved *
#
# New historical moving average record: 0.00061
#
# * Models saved *
#
# New historical moving average record: 0.00062
#
# * Models saved *
#
# New historical moving average record: 0.00064
#
# * Models saved *
#
# New historical moving average record: 0.00064
#
# * Models saved *
#
# New historical moving average record: 0.00065
#
# * Models saved *
#
# New historical moving average record: 0.00066
#
# * Models saved *
#
# New historical moving average record: 0.00068
#
# * Models saved *
#
# New historical moving average record: 0.00068
#
# * Models saved *
#
# New historical moving average record: 0.00069
#
# * Models saved *
#
# New historical moving average record: 0.00069
#
# * Models saved *
#
# New historical moving average record: 0.00069
#
# * Models saved *
#
# New historical moving average record: 0.00069
#
# * Models saved *
#
# New historical moving average record: 0.00070
#
# * Models saved *
#
# New historical moving average record: 0.00071
#
# * Models saved *
#
# New historical moving average record: 0.00073
#
# * Models saved *
#
# New historical moving average record: 0.00073
#
# * Models saved *
#
# New historical moving average record: 0.00075
#
# * Models saved *
#
# New historical moving average record: 0.00075
#
# * Models saved *
#
# New historical moving average record: 0.00075
#
# * Models saved *
#
# New historical moving average record: 0.00076
#
# * Models saved *
#
# New historical moving average record: 0.00077
#
# * Models saved *
#
# New historical moving average record: 0.00077
#
# * Models saved *
#
# New historical moving average record: 0.00078
#
# * Models saved *
#
# New historical moving average record: 0.00078
#
# * Models saved *
#
# New historical moving average record: 0.00080
#
# * Models saved *
#
# New historical moving average record: 0.00085
#
# * Models saved *
#
# New historical moving average record: 0.00086
#
# * Models saved *
#
# New historical moving average record: 0.00087
#
# * Models saved *
#
# New historical moving average record: 0.00087
#
# * Models saved *
#
# New historical moving average record: 0.00088
#
# * Models saved *
#
# New historical moving average record: 0.00088
#
# * Models saved *
#
# New historical moving average record: 0.00092
#
# Episode * 4000 * Moving Avg Reward is ==> 0.00098 * Last Reward was ==> 0.05657
# * Models saved *
#
# New historical moving average record: 0.00098
#
# * Models saved *
#
# New historical moving average record: 0.00098
#
# * Models saved *
#
# New historical moving average record: 0.00098
#
# * Models saved *
#
# New historical moving average record: 0.00098
#
# * Models saved *
#
# New historical moving average record: 0.00099
#
# * Models saved *
#
# New historical moving average record: 0.00105
#
# * Models saved *
#
# New historical moving average record: 0.00105
#
# * Models saved *
#
# New historical moving average record: 0.00106
#
# * Models saved *
#
# New historical moving average record: 0.00111
#
# * Models saved *
#
# New historical moving average record: 0.00115
#
# * Models saved *
#
# New historical moving average record: 0.00115
#
# * Models saved *
#
# New historical moving average record: 0.00119
#
# * Models saved *
#
# New historical moving average record: 0.00122
#
# * Models saved *
#
# New historical moving average record: 0.00125
#
# * Models saved *
#
# New historical moving average record: 0.00127
#
# * Models saved *
#
# New historical moving average record: 0.00127
#
# * Models saved *
#
# New historical moving average record: 0.00131
#
# * Models saved *
#
# New historical moving average record: 0.00132
#
# * Models saved *
#
# New historical moving average record: 0.00137
#
# * Models saved *
#
# New historical moving average record: 0.00140
#
# * Models saved *
#
# New historical moving average record: 0.00147
#
# * Models saved *
#
# New historical moving average record: 0.00147
#
# * Models saved *
#
# New historical moving average record: 0.00149
#
# * Models saved *
#
# New historical moving average record: 0.00151
#
# * Models saved *
#
# New historical moving average record: 0.00152
#
# * Models saved *
#
# New historical moving average record: 0.00153
#
# * Models saved *
#
# New historical moving average record: 0.00158
#
# * Models saved *
#
# New historical moving average record: 0.00162
#
# * Models saved *
#
# New historical moving average record: 0.00167
#
# * Models saved *
#
# New historical moving average record: 0.00170
#
# * Models saved *
#
# New historical moving average record: 0.00171
#
# * Models saved *
#
# New historical moving average record: 0.00173
#
# * Models saved *
#
# New historical moving average record: 0.00174
#
# * Models saved *
#
# New historical moving average record: 0.00175
#
# * Models saved *
#
# New historical moving average record: 0.00181
#
# * Models saved *
#
# New historical moving average record: 0.00182
#
# * Models saved *
#
# New historical moving average record: 0.00184
#
# * Models saved *
#
# New historical moving average record: 0.00187
#
# * Models saved *
#
# New historical moving average record: 0.00192
#
# * Models saved *
#
# New historical moving average record: 0.00192
#
# * Models saved *
#
# New historical moving average record: 0.00201
#
# * Models saved *
#
# New historical moving average record: 0.00206
#
# * Models saved *
#
# New historical moving average record: 0.00208
#
# * Models saved *
#
# New historical moving average record: 0.00210
#
# * Models saved *
#
# New historical moving average record: 0.00213
#
# * Models saved *
#
# New historical moving average record: 0.00217
# * Models saved *
#
# New historical moving average record: 0.00223
#
# * Models saved *
#
# New historical moving average record: 0.00225
#
# * Models saved *
#
# New historical moving average record: 0.00230
#
# * Models saved *
#
# New historical moving average record: 0.00239
#
# * Models saved *
#
# New historical moving average record: 0.00241
#
# * Models saved *
#
# New historical moving average record: 0.00242
#
# * Models saved *
#
# New historical moving average record: 0.00251
#
# * Models saved *
#
# New historical moving average record: 0.00253
#
# * Models saved *
#
# New historical moving average record: 0.00255
#
# * Models saved *
#
# New historical moving average record: 0.00257
#
# Episode * 4100 * Moving Avg Reward is ==> 0.00256 * Last Reward was ==> 0.00458
# * Models saved *
#
# New historical moving average record: 0.00257
#
# * Models saved *
#
# New historical moving average record: 0.00257
#
# * Models saved *
#
# New historical moving average record: 0.00259
#
# * Models saved *
#
# New historical moving average record: 0.00273
#
# * Models saved *
#
# New historical moving average record: 0.00275
#
# * Models saved *
#
# New historical moving average record: 0.00288
#
# * Models saved *
#
# New historical moving average record: 0.00298
#
# * Models saved *
#
# New historical moving average record: 0.00301
#
# * Models saved *
#
# New historical moving average record: 0.00304
#
# * Models saved *
#
# New historical moving average record: 0.00308
#
# * Models saved *
#
# New historical moving average record: 0.00314
#
# * Models saved *
#
# New historical moving average record: 0.00314
#
# * Models saved *
#
# New historical moving average record: 0.00324
#
# * Models saved *
#
# New historical moving average record: 0.00341
#
# * Models saved *
#
# New historical moving average record: 0.00342
#
# * Models saved *
#
# New historical moving average record: 0.00349
#
# * Models saved *
#
# New historical moving average record: 0.00350
#
# * Models saved *
#
# New historical moving average record: 0.00351
#
# * Models saved *
#
# New historical moving average record: 0.00355
#
# * Models saved *
#
# New historical moving average record: 0.00363
#
# * Models saved *
#
# New historical moving average record: 0.00364
#
# * Models saved *
#
# New historical moving average record: 0.00365
#
# * Models saved *
#
# New historical moving average record: 0.00369
#
# * Models saved *
#
# New historical moving average record: 0.00383
#
# * Models saved *
#
# New historical moving average record: 0.00389
#
# * Models saved *
#
# New historical moving average record: 0.00399
#
# * Models saved *
#
# New historical moving average record: 0.00408
#
# * Models saved *
#
# New historical moving average record: 0.00409
#
# * Models saved *
#
# New historical moving average record: 0.00410
#
# * Models saved *
#
# New historical moving average record: 0.00420
#
# * Models saved *
#
# New historical moving average record: 0.00422
#
# * Models saved *
#
# New historical moving average record: 0.00431
#
# * Models saved *
#
# New historical moving average record: 0.00433
#
# * Models saved *
#
# New historical moving average record: 0.00440
#
# * Models saved *
#
# New historical moving average record: 0.00449
#
# * Models saved *
#
# New historical moving average record: 0.00450
#
# * Models saved *
#
# New historical moving average record: 0.00455
#
# * Models saved *
#
# New historical moving average record: 0.00463
#
# * Models saved *
#
# New historical moving average record: 0.00465
#
# * Models saved *
#
# New historical moving average record: 0.00466
#
# * Models saved *
#
# New historical moving average record: 0.00471
#
# * Models saved *
#
# New historical moving average record: 0.00476
#
# * Models saved *
#
# New historical moving average record: 0.00484
#
# * Models saved *
#
# New historical moving average record: 0.00491
#
# * Models saved *
#
# New historical moving average record: 0.00492
#
# * Models saved *
#
# New historical moving average record: 0.00494
#
# * Models saved *
#
# New historical moving average record: 0.00498
#
# * Models saved *
#
# New historical moving average record: 0.00511
#
# * Models saved *
#
# New historical moving average record: 0.00514
#
# * Models saved *
#
# New historical moving average record: 0.00515
#
# * Models saved *
#
# New historical moving average record: 0.00515
#
# * Models saved *
#
# New historical moving average record: 0.00526
#
# * Models saved *
#
# New historical moving average record: 0.00535
#
# * Models saved *
#
# New historical moving average record: 0.00540
#
# * Models saved *
#
# New historical moving average record: 0.00541
#
# * Models saved *
#
# New historical moving average record: 0.00550
#
# * Models saved *
#
# New historical moving average record: 0.00553
#
# * Models saved *
#
# New historical moving average record: 0.00555
#
# * Models saved *
#
# New historical moving average record: 0.00558
#
# Episode * 4200 * Moving Avg Reward is ==> 0.00565 * Last Reward was ==> 0.07224
# * Models saved *
#
# New historical moving average record: 0.00565
#
# * Models saved *
#
# New historical moving average record: 0.00566
#
# * Models saved *
#
# New historical moving average record: 0.00570
#
# * Models saved *
#
# New historical moving average record: 0.00580
#
# * Models saved *
#
# New historical moving average record: 0.00585
#
# * Models saved *
#
# New historical moving average record: 0.00588
#
# * Models saved *
#
# New historical moving average record: 0.00590
#
# * Models saved *
#
# New historical moving average record: 0.00591
#
# * Models saved *
#
# New historical moving average record: 0.00592
#
# * Models saved *
#
# New historical moving average record: 0.00593
#
# * Models saved *
#
# New historical moving average record: 0.00595
#
# * Models saved *
#
# New historical moving average record: 0.00597
#
# * Models saved *
#
# New historical moving average record: 0.00603
#
# * Models saved *
#
# New historical moving average record: 0.00610
#
# * Models saved *
#
# New historical moving average record: 0.00612
#
# * Models saved *
#
# New historical moving average record: 0.00622
#
# * Models saved *
#
# New historical moving average record: 0.00624
#
# * Models saved *
#
# New historical moving average record: 0.00627
#
# * Models saved *
#
# New historical moving average record: 0.00636
#
# * Models saved *
#
# New historical moving average record: 0.00647
#
# * Models saved *
#
# New historical moving average record: 0.00648
#
# * Models saved *
#
# New historical moving average record: 0.00652
#
# * Models saved *
#
# New historical moving average record: 0.00653
#
# * Models saved *
#
# New historical moving average record: 0.00662
#
# * Models saved *
#
# New historical moving average record: 0.00662
#
# * Models saved *
#
# New historical moving average record: 0.00665
#
# * Models saved *
#
# New historical moving average record: 0.00667
#
# * Models saved *
#
# New historical moving average record: 0.00673
#
# * Models saved *
#
# New historical moving average record: 0.00679
#
# * Models saved *
#
# New historical moving average record: 0.00682
#
# * Models saved *
#
# New historical moving average record: 0.00689
#
# * Models saved *
#
# New historical moving average record: 0.00703
#
# * Models saved *
#
# New historical moving average record: 0.00705
#
# * Models saved *
#
# New historical moving average record: 0.00705
#
# * Models saved *
#
# New historical moving average record: 0.00706
#
# * Models saved *
#
# New historical moving average record: 0.00713
#
# * Models saved *
#
# New historical moving average record: 0.00722
#
# * Models saved *
#
# New historical moving average record: 0.00729
#
# * Models saved *
#
# New historical moving average record: 0.00729
#
# * Models saved *
#
# New historical moving average record: 0.00735
#
# * Models saved *
#
# New historical moving average record: 0.00738
#
# * Models saved *
#
# New historical moving average record: 0.00740
#
# * Models saved *
#
# New historical moving average record: 0.00749
#
# * Models saved *
#
# New historical moving average record: 0.00754
#
# * Models saved *
#
# New historical moving average record: 0.00758
#
# * Models saved *
#
# New historical moving average record: 0.00763
#
# * Models saved *
#
# New historical moving average record: 0.00764
#
# * Models saved *
#
# New historical moving average record: 0.00767
#
# * Models saved *
#
# New historical moving average record: 0.00767
#
# * Models saved *
#
# New historical moving average record: 0.00770
#
# * Models saved *
#
# New historical moving average record: 0.00775
#
# * Models saved *
#
# New historical moving average record: 0.00776
#
# * Models saved *
#
# New historical moving average record: 0.00783
#
# * Models saved *
#
# New historical moving average record: 0.00792
#
# * Models saved *
#
# New historical moving average record: 0.00803
# Episode * 4300 * Moving Avg Reward is ==> 0.00799 * Last Reward was ==> -0.03834
# * Models saved *
#
# New historical moving average record: 0.00803
#
# * Models saved *
#
# New historical moving average record: 0.00809
#
# * Models saved *
#
# New historical moving average record: 0.00818
#
# * Models saved *
#
# New historical moving average record: 0.00824
#
# * Models saved *
#
# New historical moving average record: 0.00825
#
# * Models saved *
#
# New historical moving average record: 0.00826
#
# * Models saved *
#
# New historical moving average record: 0.00827
#
# * Models saved *
#
# New historical moving average record: 0.00833
#
# * Models saved *
#
# New historical moving average record: 0.00844
#
# * Models saved *
#
# New historical moving average record: 0.00852
#
# * Models saved *
#
# New historical moving average record: 0.00852
#
# * Models saved *
#
# New historical moving average record: 0.00855
#
# * Models saved *
#
# New historical moving average record: 0.00856
#
# * Models saved *
#
# New historical moving average record: 0.00861
#
# * Models saved *
#
# New historical moving average record: 0.00864
#
# * Models saved *
#
# New historical moving average record: 0.00867
#
# * Models saved *
#
# New historical moving average record: 0.00872
#
# * Models saved *
#
# New historical moving average record: 0.00874
#
# * Models saved *
#
# New historical moving average record: 0.00880
#
# * Models saved *
#
# New historical moving average record: 0.00888
#
# * Models saved *
#
# New historical moving average record: 0.00888
#
# * Models saved *
#
# New historical moving average record: 0.00894
#
# * Models saved *
#
# New historical moving average record: 0.00895
#
# * Models saved *
#
# New historical moving average record: 0.00901
#
# * Models saved *
#
# New historical moving average record: 0.00903
#
# * Models saved *
#
# New historical moving average record: 0.00906
#
# * Models saved *
#
# New historical moving average record: 0.00909
#
# * Models saved *
#
# New historical moving average record: 0.00910
#
# * Models saved *
#
# New historical moving average record: 0.00911
#
# * Models saved *
#
# New historical moving average record: 0.00916
#
# * Models saved *
#
# New historical moving average record: 0.00922
#
# * Models saved *
#
# New historical moving average record: 0.00922
#
# * Models saved *
#
# New historical moving average record: 0.00927
#
# * Models saved *
#
# New historical moving average record: 0.00929
#
# * Models saved *
#
# New historical moving average record: 0.00935
#
# * Models saved *
#
# New historical moving average record: 0.00939
#
# * Models saved *
#
# New historical moving average record: 0.00954
#
# * Models saved *
#
# New historical moving average record: 0.00957
#
# * Models saved *
#
# New historical moving average record: 0.00963
#
# * Models saved *
#
# New historical moving average record: 0.00966
#
# * Models saved *
#
# New historical moving average record: 0.00969
#
# * Models saved *
#
# New historical moving average record: 0.00970
#
# * Models saved *
#
# New historical moving average record: 0.00975
#
# * Models saved *
#
# New historical moving average record: 0.00982
#
# * Models saved *
#
# New historical moving average record: 0.00984
#
# * Models saved *
#
# New historical moving average record: 0.00985
#
# * Models saved *
#
# New historical moving average record: 0.00985
#
# * Models saved *
#
# New historical moving average record: 0.00989
#
# * Models saved *
#
# New historical moving average record: 0.00992
#
# * Models saved *
#
# New historical moving average record: 0.00994
#
# * Models saved *
#
# New historical moving average record: 0.00995
#
# * Models saved *
#
# New historical moving average record: 0.00995
#
# * Models saved *
#
# New historical moving average record: 0.00997
#
# * Models saved *
#
# New historical moving average record: 0.00997
#
# * Models saved *
#
# New historical moving average record: 0.00998
#
# * Models saved *
#
# New historical moving average record: 0.01001
#
# * Models saved *
#
# New historical moving average record: 0.01007
#
# * Models saved *
#
# New historical moving average record: 0.01010
#
# * Models saved *
#
# New historical moving average record: 0.01017
#
# * Models saved *
#
# New historical moving average record: 0.01020
#
# Episode * 4400 * Moving Avg Reward is ==> 0.01021 * Last Reward was ==> 0.00948
# * Models saved *
#
# New historical moving average record: 0.01021
#
# * Models saved *
#
# New historical moving average record: 0.01027
#
# * Models saved *
#
# New historical moving average record: 0.01030
#
# * Models saved *
#
# New historical moving average record: 0.01036
#
# * Models saved *
#
# New historical moving average record: 0.01041
#
# * Models saved *
#
# New historical moving average record: 0.01042
#
# * Models saved *
#
# New historical moving average record: 0.01042
#
# * Models saved *
#
# New historical moving average record: 0.01043
#
# * Models saved *
#
# New historical moving average record: 0.01051
#
# * Models saved *
#
# New historical moving average record: 0.01051
#
# * Models saved *
#
# New historical moving average record: 0.01060
#
# * Models saved *
#
# New historical moving average record: 0.01062
#
# * Models saved *
#
# New historical moving average record: 0.01062
#
# * Models saved *
#
# New historical moving average record: 0.01063
#
# * Models saved *
#
# New historical moving average record: 0.01065
#
# * Models saved *
#
# New historical moving average record: 0.01071
#
# * Models saved *
#
# New historical moving average record: 0.01073
#
# * Models saved *
#
# New historical moving average record: 0.01074
#
# * Models saved *
#
# New historical moving average record: 0.01076
#
# * Models saved *
#
# New historical moving average record: 0.01080
#
# * Models saved *
#
# New historical moving average record: 0.01085
#
# * Models saved *
#
# New historical moving average record: 0.01088
#
# * Models saved *
#
# New historical moving average record: 0.01093
#
# * Models saved *
#
# New historical moving average record: 0.01095
#
# * Models saved *
#
# New historical moving average record: 0.01098
#
# * Models saved *
#
# New historical moving average record: 0.01098
#
# * Models saved *
#
# New historical moving average record: 0.01105
#
# * Models saved *
#
# New historical moving average record: 0.01108
#
# * Models saved *
#
# New historical moving average record: 0.01111
#
# * Models saved *
#
# New historical moving average record: 0.01116
#
# * Models saved *
#
# New historical moving average record: 0.01121
#
# * Models saved *
#
# New historical moving average record: 0.01123
#
# * Models saved *
#
# New historical moving average record: 0.01127
#
# * Models saved *
#
# New historical moving average record: 0.01130
#
# * Models saved *
#
# New historical moving average record: 0.01132
#
# * Models saved *
#
# New historical moving average record: 0.01135
#
# * Models saved *
#
# New historical moving average record: 0.01139
#
# * Models saved *
#
# New historical moving average record: 0.01142
#
# * Models saved *
#
# New historical moving average record: 0.01156
#
# * Models saved *
#
# New historical moving average record: 0.01158
#
# * Models saved *
#
# New historical moving average record: 0.01162
#
# * Models saved *
#
# New historical moving average record: 0.01163
#
# * Models saved *
#
# New historical moving average record: 0.01166
#
# * Models saved *
#
# New historical moving average record: 0.01170
#
# * Models saved *
#
# New historical moving average record: 0.01172
#
# * Models saved *
#
# New historical moving average record: 0.01175
#
# * Models saved *
#
# New historical moving average record: 0.01177
#
# * Models saved *
#
# New historical moving average record: 0.01187
#
# * Models saved *
#
# New historical moving average record: 0.01195
#
# * Models saved *
#
# New historical moving average record: 0.01197
#
# * Models saved *
#
# New historical moving average record: 0.01200
#
# * Models saved *
#
# New historical moving average record: 0.01209
#
# * Models saved *
#
# New historical moving average record: 0.01217
#
# * Models saved *
#
# New historical moving average record: 0.01220
#
# * Models saved *
#
# New historical moving average record: 0.01225
#
# * Models saved *
#
# New historical moving average record: 0.01230
#
# * Models saved *
#
# New historical moving average record: 0.01239
#
# * Models saved *
#
# New historical moving average record: 0.01244
#
# * Models saved *
#
# New historical moving average record: 0.01246
#
# * Models saved *
#
# New historical moving average record: 0.01255
#
# * Models saved *
#
# New historical moving average record: 0.01260
#
# * Models saved *
#
# New historical moving average record: 0.01262
#
# * Models saved *
#
# New historical moving average record: 0.01268
#
# * Models saved *
#
# New historical moving average record: 0.01269
# * Models saved *
#
# New historical moving average record: 0.01269
#
# * Models saved *
#
# New historical moving average record: 0.01270
#
# * Models saved *
#
# New historical moving average record: 0.01275
#
# * Models saved *
#
# New historical moving average record: 0.01275
#
# * Models saved *
#
# New historical moving average record: 0.01283
#
# Episode * 4500 * Moving Avg Reward is ==> 0.01286 * Last Reward was ==> 0.03591
# * Models saved *
#
# New historical moving average record: 0.01286
#
# * Models saved *
#
# New historical moving average record: 0.01288
#
# * Models saved *
#
# New historical moving average record: 0.01289
#
# * Models saved *
#
# New historical moving average record: 0.01295
#
# * Models saved *
#
# New historical moving average record: 0.01298
#
# * Models saved *
#
# New historical moving average record: 0.01302
#
# * Models saved *
#
# New historical moving average record: 0.01304
#
# * Models saved *
#
# New historical moving average record: 0.01313
#
# * Models saved *
#
# New historical moving average record: 0.01316
#
# * Models saved *
#
# New historical moving average record: 0.01317
#
# * Models saved *
#
# New historical moving average record: 0.01321
#
# * Models saved *
#
# New historical moving average record: 0.01322
#
# * Models saved *
#
# New historical moving average record: 0.01323
#
# * Models saved *
#
# New historical moving average record: 0.01331
#
# * Models saved *
#
# New historical moving average record: 0.01332
#
# * Models saved *
#
# New historical moving average record: 0.01332
#
# * Models saved *
#
# New historical moving average record: 0.01334
#
# * Models saved *
#
# New historical moving average record: 0.01339
#
# * Models saved *
#
# New historical moving average record: 0.01342
#
# * Models saved *
#
# New historical moving average record: 0.01344
#
# * Models saved *
#
# New historical moving average record: 0.01347
#
# * Models saved *
#
# New historical moving average record: 0.01349
#
# * Models saved *
#
# New historical moving average record: 0.01351
#
# * Models saved *
#
# New historical moving average record: 0.01355
#
# * Models saved *
#
# New historical moving average record: 0.01358
#
# * Models saved *
#
# New historical moving average record: 0.01359
#
# * Models saved *
#
# New historical moving average record: 0.01366
#
# * Models saved *
#
# New historical moving average record: 0.01373
#
# * Models saved *
#
# New historical moving average record: 0.01375
#
# * Models saved *
#
# New historical moving average record: 0.01376
#
# * Models saved *
#
# New historical moving average record: 0.01382
#
# * Models saved *
#
# New historical moving average record: 0.01393
#
# * Models saved *
#
# New historical moving average record: 0.01406
#
# * Models saved *
#
# New historical moving average record: 0.01409
#
# * Models saved *
#
# New historical moving average record: 0.01415
#
# * Models saved *
#
# New historical moving average record: 0.01419
#
# * Models saved *
#
# New historical moving average record: 0.01422
#
# * Models saved *
#
# New historical moving average record: 0.01431
#
# * Models saved *
#
# New historical moving average record: 0.01438
#
# * Models saved *
#
# New historical moving average record: 0.01443
#
# * Models saved *
#
# New historical moving average record: 0.01446
#
# * Models saved *
#
# New historical moving average record: 0.01456
#
# * Models saved *
#
# New historical moving average record: 0.01458
#
# * Models saved *
#
# New historical moving average record: 0.01470
#
# * Models saved *
#
# New historical moving average record: 0.01479
#
# * Models saved *
#
# New historical moving average record: 0.01483
#
# * Models saved *
#
# New historical moving average record: 0.01486
#
# * Models saved *
#
# New historical moving average record: 0.01491
#
# * Models saved *
#
# New historical moving average record: 0.01498
#
# * Models saved *
#
# New historical moving average record: 0.01506
#
# * Models saved *
#
# New historical moving average record: 0.01514
#
# * Models saved *
#
# New historical moving average record: 0.01519
#
# * Models saved *
#
# New historical moving average record: 0.01522
#
# * Models saved *
#
# New historical moving average record: 0.01524
#
# * Models saved *
#
# New historical moving average record: 0.01526
#
# * Models saved *
#
# New historical moving average record: 0.01537
#
# * Models saved *
#
# New historical moving average record: 0.01542
#
# * Models saved *
#
# New historical moving average record: 0.01545
#
# Episode * 4600 * Moving Avg Reward is ==> 0.01547 * Last Reward was ==> 0.04000
# * Models saved *
#
# New historical moving average record: 0.01547
#
# * Models saved *
#
# New historical moving average record: 0.01548
#
# * Models saved *
#
# New historical moving average record: 0.01551
#
# * Models saved *
#
# New historical moving average record: 0.01556
#
# * Models saved *
#
# New historical moving average record: 0.01564
#
# * Models saved *
#
# New historical moving average record: 0.01568
#
# * Models saved *
#
# New historical moving average record: 0.01571
#
# * Models saved *
#
# New historical moving average record: 0.01574
#
# * Models saved *
#
# New historical moving average record: 0.01582
#
# * Models saved *
#
# New historical moving average record: 0.01590
#
# * Models saved *
#
# New historical moving average record: 0.01592
#
# * Models saved *
#
# New historical moving average record: 0.01603
#
# * Models saved *
#
# New historical moving average record: 0.01603
#
# * Models saved *
#
# New historical moving average record: 0.01613
#
# * Models saved *
#
# New historical moving average record: 0.01620
#
# * Models saved *
#
# New historical moving average record: 0.01622
#
# * Models saved *
#
# New historical moving average record: 0.01628
#
# * Models saved *
#
# New historical moving average record: 0.01636
#
# * Models saved *
#
# New historical moving average record: 0.01641
#
# * Models saved *
#
# New historical moving average record: 0.01645
#
# * Models saved *
#
# New historical moving average record: 0.01647
#
# * Models saved *
#
# New historical moving average record: 0.01652
#
# * Models saved *
#
# New historical moving average record: 0.01657
#
# * Models saved *
#
# New historical moving average record: 0.01658
#
# * Models saved *
#
# New historical moving average record: 0.01666
#
# * Models saved *
#
# New historical moving average record: 0.01672
#
# * Models saved *
#
# New historical moving average record: 0.01683
#
# * Models saved *
#
# New historical moving average record: 0.01685
#
# * Models saved *
#
# New historical moving average record: 0.01691
#
# * Models saved *
#
# New historical moving average record: 0.01704
#
# * Models saved *
#
# New historical moving average record: 0.01705
#
# * Models saved *
#
# New historical moving average record: 0.01719
#
# * Models saved *
#
# New historical moving average record: 0.01725
#
# * Models saved *
#
# New historical moving average record: 0.01727
#
# * Models saved *
#
# New historical moving average record: 0.01729
#
# * Models saved *
#
# New historical moving average record: 0.01732
#
# * Models saved *
#
# New historical moving average record: 0.01736
#
# * Models saved *
#
# New historical moving average record: 0.01743
#
# * Models saved *
#
# New historical moving average record: 0.01744
#
# * Models saved *
#
# New historical moving average record: 0.01748
#
# * Models saved *
#
# New historical moving average record: 0.01752
#
# * Models saved *
#
# New historical moving average record: 0.01771
#
# * Models saved *
#
# New historical moving average record: 0.01776
#
# * Models saved *
#
# New historical moving average record: 0.01781
#
# * Models saved *
#
# New historical moving average record: 0.01782
#
# * Models saved *
#
# New historical moving average record: 0.01792
#
# * Models saved *
#
# New historical moving average record: 0.01796
#
# * Models saved *
#
# New historical moving average record: 0.01799
#
# * Models saved *
#
# New historical moving average record: 0.01800
#
# * Models saved *
#
# New historical moving average record: 0.01817
#
# * Models saved *
#
# New historical moving average record: 0.01828
#
# * Models saved *
#
# New historical moving average record: 0.01835
#
# * Models saved *
#
# New historical moving average record: 0.01847
#
# * Models saved *
#
# New historical moving average record: 0.01855
#
# * Models saved *
#
# New historical moving average record: 0.01858
#
# * Models saved *
#
# New historical moving average record: 0.01859
#
# * Models saved *
#
# New historical moving average record: 0.01862
#
# * Models saved *
#
# New historical moving average record: 0.01867
#
# * Models saved *
#
# New historical moving average record: 0.01873
#
# * Models saved *
#
# New historical moving average record: 0.01883
#
# * Models saved *
#
# New historical moving average record: 0.01888
# * Models saved *
#
# New historical moving average record: 0.01896
#
# * Models saved *
#
# New historical moving average record: 0.01902
#
# * Models saved *
#
# New historical moving average record: 0.01918
#
# * Models saved *
#
# New historical moving average record: 0.01920
#
# * Models saved *
#
# New historical moving average record: 0.01926
#
# Episode * 4700 * Moving Avg Reward is ==> 0.01935 * Last Reward was ==> 0.08568
# * Models saved *
#
# New historical moving average record: 0.01935
#
# * Models saved *
#
# New historical moving average record: 0.01937
#
# * Models saved *
#
# New historical moving average record: 0.01943
#
# * Models saved *
#
# New historical moving average record: 0.01951
#
# * Models saved *
#
# New historical moving average record: 0.01963
#
# * Models saved *
#
# New historical moving average record: 0.01969
#
# * Models saved *
#
# New historical moving average record: 0.01972
#
# * Models saved *
#
# New historical moving average record: 0.01977
#
# * Models saved *
#
# New historical moving average record: 0.01984
#
# * Models saved *
#
# New historical moving average record: 0.01987
#
# * Models saved *
#
# New historical moving average record: 0.02000
#
# * Models saved *
#
# New historical moving average record: 0.02008
#
# * Models saved *
#
# New historical moving average record: 0.02010
#
# * Models saved *
#
# New historical moving average record: 0.02021
#
# * Models saved *
#
# New historical moving average record: 0.02024
#
# * Models saved *
#
# New historical moving average record: 0.02033
#
# * Models saved *
#
# New historical moving average record: 0.02046
#
# * Models saved *
#
# New historical moving average record: 0.02053
#
# * Models saved *
#
# New historical moving average record: 0.02057
#
# * Models saved *
#
# New historical moving average record: 0.02065
#
# * Models saved *
#
# New historical moving average record: 0.02070
#
# * Models saved *
#
# New historical moving average record: 0.02070
#
# * Models saved *
#
# New historical moving average record: 0.02083
#
# * Models saved *
#
# New historical moving average record: 0.02088
#
# * Models saved *
#
# New historical moving average record: 0.02094
#
# * Models saved *
#
# New historical moving average record: 0.02099
#
# * Models saved *
#
# New historical moving average record: 0.02101
#
# * Models saved *
#
# New historical moving average record: 0.02111
#
# * Models saved *
#
# New historical moving average record: 0.02111
#
# * Models saved *
#
# New historical moving average record: 0.02117
#
# * Models saved *
#
# New historical moving average record: 0.02120
#
# * Models saved *
#
# New historical moving average record: 0.02125
#
# * Models saved *
#
# New historical moving average record: 0.02135
#
# * Models saved *
#
# New historical moving average record: 0.02135
#
# * Models saved *
#
# New historical moving average record: 0.02141
#
# * Models saved *
#
# New historical moving average record: 0.02147
#
# * Models saved *
#
# New historical moving average record: 0.02160
#
# * Models saved *
#
# New historical moving average record: 0.02167
#
# * Models saved *
#
# New historical moving average record: 0.02178
#
# * Models saved *
#
# New historical moving average record: 0.02186
#
# * Models saved *
#
# New historical moving average record: 0.02200
#
# * Models saved *
#
# New historical moving average record: 0.02200
#
# * Models saved *
#
# New historical moving average record: 0.02207
#
# * Models saved *
#
# New historical moving average record: 0.02210
#
# * Models saved *
#
# New historical moving average record: 0.02213
#
# * Models saved *
#
# New historical moving average record: 0.02223
#
# * Models saved *
#
# New historical moving average record: 0.02231
#
# * Models saved *
#
# New historical moving average record: 0.02237
#
# * Models saved *
#
# New historical moving average record: 0.02250
#
# * Models saved *
#
# New historical moving average record: 0.02251
#
# * Models saved *
#
# New historical moving average record: 0.02263
#
# * Models saved *
#
# New historical moving average record: 0.02277
#
# * Models saved *
#
# New historical moving average record: 0.02291
#
# * Models saved *
#
# New historical moving average record: 0.02306
#
# * Models saved *
#
# New historical moving average record: 0.02310
#
# * Models saved *
#
# New historical moving average record: 0.02319
#
# * Models saved *
#
# New historical moving average record: 0.02320
#
# * Models saved *
#
# New historical moving average record: 0.02321
#
# * Models saved *
#
# New historical moving average record: 0.02324
#
# * Models saved *
#
# New historical moving average record: 0.02326
#
# * Models saved *
#
# New historical moving average record: 0.02329
#
# * Models saved *
#
# New historical moving average record: 0.02340
#
# * Models saved *
#
# New historical moving average record: 0.02347
#
# * Models saved *
#
# New historical moving average record: 0.02351
#
# * Models saved *
#
# New historical moving average record: 0.02360
#
# * Models saved *
#
# New historical moving average record: 0.02362
#
# * Models saved *
#
# New historical moving average record: 0.02368
#
# * Models saved *
#
# New historical moving average record: 0.02369
#
# * Models saved *
#
# New historical moving average record: 0.02371
#
# * Models saved *
#
# New historical moving average record: 0.02375
#
# * Models saved *
#
# New historical moving average record: 0.02381
#
# * Models saved *
#
# New historical moving average record: 0.02384
#
# * Models saved *
#
# New historical moving average record: 0.02387
#
# * Models saved *
#
# New historical moving average record: 0.02389
#
# Episode * 4800 * Moving Avg Reward is ==> 0.02388 * Last Reward was ==> -0.01214
# * Models saved *
#
# New historical moving average record: 0.02392
#
# * Models saved *
#
# New historical moving average record: 0.02392
#
# * Models saved *
#
# New historical moving average record: 0.02395
#
# * Models saved *
#
# New historical moving average record: 0.02403
#
# * Models saved *
#
# New historical moving average record: 0.02403
#
# * Models saved *
#
# New historical moving average record: 0.02405
#
# * Models saved *
#
# New historical moving average record: 0.02406
#
# * Models saved *
#
# New historical moving average record: 0.02407
#
# * Models saved *
#
# New historical moving average record: 0.02410
#
# * Models saved *
#
# New historical moving average record: 0.02414
#
# * Models saved *
#
# New historical moving average record: 0.02418
#
# * Models saved *
#
# New historical moving average record: 0.02424
#
# * Models saved *
#
# New historical moving average record: 0.02425
#
# * Models saved *
#
# New historical moving average record: 0.02426
#
# * Models saved *
#
# New historical moving average record: 0.02429
#
# * Models saved *
#
# New historical moving average record: 0.02429
#
# * Models saved *
#
# New historical moving average record: 0.02431
#
# * Models saved *
#
# New historical moving average record: 0.02431
#
# * Models saved *
#
# New historical moving average record: 0.02433
#
# * Models saved *
#
# New historical moving average record: 0.02435
#
# * Models saved *
#
# New historical moving average record: 0.02435
#
# * Models saved *
#
# New historical moving average record: 0.02436
#
# * Models saved *
#
# New historical moving average record: 0.02437
#
# * Models saved *
#
# New historical moving average record: 0.02439
#
# ...
# * Models saved *
#
# New historical moving average record: 0.14216
#
# * Models saved *
#
# New historical moving average record: 0.14219
#
# * Models saved *
#
# New historical moving average record: 0.14226
#
# * Models saved *
#
# New historical moving average record: 0.14231
#
# Episode * 17900 * Moving Avg Reward is ==> 0.14234 * Last Reward was ==> 0.16808
# * Models saved *
#
# New historical moving average record: 0.14234
#
# * Models saved *
#
# New historical moving average record: 0.14235
#
# * Models saved *
#
# New historical moving average record: 0.14236
#
# * Models saved *
#
# New historical moving average record: 0.14243
#
# * Models saved *
#
# New historical moving average record: 0.14247
#
# * Models saved *
#
# New historical moving average record: 0.14254
#
# * Models saved *
#
# New historical moving average record: 0.14257
#
# * Models saved *
#
# New historical moving average record: 0.14261
#
# * Models saved *
#
# New historical moving average record: 0.14270
#
# * Models saved *
#
# New historical moving average record: 0.14279
#
# * Models saved *
#
# New historical moving average record: 0.14291
#
# * Models saved *
#
# New historical moving average record: 0.14296
#
# * Models saved *
#
# New historical moving average record: 0.14298
#
# * Models saved *
#
# New historical moving average record: 0.14310
#
# * Models saved *
#
# New historical moving average record: 0.14314
#
# * Models saved *
#
# New historical moving average record: 0.14316
#
# * Models saved *
#
# New historical moving average record: 0.14324
#
# * Models saved *
#
# New historical moving average record: 0.14325
#
# * Models saved *
#
# New historical moving average record: 0.14326
#
# * Models saved *
#
# New historical moving average record: 0.14334
#
# * Models saved *
#
# New historical moving average record: 0.14338
#
# * Models saved *
#
# New historical moving average record: 0.14342
#
# * Models saved *
#
# New historical moving average record: 0.14347
#
# * Models saved *
#
# New historical moving average record: 0.14355
#
# * Models saved *
#
# New historical moving average record: 0.14357
#
# * Models saved *
#
# New historical moving average record: 0.14358
#
# * Models saved *
#
# New historical moving average record: 0.14367
#
# * Models saved *
#
# New historical moving average record: 0.14378
#
# * Models saved *
#
# New historical moving average record: 0.14383
#
# * Models saved *
#
# New historical moving average record: 0.14384
#
# * Models saved *
#
# New historical moving average record: 0.14390
#
# * Models saved *
#
# New historical moving average record: 0.14400
#
# * Models saved *
#
# New historical moving average record: 0.14416
#
# * Models saved *
#
# New historical moving average record: 0.14419
#
# * Models saved *
#
# New historical moving average record: 0.14427
#
# * Models saved *
#
# New historical moving average record: 0.14431
#
# * Models saved *
#
# New historical moving average record: 0.14439
#
# * Models saved *
#
# New historical moving average record: 0.14448
#
# * Models saved *
#
# New historical moving average record: 0.14449
#
# * Models saved *
#
# New historical moving average record: 0.14451
#
# * Models saved *
#
# New historical moving average record: 0.14454
#
# * Models saved *
#
# New historical moving average record: 0.14457
#
# * Models saved *
#
# New historical moving average record: 0.14462
#
# * Models saved *
#
# New historical moving average record: 0.14466
#
# * Models saved *
#
# New historical moving average record: 0.14468
#
# * Models saved *
#
# New historical moving average record: 0.14470
#
# * Models saved *
#
# New historical moving average record: 0.14480
#
# * Models saved *
#
# New historical moving average record: 0.14485
#
# * Models saved *
#
# New historical moving average record: 0.14495
#
# Episode * 18000 * Moving Avg Reward is ==> 0.14502 * Last Reward was ==> 0.19800
# * Models saved *
#
# New historical moving average record: 0.14502
#
# * Models saved *
#
# New historical moving average record: 0.14502
#
# * Models saved *
#
# New historical moving average record: 0.14507
#
# * Models saved *
#
# New historical moving average record: 0.14518
#
# * Models saved *
#
# New historical moving average record: 0.14520
#
# * Models saved *
#
# New historical moving average record: 0.14526
#
# * Models saved *
#
# New historical moving average record: 0.14528
#
# * Models saved *
#
# New historical moving average record: 0.14528
#
# * Models saved *
#
# New historical moving average record: 0.14537
#
# * Models saved *
#
# New historical moving average record: 0.14546
#
# * Models saved *
#
# New historical moving average record: 0.14549
#
# * Models saved *
#
# New historical moving average record: 0.14551
#
# * Models saved *
#
# New historical moving average record: 0.14564
#
# * Models saved *
#
# New historical moving average record: 0.14567
#
# * Models saved *
#
# New historical moving average record: 0.14569
#
# * Models saved *
#
# New historical moving average record: 0.14571
#
# * Models saved *
#
# New historical moving average record: 0.14572
#
# * Models saved *
#
# New historical moving average record: 0.14573
#
# * Models saved *
#
# New historical moving average record: 0.14576
#
# * Models saved *
#
# New historical moving average record: 0.14585
#
# * Models saved *
#
# New historical moving average record: 0.14590
#
# * Models saved *
#
# New historical moving average record: 0.14598
#
# * Models saved *
#
# New historical moving average record: 0.14601
#
# * Models saved *
#
# New historical moving average record: 0.14607
#
# * Models saved *
#
# New historical moving average record: 0.14608
#
# * Models saved *
#
# New historical moving average record: 0.14611
#
# * Models saved *
#
# New historical moving average record: 0.14617
#
# * Models saved *
#
# New historical moving average record: 0.14620
#
# * Models saved *
#
# New historical moving average record: 0.14622
#
# * Models saved *
#
# New historical moving average record: 0.14632
# * Models saved *
#
# New historical moving average record: 0.14639
#
# * Models saved *
#
# New historical moving average record: 0.14644
#
# * Models saved *
#
# New historical moving average record: 0.14661
#
# * Models saved *
#
# New historical moving average record: 0.14663
#
# * Models saved *
#
# New historical moving average record: 0.14670
#
# * Models saved *
#
# New historical moving average record: 0.14679
#
# * Models saved *
#
# New historical moving average record: 0.14697
#
# * Models saved *
#
# New historical moving average record: 0.14699
#
# * Models saved *
#
# New historical moving average record: 0.14706
#
# * Models saved *
#
# New historical moving average record: 0.14709
#
# * Models saved *
#
# New historical moving average record: 0.14711
#
# * Models saved *
#
# New historical moving average record: 0.14712
#
# * Models saved *
#
# New historical moving average record: 0.14721
#
# * Models saved *
#
# New historical moving average record: 0.14724
#
# * Models saved *
#
# New historical moving average record: 0.14727
#
# * Models saved *
#
# New historical moving average record: 0.14742
#
# * Models saved *
#
# New historical moving average record: 0.14745
#
# * Models saved *
#
# New historical moving average record: 0.14753
#
# Episode * 18100 * Moving Avg Reward is ==> 0.14742 * Last Reward was ==> 0.10154
# * Models saved *
#
# New historical moving average record: 0.14754
#
# * Models saved *
#
# New historical moving average record: 0.14762
#
# * Models saved *
#
# New historical moving average record: 0.14766
#
# * Models saved *
#
# New historical moving average record: 0.14778
#
# * Models saved *
#
# New historical moving average record: 0.14780
#
# * Models saved *
#
# New historical moving average record: 0.14795
#
# * Models saved *
#
# New historical moving average record: 0.14805
#
# * Models saved *
#
# New historical moving average record: 0.14805
#
# * Models saved *
#
# New historical moving average record: 0.14805
#
# * Models saved *
#
# New historical moving average record: 0.14807
#
# * Models saved *
#
# New historical moving average record: 0.14808
#
# * Models saved *
#
# New historical moving average record: 0.14811
#
# * Models saved *
#
# New historical moving average record: 0.14813
#
# * Models saved *
#
# New historical moving average record: 0.14815
#
# * Models saved *
#
# New historical moving average record: 0.14826
#
# * Models saved *
#
# New historical moving average record: 0.14828
#
# * Models saved *
#
# New historical moving average record: 0.14828
#
# * Models saved *
#
# New historical moving average record: 0.14835
#
# * Models saved *
#
# New historical moving average record: 0.14849
#
# * Models saved *
#
# New historical moving average record: 0.14851
#
# * Models saved *
#
# New historical moving average record: 0.14860
#
# * Models saved *
#
# New historical moving average record: 0.14868
#
# * Models saved *
#
# New historical moving average record: 0.14873
#
# * Models saved *
#
# New historical moving average record: 0.14878
#
# * Models saved *
#
# New historical moving average record: 0.14879
#
# * Models saved *
#
# New historical moving average record: 0.14892
#
# * Models saved *
#
# New historical moving average record: 0.14900
#
# Episode * 18200 * Moving Avg Reward is ==> 0.14885 * Last Reward was ==> 0.07839
# * Models saved *
#
# New historical moving average record: 0.14908
#
# * Models saved *
#
# New historical moving average record: 0.14911
#
# * Models saved *
#
# New historical moving average record: 0.14911
#
# * Models saved *
#
# New historical moving average record: 0.14915
#
# Episode * 18300 * Moving Avg Reward is ==> 0.14889 * Last Reward was ==> 0.20088
# * Models saved *
#
# New historical moving average record: 0.14915
#
# Episode * 18400 * Moving Avg Reward is ==> 0.14710 * Last Reward was ==> 0.08879
# Episode * 18500 * Moving Avg Reward is ==> 0.14661 * Last Reward was ==> 0.14754
# Episode * 18600 * Moving Avg Reward is ==> 0.14691 * Last Reward was ==> 0.08489
# Episode * 18700 * Moving Avg Reward is ==> 0.14719 * Last Reward was ==> 0.18428
# Episode * 18800 * Moving Avg Reward is ==> 0.14778 * Last Reward was ==> 0.08335
# Episode * 18900 * Moving Avg Reward is ==> 0.14784 * Last Reward was ==> 0.14847
# Episode * 19000 * Moving Avg Reward is ==> 0.14700 * Last Reward was ==> 0.07868
# Episode * 19100 * Moving Avg Reward is ==> 0.14679 * Last Reward was ==> 0.08643
# Episode * 19200 * Moving Avg Reward is ==> 0.14770 * Last Reward was ==> 0.18731
# Episode * 19300 * Moving Avg Reward is ==> 0.14873 * Last Reward was ==> 0.14156
# * Models saved *
#
# New historical moving average record: 0.14918
#
# * Models saved *
#
# New historical moving average record: 0.14920
#
# * Models saved *
#
# New historical moving average record: 0.14933
#
# * Models saved *
#
# New historical moving average record: 0.14940
#
# * Models saved *
#
# New historical moving average record: 0.14948
#
# * Models saved *
#
# New historical moving average record: 0.14953
#
# * Models saved *
#
# New historical moving average record: 0.14962
#
# * Models saved *
#
# New historical moving average record: 0.14967
#
# * Models saved *
#
# New historical moving average record: 0.14983
#
# Episode * 19400 * Moving Avg Reward is ==> 0.14992 * Last Reward was ==> 0.18323
# * Models saved *
#
# New historical moving average record: 0.14992
#
# * Models saved *
#
# New historical moving average record: 0.15001
#
# * Models saved *
#
# New historical moving average record: 0.15009
#
# * Models saved *
#
# New historical moving average record: 0.15015
#
# * Models saved *
#
# New historical moving average record: 0.15019
#
# * Models saved *
#
# New historical moving average record: 0.15022
#
# * Models saved *
#
# New historical moving average record: 0.15028
#
# * Models saved *
#
# New historical moving average record: 0.15032
#
# * Models saved *
#
# New historical moving average record: 0.15039
#
# * Models saved *
#
# New historical moving average record: 0.15048
#
# * Models saved *
#
# New historical moving average record: 0.15055
#
# * Models saved *
#
# New historical moving average record: 0.15059
#
# * Models saved *
#
# New historical moving average record: 0.15059
#
# * Models saved *
#
# New historical moving average record: 0.15061
#
# * Models saved *
#
# New historical moving average record: 0.15069
#
# * Models saved *
#
# New historical moving average record: 0.15076
#
# * Models saved *
#
# New historical moving average record: 0.15086
#
# * Models saved *
#
# New historical moving average record: 0.15090
#
# * Models saved *
#
# New historical moving average record: 0.15093
#
# * Models saved *
#
# New historical moving average record: 0.15093
#
# * Models saved *
#
# New historical moving average record: 0.15099
#
# * Models saved *
#
# New historical moving average record: 0.15100
#
# * Models saved *
#
# New historical moving average record: 0.15105
#
# * Models saved *
#
# New historical moving average record: 0.15110
#
# * Models saved *
#
# New historical moving average record: 0.15120
#
# * Models saved *
#
# New historical moving average record: 0.15121
#
# * Models saved *
#
# New historical moving average record: 0.15133
#
# * Models saved *
#
# New historical moving average record: 0.15138
#
# * Models saved *
#
# New historical moving average record: 0.15143
#
# * Models saved *
#
# New historical moving average record: 0.15146
#
# * Models saved *
#
# New historical moving average record: 0.15156
#
# * Models saved *
#
# New historical moving average record: 0.15158
#
# * Models saved *
#
# New historical moving average record: 0.15159
#
# * Models saved *
#
# New historical moving average record: 0.15169
#
# * Models saved *
#
# New historical moving average record: 0.15174
#
# * Models saved *
#
# New historical moving average record: 0.15175
#
# * Models saved *
#
# New historical moving average record: 0.15177
#
# * Models saved *
#
# New historical moving average record: 0.15184
#
# * Models saved *
#
# New historical moving average record: 0.15191
#
# * Models saved *
#
# New historical moving average record: 0.15194
#
# * Models saved *
#
# New historical moving average record: 0.15195
#
# * Models saved *
#
# New historical moving average record: 0.15198
#
# * Models saved *
#
# New historical moving average record: 0.15200
#
# * Models saved *
#
# New historical moving average record: 0.15204
#
# * Models saved *
#
# New historical moving average record: 0.15207
#
# * Models saved *
#
# New historical moving average record: 0.15208
#
# * Models saved *
#
# New historical moving average record: 0.15210
#
# * Models saved *
#
# New historical moving average record: 0.15216
#
# Episode * 19500 * Moving Avg Reward is ==> 0.15201 * Last Reward was ==> 0.21089
# * Models saved *
#
# New historical moving average record: 0.15221
# * Models saved *
#
# New historical moving average record: 0.15222
#
# * Models saved *
#
# New historical moving average record: 0.15224
#
# * Models saved *
#
# New historical moving average record: 0.15227
#
# * Models saved *
#
# New historical moving average record: 0.15238
#
# * Models saved *
#
# New historical moving average record: 0.15242
#
# * Models saved *
#
# New historical moving average record: 0.15243
#
# * Models saved *
#
# New historical moving average record: 0.15246
#
# * Models saved *
#
# New historical moving average record: 0.15249
#
# * Models saved *
#
# New historical moving average record: 0.15255
#
# * Models saved *
#
# New historical moving average record: 0.15258
#
# * Models saved *
#
# New historical moving average record: 0.15268
#
# Episode * 19600 * Moving Avg Reward is ==> 0.15207 * Last Reward was ==> 0.11097
# Episode * 19700 * Moving Avg Reward is ==> 0.15177 * Last Reward was ==> 0.11928
# Episode * 19800 * Moving Avg Reward is ==> 0.15245 * Last Reward was ==> 0.16146
# * Models saved *
#
# New historical moving average record: 0.15270
#
# * Models saved *
#
# New historical moving average record: 0.15272
#
# * Models saved *
#
# New historical moving average record: 0.15275
#
# * Models saved *
#
# New historical moving average record: 0.15276
#
# * Models saved *
#
# New historical moving average record: 0.15277
#
# * Models saved *
#
# New historical moving average record: 0.15281
#
# * Models saved *
#
# New historical moving average record: 0.15284
#
# * Models saved *
#
# New historical moving average record: 0.15298
#
# * Models saved *
#
# New historical moving average record: 0.15299
#
# * Models saved *
#
# New historical moving average record: 0.15301
#
# * Models saved *
#
# New historical moving average record: 0.15306
#
# * Models saved *
#
# New historical moving average record: 0.15306
#
# Episode * 19900 * Moving Avg Reward is ==> 0.15299 * Last Reward was ==> 0.07801
# * Models saved *
#
# New historical moving average record: 0.15312
#
# * Models saved *
#
# New historical moving average record: 0.15334
#
# All episodes are returning positive profits.Agent solved environment at the episode 19937
# All episodes are returning positive profits.Agent solved environment at the episode 19937
# A2C + CNN + 0.25 threshold -> Executed in 1h 1m 4s, finished 18:43:51 2022-08-08

# %%
agent.env.initial_investment
# Out:
# 1408.2217407226562

# %% [markdown]
# ### Test the results
# * Runs a set of episodes with **unseen data**
# * Stores the results in a csv file for later consulting

# %%
success = 0
n_tests = 10000

scores = []
targets = []
portfolio_target_ratios = []
initial_investments = []

for i in trange(n_tests):
    state = agent.env.reset(visualize=False,mode="test")
    step = 0
    score = 0
    reward = 0
    done = False
    
    targets.append((agent.env.episode_target-agent.env.initial_investment)/agent.env.initial_investment)
    initial_investments.append(agent.env.initial_investment)

    while not done:
        agent.env.render()
        
        # Select action
        action, action_onehot, prediction = agent.act(state)
        
        # Retrieve new state, reward, and whether the state is terminal
        next_state, reward, done, info = agent.env.step(action)
        
        # End of episode, track scores here
        if done :
            if agent.env.portfolio_value > agent.env.initial_investment:
                success +=1

        step+=1
        state = next_state
        score += reward
    
    # Track scores and ratios
    scores.append(score)
    portfolio_target_ratios.append(info["portfolio_value"]/info["episode_target"] -1)
    
    
test_results_dataframe = pd.DataFrame([[
    n_tests,
    str(round(np.mean(scores)*100,3))+'%',
    str(round(np.mean(targets)*100,3))+'%',
    str(round(np.mean(portfolio_target_ratios)*100,3))+'%',
    str(round(min(scores)*100,3))+'%',
    str(round(max(scores)*100,3))+'%',
    str(round((success/n_tests)*100,3)) +'%'
]],
    columns=[
        '# Blind tests',
        '% Average portfolio return', 
        '% Desired portfolio return', 
        'Portfolio/Target rate',
        '% Historical minimum return',
        '% Historical maximum return', 
        '% Episodes concluded with positive outcome'
    ]
)


agent.results_writer.store_test_results(agent,test_results_dataframe)

test_results_dataframe.T
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [7], in <cell line: 9>()
#      20 agent.env.render()
#      22 # Select action
# ---> 23 action, action_onehot, prediction = agent.act(state)
#      25 # Retrieve new state, reward, and whether the state is terminal
#      26 next_state, reward, done, info = agent.env.step(action)
#
# File ~\Development\GIT\tmp\reinforcement-learning\src\agents\actor_critic\a2c.py:240, in A2CAgent.act(self, state, deterministic)
#     239 def act(self,state,deterministic=True):
# --> 240     action, action_onehot, prediction = self.actor.act(state,deterministic=deterministic)
#     241     return action, action_onehot, prediction
#
# File ~\Development\GIT\tmp\reinforcement-learning\src\agents\actor_critic\a2c.py:92, in ActorNetwork.act(self, state, deterministic)
#      90 state = np.expand_dims(state, axis=0)
#      91 if self.action_space_mode == "discrete":
# ---> 92     prediction = self.model.predict(state)[0]
#      93     if deterministic:
#      94         action = np.argmax(prediction)
#
# File ~\anaconda3\envs\ai_4\lib\site-packages\keras\engine\training_v1.py:970, in Model.predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#     967 self._check_call_args('predict')
#     969 func = self._select_training_loop(x)
# --> 970 return func.predict(
#     971     self,
#     972     x=x,
#     973     batch_size=batch_size,
#     974     verbose=verbose,
#     975     steps=steps,
#     976     callbacks=callbacks,
#     977     max_queue_size=max_queue_size,
#     978     workers=workers,
#     979     use_multiprocessing=use_multiprocessing)
#
# File ~\anaconda3\envs\ai_4\lib\site-packages\keras\engine\training_arrays_v1.py:700, in ArrayLikeTrainingLoop.predict(self, model, x, batch_size, verbose, steps, callbacks, **kwargs)
#     697 batch_size = model._validate_or_infer_batch_size(batch_size, steps, x)
#     698 x, _, _ = model._standardize_user_data(
#     699     x, check_steps=True, steps_name='steps', steps=steps)
# --> 700 return predict_loop(
#     701     model,
#     702     x,
#     703     batch_size=batch_size,
#     704     verbose=verbose,
#     705     steps=steps,
#     706     callbacks=callbacks)
#
# File ~\anaconda3\envs\ai_4\lib\site-packages\keras\engine\training_arrays_v1.py:377, in model_iteration(model, inputs, targets, sample_weights, batch_size, epochs, verbose, callbacks, val_inputs, val_targets, val_sample_weights, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq, mode, validation_in_fit, prepared_feed_values_from_dataset, steps_name, **kwargs)
#     374 callbacks._call_batch_hook(mode, 'begin', batch_index, batch_logs)
#     376 # Get outputs.
# --> 377 batch_outs = f(ins_batch)
#     378 if not isinstance(batch_outs, list):
#     379   batch_outs = [batch_outs]
#
# File ~\anaconda3\envs\ai_4\lib\site-packages\keras\backend.py:4275, in GraphExecutionFunction.__call__(self, inputs)
#    4269 if (self._callable_fn is None or feed_arrays != self._feed_arrays or
#    4270     symbol_vals != self._symbol_vals or
#    4271     feed_symbols != self._feed_symbols or self.fetches != self._fetches or
#    4272     session != self._session):
#    4273   self._make_callable(feed_arrays, feed_symbols, symbol_vals, session)
# -> 4275 fetched = self._callable_fn(*array_vals,
#    4276                             run_metadata=self.run_metadata)
#    4277 self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    4278 output_structure = tf.nest.pack_sequence_as(
#    4279     self._outputs_structure,
#    4280     fetched[:len(self.outputs)],
#    4281     expand_composites=True)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\client\session.py:1480, in BaseSession._Callable.__call__(self, *args, **kwargs)
#    1478 try:
#    1479   run_metadata_ptr = tf_session.TF_NewBuffer() if run_metadata else None
# -> 1480   ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1481                                          self._handle, args,
#    1482                                          run_metadata_ptr)
#    1483   if run_metadata:
#    1484     proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Visual test
# * Runs a set of episodes with **unseen data**
# * See the evolution in real time

# %%
success = 0
n_tests = 10

scores = []
targets = []


for i in trange(n_tests):
    state = agent.env.reset(visualize=True,mode="test")
    step = 0
    score = 0
    reward = 0
    done = False
    targets.append((agent.env.episode_target-agent.env.initial_investment)/agent.env.initial_investment)
    initial_portfolio = agent.env.portfolio_value

    while not done:
        agent.env.render()
        
        # Select desired action
        action, action_onehot, prediction = agent.act(state)

        # Retrieve new state, reward, and whether the state is terminal
        next_state, reward, done, _ = agent.env.step(action)

        # End of episode, track scores here
        if done :
            if agent.env.portfolio_value > agent.env.initial_investment:
                success +=1

        step+=1
        state = next_state
        score += reward
    
    scores.append(score)

agent.env.close()

# %% [markdown]
# ### Transactions profit
# * Track how much the agent gained by doing purchases and sales
# * Doesn't track the portfolio value
# * Already has the fees discounted

# %%
success = 0
n_tests = 10000

test_results_data = []
test_results_columns = [
    'dataset id',
    'episode start date', 
    'episode end date',
    'episode working days',
    'total transactions',
    'total transaction profit',
    "dataframe hash",
    "agent hash"
]

print('NOTE: This test only tracks the transactions profit. ')

for i in trange(n_tests):
    trading_history = []
    state = agent.env.reset(visualize=False,mode="test")
    step = 0
    score = 0
    reward = 0
    done = False
    #targets.append((agent.env.episode_target-agent.env.initial_investment)/agent.env.initial_investment)
    #initial_portfolio = agent.env.portfolio_value
    
    j = 0
    num_stocks = 0
    while not done:
        agent.env.render()
        
        # Select desired action
        action, action_onehot, prediction = agent.act(state)
        current_price = agent.env.df.iloc[agent.env.current_step -1]['close']
        
        if action == agent.env.ACTIONS.BUY:
            discounted_price = current_price * (1+agent.env.fees.BUY) 
            if agent.env.stock_held < agent.env.maximum_stocks_held and agent.env.cash_in_hand >= discounted_price:
                num_stocks +=1
                trading_history.append(['buy', discounted_price])
        elif action == agent.env.ACTIONS.SELL:
            if agent.env.stock_held > 0:
                discounted_price = current_price * (1-agent.env.fees.SELL) 
                trading_history.append(['sell', discounted_price])
                num_stocks =0
                
        # Retrieve new state, reward, and whether the state is terminal
        next_state, reward, done, _ = agent.env.step(action)

        # Update current state
        if done :
            if agent.env.portfolio_value > agent.env.initial_investment:
                success +=1
                
            profits = []
            purchases = []
            for e in trading_history:
                if e[0] == 'buy':
                    purchases.append(e[1])
                else:
                    profits.append((e[1]* len(purchases) - sum(purchases)) / sum(purchases))
                    purchases.clear() 
                    
            test_results_data.append([
                agent.env.dataset_idx,
                agent.env.df.iloc[agent.env.lookback].name,
                agent.env.df.iloc[-1].name,
                agent.env.window_size,
                len(profits),
                sum(profits)*100,
                agent.env.df_name,
                agent.hash
            ])


        step+=1
        state = next_state
        score += reward
    

agent.env.close()


pd.DataFrame(test_results_data,columns=test_results_columns)

# %%
transaction_results_df = pd.DataFrame(test_results_data,columns=test_results_columns)

# %%
transaction_results_df.sort_values(by="dataset id")

# %%
transaction_results_df[transaction_results_df['total transaction profit'] <= 0]

# %%
failed_episodes_df = transaction_results_df[transaction_results_df['total transaction profit'] <= 0]
failed_episodes_idx = failed_episodes_df['dataset id'].unique()
failed_episodes_idx.sort()

# %%
len(transaction_results_df[transaction_results_df['total transaction profit'] <= 0]['dataset id'].unique()),len(transaction_results_df[transaction_results_df['total transaction profit'] > 0]['dataset id'].unique())

# %%
import matplotlib.pyplot as plt 

for idx in failed_episodes_idx:
    plt.figure(figsize=(16,4))
    plt.plot(agent.env.df['close'])
    plt.title('#'+str(idx)+' - ' + str(len(failed_episodes_df[failed_episodes_df['dataset id'] == idx])) +'/' + str(len(transaction_results_df[transaction_results_df['dataset id'] == idx])))
