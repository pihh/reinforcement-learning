# %%
import shutup
shutup.please()

import gym
import src.environments.continuous.stock_trading  

import numpy as np
import pandas as pd 

from tqdm.notebook import trange, tqdm

# %% [markdown]
# ### Train the agent
# * Run it until he has a running average above the success_threshold
# * Use a large number of episodes for the running average ( 1000+ ) so if even it falls into a privileged sample, it wont be prone to error

# %%
from src.agents.ppo import PpoAgent

# %%
def environment(describe=True):
    env = gym.make('StockTradingEnvironment-v0',
            use_technical_indicators= [
            "macd",
            "boll_ub",
            "boll_lb",
            "rsi_30",
            "cci_30",
            "dx_30",
            "close_30_sma",
            "close_60_sma",
        ])
    
    poc_threshold = 0.3 # 10% 
    print('* Original success threshold', env.success_threshold)
    
    print('* POC success threshold', poc_threshold)
    print()
    
    env.success_threshold = poc_threshold
    
    return env

# %%
agent=PpoAgent(
        environment,
        actor_learning_rate=0.000025,
        critic_learning_rate=0.000025,
        policy="CNN",
        epochs=10,
        n_workers=8)

agent.load()
    
agent.learn(
        timesteps=-1, 
        log_every=100,
        success_threshold_lookback=1000,
        success_strict=False,
    )
# Out:
# * Original success threshold 0.0855973435323849
# * POC success threshold 0.1
#
# @TODO Agent._load_agent_configuration()
#
# * Could not load the following models: ['ppo-actor', 'ppo-critic'] *
#
# * Booting worker 0
#
# * Original success threshold 0.0855973435323849
# * POC success threshold 0.1
#
# * Booting worker 1
#
# * Original success threshold 0.0855973435323849
# * POC success threshold 0.1
#
# * Booting worker 2
#
# * Original success threshold 0.0855973435323849
# * POC success threshold 0.1
#
# * Booting worker 3
#
# * Original success threshold 0.0855973435323849
# * POC success threshold 0.1
#
# * Booting worker 4
#
# * Original success threshold 0.0855973435323849
# * POC success threshold 0.1
#
# * Booting worker 5
#
# * Original success threshold 0.0855973435323849
# * POC success threshold 0.1
#
# * Booting worker 6
#
# * Original success threshold 0.0855973435323849
# * POC success threshold 0.1
#
# * Booting worker 7
#
# * Original success threshold 0.0855973435323849
# * POC success threshold 0.1
#
# Episode * 100 * Worker #3 * Moving Avg Reward is ==> -0.00587 * Last Reward was ==> -0.03725
# Episode * 200 * Worker #7 * Moving Avg Reward is ==> -0.00455 * Last Reward was ==> -0.02347
#
# * Will replay
# * Worker 0 finnished learning phase
# * Worker 1 finnished learning phase
# * Worker 2 finnished learning phase
# * Worker 3 finnished learning phase
# * Worker 4 finnished learning phase
# * Worker 5 finnished learning phase
# * Worker 6 finnished learning phase
# * Worker 7 finnished learning phase
# * Will resume
#
# Episode * 300 * Worker #3 * Moving Avg Reward is ==> -0.00288 * Last Reward was ==> 0.02921
# Episode * 400 * Worker #7 * Moving Avg Reward is ==> -0.00174 * Last Reward was ==> -0.02989
# Episode * 500 * Worker #3 * Moving Avg Reward is ==> -0.00116 * Last Reward was ==> 0.00608
#
# * Will replay
# * Worker 0 finnished learning phase
# * Worker 1 finnished learning phase
# * Worker 2 finnished learning phase
# * Worker 3 finnished learning phase
# * Worker 4 finnished learning phase
# * Worker 5 finnished learning phase
# * Worker 6 finnished learning phase
# * Worker 7 finnished learning phase
# * Will resume
#
# Episode * 600 * Worker #7 * Moving Avg Reward is ==> -0.00030 * Last Reward was ==> -0.03926
# Episode * 700 * Worker #3 * Moving Avg Reward is ==> 0.00142 * Last Reward was ==> -0.00601
#
# * Will replay
# * Worker 0 finnished learning phase
# * Worker 1 finnished learning phase
# * Worker 2 finnished learning phase
# * Worker 3 finnished learning phase
# * Worker 4 finnished learning phase
# * Worker 5 finnished learning phase
# * Worker 6 finnished learning phase
# * Worker 7 finnished learning phase
# * Will resume
#
# Episode * 800 * Worker #7 * Moving Avg Reward is ==> 0.00415 * Last Reward was ==> 0.03039
# Episode * 900 * Worker #3 * Moving Avg Reward is ==> 0.00630 * Last Reward was ==> 0.00649
# Episode * 1000 * Worker #7 * Moving Avg Reward is ==> 0.00947 * Last Reward was ==> 0.01374 * Total episodes ending on loss: 401/1000
# * Models saved *
#
# New historical moving average record: 0.00948
#
# * Models saved *
#
# New historical moving average record: 0.00949
#
# * Models saved *
#
# New historical moving average record: 0.00958
#
# * Models saved *
#
# New historical moving average record: 0.00962
#
# * Models saved *
#
# New historical moving average record: 0.00964
#
# * Models saved *
#
# New historical moving average record: 0.00966
#
#
# * Will replay
# * Worker 0 finnished learning phase
# * Worker 1 finnished learning phase
# * Worker 2 finnished learning phase
# * Worker 3 finnished learning phase
# * Worker 4 finnished learning phase
# * Worker 5 finnished learning phase
# * Worker 6 finnished learning phase
# * Worker 7 finnished learning phase
# * Will resume
#
# * Models saved *
#
# New historical moving average record: 0.00981
#
# * Models saved *
#
# New historical moving average record: 0.00982
#
# * Models saved *
#
# New historical moving average record: 0.00982
#
# * Models saved *
#
# New historical moving average record: 0.00984
#
# * Models saved *
#
# New historical moving average record: 0.00986
#
# * Models saved *
#
# New historical moving average record: 0.00992
#
# * Models saved *
#
# New historical moving average record: 0.00996
#
# * Models saved *
#
# New historical moving average record: 0.00997
#
# * Models saved *
#
# New historical moving average record: 0.01011
#
# * Models saved *
#
# New historical moving average record: 0.01012
#
# * Models saved *
#
# New historical moving average record: 0.01018
#
# * Models saved *
#
# New historical moving average record: 0.01024
#
# * Models saved *
#
# New historical moving average record: 0.01025
#
# * Models saved *
#
# New historical moving average record: 0.01035
#
# * Models saved *
#
# New historical moving average record: 0.01043
#
# * Models saved *
#
# New historical moving average record: 0.01056
#
# * Models saved *
#
# New historical moving average record: 0.01072
#
# * Models saved *
#
# New historical moving average record: 0.01076
#
# * Models saved *
#
# New historical moving average record: 0.01079
#
# * Models saved *
#
# New historical moving average record: 0.01098
#
# * Models saved *
#
# New historical moving average record: 0.01103
#
# * Models saved *
#
# New historical moving average record: 0.01112
#
# * Models saved *
#
# New historical moving average record: 0.01123
#
# * Models saved *
#
# New historical moving average record: 0.01129
#
# * Models saved *
#
# New historical moving average record: 0.01141
#
# * Models saved *
#
# New historical moving average record: 0.01142
#
# * Models saved *
#
# New historical moving average record: 0.01156
#
# * Models saved *
#
# New historical moving average record: 0.01166
#
# * Models saved *
#
# New historical moving average record: 0.01171
#
# * Models saved *
#
# New historical moving average record: 0.01176
#
# * Models saved *
#
# New historical moving average record: 0.01179
#
# * Models saved *
#
# New historical moving average record: 0.01192
#
# * Models saved *
#
# New historical moving average record: 0.01197
#
# * Models saved *
#
# New historical moving average record: 0.01197
#
# * Models saved *
#
# New historical moving average record: 0.01205
#
# * Models saved *
#
# New historical moving average record: 0.01218
#
# * Models saved *
#
# New historical moving average record: 0.01232
#
# * Models saved *
#
# New historical moving average record: 0.01248
#
# * Models saved *
#
# New historical moving average record: 0.01254
#
# * Models saved *
#
# New historical moving average record: 0.01258
#
# * Models saved *
#
# New historical moving average record: 0.01270
#
# * Models saved *
#
# New historical moving average record: 0.01275
#
# * Models saved *
#
# New historical moving average record: 0.01284
#
# * Models saved *
#
# New historical moving average record: 0.01290
#
# * Models saved *
#
# New historical moving average record: 0.01291
#
# * Models saved *
#
# New historical moving average record: 0.01301
#
# * Models saved *
#
# New historical moving average record: 0.01304
#
# * Models saved *
#
# New historical moving average record: 0.01310
#
# * Models saved *
#
# New historical moving average record: 0.01327
#
# * Models saved *
#
# New historical moving average record: 0.01332
#
# * Models saved *
#
# New historical moving average record: 0.01341
#
# * Models saved *
#
# New historical moving average record: 0.01348
#
# * Models saved *
#
# New historical moving average record: 0.01352
#
# * Models saved *
#
# New historical moving average record: 0.01361
#
# * Models saved *
#
# New historical moving average record: 0.01373
#
# * Models saved *
#
# New historical moving average record: 0.01383
#
# * Models saved *
#
# New historical moving average record: 0.01394
#
# * Models saved *
#
# New historical moving average record: 0.01398
#
# * Models saved *
#
# New historical moving average record: 0.01410
#
# * Models saved *
#
# New historical moving average record: 0.01418
#
# * Models saved *
#
# New historical moving average record: 0.01431
#
# * Models saved *
#
# New historical moving average record: 0.01433
#
# * Models saved *
#
# New historical moving average record: 0.01442
#
# * Models saved *
#
# New historical moving average record: 0.01455
#
# * Models saved *
#
# New historical moving average record: 0.01459
#
# * Models saved *
#
# New historical moving average record: 0.01467
#
# * Models saved *
#
# New historical moving average record: 0.01475
#
# * Models saved *
#
# New historical moving average record: 0.01479
#
# * Models saved *
#
# New historical moving average record: 0.01489
#
# * Models saved *
#
# New historical moving average record: 0.01495
#
# * Models saved *
#
# New historical moving average record: 0.01499
#
# * Models saved *
#
# New historical moving average record: 0.01506
#
# * Models saved *
#
# New historical moving average record: 0.01510
# * Models saved *
#
# New historical moving average record: 0.01518
#
# * Models saved *
#
# New historical moving average record: 0.01530
#
# * Models saved *
#
# New historical moving average record: 0.01541
#
# Episode * 1100 * Worker #3 * Moving Avg Reward is ==> 0.01550 * Last Reward was ==> 0.04955 * Total episodes ending on loss: 354/1000
# * Models saved *
#
# New historical moving average record: 0.01550
#
# * Models saved *
#
# New historical moving average record: 0.01556
#
# * Models saved *
#
# New historical moving average record: 0.01557
#
# * Models saved *
#
# New historical moving average record: 0.01566
#
# * Models saved *
#
# New historical moving average record: 0.01567
#
# * Models saved *
#
# New historical moving average record: 0.01569
#
# * Models saved *
#
# New historical moving average record: 0.01579
#
# * Models saved *
#
# New historical moving average record: 0.01588
#
# * Models saved *
#
# New historical moving average record: 0.01595
#
# * Models saved *
#
# New historical moving average record: 0.01601
#
# * Models saved *
#
# New historical moving average record: 0.01603
#
# * Models saved *
#
# New historical moving average record: 0.01618
#
# * Models saved *
#
# New historical moving average record: 0.01622
#
# * Models saved *
#
# New historical moving average record: 0.01623
#
# * Models saved *
#
# New historical moving average record: 0.01628
#
# * Models saved *
#
# New historical moving average record: 0.01636
#
# * Models saved *
#
# New historical moving average record: 0.01646
#
# * Models saved *
#
# New historical moving average record: 0.01656
#
# * Models saved *
#
# New historical moving average record: 0.01663
#
# * Models saved *
#
# New historical moving average record: 0.01673
#
# * Models saved *
#
# New historical moving average record: 0.01682
#
# * Models saved *
#
# New historical moving average record: 0.01687
#
# * Models saved *
#
# New historical moving average record: 0.01690
#
# * Models saved *
#
# New historical moving average record: 0.01700
#
# * Models saved *
#
# New historical moving average record: 0.01706
#
# * Models saved *
#
# New historical moving average record: 0.01708
#
# * Models saved *
#
# New historical moving average record: 0.01721
#
# * Models saved *
#
# New historical moving average record: 0.01726
#
# * Models saved *
#
# New historical moving average record: 0.01731
#
# * Models saved *
#
# New historical moving average record: 0.01740
#
# * Models saved *
#
# New historical moving average record: 0.01752
#
# * Models saved *
#
# New historical moving average record: 0.01765
#
# * Models saved *
#
# New historical moving average record: 0.01771
#
# * Models saved *
#
# New historical moving average record: 0.01780
#
# * Models saved *
#
# New historical moving average record: 0.01786
#
# * Models saved *
#
# New historical moving average record: 0.01790
#
# * Models saved *
#
# New historical moving average record: 0.01804
#
# * Models saved *
#
# New historical moving average record: 0.01812
#
# * Models saved *
#
# New historical moving average record: 0.01824
#
# * Models saved *
#
# New historical moving average record: 0.01826
#
# * Models saved *
#
# New historical moving average record: 0.01838
#
# * Models saved *
#
# New historical moving average record: 0.01839
#
# * Models saved *
#
# New historical moving average record: 0.01849
#
# * Models saved *
#
# New historical moving average record: 0.01852
#
# * Models saved *
#
# New historical moving average record: 0.01860
#
# * Models saved *
#
# New historical moving average record: 0.01863
#
# * Models saved *
#
# New historical moving average record: 0.01871
#
# * Models saved *
#
# New historical moving average record: 0.01875
#
# * Models saved *
#
# New historical moving average record: 0.01885
#
# * Models saved *
#
# New historical moving average record: 0.01892
#
# * Models saved *
#
# New historical moving average record: 0.01902
#
# * Models saved *
#
# New historical moving average record: 0.01915
#
# * Models saved *
#
# New historical moving average record: 0.01931
#
# * Models saved *
#
# New historical moving average record: 0.01936
#
# * Models saved *
#
# New historical moving average record: 0.01942
#
# * Models saved *
#
# New historical moving average record: 0.01949
#
# * Models saved *
#
# New historical moving average record: 0.01950
#
# * Models saved *
#
# New historical moving average record: 0.01959
#
# * Models saved *
#
# New historical moving average record: 0.01976
#
# * Models saved *
#
# New historical moving average record: 0.01986
#
# * Models saved *
#
# New historical moving average record: 0.01993
#
# * Models saved *
#
# New historical moving average record: 0.01998
#
# * Models saved *
#
# New historical moving average record: 0.02001
#
# * Models saved *
#
# New historical moving average record: 0.02007
#
# * Models saved *
#
# New historical moving average record: 0.02008
#
# * Models saved *
#
# New historical moving average record: 0.02015
#
# * Models saved *
#
# New historical moving average record: 0.02017
#
# * Models saved *
#
# New historical moving average record: 0.02024
#
# * Models saved *
#
# New historical moving average record: 0.02035
#
# * Models saved *
#
# New historical moving average record: 0.02038
#
# * Models saved *
#
# New historical moving average record: 0.02039
#
# * Models saved *
#
# New historical moving average record: 0.02043
#
# * Models saved *
#
# New historical moving average record: 0.02050
#
# * Models saved *
#
# New historical moving average record: 0.02061
#
# * Models saved *
#
# New historical moving average record: 0.02068
#
# * Models saved *
#
# New historical moving average record: 0.02071
#
# * Models saved *
#
# New historical moving average record: 0.02084
#
# * Models saved *
#
# New historical moving average record: 0.02090
#
# * Models saved *
#
# New historical moving average record: 0.02099
#
# * Models saved *
#
# New historical moving average record: 0.02099
#
# * Models saved *
#
# New historical moving average record: 0.02108
#
# * Models saved *
#
# New historical moving average record: 0.02111
#
# * Models saved *
#
# New historical moving average record: 0.02120
#
# * Models saved *
#
# New historical moving average record: 0.02131
#
# * Models saved *
#
# New historical moving average record: 0.02137
#
# * Models saved *
#
# New historical moving average record: 0.02138
#
# * Models saved *
#
# New historical moving average record: 0.02146
#
# * Models saved *
#
# New historical moving average record: 0.02157
#
# * Models saved *
#
# New historical moving average record: 0.02159
#
# Episode * 1200 * Worker #7 * Moving Avg Reward is ==> 0.02171 * Last Reward was ==> 0.09323 * Total episodes ending on loss: 307/1000
# * Models saved *
#
# New historical moving average record: 0.02171
#
# * Models saved *
#
# New historical moving average record: 0.02175
#
# * Models saved *
#
# New historical moving average record: 0.02185
#
# * Models saved *
#
# New historical moving average record: 0.02188
#
# * Models saved *
#
# New historical moving average record: 0.02200
#
# * Models saved *
#
# New historical moving average record: 0.02209
#
# * Models saved *
#
# New historical moving average record: 0.02232
#
# * Models saved *
#
# New historical moving average record: 0.02232
#
# * Models saved *
#
# New historical moving average record: 0.02242
#
# * Models saved *
#
# New historical moving average record: 0.02250
#
# * Models saved *
#
# New historical moving average record: 0.02263
#
# * Models saved *
#
# New historical moving average record: 0.02274
#
# * Models saved *
#
# New historical moving average record: 0.02284
#
# * Models saved *
#
# New historical moving average record: 0.02286
#
# * Models saved *
#
# New historical moving average record: 0.02300
#
# * Models saved *
#
# New historical moving average record: 0.02306
#
# * Models saved *
#
# New historical moving average record: 0.02316
#
# * Models saved *
#
# New historical moving average record: 0.02327
#
# * Models saved *
#
# New historical moving average record: 0.02339
#
# * Models saved *
#
# New historical moving average record: 0.02343
#
# * Models saved *
#
# New historical moving average record: 0.02344
#
# * Models saved *
#
# New historical moving average record: 0.02349
#
# * Models saved *
#
# New historical moving average record: 0.02353
#
# * Models saved *
#
# New historical moving average record: 0.02354
#
# * Models saved *
#
# New historical moving average record: 0.02357
#
# * Models saved *
#
# New historical moving average record: 0.02357
#
# * Models saved *
#
# New historical moving average record: 0.02372
#
# * Models saved *
#
# New historical moving average record: 0.02385
#
# * Models saved *
#
# New historical moving average record: 0.02391
#
# * Models saved *
#
# New historical moving average record: 0.02397
#
# * Models saved *
#
# New historical moving average record: 0.02400
#
# * Models saved *
#
# New historical moving average record: 0.02407
#
# * Models saved *
#
# New historical moving average record: 0.02411
#
# * Models saved *
#
# New historical moving average record: 0.02417
#
# * Models saved *
#
# New historical moving average record: 0.02424
# * Models saved *
#
# New historical moving average record: 0.02425
#
# * Models saved *
#
# New historical moving average record: 0.02436
#
# * Models saved *
#
# New historical moving average record: 0.02443
#
# * Models saved *
#
# New historical moving average record: 0.02449
#
# * Models saved *
#
# New historical moving average record: 0.02454
#
# * Models saved *
#
# New historical moving average record: 0.02460
#
# * Models saved *
#
# New historical moving average record: 0.02466
#
# * Models saved *
#
# New historical moving average record: 0.02469
#
# * Models saved *
#
# New historical moving average record: 0.02475
#
# * Models saved *
#
# New historical moving average record: 0.02478
#
# * Models saved *
#
# New historical moving average record: 0.02496
#
# * Models saved *
#
# New historical moving average record: 0.02500
#
# * Models saved *
#
# New historical moving average record: 0.02507
#
# * Models saved *
#
# New historical moving average record: 0.02518
#
# * Models saved *
#
# New historical moving average record: 0.02524
#
# * Models saved *
#
# New historical moving average record: 0.02530
#
# * Models saved *
#
# New historical moving average record: 0.02534
#
# * Models saved *
#
# New historical moving average record: 0.02537
#
# * Models saved *
#
# New historical moving average record: 0.02546
#
# * Models saved *
#
# New historical moving average record: 0.02549
#
# * Models saved *
#
# New historical moving average record: 0.02556
#
# * Models saved *
#
# New historical moving average record: 0.02561
#
# * Models saved *
#
# New historical moving average record: 0.02562
#
#
# * Will replay
# * Worker 0 finnished learning phase
# * Worker 1 finnished learning phase
# * Worker 2 finnished learning phase
# * Worker 3 finnished learning phase
# * Worker 4 finnished learning phase
# * Worker 5 finnished learning phase
# * Worker 6 finnished learning phase
# * Worker 7 finnished learning phase
# * Will resume
#
# * Models saved *
#
# New historical moving average record: 0.02566
#
# * Models saved *
#
# New historical moving average record: 0.02574
#
# * Models saved *
#
# New historical moving average record: 0.02584
#
# * Models saved *
#
# New historical moving average record: 0.02598
#
# * Models saved *
#
# New historical moving average record: 0.02612
#
# * Models saved *
#
# New historical moving average record: 0.02624
#
# * Models saved *
#
# New historical moving average record: 0.02629
#
# * Models saved *
#
# New historical moving average record: 0.02631
#
# * Models saved *
#
# New historical moving average record: 0.02642
#
# * Models saved *
#
# New historical moving average record: 0.02655
#
# * Models saved *
#
# New historical moving average record: 0.02670
#
# * Models saved *
#
# New historical moving average record: 0.02688
#
# * Models saved *
#
# New historical moving average record: 0.02698
#
# * Models saved *
#
# New historical moving average record: 0.02708
#
# * Models saved *
#
# New historical moving average record: 0.02709
#
# * Models saved *
#
# New historical moving average record: 0.02715
#
# * Models saved *
#
# New historical moving average record: 0.02724
#
# * Models saved *
#
# New historical moving average record: 0.02746
#
# * Models saved *
#
# New historical moving average record: 0.02748
#
# * Models saved *
#
# New historical moving average record: 0.02761
#
# * Models saved *
#
# New historical moving average record: 0.02775
#
# * Models saved *
#
# New historical moving average record: 0.02783
#
# * Models saved *
#
# New historical moving average record: 0.02796
#
# * Models saved *
#
# New historical moving average record: 0.02808
#
# * Models saved *
#
# New historical moving average record: 0.02809
#
# * Models saved *
#
# New historical moving average record: 0.02821
#
# * Models saved *
#
# New historical moving average record: 0.02833
#
# * Models saved *
#
# New historical moving average record: 0.02838
#
# * Models saved *
#
# New historical moving average record: 0.02839
#
# * Models saved *
#
# New historical moving average record: 0.02845
#
# * Models saved *
#
# New historical moving average record: 0.02866
#
# * Models saved *
#
# New historical moving average record: 0.02880
#
# * Models saved *
#
# New historical moving average record: 0.02903
#
# * Models saved *
#
# New historical moving average record: 0.02912
#
# Episode * 1300 * Worker #3 * Moving Avg Reward is ==> 0.02918 * Last Reward was ==> 0.08878 * Total episodes ending on loss: 255/1000
# * Models saved *
#
# New historical moving average record: 0.02918
#
# * Models saved *
#
# New historical moving average record: 0.02920
#
# * Models saved *
#
# New historical moving average record: 0.02931
#
# * Models saved *
#
# New historical moving average record: 0.02941
#
# * Models saved *
#
# New historical moving average record: 0.02948
#
# * Models saved *
#
# New historical moving average record: 0.02963
#
# * Models saved *
#
# New historical moving average record: 0.02970
#
# * Models saved *
#
# New historical moving average record: 0.02978
#
# * Models saved *
#
# New historical moving average record: 0.02990
#
# * Models saved *
#
# New historical moving average record: 0.02990
#
# * Models saved *
#
# New historical moving average record: 0.03009
#
# * Models saved *
#
# New historical moving average record: 0.03018
#
# * Models saved *
#
# New historical moving average record: 0.03034
#
# * Models saved *
#
# New historical moving average record: 0.03042
#
# * Models saved *
#
# New historical moving average record: 0.03052
#
# * Models saved *
#
# New historical moving average record: 0.03065
#
# * Models saved *
#
# New historical moving average record: 0.03076
#
# * Models saved *
#
# New historical moving average record: 0.03089
#
# * Models saved *
#
# New historical moving average record: 0.03095
#
# * Models saved *
#
# New historical moving average record: 0.03107
#
# * Models saved *
#
# New historical moving average record: 0.03117
#
# * Models saved *
#
# New historical moving average record: 0.03118
#
# * Models saved *
#
# New historical moving average record: 0.03133
#
# * Models saved *
#
# New historical moving average record: 0.03154
#
# * Models saved *
#
# New historical moving average record: 0.03163
#
# * Models saved *
#
# New historical moving average record: 0.03166
#
# * Models saved *
#
# New historical moving average record: 0.03168
#
# * Models saved *
#
# New historical moving average record: 0.03175
#
# * Models saved *
#
# New historical moving average record: 0.03188
#
# * Models saved *
#
# New historical moving average record: 0.03211
#
# * Models saved *
#
# New historical moving average record: 0.03218
#
# * Models saved *
#
# New historical moving average record: 0.03233
#
# * Models saved *
#
# New historical moving average record: 0.03248
#
# * Models saved *
#
# New historical moving average record: 0.03257
#
# * Models saved *
#
# New historical moving average record: 0.03272
#
# * Models saved *
#
# New historical moving average record: 0.03280
#
# * Models saved *
#
# New historical moving average record: 0.03295
#
# * Models saved *
#
# New historical moving average record: 0.03302
#
# * Models saved *
#
# New historical moving average record: 0.03312
#
# * Models saved *
#
# New historical moving average record: 0.03322
#
# * Models saved *
#
# New historical moving average record: 0.03335
#
# * Models saved *
#
# New historical moving average record: 0.03337
#
# * Models saved *
#
# New historical moving average record: 0.03346
#
# * Models saved *
#
# New historical moving average record: 0.03363
#
# * Models saved *
#
# New historical moving average record: 0.03368
#
# * Models saved *
#
# New historical moving average record: 0.03380
#
# * Models saved *
#
# New historical moving average record: 0.03382
#
# * Models saved *
#
# New historical moving average record: 0.03391
#
# * Models saved *
#
# New historical moving average record: 0.03395
#
# * Models saved *
#
# New historical moving average record: 0.03400
#
# * Models saved *
#
# New historical moving average record: 0.03406
#
# * Models saved *
#
# New historical moving average record: 0.03414
#
# * Models saved *
#
# New historical moving average record: 0.03427
#
# * Models saved *
#
# New historical moving average record: 0.03445
#
# * Models saved *
#
# New historical moving average record: 0.03454
#
# * Models saved *
#
# New historical moving average record: 0.03458
#
# * Models saved *
#
# New historical moving average record: 0.03464
#
# * Models saved *
#
# New historical moving average record: 0.03465
#
# * Models saved *
#
# New historical moving average record: 0.03478
#
# * Models saved *
#
# New historical moving average record: 0.03489
#
# * Models saved *
#
# New historical moving average record: 0.03498
#
# * Models saved *
#
# New historical moving average record: 0.03510
#
# * Models saved *
#
# New historical moving average record: 0.03524
#
# * Models saved *
#
# New historical moving average record: 0.03544
#
# * Models saved *
#
# New historical moving average record: 0.03558
#
# * Models saved *
#
# New historical moving average record: 0.03569
#
# * Models saved *
#
# New historical moving average record: 0.03580
# * Models saved *
#
# New historical moving average record: 0.03583
#
# * Models saved *
#
# New historical moving average record: 0.03603
#
# * Models saved *
#
# New historical moving average record: 0.03628
#
# * Models saved *
#
# New historical moving average record: 0.03630
#
# * Models saved *
#
# New historical moving average record: 0.03635
#
# * Models saved *
#
# New historical moving average record: 0.03642
#
# * Models saved *
#
# New historical moving average record: 0.03654
#
# * Models saved *
#
# New historical moving average record: 0.03659
#
# * Models saved *
#
# New historical moving average record: 0.03662
#
# * Models saved *
#
# New historical moving average record: 0.03669
#
# * Models saved *
#
# New historical moving average record: 0.03680
#
# * Models saved *
#
# New historical moving average record: 0.03694
#
# * Models saved *
#
# New historical moving average record: 0.03706
#
# * Models saved *
#
# New historical moving average record: 0.03713
#
# * Models saved *
#
# New historical moving average record: 0.03723
#
# * Models saved *
#
# New historical moving average record: 0.03737
#
# * Models saved *
#
# New historical moving average record: 0.03738
#
# * Models saved *
#
# New historical moving average record: 0.03742
#
# * Models saved *
#
# New historical moving average record: 0.03746
#
# * Models saved *
#
# New historical moving average record: 0.03757
#
# * Models saved *
#
# New historical moving average record: 0.03760
#
# * Models saved *
#
# New historical moving average record: 0.03765
#
# * Models saved *
#
# New historical moving average record: 0.03770
#
# * Models saved *
#
# New historical moving average record: 0.03781
#
# * Models saved *
#
# New historical moving average record: 0.03788
#
# * Models saved *
#
# New historical moving average record: 0.03798
#
# * Models saved *
#
# New historical moving average record: 0.03812
#
# * Models saved *
#
# New historical moving average record: 0.03826
#
# * Models saved *
#
# New historical moving average record: 0.03832
#
# * Models saved *
#
# New historical moving average record: 0.03841
#
# * Models saved *
#
# New historical moving average record: 0.03852
#
# Episode * 1400 * Worker #7 * Moving Avg Reward is ==> 0.03873 * Last Reward was ==> 0.18247 * Total episodes ending on loss: 210/1000
# * Models saved *
#
# New historical moving average record: 0.03873
#
# * Models saved *
#
# New historical moving average record: 0.03877
#
# * Models saved *
#
# New historical moving average record: 0.03886
#
# * Models saved *
#
# New historical moving average record: 0.03898
#
# * Models saved *
#
# New historical moving average record: 0.03904
#
# * Models saved *
#
# New historical moving average record: 0.03908
#
# * Models saved *
#
# New historical moving average record: 0.03909
#
# * Models saved *
#
# New historical moving average record: 0.03921
#
# * Models saved *
#
# New historical moving average record: 0.03923
#
# * Models saved *
#
# New historical moving average record: 0.03930
#
# * Models saved *
#
# New historical moving average record: 0.03940
#
# * Models saved *
#
# New historical moving average record: 0.03959
#
# * Models saved *
#
# New historical moving average record: 0.03971
#
# * Models saved *
#
# New historical moving average record: 0.03973
#
# * Models saved *
#
# New historical moving average record: 0.03981
#
# * Models saved *
#
# New historical moving average record: 0.03989
#
# * Models saved *
#
# New historical moving average record: 0.03996
#
# * Models saved *
#
# New historical moving average record: 0.04000
#
# * Models saved *
#
# New historical moving average record: 0.04011
#
# * Models saved *
#
# New historical moving average record: 0.04018
#
# * Models saved *
#
# New historical moving average record: 0.04024
#
# * Models saved *
#
# New historical moving average record: 0.04034
#
# * Models saved *
#
# New historical moving average record: 0.04045
#
# * Models saved *
#
# New historical moving average record: 0.04051
#
# * Models saved *
#
# New historical moving average record: 0.04067
#
# * Models saved *
#
# New historical moving average record: 0.04080
#
# * Models saved *
#
# New historical moving average record: 0.04090
#
# * Models saved *
#
# New historical moving average record: 0.04097
#
# * Models saved *
#
# New historical moving average record: 0.04105
#
# * Models saved *
#
# New historical moving average record: 0.04118
#
# * Models saved *
#
# New historical moving average record: 0.04124
#
# * Models saved *
#
# New historical moving average record: 0.04146
#
# * Models saved *
#
# New historical moving average record: 0.04157
#
# * Models saved *
#
# New historical moving average record: 0.04158
#
# * Models saved *
#
# New historical moving average record: 0.04165
#
# * Models saved *
#
# New historical moving average record: 0.04172
#
# * Models saved *
#
# New historical moving average record: 0.04186
#
# * Models saved *
#
# New historical moving average record: 0.04191
#
# * Models saved *
#
# New historical moving average record: 0.04201
#
# * Models saved *
#
# New historical moving average record: 0.04210
#
# * Models saved *
#
# New historical moving average record: 0.04222
#
# * Models saved *
#
# New historical moving average record: 0.04226
#
# * Models saved *
#
# New historical moving average record: 0.04234
#
# * Models saved *
#
# New historical moving average record: 0.04242
#
# * Models saved *
#
# New historical moving average record: 0.04250
#
# * Models saved *
#
# New historical moving average record: 0.04260
#
# * Models saved *
#
# New historical moving average record: 0.04265
#
# * Models saved *
#
# New historical moving average record: 0.04270
#
# * Models saved *
#
# New historical moving average record: 0.04281
#
# * Models saved *
#
# New historical moving average record: 0.04289
#
# * Models saved *
#
# New historical moving average record: 0.04307
#
# * Models saved *
#
# New historical moving average record: 0.04311
#
# * Models saved *
#
# New historical moving average record: 0.04325
#
# * Models saved *
#
# New historical moving average record: 0.04333
#
# * Models saved *
#
# New historical moving average record: 0.04341
#
# * Models saved *
#
# New historical moving average record: 0.04357
#
# * Models saved *
#
# New historical moving average record: 0.04373
#
# * Models saved *
#
# New historical moving average record: 0.04390
#
# * Models saved *
#
# New historical moving average record: 0.04391
#
# * Models saved *
#
# New historical moving average record: 0.04402
#
# * Models saved *
#
# New historical moving average record: 0.04406
#
# * Models saved *
#
# New historical moving average record: 0.04413
#
# * Models saved *
#
# New historical moving average record: 0.04422
#
# * Models saved *
#
# New historical moving average record: 0.04431
#
# * Models saved *
#
# New historical moving average record: 0.04447
#
# * Models saved *
#
# New historical moving average record: 0.04448
#
# * Models saved *
#
# New historical moving average record: 0.04456
#
# * Models saved *
#
# New historical moving average record: 0.04467
#
# * Models saved *
#
# New historical moving average record: 0.04474
#
# * Models saved *
#
# New historical moving average record: 0.04490
#
# * Models saved *
#
# New historical moving average record: 0.04497
#
# * Models saved *
#
# New historical moving average record: 0.04506
#
# * Models saved *
#
# New historical moving average record: 0.04512
#
# * Models saved *
#
# New historical moving average record: 0.04522
#
# * Models saved *
#
# New historical moving average record: 0.04536
#
# * Models saved *
#
# New historical moving average record: 0.04545
#
# * Models saved *
#
# New historical moving average record: 0.04565
#
# * Models saved *
#
# New historical moving average record: 0.04584
#
# * Models saved *
#
# New historical moving average record: 0.04589
#
# * Models saved *
#
# New historical moving average record: 0.04599
#
# * Models saved *
#
# New historical moving average record: 0.04610
#
# * Models saved *
#
# New historical moving average record: 0.04627
#
# * Models saved *
#
# New historical moving average record: 0.04640
#
# * Models saved *
#
# New historical moving average record: 0.04651
#
# * Models saved *
#
# New historical moving average record: 0.04664
#
# * Models saved *
#
# New historical moving average record: 0.04677
#
# * Models saved *
#
# New historical moving average record: 0.04690
#
# * Models saved *
#
# New historical moving average record: 0.04703
#
# * Models saved *
#
# New historical moving average record: 0.04704
#
# * Models saved *
#
# New historical moving average record: 0.04709
#
# * Models saved *
#
# New historical moving average record: 0.04718
#
# * Models saved *
#
# New historical moving average record: 0.04728
#
# * Models saved *
#
# New historical moving average record: 0.04739
# * Models saved *
#
# New historical moving average record: 0.04743
#
# * Models saved *
#
# New historical moving average record: 0.04751
#
# * Models saved *
#
# New historical moving average record: 0.04761
#
# * Models saved *
#
# New historical moving average record: 0.04765
#
# Episode * 1500 * Worker #3 * Moving Avg Reward is ==> 0.04776 * Last Reward was ==> 0.10747 * Total episodes ending on loss: 156/1000
# * Models saved *
#
# New historical moving average record: 0.04776
#
# * Models saved *
#
# New historical moving average record: 0.04796
#
# * Models saved *
#
# New historical moving average record: 0.04809
#
# * Models saved *
#
# New historical moving average record: 0.04823
#
# * Models saved *
#
# New historical moving average record: 0.04830
#
# * Models saved *
#
# New historical moving average record: 0.04840
#
# * Models saved *
#
# New historical moving average record: 0.04861
#
# * Models saved *
#
# New historical moving average record: 0.04871
#
# * Models saved *
#
# New historical moving average record: 0.04879
#
# * Models saved *
#
# New historical moving average record: 0.04887
#
# * Models saved *
#
# New historical moving average record: 0.04894
#
# * Models saved *
#
# New historical moving average record: 0.04895
#
# * Models saved *
#
# New historical moving average record: 0.04895
#
# * Models saved *
#
# New historical moving average record: 0.04909
#
# * Models saved *
#
# New historical moving average record: 0.04913
#
# * Models saved *
#
# New historical moving average record: 0.04917
#
# * Models saved *
#
# New historical moving average record: 0.04929
#
# * Models saved *
#
# New historical moving average record: 0.04941
#
# * Models saved *
#
# New historical moving average record: 0.04955
#
#
# * Will replay
# * Worker 0 finnished learning phase
# * Worker 1 finnished learning phase
# * Worker 2 finnished learning phase
# * Worker 3 finnished learning phase
# * Worker 4 finnished learning phase
# * Worker 5 finnished learning phase
# * Worker 6 finnished learning phase
# * Worker 7 finnished learning phase
# * Will resume
#
# * Models saved *
#
# New historical moving average record: 0.04961
#
# * Models saved *
#
# New historical moving average record: 0.04971
#
# * Models saved *
#
# New historical moving average record: 0.04988
#
# * Models saved *
#
# New historical moving average record: 0.05008
#
# * Models saved *
#
# New historical moving average record: 0.05023
#
# * Models saved *
#
# New historical moving average record: 0.05037
#
# * Models saved *
#
# New historical moving average record: 0.05045
#
# * Models saved *
#
# New historical moving average record: 0.05048
#
# * Models saved *
#
# New historical moving average record: 0.05071
#
# * Models saved *
#
# New historical moving average record: 0.05082
#
# * Models saved *
#
# New historical moving average record: 0.05097
#
# * Models saved *
#
# New historical moving average record: 0.05107
#
# * Models saved *
#
# New historical moving average record: 0.05119
#
# * Models saved *
#
# New historical moving average record: 0.05126
#
# * Models saved *
#
# New historical moving average record: 0.05135
#
# * Models saved *
#
# New historical moving average record: 0.05139
#
# * Models saved *
#
# New historical moving average record: 0.05158
#
# * Models saved *
#
# New historical moving average record: 0.05164
#
# * Models saved *
#
# New historical moving average record: 0.05172
#
# * Models saved *
#
# New historical moving average record: 0.05186
#
# * Models saved *
#
# New historical moving average record: 0.05210
#
# * Models saved *
#
# New historical moving average record: 0.05229
#
# * Models saved *
#
# New historical moving average record: 0.05239
#
# * Models saved *
#
# New historical moving average record: 0.05248
#
# * Models saved *
#
# New historical moving average record: 0.05254
#
# * Models saved *
#
# New historical moving average record: 0.05268
#
# * Models saved *
#
# New historical moving average record: 0.05282
#
# * Models saved *
#
# New historical moving average record: 0.05283
#
# * Models saved *
#
# New historical moving average record: 0.05288
#
# * Models saved *
#
# New historical moving average record: 0.05296
#
# * Models saved *
#
# New historical moving average record: 0.05306
#
# * Models saved *
#
# New historical moving average record: 0.05318
#
# * Models saved *
#
# New historical moving average record: 0.05334
#
# * Models saved *
#
# New historical moving average record: 0.05342
#
# * Models saved *
#
# New historical moving average record: 0.05356
#
# * Models saved *
#
# New historical moving average record: 0.05371
#
# * Models saved *
#
# New historical moving average record: 0.05383
#
# * Models saved *
#
# New historical moving average record: 0.05403
#
# * Models saved *
#
# New historical moving average record: 0.05418
#
# * Models saved *
#
# New historical moving average record: 0.05433
#
# * Models saved *
#
# New historical moving average record: 0.05446
#
# * Models saved *
#
# New historical moving average record: 0.05452
#
# * Models saved *
#
# New historical moving average record: 0.05466
#
# * Models saved *
#
# New historical moving average record: 0.05489
#
# * Models saved *
#
# New historical moving average record: 0.05506
#
# * Models saved *
#
# New historical moving average record: 0.05527
#
# * Models saved *
#
# New historical moving average record: 0.05544
#
# * Models saved *
#
# New historical moving average record: 0.05546
#
# * Models saved *
#
# New historical moving average record: 0.05549
#
# * Models saved *
#
# New historical moving average record: 0.05560
#
# * Models saved *
#
# New historical moving average record: 0.05583
#
# * Models saved *
#
# New historical moving average record: 0.05591
#
# * Models saved *
#
# New historical moving average record: 0.05599
#
# * Models saved *
#
# New historical moving average record: 0.05610
#
# * Models saved *
#
# New historical moving average record: 0.05613
#
# * Models saved *
#
# New historical moving average record: 0.05627
#
# * Models saved *
#
# New historical moving average record: 0.05634
#
# * Models saved *
#
# New historical moving average record: 0.05641
#
# * Models saved *
#
# New historical moving average record: 0.05648
#
# * Models saved *
#
# New historical moving average record: 0.05659
#
# * Models saved *
#
# New historical moving average record: 0.05670
#
# * Models saved *
#
# New historical moving average record: 0.05678
#
# * Models saved *
#
# New historical moving average record: 0.05688
#
# * Models saved *
#
# New historical moving average record: 0.05701
#
# * Models saved *
#
# New historical moving average record: 0.05723
#
# * Models saved *
#
# New historical moving average record: 0.05734
#
# * Models saved *
#
# New historical moving average record: 0.05747
#
# * Models saved *
#
# New historical moving average record: 0.05756
#
# * Models saved *
#
# New historical moving average record: 0.05779
#
# * Models saved *
#
# New historical moving average record: 0.05799
#
# * Models saved *
#
# New historical moving average record: 0.05810
#
# * Models saved *
#
# New historical moving average record: 0.05818
#
# * Models saved *
#
# New historical moving average record: 0.05827
#
# * Models saved *
#
# New historical moving average record: 0.05843
#
# * Models saved *
#
# New historical moving average record: 0.05846
#
# * Models saved *
#
# New historical moving average record: 0.05858
#
# * Models saved *
#
# New historical moving average record: 0.05870
#
# * Models saved *
#
# New historical moving average record: 0.05885
#
# Episode * 1600 * Worker #7 * Moving Avg Reward is ==> 0.05898 * Last Reward was ==> 0.08416 * Total episodes ending on loss: 108/1000
# * Models saved *
#
# New historical moving average record: 0.05898
#
# * Models saved *
#
# New historical moving average record: 0.05915
#
# * Models saved *
#
# New historical moving average record: 0.05930
#
# * Models saved *
#
# New historical moving average record: 0.05935
#
# * Models saved *
#
# New historical moving average record: 0.05948
#
# * Models saved *
#
# New historical moving average record: 0.05960
#
# * Models saved *
#
# New historical moving average record: 0.05981
#
# * Models saved *
#
# New historical moving average record: 0.05997
#
# * Models saved *
#
# New historical moving average record: 0.06006
#
# * Models saved *
#
# New historical moving average record: 0.06020
#
# * Models saved *
#
# New historical moving average record: 0.06026
#
# * Models saved *
#
# New historical moving average record: 0.06038
#
# * Models saved *
#
# New historical moving average record: 0.06046
#
# * Models saved *
#
# New historical moving average record: 0.06054
#
# * Models saved *
#
# New historical moving average record: 0.06062
#
# * Models saved *
#
# New historical moving average record: 0.06071
#
# * Models saved *
#
# New historical moving average record: 0.06076
# * Models saved *
#
# New historical moving average record: 0.06090
#
# * Models saved *
#
# New historical moving average record: 0.06103
#
# * Models saved *
#
# New historical moving average record: 0.06117
#
# * Models saved *
#
# New historical moving average record: 0.06132
#
# * Models saved *
#
# New historical moving average record: 0.06153
#
# * Models saved *
#
# New historical moving average record: 0.06160
#
# * Models saved *
#
# New historical moving average record: 0.06171
#
# * Models saved *
#
# New historical moving average record: 0.06179
#
# * Models saved *
#
# New historical moving average record: 0.06187
#
# * Models saved *
#
# New historical moving average record: 0.06202
#
# * Models saved *
#
# New historical moving average record: 0.06207
#
# * Models saved *
#
# New historical moving average record: 0.06214
#
# * Models saved *
#
# New historical moving average record: 0.06215
#
# * Models saved *
#
# New historical moving average record: 0.06225
#
# * Models saved *
#
# New historical moving average record: 0.06227
#
# * Models saved *
#
# New historical moving average record: 0.06231
#
# * Models saved *
#
# New historical moving average record: 0.06243
#
# * Models saved *
#
# New historical moving average record: 0.06248
#
# * Models saved *
#
# New historical moving average record: 0.06263
#
# * Models saved *
#
# New historical moving average record: 0.06275
#
# * Models saved *
#
# New historical moving average record: 0.06287
#
# * Models saved *
#
# New historical moving average record: 0.06305
#
# * Models saved *
#
# New historical moving average record: 0.06324
#
# * Models saved *
#
# New historical moving average record: 0.06331
#
# * Models saved *
#
# New historical moving average record: 0.06334
#
# * Models saved *
#
# New historical moving average record: 0.06347
#
# * Models saved *
#
# New historical moving average record: 0.06356
#
# * Models saved *
#
# New historical moving average record: 0.06370
#
# * Models saved *
#
# New historical moving average record: 0.06386
#
# * Models saved *
#
# New historical moving average record: 0.06395
#
# * Models saved *
#
# New historical moving average record: 0.06404
#
# * Models saved *
#
# New historical moving average record: 0.06409
#
# * Models saved *
#
# New historical moving average record: 0.06428
#
# * Models saved *
#
# New historical moving average record: 0.06443
#
# * Models saved *
#
# New historical moving average record: 0.06446
#
# * Models saved *
#
# New historical moving average record: 0.06452
#
# * Models saved *
#
# New historical moving average record: 0.06453
#
# * Models saved *
#
# New historical moving average record: 0.06460
#
# * Models saved *
#
# New historical moving average record: 0.06483
#
# * Models saved *
#
# New historical moving average record: 0.06496
#
# * Models saved *
#
# New historical moving average record: 0.06510
#
# * Models saved *
#
# New historical moving average record: 0.06526
#
# * Models saved *
#
# New historical moving average record: 0.06541
#
# * Models saved *
#
# New historical moving average record: 0.06549
#
# * Models saved *
#
# New historical moving average record: 0.06549
#
# * Models saved *
#
# New historical moving average record: 0.06569
#
# * Models saved *
#
# New historical moving average record: 0.06582
#
# * Models saved *
#
# New historical moving average record: 0.06597
#
# * Models saved *
#
# New historical moving average record: 0.06608
#
# * Models saved *
#
# New historical moving average record: 0.06623
#
# * Models saved *
#
# New historical moving average record: 0.06643
#
# * Models saved *
#
# New historical moving average record: 0.06655
#
# * Models saved *
#
# New historical moving average record: 0.06664
#
# * Models saved *
#
# New historical moving average record: 0.06666
#
# * Models saved *
#
# New historical moving average record: 0.06679
#
# * Models saved *
#
# New historical moving average record: 0.06686
#
# * Models saved *
#
# New historical moving average record: 0.06698
#
# * Models saved *
#
# New historical moving average record: 0.06701
#
# * Models saved *
#
# New historical moving average record: 0.06713
#
# * Models saved *
#
# New historical moving average record: 0.06717
#
# * Models saved *
#
# New historical moving average record: 0.06730
#
# * Models saved *
#
# New historical moving average record: 0.06740
#
# * Models saved *
#
# New historical moving average record: 0.06746
#
# * Models saved *
#
# New historical moving average record: 0.06761
#
# * Models saved *
#
# New historical moving average record: 0.06773
#
# * Models saved *
#
# New historical moving average record: 0.06773
#
# * Models saved *
#
# New historical moving average record: 0.06782
#
# * Models saved *
#
# New historical moving average record: 0.06786
#
# * Models saved *
#
# New historical moving average record: 0.06792
#
# * Models saved *
#
# New historical moving average record: 0.06810
#
# * Models saved *
#
# New historical moving average record: 0.06817
#
# * Models saved *
#
# New historical moving average record: 0.06824
#
# * Models saved *
#
# New historical moving average record: 0.06835
#
# * Models saved *
#
# New historical moving average record: 0.06851
#
# * Models saved *
#
# New historical moving average record: 0.06864
#
# * Models saved *
#
# New historical moving average record: 0.06881
#
# * Models saved *
#
# New historical moving average record: 0.06890
#
# * Models saved *
#
# New historical moving average record: 0.06899
#
# * Models saved *
#
# New historical moving average record: 0.06908
#
# * Models saved *
#
# New historical moving average record: 0.06919
#
# * Models saved *
#
# New historical moving average record: 0.06939
#
# Episode * 1700 * Worker #3 * Moving Avg Reward is ==> 0.06957 * Last Reward was ==> 0.17591 * Total episodes ending on loss: 76/1000
# * Models saved *
#
# New historical moving average record: 0.06957
#
# * Models saved *
#
# New historical moving average record: 0.06970
#
# * Models saved *
#
# New historical moving average record: 0.06987
#
# * Models saved *
#
# New historical moving average record: 0.07007
#
# * Models saved *
#
# New historical moving average record: 0.07014
#
# * Models saved *
#
# New historical moving average record: 0.07027
#
# * Models saved *
#
# New historical moving average record: 0.07037
#
# * Models saved *
#
# New historical moving average record: 0.07051
#
# * Models saved *
#
# New historical moving average record: 0.07053
#
# * Models saved *
#
# New historical moving average record: 0.07056
#
# * Models saved *
#
# New historical moving average record: 0.07071
#
# * Models saved *
#
# ...
#
# New historical moving average record: 0.08282
#
# * Models saved *
#
# New historical moving average record: 0.08296
#
# * Models saved *
#
# New historical moving average record: 0.08309
#
# * Models saved *
#
# New historical moving average record: 0.08341
#
# * Models saved *
#
# New historical moving average record: 0.08351
#
# * Models saved *
#
# New historical moving average record: 0.08364
#
# * Models saved *
#
# New historical moving average record: 0.08384
#
# * Models saved *
#
# New historical moving average record: 0.08393
#
# * Models saved *
#
# New historical moving average record: 0.08402
#
# * Models saved *
#
# New historical moving average record: 0.08420
#
# * Models saved *
#
# New historical moving average record: 0.08427
#
# * Models saved *
#
# New historical moving average record: 0.08437
#
# * Models saved *
#
# New historical moving average record: 0.08439
#
# * Models saved *
#
# New historical moving average record: 0.08461
#
# * Models saved *
#
# New historical moving average record: 0.08475
#
# * Models saved *
#
# New historical moving average record: 0.08483
#
# * Models saved *
#
# New historical moving average record: 0.08494
#
# * Models saved *
#
# New historical moving average record: 0.08497
#
# * Models saved *
#
# New historical moving average record: 0.08504
#
# * Models saved *
#
# New historical moving average record: 0.08523
#
# * Models saved *
#
# New historical moving average record: 0.08544
#
# * Models saved *
#
# New historical moving average record: 0.08561
#
# * Models saved *
#
# New historical moving average record: 0.08583
#
# * Models saved *
#
# New historical moving average record: 0.08595
#
# * Models saved *
#
# New historical moving average record: 0.08610
#
# * Models saved *
#
# New historical moving average record: 0.08617
#
# * Models saved *
#
# New historical moving average record: 0.08631
#
# * Models saved *
#
# New historical moving average record: 0.08639
#
# * Models saved *
#
# New historical moving average record: 0.08652
#
# * Models saved *
#
# New historical moving average record: 0.08658
#
# * Models saved *
#
# New historical moving average record: 0.08671
#
# * Models saved *
#
# New historical moving average record: 0.08680
#
# * Models saved *
#
# New historical moving average record: 0.08709
#
# * Models saved *
#
# New historical moving average record: 0.08724
#
# * Models saved *
#
# New historical moving average record: 0.08726
#
# * Models saved *
#
# New historical moving average record: 0.08734
#
# * Models saved *
#
# New historical moving average record: 0.08746
#
# * Models saved *
#
# New historical moving average record: 0.08771
#
# * Models saved *
#
# New historical moving average record: 0.08782
#
# * Models saved *
#
# New historical moving average record: 0.08783
#
# * Models saved *
#
# New historical moving average record: 0.08798
#
# * Models saved *
#
# New historical moving average record: 0.08811
#
# * Models saved *
#
# New historical moving average record: 0.08819
#
# * Models saved *
#
# New historical moving average record: 0.08840
#
# * Models saved *
#
# New historical moving average record: 0.08848
#
# * Models saved *
#
# New historical moving average record: 0.08866
#
# * Models saved *
#
# New historical moving average record: 0.08882
#
# * Models saved *
#
# New historical moving average record: 0.08904
#
# * Models saved *
#
# New historical moving average record: 0.08913
#
# * Models saved *
#
# New historical moving average record: 0.08929
#
# * Models saved *
#
# New historical moving average record: 0.08947
#
# * Models saved *
#
# New historical moving average record: 0.08960
#
# * Models saved *
#
# New historical moving average record: 0.08979
#
# * Models saved *
#
# New historical moving average record: 0.08991
# * Models saved *
#
# New historical moving average record: 0.08995
#
# * Models saved *
#
# New historical moving average record: 0.09014
#
# * Models saved *
#
# New historical moving average record: 0.09034
#
# * Models saved *
#
# New historical moving average record: 0.09038
#
# * Models saved *
#
# New historical moving average record: 0.09057
#
# * Models saved *
#
# New historical moving average record: 0.09073
#
# * Models saved *
#
# New historical moving average record: 0.09092
#
# * Models saved *
#
# New historical moving average record: 0.09104
#
# * Models saved *
#
# New historical moving average record: 0.09112
#
# * Models saved *
#
# New historical moving average record: 0.09122
#
# * Models saved *
#
# New historical moving average record: 0.09126
#
# * Models saved *
#
# New historical moving average record: 0.09145
#
# * Models saved *
#
# New historical moving average record: 0.09156
#
# * Models saved *
#
# New historical moving average record: 0.09164
#
# * Models saved *
#
# New historical moving average record: 0.09176
#
# * Models saved *
#
# New historical moving average record: 0.09187
#
# * Models saved *
#
# New historical moving average record: 0.09193
#
# * Models saved *
#
# New historical moving average record: 0.09211
#
# Episode * 1900 * Worker #3 * Moving Avg Reward is ==> 0.09222 * Last Reward was ==> 0.11495 * Total episodes ending on loss: 25/1000
# * Models saved *
#
# New historical moving average record: 0.09222
#
# * Models saved *
#
# New historical moving average record: 0.09242
#
# * Models saved *
#
# New historical moving average record: 0.09249
#
# * Models saved *
#
# New historical moving average record: 0.09275
#
# * Models saved *
#
# New historical moving average record: 0.09290
#
# * Models saved *
#
# New historical moving average record: 0.09306
#
# * Models saved *
#
# New historical moving average record: 0.09315
#
# * Models saved *
#
# New historical moving average record: 0.09325
#
# * Models saved *
#
# New historical moving average record: 0.09330
#
# * Models saved *
#
# New historical moving average record: 0.09337
#
# * Models saved *
#
# New historical moving average record: 0.09344
#
# * Models saved *
#
# New historical moving average record: 0.09354
#
# * Models saved *
#
# New historical moving average record: 0.09369
#
# * Models saved *
#
# New historical moving average record: 0.09383
#
# * Models saved *
#
# New historical moving average record: 0.09397
#
# * Models saved *
#
# New historical moving average record: 0.09410
#
# * Models saved *
#
# New historical moving average record: 0.09426
#
# * Models saved *
#
# New historical moving average record: 0.09442
#
# * Models saved *
#
# New historical moving average record: 0.09461
#
# * Models saved *
#
# New historical moving average record: 0.09468
#
# * Models saved *
#
# New historical moving average record: 0.09482
#
# * Models saved *
#
# New historical moving average record: 0.09494
#
# * Models saved *
#
# New historical moving average record: 0.09511
#
# * Models saved *
#
# New historical moving average record: 0.09514
#
# * Models saved *
#
# New historical moving average record: 0.09517
#
# * Models saved *
#
# New historical moving average record: 0.09521
#
# * Models saved *
#
# New historical moving average record: 0.09534
#
# * Models saved *
#
# New historical moving average record: 0.09552
#
# * Models saved *
#
# New historical moving average record: 0.09552
#
# * Models saved *
#
# New historical moving average record: 0.09568
#
# * Models saved *
#
# New historical moving average record: 0.09579
#
# * Models saved *
#
# New historical moving average record: 0.09595
#
# * Models saved *
#
# New historical moving average record: 0.09600
#
# * Models saved *
#
# New historical moving average record: 0.09607
#
# * Models saved *
#
# New historical moving average record: 0.09618
#
# * Models saved *
#
# New historical moving average record: 0.09625
#
# * Models saved *
#
# New historical moving average record: 0.09628
#
# * Models saved *
#
# New historical moving average record: 0.09640
#
# * Models saved *
#
# New historical moving average record: 0.09645
#
# * Models saved *
#
# New historical moving average record: 0.09645
#
# * Models saved *
#
# New historical moving average record: 0.09652
#
# * Models saved *
#
# New historical moving average record: 0.09666
#
# * Models saved *
#
# New historical moving average record: 0.09675
#
# * Models saved *
#
# New historical moving average record: 0.09681
#
# * Models saved *
#
# New historical moving average record: 0.09692
#
# * Models saved *
#
# New historical moving average record: 0.09698
#
# * Models saved *
#
# New historical moving average record: 0.09717
#
# * Models saved *
#
# New historical moving average record: 0.09724
#
# * Models saved *
#
# New historical moving average record: 0.09732
#
# * Models saved *
#
# New historical moving average record: 0.09749
#
# * Models saved *
#
# New historical moving average record: 0.09754
#
# * Models saved *
#
# New historical moving average record: 0.09768
#
# * Models saved *
#
# New historical moving average record: 0.09776
#
# * Models saved *
#
# New historical moving average record: 0.09791
#
# * Models saved *
#
# New historical moving average record: 0.09815
#
# * Models saved *
#
# New historical moving average record: 0.09831
#
# * Models saved *
#
# New historical moving average record: 0.09841
#
# * Models saved *
#
# New historical moving average record: 0.09853
#
# * Models saved *
#
# New historical moving average record: 0.09859
#
# * Models saved *
#
# New historical moving average record: 0.09882
#
# * Models saved *
#
# New historical moving average record: 0.09897
#
# * Models saved *
#
# New historical moving average record: 0.09913
#
# * Models saved *
#
# New historical moving average record: 0.09928
#
# * Models saved *
#
# New historical moving average record: 0.09946
#
# * Models saved *
#
# New historical moving average record: 0.09957
#
# * Models saved *
#
# New historical moving average record: 0.09978
#
# * Models saved *
#
# New historical moving average record: 0.09981
#
# * Models saved *
#
# New historical moving average record: 0.09997
#
# * Models saved *
#
# New historical moving average record: 0.10006
#
# Agent solved environment at the episode 1971
# * Models saved *
#
# New historical moving average record: 0.10012
#
# Agent solved environment at the episode 1972
# * Models saved *
#
# New historical moving average record: 0.10027
#
# Agent solved environment at the episode 1973
# * Models saved *
#
# New historical moving average record: 0.10037
#
# Agent solved environment at the episode 1974
# * Models saved *
#
# New historical moving average record: 0.10044
#
# Agent solved environment at the episode 1975
# * Models saved *
#
# New historical moving average record: 0.10057
#
# Agent solved environment at the episode 1976
# * Models saved *
#
# New historical moving average record: 0.10070
#
# Agent solved environment at the episode 1977
# * Models saved *
#
# New historical moving average record: 0.10078
#
# Agent solved environment at the episode 1978
# * Models saved *
#
# New historical moving average record: 0.10088
#
# Agent solved environment at the episode 1979
# * Models saved *
#
# New historical moving average record: 0.10098
#
# Agent solved environment at the episode 1980
# * Models saved *
#
# New historical moving average record: 0.10107
#
# Agent solved environment at the episode 1981
# * Models saved *
#
# New historical moving average record: 0.10123
#
# Agent solved environment at the episode 1982
# * Models saved *
#
# New historical moving average record: 0.10136
#
# Agent solved environment at the episode 1983
# * Models saved *
#
# New historical moving average record: 0.10149
#
# Agent solved environment at the episode 1984
# * Models saved *
#
# New historical moving average record: 0.10150
#
# Agent solved environment at the episode 1985
# * Models saved *
#
# New historical moving average record: 0.10170
#
# Agent solved environment at the episode 1986
# * Models saved *
#
# New historical moving average record: 0.10185
#
# Agent solved environment at the episode 1987
# * Models saved *
#
# New historical moving average record: 0.10210
#
# Agent solved environment at the episode 1988
# * Models saved *
#
# New historical moving average record: 0.10222
#
# Agent solved environment at the episode 1989
# * Models saved *
#
# New historical moving average record: 0.10228
#
# Agent solved environment at the episode 1990
# * Models saved *
#
# New historical moving average record: 0.10243
#
# Agent solved environment at the episode 1991
# * Models saved *
#
# New historical moving average record: 0.10269
#
# Agent solved environment at the episode 1992
# * Models saved *
#
# New historical moving average record: 0.10282
#
# Agent solved environment at the episode 1993
# * Models saved *
#
# New historical moving average record: 0.10288
#
# Agent solved environment at the episode 1994
# * Models saved *
#
# New historical moving average record: 0.10296
#
# Agent solved environment at the episode 1995
# * Models saved *
#
# New historical moving average record: 0.10309
#
# Agent solved environment at the episode 1996
# * Models saved *
#
# New historical moving average record: 0.10333
#
# Agent solved environment at the episode 1997
# * Models saved *
#
# New historical moving average record: 0.10340
#
# Agent solved environment at the episode 1998
# * Models saved *
#
# New historical moving average record: 0.10352
#
# Agent solved environment at the episode 1999
# Episode * 2000 * Worker #7 * Moving Avg Reward is ==> 0.10365 * Last Reward was ==> 0.14353 * Total episodes ending on loss: 12/1000
# * Models saved *
#
# New historical moving average record: 0.10365
#
# Agent solved environment at the episode 2000
# * Models saved *
#
# New historical moving average record: 0.10378
#
# Agent solved environment at the episode 2001
# * Models saved *
#
# New historical moving average record: 0.10390
#
# Agent solved environment at the episode 2002
# * Models saved *
#
# New historical moving average record: 0.10400
#
# Agent solved environment at the episode 2003
# * Models saved *
#
# New historical moving average record: 0.10422
#
# Agent solved environment at the episode 2004
# * Models saved *
#
# New historical moving average record: 0.10426
#
# Agent solved environment at the episode 2005
# * Models saved *
#
# New historical moving average record: 0.10443
#
# Agent solved environment at the episode 2006
# * Models saved *
#
# New historical moving average record: 0.10457
#
# Agent solved environment at the episode 2007
# * Models saved *
#
# New historical moving average record: 0.10471
#
# Agent solved environment at the episode 2008
# * Models saved *
#
# New historical moving average record: 0.10483
#
# Agent solved environment at the episode 2009
# * Models saved *
#
# New historical moving average record: 0.10495
#
# Agent solved environment at the episode 2010
# * Models saved *
#
# New historical moving average record: 0.10512
#
# Agent solved environment at the episode 2011
# * Models saved *
#
# New historical moving average record: 0.10518
#
# Agent solved environment at the episode 2012
# * Models saved *
#
# New historical moving average record: 0.10533
#
# Agent solved environment at the episode 2013
# * Models saved *
#
# New historical moving average record: 0.10540
#
# Agent solved environment at the episode 2014
# * Models saved *
#
# New historical moving average record: 0.10547
#
# Agent solved environment at the episode 2015
# * Models saved *
#
# New historical moving average record: 0.10559
#
# Agent solved environment at the episode 2016
# * Models saved *
#
# New historical moving average record: 0.10564
#
# Agent solved environment at the episode 2017
# * Models saved *
#
# New historical moving average record: 0.10573
#
# Agent solved environment at the episode 2018
# * Models saved *
#
# New historical moving average record: 0.10588
#
# Agent solved environment at the episode 2019
# * Models saved *
#
# New historical moving average record: 0.10602
#
# Agent solved environment at the episode 2020
# * Models saved *
#
# New historical moving average record: 0.10615
#
# Agent solved environment at the episode 2021
# * Models saved *
#
# New historical moving average record: 0.10624
#
# Agent solved environment at the episode 2022
# * Models saved *
#
# New historical moving average record: 0.10635
#
# Agent solved environment at the episode 2023
# * Models saved *
#
# New historical moving average record: 0.10656
#
# Agent solved environment at the episode 2024
# Agent solved environment at the episode 2024
# Worker <Worker name='Worker-1' pid=25508 parent=24896 started> has shut down
# Worker <Worker name='Worker-2' pid=25588 parent=24896 started> has shut down
# Worker <Worker name='Worker-3' pid=23804 parent=24896 started> has shut down
# Worker <Worker name='Worker-4' pid=23280 parent=24896 started> has shut down
# Worker <Worker name='Worker-5' pid=15136 parent=24896 started> has shut down
# Worker <Worker name='Worker-6' pid=7404 parent=24896 started> has shut down
# Worker <Worker name='Worker-7' pid=10132 parent=24896 started> has shut down
# Worker <Worker name='Worker-8' pid=22440 parent=24896 started> has shut down
# * Learning cycle took 00:09:06 to finnish.

# %%
xxxxxxxxxxxxx
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 xxxxxxxxxxxxx
#
# NameError: name 'xxxxxxxxxxxxx' is not defined

# %%
agent.training_duration
# Out:
# '00:09:06'

# %% [markdown]
# ### Test the results
# * Runs a set of episodes with unseen data
# * Stores the results in a csv file for later consulting

# %%
success = 0
n_tests = 10000

scores = []
targets = []
portfolio_target_ratios = []
initial_investments = []

for i in trange(n_tests):
    state = agent.env.reset(visualize=False,mode="test")
    step = 0
    score = 0
    reward = 0
    done = False
    
    targets.append((agent.env.episode_target-agent.env.initial_investment)/agent.env.initial_investment)
    initial_investments.append(agent.env.initial_investment)

    while not done:
        state = agent.reshape_state(state)
        agent.env.render()
        #state = np.expand_dims(state, axis=0)
        action, action_onehot, prediction = agent.choose_action(state)
        # Retrieve new state, reward, and whether the state is terminal
        next_state, reward, done, info = agent.env.step(action)
        #print(action, reward, agent.env.portfolio_value)
        # Memorize (state, action, reward) for training
        #self.buffer.remember(np.expand_dims(state, axis=0), action_onehot, reward)
        # Update current state
        if done :
            if agent.env.portfolio_value > agent.env.initial_investment:
                success +=1

        step+=1
        state = next_state
        score += reward
    
    # Track scores and ratios
    scores.append(score)
    portfolio_target_ratios.append(info["portfolio_value"]/info["episode_target"] -1)
    
    
test_results_dataframe = pd.DataFrame([[
    n_tests,
    str(round(np.mean(scores)*100,3))+'%',
    str(round(np.mean(targets)*100,3))+'%',
    str(round(np.mean(portfolio_target_ratios)*100,3))+'%',
    str(round(min(scores)*100,3))+'%',
    str(round(max(scores)*100,3))+'%',
    str(round((success/n_tests)*100,3)) +'%'
]],
    columns=[
        '# Blind tests',
        '% Average portfolio return', 
        '% Desired portfolio return', 
        'Portfolio/Target rate',
        '% Historical minimum return',
        '% Historical maximum return', 
        '% Episodes concluded with positive outcome'
    ]
)



test_results_dataframe.T

# %%
agent.results_writer.store_test_results(agent,test_results_dataframe)

# %% [markdown]
# ### Visual test
# * Runs a set of episodes with unseen data
# * See the evolution in real time

# %%
success = 0
n_tests = 2

scores = []
targets = []


for i in trange(n_tests):
    state = agent.env.reset(visualize=True,mode="test")
    step = 0
    score = 0
    reward = 0
    done = False
    targets.append((agent.env.episode_target-agent.env.initial_investment)/agent.env.initial_investment)
    initial_portfolio = agent.env.portfolio_value

    while not done:
        agent.env.render()
        
        # Shape the state
        state = agent.reshape_state(state)
        # Select a action
        action, action_onehot, prediction = agent.choose_action(state)
        
        # Retrieve new state, reward, and whether the state is terminal
        next_state, reward, done, _ = agent.env.step(action)
        
        # End of episode, track scores here
        if done :
            if agent.env.portfolio_value > agent.env.initial_investment:
                success +=1

        step+=1
        state = next_state
        score += reward
    
    scores.append(score)

agent.env.close()

# %% [markdown]
# ### Transactions profit
# * Track how much the agent gained by doing purchases and sales
# * Doesn't track the portfolio value
# * Already has the fees discounted

# %%
success = 0
n_tests = 10000

test_results_data = []
test_results_columns = [
    'dataset id',
    'episode start date', 
    'episode end date',
    'episode working days',
    'total transactions',
    'total transaction profit',
    "dataframe hash",
    "agent hash"
]

print('NOTE: This test only tracks the transactions profit. ')

for i in trange(n_tests):
    trading_history = []
    state = agent.env.reset(visualize=False,mode="test")
    step = 0
    score = 0
    reward = 0
    done = False
    #targets.append((agent.env.episode_target-agent.env.initial_investment)/agent.env.initial_investment)
    #initial_portfolio = agent.env.portfolio_value
    
    j = 0
    num_stocks = 0
    while not done:
        agent.env.render()
        
        # Select desired action
        state = agent.reshape_state(state)
        action, action_onehot, prediction = agent.choose_action(state)
        current_price = agent.env.df.iloc[agent.env.current_step -1]['close']
        
        if action == agent.env.ACTIONS.BUY:
            discounted_price = current_price * (1+agent.env.fees.BUY) 
            if agent.env.stock_held < agent.env.maximum_stocks_held and agent.env.cash_in_hand >= discounted_price:
                num_stocks +=1
                trading_history.append(['buy', discounted_price])
        elif action == agent.env.ACTIONS.SELL:
            if agent.env.stock_held > 0:
                discounted_price = current_price * (1-agent.env.fees.SELL) 
                trading_history.append(['sell', discounted_price])
                num_stocks =0
                
        # Retrieve new state, reward, and whether the state is terminal
        next_state, reward, done, _ = agent.env.step(action)

        # Update current state
        if done :
            if agent.env.portfolio_value > agent.env.initial_investment:
                success +=1
                
            profits = []
            purchases = []
            for e in trading_history:
                if e[0] == 'buy':
                    purchases.append(e[1])
                else:
                    profits.append((e[1]* len(purchases) - sum(purchases)) / sum(purchases))
                    purchases.clear() 
                    
            test_results_data.append([
                agent.env.dataset_idx,
                agent.env.df.iloc[agent.env.lookback].name,
                agent.env.df.iloc[-1].name,
                agent.env.window_size,
                len(profits),
                sum(profits)*100,
                agent.env.df_name,
                agent.hash
            ])


        step+=1
        state = next_state
        score += reward
    

agent.env.close()


pd.DataFrame(test_results_data,columns=test_results_columns)

# %%
transaction_results_df = pd.DataFrame(test_results_data,columns=test_results_columns)
transaction_results_df.sort_values(by="dataset id")

# %%
failed_episodes_df = transaction_results_df[transaction_results_df['total transaction profit'] <= 0]
failed_episodes_idx = failed_episodes_df['dataset id'].unique()
failed_episodes_idx.sort()

# %%
len(transaction_results_df[transaction_results_df['total transaction profit'] <= 0]['dataset id'].unique()),len(transaction_results_df[transaction_results_df['total transaction profit'] > 0]['dataset id'].unique())

# %%
import matplotlib.pyplot as plt 

for idx in failed_episodes_idx:
    plt.figure(figsize=(16,4))
    plt.plot(agent.env.df['close'])
    plt.title('#'+str(idx)+' - ' + str(len(failed_episodes_df[failed_episodes_df['dataset id'] == idx])) +'/' + str(len(transaction_results_df[transaction_results_df['dataset id'] == idx])))
