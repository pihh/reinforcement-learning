# %%
import shutup
shutup.please()

import gym
import src.environments.continuous.stock_trading  

import numpy as np
import pandas as pd

# %%
env = gym.make('StockTradingEnvironment-v0', use_technical_indicators= [
    "macd",
    "boll_ub",
    "boll_lb",
    "rsi_30",
    "cci_30",
    "dx_30",
    "close_30_sma",
    "close_60_sma",
])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 env = gym.make('StockTradingEnvironment-v0', use_technical_indicators= [
#       2     "macd",
#       3     "boll_ub",
#       4     "boll_lb",
#       5     "rsi_30",
#       6     "cci_30",
#       7     "dx_30",
#       8     "close_30_sma",
#       9     "close_60_sma",
#      10 ])
#
# File ~\anaconda3\envs\ai_4\lib\site-packages\gym\envs\registration.py:676, in make(id, **kwargs)
#     675 def make(id: str, **kwargs) -> "Env":
# --> 676     return registry.make(id, **kwargs)
#
# File ~\anaconda3\envs\ai_4\lib\site-packages\gym\envs\registration.py:520, in EnvRegistry.make(self, path, **kwargs)
#     518 spec = self.spec(path)
#     519 # Construct the environment
# --> 520 return spec.make(**kwargs)
#
# File ~\anaconda3\envs\ai_4\lib\site-packages\gym\envs\registration.py:139, in EnvSpec.make(self, **kwargs)
#     137     env = self.entry_point(**_kwargs)
#     138 else:
# --> 139     cls = load(self.entry_point)
#     140     env = cls(**_kwargs)
#     142 # Make the environment aware of which spec it came from.
#
# File ~\anaconda3\envs\ai_4\lib\site-packages\gym\envs\registration.py:55, in load(name)
#      53 def load(name: str) -> Type:
#      54     mod_name, attr_name = name.split(":")
# ---> 55     mod = importlib.import_module(mod_name)
#      56     fn = getattr(mod, attr_name)
#      57     return fn
#
# File ~\anaconda3\envs\ai_4\lib\importlib\__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1006, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:688, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:883, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~\Development\GIT\tmp\reinforcement-learning\src\environments\continuous\stock_trading\v0.py:18, in <module>
#      16 from src.constants import FEES
#      17 from src.constants import ACTIONS
# ---> 18 from src.utils.data import Downloader
#      19 from src.utils.data import FeatureEngeneer
#      20 from src.utils.trading_graph import TradingGraph
#
# File ~\Development\GIT\tmp\reinforcement-learning\src\utils\data.py:5, in <module>
#       3 import numpy as np
#       4 import pandas as pd
# ----> 5 import yfinance as yf
#       7 from datetime import datetime, timedelta
#       8 from stockstats import StockDataFrame as Sdf
#
# File ~\anaconda3\envs\ai_4\lib\site-packages\yfinance\__init__.py:23, in <module>
#       1 #!/usr/bin/env python
#       2 # -*- coding: utf-8 -*-
#       3 #
#    (...)
#      19 # limitations under the License.
#      20 #
#      22 from . import version
# ---> 23 from .ticker import Ticker
#      24 from .tickers import Tickers
#      25 from .multi import download
#
# File ~\anaconda3\envs\ai_4\lib\site-packages\yfinance\ticker.py:26, in <module>
#      24 # import time as _time
#      25 import datetime as _datetime
# ---> 26 import requests as _requests
#      27 import pandas as _pd
#      28 # import numpy as _np
#      29
#      30 # import json as _json
#      31 # import re as _re
#
# File ~\anaconda3\envs\ai_4\lib\site-packages\requests\__init__.py:134, in <module>
#     131 from .__version__ import __copyright__, __cake__
#     133 from . import utils
# --> 134 from . import packages
#     135 from .models import Request, Response, PreparedRequest
#     136 from .api import request, get, head, post, patch, put, delete, options
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1002, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:945, in _find_spec(name, path, target)
#
# File <frozen importlib._bootstrap_external>:1439, in find_spec(cls, fullname, path, target)
#
# File <frozen importlib._bootstrap_external>:1411, in _get_spec(cls, fullname, path, target)
#
# File <frozen importlib._bootstrap_external>:1544, in find_spec(self, fullname, target)
#
# File <frozen importlib._bootstrap_external>:147, in _path_stat(path)
#
# KeyboardInterrupt:

# %%
pd.read_csv('src/environments/continuous/stock_trading/datasets/67b906a1ca1d5e7e03dd20f0c89fd03c/targets.csv').targets.iloc[0]

# %%
env.train_dataframe_id_range,env.test_dataframe_id_range

# %%
env.load_dataset_by_index(0)
env.df

# %%
env.success_threshold

# %%
import pandas as pd
episode_targets = []
for i in range(env.n_dataframes):
    env.load_dataset_by_index(i)
    raw_slice = env.df 
    episode_targets.append([
                    env.get_episode_target(raw_slice),
                    raw_slice.iloc[env.lookback-1].open,
                    raw_slice.iloc[env.lookback-1].low,
                    raw_slice.iloc[env.lookback-1].high,
                    raw_slice.iloc[env.lookback-1].close,
                    raw_slice.iloc[env.lookback-1].volume,
                ])




pd.DataFrame(episode_targets,columns=['targets','open','low','high','close','volume']).to_csv(env.df_path+'/targets.csv', index=False)

# %%
episode_columns = ['targets','close','open','high','low','volume']

#pd.DataFrame([[1,2],[1,2]],columns=['a','b'])
#np.array(episode_targets).shape ,=['targets','close','open','high','low','volume']).
pd.DataFrame(episode_targets,columns=episode_columns)

# %%
state = env.reset()

# %%
state

# %%
next_state = env.step([1])
next_state

# %%
next_state[0][0] == state[1]

# %%
# env.reset()
# for i in range(100):
#     next_state, reward, done, _ = env.step(0)
#     print(i, reward,done)#,next_state[-1])
#     if done:
#         break

# %%
len(env.df),env.window_size, env.lookback, env.window_size+ env.lookback

# %%
# prices = [5,2,1,7,0,6,3]

# """
# # mins = min de inicio até i inclusive 
#     0 - 5
#     1 - 2
#     2 - 2
#     3 - 2
# # maxs = max de i até fim inclusive
#     0 - 6
#     1 - 6
#     2 - 6
#     3 - 3
# """

# mins = [] #[5,2,2,2]
# maxs = [] #[6,6,6,3]

# ### MINS
# # i = 0 -> prices [0 -> 1] [0:1]
# # mins.append(min(prices[0:1]))
# ### MAXS
# # i = 0 -> prices[0:]
# # i = 1 -> prices[1:]
# # prices[3:]

# for i in range(len(prices)):
#     mins.append(min(prices[0:i+1]))
#     maxs.append(max(prices[i:]))
    
# #mins,maxs
# global_max_single_trade_profit = 0
# for i in range(len(prices)):
#     _min = mins[i]
#     _max = maxs[i]
    
#     print('At {} could have bought at {} and sold at {} so it had {} profit'.format(
#         i,
#         _min,
#         _max,
#         _max-_min
#     ))
#     local_max_single_trade_profit = _max-_min
#     if local_max_single_trade_profit > global_max_single_trade_profit:
#         global_max_single_trade_profit = local_max_single_trade_profit

# print()
# print('Best case scenario would have a profit of {}'.format(global_max_single_trade_profit))

# %%
# for i in range(len(prices)):
#     mins.append(min(prices[0:i+1]))
#     maxs.append(max(prices[i:]))
    
# #mins,maxs
# global_max_single_trade_profit = 0
# for i in range(len(prices)):
#     _min = mins[i]
#     _max = maxs[i]
    
#     print('At {} could have bought at {} and sold at {} so it had {} profit'.format(
#         i,
#         _min,
#         _max,
#         _max-_min
#     ))
#     local_max_single_trade_profit = _max-_min
#     if local_max_single_trade_profit > global_max_single_trade_profit:
#         global_max_single_trade_profit = local_max_single_trade_profit

# print()
# print('Best case scenario would have a profit of {}'.format(global_max_single_trade_profit))

# %%
# prices = env.df.close.values

# mins = [] 
# maxs = [] 

# for i in range(len(prices)):
#     mins.append(min(prices[0:i+1]))
#     maxs.append(max(prices[i:]))
# #     
# #mins,maxs
# global_max_single_trade_profit = 0
# for i in range(len(prices)):
#     _min = mins[i]
#     _max = maxs[i]
    
#     print('At {} could have bought at {} and sold at {} so it had {} profit'.format(
#         i,
#         _min,
#         _max,
#         _max-_min
#     ))
#     local_max_single_trade_profit = _max-_min
#     if local_max_single_trade_profit > global_max_single_trade_profit:
#         global_max_single_trade_profit = local_max_single_trade_profit

# print()
# print('Best case scenario would have a profit of {}'.format(global_max_single_trade_profit))

# %%
#prices * (0.5)
#env.fees['BUY']

# %%
# env.n_dataframes

# %%
# targets = []
# for i in range(env.n_dataframes):
#     env.load_dataset_by_index(i)
#     target = env.calculate_episode_target(env.df)
#     targets.append(target)
    
# targets

# %%
# import pandas as pd
# pd.DataFrame(targets,columns=['targets']).to_csv(env.df_path+'/targets.csv', index=False)

# %%
#pd.read_csv(env.df_path+'/targets.csv')

# %%
from src.agents.actor_critic.a2c import A2CAgent

# %%
def environment():
    env = gym.make('StockTradingEnvironment-v0',
                   use_technical_indicators= [
        "macd",
        "boll_ub",
        "boll_lb",
        "rsi_30",
        "cci_30",
        "dx_30",
        "close_30_sma",
        "close_60_sma",
    ])
    
    env.success_threshold =0.05 # 5%
    return env

# %%
agent=A2CAgent(environment, epochs=1, actor_learning_rate=0.000025,critic_learning_rate=0.000025)
#agent.load()
environment().success_threshold

# %%
agent.learning_log.episodes

# %%
agent.env.mode = "train"
agent.learning_log.episodes = 0
agent.learn(
    timesteps=-1, 
    log_every=100,
    success_threshold_lookback=1000,
    success_strict=True,
    
)

# %%
agent.env.mode = "test"
scores = []
success = 0

for i in range(100):
    state = agent.env.reset()
    score = 0
    reward = 0
    done = False
    initial_portfolio = agent.env.portfolio_value
    step = 0
    while not done:
                
        #state = np.expand_dims(state, axis=0)
        action, action_onehot, prediction = agent.act(state)
        # Retrieve new state, reward, and whether the state is terminal
        next_state, reward, done, _ = agent.env.step(action)
        #print(action, reward, agent.env.portfolio_value)
        # Memorize (state, action, reward) for training
        #self.buffer.remember(np.expand_dims(state, axis=0), action_onehot, reward)
        # Update current state
        if done :
            if step < 65:
                success +=1
        step+=1
        state = next_state
        score += reward
    
    #print(score,initial_portfolio, agent.env.portfolio_value)
    scores.append(score)
    
print(np.mean(scores))
print(min(scores))
print(max(scores))
print(success)
