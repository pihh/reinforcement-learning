# %%
import shutup
shutup.please()

import gym
import src.environments.continuous.stock_trading  

import numpy as np
import pandas as pd 

from tqdm.notebook import trange, tqdm

# %% [markdown]
# ### Train the agent
# * Run it until he has a running average above the success_threshold
# * Use a large number of episodes for the running average ( 1000+ ) so if even it falls into a privileged sample, it wont be prone to error

# %%
def environment():
    env = gym.make('StockTradingEnvironment-v0',
        use_technical_indicators= [
        "macd",
        "boll_ub",
        "boll_lb",
        "rsi_30",
        "cci_30",
        "dx_30",
        "close_30_sma",
        "close_60_sma",
    ])
    
    env.success_threshold =0.25 # 25%
    return env

# from src.environments.continuous.trading import environment

# %%
from src.agents.actor_critic.a2c import A2CAgent

# %%
agent=A2CAgent(environment, epochs=1, actor_learning_rate=0.000025,critic_learning_rate=0.000025,policy="CNN")
agent.load()
environment().success_threshold
# Out:
# [Errno 2] Unable to open file (unable to open file: name = 'storage/environments/AaplStockTradingEnvironment-v0/23773bb461926c23ff13bee130dda8e0/models/a2c-actor.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
#
# [Errno 2] Unable to open file (unable to open file: name = 'storage/environments/AaplStockTradingEnvironment-v0/23773bb461926c23ff13bee130dda8e0/models/a2c-critic.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# 0.25

# %%
# agent.hash

# %%
agent.env.mode = "train"
agent.learning_log.episodes = 0
agent.learn(
    timesteps=-1, 
    log_every=100,
    success_threshold_lookback=1000,
    success_strict=True,
)
# Out:
# Episode * 100 * Worker * False * Moving Avg Reward is ==> -0.00058 * Last Reward was ==> 0.04225
# Episode * 200 * Worker * False * Moving Avg Reward is ==> 0.00424 * Last Reward was ==> -0.04849
# Episode * 300 * Worker * False * Moving Avg Reward is ==> 0.00534 * Last Reward was ==> 0.01121
# Episode * 400 * Worker * False * Moving Avg Reward is ==> 0.00489 * Last Reward was ==> -0.00095
# Episode * 500 * Worker * False * Moving Avg Reward is ==> 0.00733 * Last Reward was ==> 0.03715
# Episode * 600 * Worker * False * Moving Avg Reward is ==> 0.00904 * Last Reward was ==> 0.05322
# Episode * 700 * Worker * False * Moving Avg Reward is ==> 0.01181 * Last Reward was ==> 0.02338
# Episode * 800 * Worker * False * Moving Avg Reward is ==> 0.01311 * Last Reward was ==> -0.00243
# Episode * 900 * Worker * False * Moving Avg Reward is ==> 0.01464 * Last Reward was ==> 0.15506
# Episode * 1000 * Worker * False * Moving Avg Reward is ==> 0.01598 * Last Reward was ==> -0.02348
# * Models saved *
#
# New historical moving average record: 0.01598
#
# * Models saved *
#
# New historical moving average record: 0.01603
#
# * Models saved *
#
# New historical moving average record: 0.01606
#
# * Models saved *
#
# New historical moving average record: 0.01617
#
# * Models saved *
#
# New historical moving average record: 0.01645
#
# * Models saved *
#
# New historical moving average record: 0.01650
#
# * Models saved *
#
# New historical moving average record: 0.01653
#
# * Models saved *
#
# New historical moving average record: 0.01654
#
# * Models saved *
#
# New historical moving average record: 0.01661
#
# * Models saved *
#
# New historical moving average record: 0.01663
#
# * Models saved *
#
# New historical moving average record: 0.01672
#
# * Models saved *
#
# New historical moving average record: 0.01685
#
# * Models saved *
#
# New historical moving average record: 0.01690
#
# * Models saved *
#
# New historical moving average record: 0.01691
#
# * Models saved *
#
# New historical moving average record: 0.01695
#
# * Models saved *
#
# New historical moving average record: 0.01705
#
# * Models saved *
#
# New historical moving average record: 0.01710
#
# * Models saved *
#
# New historical moving average record: 0.01717
#
# * Models saved *
#
# New historical moving average record: 0.01723
#
# * Models saved *
#
# New historical moving average record: 0.01724
#
# * Models saved *
#
# New historical moving average record: 0.01739
#
# * Models saved *
#
# New historical moving average record: 0.01740
#
# * Models saved *
#
# New historical moving average record: 0.01748
#
# * Models saved *
#
# New historical moving average record: 0.01760
#
# * Models saved *
#
# New historical moving average record: 0.01771
#
# * Models saved *
#
# New historical moving average record: 0.01775
#
# * Models saved *
#
# New historical moving average record: 0.01778
#
# * Models saved *
#
# New historical moving average record: 0.01779
#
# * Models saved *
#
# New historical moving average record: 0.01783
#
# * Models saved *
#
# New historical moving average record: 0.01807
#
# * Models saved *
#
# New historical moving average record: 0.01821
#
# * Models saved *
#
# New historical moving average record: 0.01835
#
# * Models saved *
#
# New historical moving average record: 0.01838
#
# * Models saved *
#
# New historical moving average record: 0.01854
#
# * Models saved *
#
# New historical moving average record: 0.01864
#
# * Models saved *
#
# New historical moving average record: 0.01874
#
# * Models saved *
#
# New historical moving average record: 0.01885
#
# * Models saved *
#
# New historical moving average record: 0.01902
#
# * Models saved *
#
# New historical moving average record: 0.01909
#
# * Models saved *
#
# New historical moving average record: 0.01926
#
# * Models saved *
#
# New historical moving average record: 0.01936
#
# * Models saved *
#
# New historical moving average record: 0.01942
#
# * Models saved *
#
# New historical moving average record: 0.01947
#
# * Models saved *
#
# New historical moving average record: 0.01963
#
# * Models saved *
#
# New historical moving average record: 0.01968
#
# * Models saved *
#
# New historical moving average record: 0.01971
#
# * Models saved *
#
# New historical moving average record: 0.01979
#
# * Models saved *
#
# New historical moving average record: 0.01998
#
# * Models saved *
#
# New historical moving average record: 0.02012
#
# * Models saved *
#
# New historical moving average record: 0.02029
#
# * Models saved *
#
# New historical moving average record: 0.02043
#
# * Models saved *
#
# New historical moving average record: 0.02047
#
# * Models saved *
#
# New historical moving average record: 0.02048
#
# * Models saved *
#
# New historical moving average record: 0.02054
#
# * Models saved *
#
# New historical moving average record: 0.02076
#
# * Models saved *
#
# New historical moving average record: 0.02089
#
# * Models saved *
#
# New historical moving average record: 0.02095
#
# * Models saved *
#
# New historical moving average record: 0.02096
#
# * Models saved *
#
# New historical moving average record: 0.02098
#
# * Models saved *
#
# New historical moving average record: 0.02105
#
# * Models saved *
#
# New historical moving average record: 0.02109
#
# * Models saved *
#
# New historical moving average record: 0.02109
#
# Episode * 1100 * Worker * False * Moving Avg Reward is ==> 0.02116 * Last Reward was ==> 0.11060
# * Models saved *
#
# New historical moving average record: 0.02116
#
# * Models saved *
#
# New historical moving average record: 0.02121
#
# * Models saved *
#
# New historical moving average record: 0.02135
#
# * Models saved *
#
# New historical moving average record: 0.02139
#
# * Models saved *
#
# New historical moving average record: 0.02145
#
# * Models saved *
#
# New historical moving average record: 0.02152
#
# * Models saved *
#
# New historical moving average record: 0.02157
#
# * Models saved *
#
# New historical moving average record: 0.02162
#
# * Models saved *
#
# New historical moving average record: 0.02163
#
# * Models saved *
#
# New historical moving average record: 0.02170
#
# * Models saved *
#
# New historical moving average record: 0.02175
#
# * Models saved *
#
# New historical moving average record: 0.02181
#
# * Models saved *
#
# New historical moving average record: 0.02197
#
# * Models saved *
#
# New historical moving average record: 0.02198
#
# * Models saved *
#
# New historical moving average record: 0.02203
#
# * Models saved *
#
# New historical moving average record: 0.02211
#
# * Models saved *
#
# New historical moving average record: 0.02215
#
# * Models saved *
#
# New historical moving average record: 0.02222
#
# * Models saved *
#
# New historical moving average record: 0.02232
#
# * Models saved *
#
# New historical moving average record: 0.02243
#
# * Models saved *
#
# New historical moving average record: 0.02246
#
# * Models saved *
#
# New historical moving average record: 0.02256
#
# * Models saved *
#
# New historical moving average record: 0.02258
#
# * Models saved *
#
# New historical moving average record: 0.02267
#
# * Models saved *
#
# New historical moving average record: 0.02272
#
# * Models saved *
#
# New historical moving average record: 0.02283
#
# * Models saved *
#
# New historical moving average record: 0.02284
#
# * Models saved *
#
# New historical moving average record: 0.02299
#
# * Models saved *
#
# New historical moving average record: 0.02305
#
# * Models saved *
#
# New historical moving average record: 0.02311
#
# * Models saved *
#
# New historical moving average record: 0.02328
#
# * Models saved *
#
# New historical moving average record: 0.02336
#
# * Models saved *
#
# New historical moving average record: 0.02340
#
# * Models saved *
#
# New historical moving average record: 0.02341
#
# * Models saved *
#
# New historical moving average record: 0.02344
#
# * Models saved *
#
# New historical moving average record: 0.02357
#
# * Models saved *
#
# New historical moving average record: 0.02358
#
# * Models saved *
#
# New historical moving average record: 0.02371
#
# Episode * 1200 * Worker * False * Moving Avg Reward is ==> 0.02383 * Last Reward was ==> 0.06809
# * Models saved *
#
# New historical moving average record: 0.02383
#
# * Models saved *
#
# New historical moving average record: 0.02395
#
# * Models saved *
#
# New historical moving average record: 0.02397
#
# * Models saved *
#
# New historical moving average record: 0.02398
#
# * Models saved *
#
# New historical moving average record: 0.02412
#
# * Models saved *
#
# New historical moving average record: 0.02418
#
# * Models saved *
#
# New historical moving average record: 0.02423
#
# * Models saved *
#
# New historical moving average record: 0.02428
#
# * Models saved *
#
# New historical moving average record: 0.02434
# * Models saved *
#
# New historical moving average record: 0.02446
#
# * Models saved *
#
# New historical moving average record: 0.02447
#
# * Models saved *
#
# New historical moving average record: 0.02453
#
# * Models saved *
#
# New historical moving average record: 0.02454
#
# * Models saved *
#
# New historical moving average record: 0.02471
#
# * Models saved *
#
# New historical moving average record: 0.02472
#
# * Models saved *
#
# New historical moving average record: 0.02475
#
# * Models saved *
#
# New historical moving average record: 0.02476
#
# * Models saved *
#
# New historical moving average record: 0.02478
#
# * Models saved *
#
# New historical moving average record: 0.02495
#
# * Models saved *
#
# New historical moving average record: 0.02501
#
# * Models saved *
#
# New historical moving average record: 0.02502
#
# * Models saved *
#
# New historical moving average record: 0.02506
#
# * Models saved *
#
# New historical moving average record: 0.02520
#
# * Models saved *
#
# New historical moving average record: 0.02527
#
# * Models saved *
#
# New historical moving average record: 0.02531
#
# * Models saved *
#
# New historical moving average record: 0.02531
#
# * Models saved *
#
# New historical moving average record: 0.02546
#
# * Models saved *
#
# New historical moving average record: 0.02552
#
# * Models saved *
#
# New historical moving average record: 0.02560
#
# * Models saved *
#
# New historical moving average record: 0.02562
#
# * Models saved *
#
# New historical moving average record: 0.02566
#
# * Models saved *
#
# New historical moving average record: 0.02569
#
# * Models saved *
#
# New historical moving average record: 0.02584
#
# * Models saved *
#
# New historical moving average record: 0.02602
#
# * Models saved *
#
# New historical moving average record: 0.02620
#
# * Models saved *
#
# New historical moving average record: 0.02620
#
# * Models saved *
#
# New historical moving average record: 0.02628
#
# * Models saved *
#
# New historical moving average record: 0.02632
#
# * Models saved *
#
# New historical moving average record: 0.02645
#
# * Models saved *
#
# New historical moving average record: 0.02647
#
# * Models saved *
#
# New historical moving average record: 0.02654
#
# * Models saved *
#
# New historical moving average record: 0.02659
#
# * Models saved *
#
# New historical moving average record: 0.02680
#
# * Models saved *
#
# New historical moving average record: 0.02688
#
# * Models saved *
#
# New historical moving average record: 0.02702
#
# * Models saved *
#
# New historical moving average record: 0.02703
#
# * Models saved *
#
# New historical moving average record: 0.02718
#
# Episode * 1300 * Worker * False * Moving Avg Reward is ==> 0.02731 * Last Reward was ==> 0.14858
# * Models saved *
#
# New historical moving average record: 0.02731
#
# * Models saved *
#
# New historical moving average record: 0.02741
#
# * Models saved *
#
# New historical moving average record: 0.02747
#
# * Models saved *
#
# New historical moving average record: 0.02750
#
# * Models saved *
#
# New historical moving average record: 0.02780
#
# * Models saved *
#
# New historical moving average record: 0.02782
#
# * Models saved *
#
# New historical moving average record: 0.02795
#
# * Models saved *
#
# New historical moving average record: 0.02803
#
# * Models saved *
#
# New historical moving average record: 0.02825
#
# * Models saved *
#
# New historical moving average record: 0.02831
#
# * Models saved *
#
# New historical moving average record: 0.02834
#
# * Models saved *
#
# New historical moving average record: 0.02844
#
# * Models saved *
#
# New historical moving average record: 0.02846
#
# * Models saved *
#
# New historical moving average record: 0.02847
#
# * Models saved *
#
# New historical moving average record: 0.02857
#
# * Models saved *
#
# New historical moving average record: 0.02862
#
# * Models saved *
#
# New historical moving average record: 0.02874
#
# * Models saved *
#
# New historical moving average record: 0.02880
#
# * Models saved *
#
# New historical moving average record: 0.02885
#
# * Models saved *
#
# New historical moving average record: 0.02901
#
# * Models saved *
#
# New historical moving average record: 0.02908
#
# * Models saved *
#
# New historical moving average record: 0.02919
#
# * Models saved *
#
# New historical moving average record: 0.02935
#
# * Models saved *
#
# New historical moving average record: 0.02937
#
# * Models saved *
#
# New historical moving average record: 0.02942
#
# * Models saved *
#
# New historical moving average record: 0.02945
#
# * Models saved *
#
# New historical moving average record: 0.02946
#
# * Models saved *
#
# New historical moving average record: 0.02947
#
# * Models saved *
#
# New historical moving average record: 0.02948
#
# * Models saved *
#
# New historical moving average record: 0.02954
#
# * Models saved *
#
# New historical moving average record: 0.02965
#
# * Models saved *
#
# New historical moving average record: 0.02967
#
# * Models saved *
#
# New historical moving average record: 0.02968
#
# * Models saved *
#
# New historical moving average record: 0.02980
#
# * Models saved *
#
# New historical moving average record: 0.02982
#
# * Models saved *
#
# New historical moving average record: 0.02985
#
# * Models saved *
#
# New historical moving average record: 0.02988
#
# * Models saved *
#
# New historical moving average record: 0.02996
#
# * Models saved *
#
# New historical moving average record: 0.03003
#
# * Models saved *
#
# New historical moving average record: 0.03021
#
# * Models saved *
#
# New historical moving average record: 0.03026
#
# * Models saved *
#
# New historical moving average record: 0.03033
#
# * Models saved *
#
# New historical moving average record: 0.03033
#
# * Models saved *
#
# New historical moving average record: 0.03038
#
# * Models saved *
#
# New historical moving average record: 0.03050
#
# * Models saved *
#
# New historical moving average record: 0.03055
#
# * Models saved *
#
# New historical moving average record: 0.03062
#
# * Models saved *
#
# New historical moving average record: 0.03068
#
# * Models saved *
#
# New historical moving average record: 0.03072
#
# * Models saved *
#
# New historical moving average record: 0.03074
#
# * Models saved *
#
# New historical moving average record: 0.03080
#
# * Models saved *
#
# New historical moving average record: 0.03092
#
# * Models saved *
#
# New historical moving average record: 0.03093
#
# * Models saved *
#
# New historical moving average record: 0.03105
#
# * Models saved *
#
# New historical moving average record: 0.03112
#
# * Models saved *
#
# New historical moving average record: 0.03119
#
# * Models saved *
#
# New historical moving average record: 0.03120
#
# * Models saved *
#
# New historical moving average record: 0.03139
#
# * Models saved *
#
# New historical moving average record: 0.03142
#
# * Models saved *
#
# New historical moving average record: 0.03142
#
# * Models saved *
#
# New historical moving average record: 0.03160
#
# Episode * 1400 * Worker * False * Moving Avg Reward is ==> 0.03171 * Last Reward was ==> 0.11171
# * Models saved *
#
# New historical moving average record: 0.03171
#
# * Models saved *
#
# New historical moving average record: 0.03174
#
# * Models saved *
#
# New historical moving average record: 0.03197
#
# * Models saved *
#
# New historical moving average record: 0.03202
#
# * Models saved *
#
# New historical moving average record: 0.03210
#
# * Models saved *
#
# New historical moving average record: 0.03215
#
# * Models saved *
#
# New historical moving average record: 0.03230
#
# * Models saved *
#
# New historical moving average record: 0.03231
#
# * Models saved *
#
# New historical moving average record: 0.03242
#
# * Models saved *
#
# New historical moving average record: 0.03248
#
# * Models saved *
#
# New historical moving average record: 0.03252
#
# * Models saved *
#
# New historical moving average record: 0.03258
#
# * Models saved *
#
# New historical moving average record: 0.03265
#
# * Models saved *
#
# New historical moving average record: 0.03275
#
# * Models saved *
#
# New historical moving average record: 0.03292
#
# * Models saved *
#
# New historical moving average record: 0.03299
#
# * Models saved *
#
# New historical moving average record: 0.03301
#
# * Models saved *
#
# New historical moving average record: 0.03311
#
# * Models saved *
#
# New historical moving average record: 0.03322
#
# * Models saved *
#
# New historical moving average record: 0.03325
#
# * Models saved *
#
# New historical moving average record: 0.03328
#
# * Models saved *
#
# New historical moving average record: 0.03338
#
# * Models saved *
#
# New historical moving average record: 0.03346
#
# * Models saved *
#
# New historical moving average record: 0.03349
#
# * Models saved *
#
# New historical moving average record: 0.03364
# * Models saved *
#
# New historical moving average record: 0.03364
#
# * Models saved *
#
# New historical moving average record: 0.03370
#
# * Models saved *
#
# New historical moving average record: 0.03377
#
# * Models saved *
#
# New historical moving average record: 0.03378
#
# * Models saved *
#
# New historical moving average record: 0.03381
#
# * Models saved *
#
# New historical moving average record: 0.03386
#
# * Models saved *
#
# New historical moving average record: 0.03390
#
# * Models saved *
#
# New historical moving average record: 0.03398
#
# * Models saved *
#
# New historical moving average record: 0.03407
#
# * Models saved *
#
# New historical moving average record: 0.03408
#
# * Models saved *
#
# New historical moving average record: 0.03416
#
# * Models saved *
#
# New historical moving average record: 0.03433
#
# * Models saved *
#
# New historical moving average record: 0.03443
#
# * Models saved *
#
# New historical moving average record: 0.03454
#
# * Models saved *
#
# New historical moving average record: 0.03460
#
# * Models saved *
#
# New historical moving average record: 0.03472
#
# * Models saved *
#
# New historical moving average record: 0.03475
#
# * Models saved *
#
# New historical moving average record: 0.03477
#
# * Models saved *
#
# New historical moving average record: 0.03489
#
# * Models saved *
#
# New historical moving average record: 0.03492
#
# * Models saved *
#
# New historical moving average record: 0.03503
#
# * Models saved *
#
# New historical moving average record: 0.03504
#
# * Models saved *
#
# New historical moving average record: 0.03514
#
# * Models saved *
#
# New historical moving average record: 0.03522
#
# * Models saved *
#
# New historical moving average record: 0.03523
#
# * Models saved *
#
# New historical moving average record: 0.03525
#
# * Models saved *
#
# New historical moving average record: 0.03538
#
# * Models saved *
#
# New historical moving average record: 0.03543
#
# * Models saved *
#
# New historical moving average record: 0.03545
#
# * Models saved *
#
# New historical moving average record: 0.03558
#
# * Models saved *
#
# New historical moving average record: 0.03563
#
# * Models saved *
#
# New historical moving average record: 0.03566
#
# * Models saved *
#
# New historical moving average record: 0.03577
#
# * Models saved *
#
# New historical moving average record: 0.03585
#
# * Models saved *
#
# New historical moving average record: 0.03588
#
# * Models saved *
#
# New historical moving average record: 0.03590
#
# * Models saved *
#
# New historical moving average record: 0.03605
#
# Episode * 1500 * Worker * False * Moving Avg Reward is ==> 0.03605 * Last Reward was ==> 0.04231
# * Models saved *
#
# New historical moving average record: 0.03605
#
# * Models saved *
#
# New historical moving average record: 0.03611
#
# * Models saved *
#
# New historical moving average record: 0.03613
#
# * Models saved *
#
# New historical moving average record: 0.03629
#
# * Models saved *
#
# New historical moving average record: 0.03643
#
# * Models saved *
#
# New historical moving average record: 0.03649
#
# * Models saved *
#
# New historical moving average record: 0.03668
#
# * Models saved *
#
# New historical moving average record: 0.03680
#
# * Models saved *
#
# New historical moving average record: 0.03685
#
# * Models saved *
#
# New historical moving average record: 0.03696
#
# * Models saved *
#
# New historical moving average record: 0.03701
#
# * Models saved *
#
# New historical moving average record: 0.03719
#
# * Models saved *
#
# New historical moving average record: 0.03732
#
# * Models saved *
#
# New historical moving average record: 0.03737
#
# * Models saved *
#
# New historical moving average record: 0.03746
#
# * Models saved *
#
# New historical moving average record: 0.03753
#
# * Models saved *
#
# New historical moving average record: 0.03766
#
# * Models saved *
#
# New historical moving average record: 0.03772
#
# * Models saved *
#
# New historical moving average record: 0.03774
#
# * Models saved *
#
# New historical moving average record: 0.03799
#
# * Models saved *
#
# New historical moving average record: 0.03809
#
# * Models saved *
#
# New historical moving average record: 0.03827
#
# * Models saved *
#
# New historical moving average record: 0.03833
#
# * Models saved *
#
# New historical moving average record: 0.03846
#
# * Models saved *
#
# New historical moving average record: 0.03848
#
# * Models saved *
#
# New historical moving average record: 0.03860
#
# * Models saved *
#
# New historical moving average record: 0.03877
#
# * Models saved *
#
# New historical moving average record: 0.03896
#
# * Models saved *
#
# New historical moving average record: 0.03898
#
# * Models saved *
#
# New historical moving average record: 0.03902
#
# * Models saved *
#
# New historical moving average record: 0.03913
#
# * Models saved *
#
# New historical moving average record: 0.03919
#
# * Models saved *
#
# New historical moving average record: 0.03921
#
# * Models saved *
#
# New historical moving average record: 0.03927
#
# * Models saved *
#
# New historical moving average record: 0.03932
#
# * Models saved *
#
# New historical moving average record: 0.03932
#
# * Models saved *
#
# New historical moving average record: 0.03934
#
# * Models saved *
#
# New historical moving average record: 0.03942
#
# * Models saved *
#
# New historical moving average record: 0.03951
#
# * Models saved *
#
# New historical moving average record: 0.03971
#
# * Models saved *
#
# New historical moving average record: 0.03981
#
# * Models saved *
#
# New historical moving average record: 0.03994
#
# * Models saved *
#
# New historical moving average record: 0.03995
#
# * Models saved *
#
# New historical moving average record: 0.03998
#
# * Models saved *
#
# New historical moving average record: 0.04001
#
# * Models saved *
#
# New historical moving average record: 0.04003
#
# * Models saved *
#
# New historical moving average record: 0.04008
#
# * Models saved *
#
# New historical moving average record: 0.04012
#
# * Models saved *
#
# New historical moving average record: 0.04028
#
# * Models saved *
#
# New historical moving average record: 0.04038
#
# * Models saved *
#
# New historical moving average record: 0.04042
#
# * Models saved *
#
# New historical moving average record: 0.04052
#
# * Models saved *
#
# New historical moving average record: 0.04068
#
# * Models saved *
#
# New historical moving average record: 0.04069
#
# * Models saved *
#
# New historical moving average record: 0.04087
#
# * Models saved *
#
# New historical moving average record: 0.04097
#
# * Models saved *
#
# New historical moving average record: 0.04101
#
# * Models saved *
#
# New historical moving average record: 0.04121
#
# * Models saved *
#
# New historical moving average record: 0.04122
#
# * Models saved *
#
# New historical moving average record: 0.04134
#
# Episode * 1600 * Worker * False * Moving Avg Reward is ==> 0.04112 * Last Reward was ==> -0.02805
# * Models saved *
#
# New historical moving average record: 0.04136
#
# * Models saved *
#
# New historical moving average record: 0.04151
#
# * Models saved *
#
# New historical moving average record: 0.04169
#
# * Models saved *
#
# New historical moving average record: 0.04187
#
# * Models saved *
#
# New historical moving average record: 0.04190
#
# * Models saved *
#
# New historical moving average record: 0.04209
#
# * Models saved *
#
# New historical moving average record: 0.04219
#
# * Models saved *
#
# New historical moving average record: 0.04234
#
# * Models saved *
#
# New historical moving average record: 0.04235
#
# * Models saved *
#
# New historical moving average record: 0.04237
#
# * Models saved *
#
# New historical moving average record: 0.04239
#
# * Models saved *
#
# New historical moving average record: 0.04245
#
# * Models saved *
#
# New historical moving average record: 0.04248
#
# * Models saved *
#
# New historical moving average record: 0.04249
#
# * Models saved *
#
# New historical moving average record: 0.04263
#
# * Models saved *
#
# New historical moving average record: 0.04275
#
# * Models saved *
#
# New historical moving average record: 0.04289
#
# * Models saved *
#
# New historical moving average record: 0.04302
#
# * Models saved *
#
# New historical moving average record: 0.04304
#
# * Models saved *
#
# New historical moving average record: 0.04311
#
# * Models saved *
#
# New historical moving average record: 0.04312
#
# * Models saved *
#
# New historical moving average record: 0.04314
#
# * Models saved *
#
# New historical moving average record: 0.04314
#
# * Models saved *
#
# New historical moving average record: 0.04316
#
# * Models saved *
#
# New historical moving average record: 0.04325
#
# * Models saved *
#
# New historical moving average record: 0.04327
#
# * Models saved *
#
# New historical moving average record: 0.04334
# * Models saved *
#
# New historical moving average record: 0.04336
#
# Episode * 1700 * Worker * False * Moving Avg Reward is ==> 0.04332 * Last Reward was ==> -0.01590
# * Models saved *
#
# New historical moving average record: 0.04337
#
# * Models saved *
#
# New historical moving average record: 0.04351
#
# * Models saved *
#
# New historical moving average record: 0.04351
#
# * Models saved *
#
# New historical moving average record: 0.04355
#
# * Models saved *
#
# New historical moving average record: 0.04364
#
# * Models saved *
#
# New historical moving average record: 0.04365
#
# * Models saved *
#
# New historical moving average record: 0.04375
#
# * Models saved *
#
# New historical moving average record: 0.04380
#
# * Models saved *
#
# New historical moving average record: 0.04389
#
# * Models saved *
#
# New historical moving average record: 0.04403
#
# * Models saved *
#
# New historical moving average record: 0.04403
#
# * Models saved *
#
# New historical moving average record: 0.04406
#
# * Models saved *
#
# New historical moving average record: 0.04407
#
# * Models saved *
#
# New historical moving average record: 0.04428
#
# * Models saved *
#
# New historical moving average record: 0.04444
#
# * Models saved *
#
# New historical moving average record: 0.04450
#
# * Models saved *
#
# New historical moving average record: 0.04454
#
# * Models saved *
#
# New historical moving average record: 0.04461
#
# * Models saved *
#
# New historical moving average record: 0.04475
#
# * Models saved *
#
# New historical moving average record: 0.04481
#
# * Models saved *
#
# New historical moving average record: 0.04482
#
# * Models saved *
#
# New historical moving average record: 0.04486
#
# * Models saved *
#
# New historical moving average record: 0.04499
#
# * Models saved *
#
# New historical moving average record: 0.04507
#
# * Models saved *
#
# New historical moving average record: 0.04508
#
# * Models saved *
#
# New historical moving average record: 0.04512
#
# * Models saved *
#
# New historical moving average record: 0.04531
#
# * Models saved *
#
# New historical moving average record: 0.04540
#
# * Models saved *
#
# New historical moving average record: 0.04546
#
# * Models saved *
#
# New historical moving average record: 0.04552
#
# * Models saved *
#
# New historical moving average record: 0.04566
#
# * Models saved *
#
# New historical moving average record: 0.04568
#
# * Models saved *
#
# New historical moving average record: 0.04570
#
# * Models saved *
#
# New historical moving average record: 0.04571
#
# * Models saved *
#
# New historical moving average record: 0.04579
#
# * Models saved *
#
# New historical moving average record: 0.04593
#
# * Models saved *
#
# New historical moving average record: 0.04602
#
# * Models saved *
#
# New historical moving average record: 0.04603
#
# * Models saved *
#
# New historical moving average record: 0.04611
#
# * Models saved *
#
# New historical moving average record: 0.04615
#
# * Models saved *
#
# New historical moving average record: 0.04617
#
# Episode * 1800 * Worker * False * Moving Avg Reward is ==> 0.04623 * Last Reward was ==> 0.06074
# * Models saved *
#
# New historical moving average record: 0.04623
#
# * Models saved *
#
# New historical moving average record: 0.04625
#
# * Models saved *
#
# New historical moving average record: 0.04626
#
# * Models saved *
#
# New historical moving average record: 0.04629
#
# * Models saved *
#
# New historical moving average record: 0.04634
#
# * Models saved *
#
# New historical moving average record: 0.04637
#
# * Models saved *
#
# New historical moving average record: 0.04647
#
# * Models saved *
#
# New historical moving average record: 0.04656
#
# * Models saved *
#
# New historical moving average record: 0.04669
#
# * Models saved *
#
# New historical moving average record: 0.04678
#
# * Models saved *
#
# New historical moving average record: 0.04681
#
# * Models saved *
#
# New historical moving average record: 0.04686
#
# * Models saved *
#
# New historical moving average record: 0.04686
#
# * Models saved *
#
# New historical moving average record: 0.04695
#
# * Models saved *
#
# New historical moving average record: 0.04697
#
# * Models saved *
#
# New historical moving average record: 0.04719
#
# * Models saved *
#
# New historical moving average record: 0.04741
#
# * Models saved *
#
# New historical moving average record: 0.04744
#
# * Models saved *
#
# New historical moving average record: 0.04767
#
# * Models saved *
#
# New historical moving average record: 0.04767
#
# * Models saved *
#
# New historical moving average record: 0.04768
#
# * Models saved *
#
# New historical moving average record: 0.04776
#
# * Models saved *
#
# New historical moving average record: 0.04794
#
# * Models saved *
#
# New historical moving average record: 0.04795
#
# * Models saved *
#
# New historical moving average record: 0.04799
#
# * Models saved *
#
# New historical moving average record: 0.04822
#
# * Models saved *
#
# New historical moving average record: 0.04825
#
# * Models saved *
#
# New historical moving average record: 0.04835
#
# * Models saved *
#
# New historical moving average record: 0.04851
#
# * Models saved *
#
# New historical moving average record: 0.04855
#
# * Models saved *
#
# New historical moving average record: 0.04871
#
# * Models saved *
#
# New historical moving average record: 0.04874
#
# * Models saved *
#
# New historical moving average record: 0.04888
#
# * Models saved *
#
# New historical moving average record: 0.04898
#
# * Models saved *
#
# New historical moving average record: 0.04904
#
# * Models saved *
#
# New historical moving average record: 0.04946
#
# * Models saved *
#
# New historical moving average record: 0.04957
#
# * Models saved *
#
# New historical moving average record: 0.04964
#
# * Models saved *
#
# New historical moving average record: 0.04975
#
# * Models saved *
#
# New historical moving average record: 0.04980
#
# * Models saved *
#
# New historical moving average record: 0.04986
#
# * Models saved *
#
# New historical moving average record: 0.05002
#
# * Models saved *
#
# New historical moving average record: 0.05010
#
# * Models saved *
#
# New historical moving average record: 0.05011
#
# * Models saved *
#
# New historical moving average record: 0.05022
#
# * Models saved *
#
# New historical moving average record: 0.05026
#
# * Models saved *
#
# New historical moving average record: 0.05027
#
# * Models saved *
#
# New historical moving average record: 0.05034
#
# * Models saved *
#
# New historical moving average record: 0.05036
#
# * Models saved *
#
# New historical moving average record: 0.05041
#
# * Models saved *
#
# New historical moving average record: 0.05043
#
# * Models saved *
#
# New historical moving average record: 0.05061
#
# * Models saved *
#
# New historical moving average record: 0.05068
#
# Episode * 1900 * Worker * False * Moving Avg Reward is ==> 0.05032 * Last Reward was ==> 0.17589
# * Models saved *
#
# New historical moving average record: 0.05068
#
# * Models saved *
#
# New historical moving average record: 0.05073
#
# * Models saved *
#
# New historical moving average record: 0.05078
#
# * Models saved *
#
# New historical moving average record: 0.05078
#
# * Models saved *
#
# New historical moving average record: 0.05081
#
# * Models saved *
#
# New historical moving average record: 0.05098
#
# * Models saved *
#
# New historical moving average record: 0.05098
#
# * Models saved *
#
# New historical moving average record: 0.05115
#
# * Models saved *
#
# New historical moving average record: 0.05125
#
# * Models saved *
#
# New historical moving average record: 0.05141
#
# * Models saved *
#
# New historical moving average record: 0.05144
#
# * Models saved *
#
# New historical moving average record: 0.05156
#
# * Models saved *
#
# New historical moving average record: 0.05163
#
# * Models saved *
#
# New historical moving average record: 0.05169
#
# * Models saved *
#
# New historical moving average record: 0.05176
#
# * Models saved *
#
# New historical moving average record: 0.05187
#
# * Models saved *
#
# New historical moving average record: 0.05188
#
# * Models saved *
#
# New historical moving average record: 0.05196
#
# * Models saved *
#
# New historical moving average record: 0.05199
#
# * Models saved *
#
# New historical moving average record: 0.05206
#
# * Models saved *
#
# New historical moving average record: 0.05213
#
# * Models saved *
#
# New historical moving average record: 0.05217
#
# * Models saved *
#
# New historical moving average record: 0.05228
#
# * Models saved *
#
# New historical moving average record: 0.05243
#
# * Models saved *
#
# New historical moving average record: 0.05255
#
# * Models saved *
#
# New historical moving average record: 0.05260
#
# * Models saved *
#
# New historical moving average record: 0.05262
# * Models saved *
#
# New historical moving average record: 0.05269
#
# * Models saved *
#
# New historical moving average record: 0.05271
#
# * Models saved *
#
# New historical moving average record: 0.05280
#
# * Models saved *
#
# New historical moving average record: 0.05287
#
# * Models saved *
#
# New historical moving average record: 0.05294
#
# * Models saved *
#
# New historical moving average record: 0.05297
#
# * Models saved *
#
# New historical moving average record: 0.05309
#
# * Models saved *
#
# New historical moving average record: 0.05323
#
# * Models saved *
#
# New historical moving average record: 0.05346
#
# * Models saved *
#
# New historical moving average record: 0.05347
#
# * Models saved *
#
# New historical moving average record: 0.05353
#
# * Models saved *
#
# New historical moving average record: 0.05362
#
# * Models saved *
#
# New historical moving average record: 0.05365
#
# * Models saved *
#
# New historical moving average record: 0.05373
#
# * Models saved *
#
# New historical moving average record: 0.05380
#
# * Models saved *
#
# New historical moving average record: 0.05387
#
# * Models saved *
#
# New historical moving average record: 0.05400
#
# * Models saved *
#
# New historical moving average record: 0.05416
#
# * Models saved *
#
# New historical moving average record: 0.05424
#
# * Models saved *
#
# New historical moving average record: 0.05425
#
# * Models saved *
#
# New historical moving average record: 0.05429
#
# * Models saved *
#
# New historical moving average record: 0.05433
#
# * Models saved *
#
# New historical moving average record: 0.05446
#
# * Models saved *
#
# New historical moving average record: 0.05460
#
# Episode * 2000 * Worker * False * Moving Avg Reward is ==> 0.05463 * Last Reward was ==> 0.01052
# * Models saved *
#
# New historical moving average record: 0.05463
#
# * Models saved *
#
# New historical moving average record: 0.05476
#
# * Models saved *
#
# New historical moving average record: 0.05480
#
# * Models saved *
#
# New historical moving average record: 0.05485
#
# * Models saved *
#
# New historical moving average record: 0.05492
#
# * Models saved *
#
# New historical moving average record: 0.05497
#
# * Models saved *
#
# New historical moving average record: 0.05500
#
# * Models saved *
#
# New historical moving average record: 0.05505
#
# * Models saved *
#
# New historical moving average record: 0.05516
#
# * Models saved *
#
# New historical moving average record: 0.05526
#
# * Models saved *
#
# New historical moving average record: 0.05527
#
# * Models saved *
#
# New historical moving average record: 0.05538
#
# * Models saved *
#
# New historical moving average record: 0.05553
#
# * Models saved *
#
# New historical moving average record: 0.05575
#
# * Models saved *
#
# New historical moving average record: 0.05581
#
# * Models saved *
#
# New historical moving average record: 0.05597
#
# * Models saved *
#
# New historical moving average record: 0.05598
#
# * Models saved *
#
# New historical moving average record: 0.05600
#
# * Models saved *
#
# New historical moving average record: 0.05613
#
# * Models saved *
#
# New historical moving average record: 0.05616
#
# * Models saved *
#
# New historical moving average record: 0.05623
#
# * Models saved *
#
# New historical moving average record: 0.05631
#
# * Models saved *
#
# New historical moving average record: 0.05637
#
# * Models saved *
#
# New historical moving average record: 0.05644
#
# * Models saved *
#
# New historical moving average record: 0.05650
#
# * Models saved *
#
# New historical moving average record: 0.05661
#
# * Models saved *
#
# New historical moving average record: 0.05665
#
# * Models saved *
#
# New historical moving average record: 0.05670
#
# * Models saved *
#
# New historical moving average record: 0.05682
#
# * Models saved *
#
# New historical moving average record: 0.05688
#
# * Models saved *
#
# New historical moving average record: 0.05707
#
# Episode * 2100 * Worker * False * Moving Avg Reward is ==> 0.05700 * Last Reward was ==> 0.03616
# * Models saved *
#
# New historical moving average record: 0.05717
#
# * Models saved *
#
# New historical moving average record: 0.05724
#
# * Models saved *
#
# New historical moving average record: 0.05728
#
# * Models saved *
#
# New historical moving average record: 0.05741
#
# * Models saved *
#
# New historical moving average record: 0.05745
#
# * Models saved *
#
# New historical moving average record: 0.05758
#
# * Models saved *
#
# New historical moving average record: 0.05762
#
# * Models saved *
#
# New historical moving average record: 0.05786
#
# * Models saved *
#
# New historical moving average record: 0.05787
#
# * Models saved *
#
# New historical moving average record: 0.05802
#
# * Models saved *
#
# New historical moving average record: 0.05806
#
# * Models saved *
#
# New historical moving average record: 0.05821
#
# * Models saved *
#
# New historical moving average record: 0.05833
#
# * Models saved *
#
# New historical moving average record: 0.05837
#
# * Models saved *
#
# New historical moving average record: 0.05856
#
# * Models saved *
#
# New historical moving average record: 0.05877
#
# * Models saved *
#
# New historical moving average record: 0.05891
#
# * Models saved *
#
# New historical moving average record: 0.05901
#
# * Models saved *
#
# New historical moving average record: 0.05909
#
# * Models saved *
#
# New historical moving average record: 0.05920
#
# * Models saved *
#
# New historical moving average record: 0.05942
#
# * Models saved *
#
# New historical moving average record: 0.05946
#
# * Models saved *
#
# New historical moving average record: 0.05950
#
# * Models saved *
#
# New historical moving average record: 0.05963
#
# * Models saved *
#
# New historical moving average record: 0.05975
#
# * Models saved *
#
# New historical moving average record: 0.05975
#
# * Models saved *
#
# New historical moving average record: 0.05985
#
# * Models saved *
#
# New historical moving average record: 0.05994
#
# * Models saved *
#
# New historical moving average record: 0.05996
#
# * Models saved *
#
# New historical moving average record: 0.06009
#
# * Models saved *
#
# New historical moving average record: 0.06016
#
# * Models saved *
#
# New historical moving average record: 0.06018
#
# * Models saved *
#
# New historical moving average record: 0.06020
#
# * Models saved *
#
# New historical moving average record: 0.06023
#
# * Models saved *
#
# New historical moving average record: 0.06043
#
# * Models saved *
#
# New historical moving average record: 0.06052
#
# * Models saved *
#
# New historical moving average record: 0.06063
#
# * Models saved *
#
# New historical moving average record: 0.06071
#
# * Models saved *
#
# New historical moving average record: 0.06082
#
# * Models saved *
#
# New historical moving average record: 0.06088
#
# * Models saved *
#
# New historical moving average record: 0.06088
#
# Episode * 2200 * Worker * False * Moving Avg Reward is ==> 0.06099 * Last Reward was ==> 0.22210
# * Models saved *
#
# New historical moving average record: 0.06099
#
# * Models saved *
#
# New historical moving average record: 0.06105
#
# * Models saved *
#
# New historical moving average record: 0.06113
#
# * Models saved *
#
# New historical moving average record: 0.06132
#
# * Models saved *
#
# New historical moving average record: 0.06144
#
# * Models saved *
#
# New historical moving average record: 0.06145
#
# * Models saved *
#
# New historical moving average record: 0.06161
#
# * Models saved *
#
# New historical moving average record: 0.06162
#
# * Models saved *
#
# New historical moving average record: 0.06166
#
# * Models saved *
#
# New historical moving average record: 0.06187
#
# * Models saved *
#
# New historical moving average record: 0.06189
#
# * Models saved *
#
# New historical moving average record: 0.06189
#
# * Models saved *
#
# New historical moving average record: 0.06196
#
# * Models saved *
#
# New historical moving average record: 0.06217
#
# * Models saved *
#
# New historical moving average record: 0.06223
#
# * Models saved *
#
# New historical moving average record: 0.06227
#
# * Models saved *
#
# New historical moving average record: 0.06237
#
# * Models saved *
#
# New historical moving average record: 0.06252
#
# * Models saved *
#
# New historical moving average record: 0.06255
#
# * Models saved *
#
# New historical moving average record: 0.06259
#
# * Models saved *
#
# New historical moving average record: 0.06272
#
# * Models saved *
#
# New historical moving average record: 0.06282
#
# * Models saved *
#
# New historical moving average record: 0.06287
#
# * Models saved *
#
# New historical moving average record: 0.06299
#
# * Models saved *
#
# New historical moving average record: 0.06308
#
# * Models saved *
#
# New historical moving average record: 0.06321
# * Models saved *
#
# New historical moving average record: 0.06327
#
# * Models saved *
#
# New historical moving average record: 0.06336
#
# * Models saved *
#
# New historical moving average record: 0.06353
#
# * Models saved *
#
# New historical moving average record: 0.06363
#
# * Models saved *
#
# New historical moving average record: 0.06366
#
# * Models saved *
#
# New historical moving average record: 0.06369
#
# * Models saved *
#
# New historical moving average record: 0.06377
#
# * Models saved *
#
# New historical moving average record: 0.06381
#
# * Models saved *
#
# New historical moving average record: 0.06392
#
# * Models saved *
#
# New historical moving average record: 0.06404
#
# * Models saved *
#
# New historical moving average record: 0.06411
#
# * Models saved *
#
# New historical moving average record: 0.06419
#
# * Models saved *
#
# New historical moving average record: 0.06424
#
# * Models saved *
#
# New historical moving average record: 0.06440
#
# * Models saved *
#
# New historical moving average record: 0.06446
#
# * Models saved *
#
# New historical moving average record: 0.06466
#
# * Models saved *
#
# New historical moving average record: 0.06468
#
# * Models saved *
#
# New historical moving average record: 0.06471
#
# Episode * 2300 * Worker * False * Moving Avg Reward is ==> 0.06464 * Last Reward was ==> 0.15250
# * Models saved *
#
# New historical moving average record: 0.06479
#
# * Models saved *
#
# New historical moving average record: 0.06484
#
# * Models saved *
#
# New historical moving average record: 0.06485
#
# * Models saved *
#
# New historical moving average record: 0.06500
#
# * Models saved *
#
# New historical moving average record: 0.06527
#
# * Models saved *
#
# New historical moving average record: 0.06534
#
# * Models saved *
#
# New historical moving average record: 0.06551
#
# * Models saved *
#
# New historical moving average record: 0.06559
#
# * Models saved *
#
# New historical moving average record: 0.06573
#
# * Models saved *
#
# New historical moving average record: 0.06582
#
# * Models saved *
#
# New historical moving average record: 0.06583
#
# * Models saved *
#
# New historical moving average record: 0.06587
#
# * Models saved *
#
# New historical moving average record: 0.06595
#
# * Models saved *
#
# New historical moving average record: 0.06597
#
# * Models saved *
#
# New historical moving average record: 0.06598
#
# * Models saved *
#
# New historical moving average record: 0.06603
#
# * Models saved *
#
# New historical moving average record: 0.06611
#
# * Models saved *
#
# New historical moving average record: 0.06617
#
# * Models saved *
#
# New historical moving average record: 0.06621
#
# * Models saved *
#
# New historical moving average record: 0.06624
#
# * Models saved *
#
# New historical moving average record: 0.06637
#
# * Models saved *
#
# New historical moving average record: 0.06653
#
# * Models saved *
#
# New historical moving average record: 0.06667
#
# * Models saved *
#
# New historical moving average record: 0.06676
#
# * Models saved *
#
# New historical moving average record: 0.06683
#
# * Models saved *
#
# New historical moving average record: 0.06697
#
# * Models saved *
#
# New historical moving average record: 0.06709
#
# * Models saved *
#
# New historical moving average record: 0.06712
#
# * Models saved *
#
# New historical moving average record: 0.06726
#
# * Models saved *
#
# New historical moving average record: 0.06737
#
# Episode * 2400 * Worker * False * Moving Avg Reward is ==> 0.06715 * Last Reward was ==> -0.00715
# * Models saved *
#
# New historical moving average record: 0.06741
#
# * Models saved *
#
# New historical moving average record: 0.06757
#
# * Models saved *
#
# New historical moving average record: 0.06762
#
# * Models saved *
#
# New historical moving average record: 0.06770
#
# * Models saved *
#
# New historical moving average record: 0.06777
#
# * Models saved *
#
# New historical moving average record: 0.06789
#
# * Models saved *
#
# New historical moving average record: 0.06799
#
# * Models saved *
#
# New historical moving average record: 0.06801
#
# * Models saved *
#
# New historical moving average record: 0.06802
#
# * Models saved *
#
# New historical moving average record: 0.06813
#
# * Models saved *
#
# New historical moving average record: 0.06818
#
# * Models saved *
#
# New historical moving average record: 0.06830
#
# * Models saved *
#
# New historical moving average record: 0.06838
#
# * Models saved *
#
# New historical moving average record: 0.06843
#
# * Models saved *
#
# New historical moving average record: 0.06844
#
# * Models saved *
#
# New historical moving average record: 0.06862
#
# * Models saved *
#
# New historical moving average record: 0.06866
#
# * Models saved *
#
# New historical moving average record: 0.06873
#
# * Models saved *
#
# New historical moving average record: 0.06881
#
# * Models saved *
#
# New historical moving average record: 0.06887
#
# * Models saved *
#
# New historical moving average record: 0.06892
#
# * Models saved *
#
# New historical moving average record: 0.06912
#
# * Models saved *
#
# New historical moving average record: 0.06920
#
# * Models saved *
#
# New historical moving average record: 0.06937
#
# * Models saved *
#
# New historical moving average record: 0.06939
#
# * Models saved *
#
# New historical moving average record: 0.06940
#
# * Models saved *
#
# New historical moving average record: 0.06944
#
# Episode * 2500 * Worker * False * Moving Avg Reward is ==> 0.06929 * Last Reward was ==> 0.05674
# * Models saved *
#
# New historical moving average record: 0.06949
#
# * Models saved *
#
# New historical moving average record: 0.06951
#
# * Models saved *
#
# New historical moving average record: 0.06961
#
# * Models saved *
#
# New historical moving average record: 0.06970
#
# * Models saved *
#
# New historical moving average record: 0.06983
#
# * Models saved *
#
# New historical moving average record: 0.06996
#
# * Models saved *
#
# New historical moving average record: 0.07006
#
# * Models saved *
#
# New historical moving average record: 0.07009
#
# * Models saved *
#
# New historical moving average record: 0.07019
#
# * Models saved *
#
# New historical moving average record: 0.07028
#
# * Models saved *
#
# New historical moving average record: 0.07036
#
# * Models saved *
#
# New historical moving average record: 0.07044
#
# * Models saved *
#
# New historical moving average record: 0.07060
#
# Episode * 2600 * Worker * False * Moving Avg Reward is ==> 0.07008 * Last Reward was ==> 0.13734
# * Models saved *
#
# New historical moving average record: 0.07073
#
# * Models saved *
#
# New historical moving average record: 0.07080
#
# * Models saved *
#
# New historical moving average record: 0.07083
#
# * Models saved *
#
# New historical moving average record: 0.07105
#
# * Models saved *
#
# New historical moving average record: 0.07121
#
# * Models saved *
#
# New historical moving average record: 0.07134
#
# * Models saved *
#
# New historical moving average record: 0.07152
#
# * Models saved *
#
# New historical moving average record: 0.07159
#
# * Models saved *
#
# New historical moving average record: 0.07159
#
# * Models saved *
#
# New historical moving average record: 0.07168
#
# * Models saved *
#
# ...
# * Models saved *
#
# New historical moving average record: 0.19406
#
# * Models saved *
#
# New historical moving average record: 0.19407
#
# * Models saved *
#
# New historical moving average record: 0.19425
#
# * Models saved *
#
# New historical moving average record: 0.19426
#
# * Models saved *
#
# New historical moving average record: 0.19431
#
# * Models saved *
#
# New historical moving average record: 0.19433
#
# * Models saved *
#
# New historical moving average record: 0.19453
#
# * Models saved *
#
# New historical moving average record: 0.19453
#
# * Models saved *
#
# New historical moving average record: 0.19460
#
# * Models saved *
#
# New historical moving average record: 0.19462
#
# * Models saved *
#
# New historical moving average record: 0.19468
#
# * Models saved *
#
# New historical moving average record: 0.19468
#
# * Models saved *
#
# New historical moving average record: 0.19477
#
# * Models saved *
#
# New historical moving average record: 0.19483
#
# * Models saved *
#
# New historical moving average record: 0.19484
#
# * Models saved *
#
# New historical moving average record: 0.19502
#
# * Models saved *
#
# New historical moving average record: 0.19504
#
# Episode * 8900 * Worker * False * Moving Avg Reward is ==> 0.19371 * Last Reward was ==> 0.20770
# * Models saved *
#
# New historical moving average record: 0.19507
#
# * Models saved *
#
# New historical moving average record: 0.19513
#
# * Models saved *
#
# New historical moving average record: 0.19517
#
# * Models saved *
#
# New historical moving average record: 0.19534
#
# * Models saved *
#
# New historical moving average record: 0.19540
#
# * Models saved *
#
# New historical moving average record: 0.19554
#
# * Models saved *
#
# New historical moving average record: 0.19558
#
# * Models saved *
#
# New historical moving average record: 0.19568
#
# * Models saved *
#
# New historical moving average record: 0.19575
#
# * Models saved *
#
# New historical moving average record: 0.19588
#
# * Models saved *
#
# New historical moving average record: 0.19601
#
# Episode * 9000 * Worker * False * Moving Avg Reward is ==> 0.19522 * Last Reward was ==> 0.27571
# * Models saved *
#
# New historical moving average record: 0.19602
#
# * Models saved *
#
# New historical moving average record: 0.19609
#
# * Models saved *
#
# New historical moving average record: 0.19623
#
# * Models saved *
#
# New historical moving average record: 0.19637
#
# Episode * 9100 * Worker * False * Moving Avg Reward is ==> 0.19588 * Last Reward was ==> 0.20437
# * Models saved *
#
# New historical moving average record: 0.19639
#
# * Models saved *
#
# New historical moving average record: 0.19641
#
# * Models saved *
#
# New historical moving average record: 0.19653
#
# * Models saved *
#
# New historical moving average record: 0.19659
#
# * Models saved *
#
# New historical moving average record: 0.19671
#
# * Models saved *
#
# New historical moving average record: 0.19683
#
# * Models saved *
#
# New historical moving average record: 0.19691
#
# * Models saved *
#
# New historical moving average record: 0.19697
#
# * Models saved *
#
# New historical moving average record: 0.19698
#
# * Models saved *
#
# New historical moving average record: 0.19700
#
# * Models saved *
#
# New historical moving average record: 0.19705
#
# * Models saved *
#
# New historical moving average record: 0.19706
#
# * Models saved *
#
# New historical moving average record: 0.19707
#
# * Models saved *
#
# New historical moving average record: 0.19712
#
# Episode * 9200 * Worker * False * Moving Avg Reward is ==> 0.19722 * Last Reward was ==> 0.30745
# * Models saved *
#
# New historical moving average record: 0.19722
#
# * Models saved *
#
# New historical moving average record: 0.19723
#
# * Models saved *
#
# New historical moving average record: 0.19725
#
# * Models saved *
#
# New historical moving average record: 0.19732
#
# * Models saved *
#
# New historical moving average record: 0.19740
#
# * Models saved *
#
# New historical moving average record: 0.19743
#
# * Models saved *
#
# New historical moving average record: 0.19756
#
# * Models saved *
#
# New historical moving average record: 0.19760
#
# * Models saved *
#
# New historical moving average record: 0.19765
#
# * Models saved *
#
# New historical moving average record: 0.19773
#
# * Models saved *
#
# New historical moving average record: 0.19783
#
# * Models saved *
#
# New historical moving average record: 0.19790
#
# * Models saved *
#
# New historical moving average record: 0.19791
#
# * Models saved *
#
# New historical moving average record: 0.19794
#
# * Models saved *
#
# New historical moving average record: 0.19799
#
# * Models saved *
#
# New historical moving average record: 0.19801
#
# * Models saved *
#
# New historical moving average record: 0.19807
#
# * Models saved *
#
# New historical moving average record: 0.19815
#
# * Models saved *
#
# New historical moving average record: 0.19831
#
# * Models saved *
#
# New historical moving average record: 0.19852
# * Models saved *
#
# New historical moving average record: 0.19858
#
# * Models saved *
#
# New historical moving average record: 0.19867
#
# * Models saved *
#
# New historical moving average record: 0.19868
#
# * Models saved *
#
# New historical moving average record: 0.19876
#
# * Models saved *
#
# New historical moving average record: 0.19882
#
# * Models saved *
#
# New historical moving average record: 0.19907
#
# * Models saved *
#
# New historical moving average record: 0.19911
#
# * Models saved *
#
# New historical moving average record: 0.19914
#
# * Models saved *
#
# New historical moving average record: 0.19918
#
# Episode * 9300 * Worker * False * Moving Avg Reward is ==> 0.19898 * Last Reward was ==> 0.27487
# * Models saved *
#
# New historical moving average record: 0.19921
#
# * Models saved *
#
# New historical moving average record: 0.19921
#
# * Models saved *
#
# New historical moving average record: 0.19926
#
# * Models saved *
#
# New historical moving average record: 0.19943
#
# * Models saved *
#
# New historical moving average record: 0.19948
#
# * Models saved *
#
# New historical moving average record: 0.19951
#
# * Models saved *
#
# New historical moving average record: 0.19953
#
# * Models saved *
#
# New historical moving average record: 0.19965
#
# * Models saved *
#
# New historical moving average record: 0.19970
#
# * Models saved *
#
# New historical moving average record: 0.19973
#
# * Models saved *
#
# New historical moving average record: 0.19975
#
# * Models saved *
#
# New historical moving average record: 0.19978
#
# * Models saved *
#
# New historical moving average record: 0.19990
#
# * Models saved *
#
# New historical moving average record: 0.19998
#
# * Models saved *
#
# New historical moving average record: 0.19999
#
# * Models saved *
#
# New historical moving average record: 0.20012
#
# * Models saved *
#
# New historical moving average record: 0.20025
#
# * Models saved *
#
# New historical moving average record: 0.20045
#
# * Models saved *
#
# New historical moving average record: 0.20045
#
# * Models saved *
#
# New historical moving average record: 0.20050
#
# * Models saved *
#
# New historical moving average record: 0.20058
#
# * Models saved *
#
# New historical moving average record: 0.20058
#
# * Models saved *
#
# New historical moving average record: 0.20059
#
# Episode * 9400 * Worker * False * Moving Avg Reward is ==> 0.20035 * Last Reward was ==> 0.36419
# * Models saved *
#
# New historical moving average record: 0.20059
#
# * Models saved *
#
# New historical moving average record: 0.20075
#
# * Models saved *
#
# New historical moving average record: 0.20096
#
# * Models saved *
#
# New historical moving average record: 0.20100
#
# * Models saved *
#
# New historical moving average record: 0.20102
#
# * Models saved *
#
# New historical moving average record: 0.20105
#
# * Models saved *
#
# New historical moving average record: 0.20117
#
# * Models saved *
#
# New historical moving average record: 0.20121
#
# * Models saved *
#
# New historical moving average record: 0.20123
#
# * Models saved *
#
# New historical moving average record: 0.20123
#
# * Models saved *
#
# New historical moving average record: 0.20129
#
# * Models saved *
#
# New historical moving average record: 0.20138
#
# * Models saved *
#
# New historical moving average record: 0.20143
#
# * Models saved *
#
# New historical moving average record: 0.20154
#
# * Models saved *
#
# New historical moving average record: 0.20155
#
# * Models saved *
#
# New historical moving average record: 0.20155
#
# * Models saved *
#
# New historical moving average record: 0.20169
#
# * Models saved *
#
# New historical moving average record: 0.20172
#
# * Models saved *
#
# New historical moving average record: 0.20176
#
# * Models saved *
#
# New historical moving average record: 0.20193
#
# * Models saved *
#
# New historical moving average record: 0.20193
#
# * Models saved *
#
# New historical moving average record: 0.20201
#
# * Models saved *
#
# New historical moving average record: 0.20216
#
# * Models saved *
#
# New historical moving average record: 0.20220
#
# * Models saved *
#
# New historical moving average record: 0.20229
#
# * Models saved *
#
# New historical moving average record: 0.20231
#
# * Models saved *
#
# New historical moving average record: 0.20242
#
# * Models saved *
#
# New historical moving average record: 0.20250
#
# * Models saved *
#
# New historical moving average record: 0.20252
#
# * Models saved *
#
# New historical moving average record: 0.20256
#
# Episode * 9500 * Worker * False * Moving Avg Reward is ==> 0.20199 * Last Reward was ==> 0.22622
# * Models saved *
#
# New historical moving average record: 0.20261
#
# * Models saved *
#
# New historical moving average record: 0.20267
#
# * Models saved *
#
# New historical moving average record: 0.20277
#
# * Models saved *
#
# New historical moving average record: 0.20278
#
# * Models saved *
#
# New historical moving average record: 0.20279
#
# * Models saved *
#
# New historical moving average record: 0.20279
#
# * Models saved *
#
# New historical moving average record: 0.20285
#
# * Models saved *
#
# New historical moving average record: 0.20287
#
# Episode * 9600 * Worker * False * Moving Avg Reward is ==> 0.20217 * Last Reward was ==> 0.28449
# Episode * 9700 * Worker * False * Moving Avg Reward is ==> 0.20208 * Last Reward was ==> 0.22334
# * Models saved *
#
# New historical moving average record: 0.20291
#
# * Models saved *
#
# New historical moving average record: 0.20292
#
# * Models saved *
#
# New historical moving average record: 0.20301
#
# * Models saved *
#
# New historical moving average record: 0.20301
#
# * Models saved *
#
# New historical moving average record: 0.20307
#
# * Models saved *
#
# New historical moving average record: 0.20308
#
# * Models saved *
#
# New historical moving average record: 0.20313
#
# * Models saved *
#
# New historical moving average record: 0.20336
#
# * Models saved *
#
# New historical moving average record: 0.20342
#
# * Models saved *
#
# New historical moving average record: 0.20342
#
# * Models saved *
#
# New historical moving average record: 0.20344
#
# * Models saved *
#
# New historical moving average record: 0.20349
#
# * Models saved *
#
# New historical moving average record: 0.20352
#
# * Models saved *
#
# New historical moving average record: 0.20362
#
# * Models saved *
#
# New historical moving average record: 0.20370
#
# * Models saved *
#
# New historical moving average record: 0.20375
#
# * Models saved *
#
# New historical moving average record: 0.20377
#
# * Models saved *
#
# New historical moving average record: 0.20382
#
# Episode * 9800 * Worker * False * Moving Avg Reward is ==> 0.20352 * Last Reward was ==> 0.14359
# * Models saved *
#
# New historical moving average record: 0.20384
#
# * Models saved *
#
# New historical moving average record: 0.20385
#
# * Models saved *
#
# New historical moving average record: 0.20391
#
# * Models saved *
#
# New historical moving average record: 0.20401
#
# * Models saved *
#
# New historical moving average record: 0.20418
#
# * Models saved *
#
# New historical moving average record: 0.20434
#
# * Models saved *
#
# New historical moving average record: 0.20435
#
# * Models saved *
#
# New historical moving average record: 0.20445
#
# * Models saved *
#
# New historical moving average record: 0.20447
#
# * Models saved *
#
# New historical moving average record: 0.20455
#
# * Models saved *
#
# New historical moving average record: 0.20465
#
# * Models saved *
#
# New historical moving average record: 0.20476
#
# * Models saved *
#
# New historical moving average record: 0.20478
#
# * Models saved *
#
# New historical moving average record: 0.20487
#
# * Models saved *
#
# New historical moving average record: 0.20500
#
# * Models saved *
#
# New historical moving average record: 0.20506
#
# * Models saved *
#
# New historical moving average record: 0.20518
#
# * Models saved *
#
# New historical moving average record: 0.20519
#
# * Models saved *
#
# New historical moving average record: 0.20529
#
# * Models saved *
#
# New historical moving average record: 0.20542
#
# * Models saved *
#
# New historical moving average record: 0.20543
#
# * Models saved *
#
# New historical moving average record: 0.20547
#
# * Models saved *
#
# New historical moving average record: 0.20553
#
# * Models saved *
#
# New historical moving average record: 0.20554
#
# * Models saved *
#
# New historical moving average record: 0.20559
#
# * Models saved *
#
# New historical moving average record: 0.20568
#
# * Models saved *
#
# New historical moving average record: 0.20587
#
# * Models saved *
#
# New historical moving average record: 0.20589
#
# * Models saved *
#
# New historical moving average record: 0.20594
#
# Episode * 9900 * Worker * False * Moving Avg Reward is ==> 0.20604 * Last Reward was ==> 0.30337
# * Models saved *
#
# New historical moving average record: 0.20604
# * Models saved *
#
# New historical moving average record: 0.20613
#
# * Models saved *
#
# New historical moving average record: 0.20615
#
# * Models saved *
#
# New historical moving average record: 0.20618
#
# * Models saved *
#
# New historical moving average record: 0.20627
#
# * Models saved *
#
# New historical moving average record: 0.20648
#
# * Models saved *
#
# New historical moving average record: 0.20650
#
# * Models saved *
#
# New historical moving average record: 0.20652
#
# * Models saved *
#
# New historical moving average record: 0.20680
#
# * Models saved *
#
# New historical moving average record: 0.20685
#
# * Models saved *
#
# New historical moving average record: 0.20689
#
# * Models saved *
#
# New historical moving average record: 0.20710
#
# * Models saved *
#
# New historical moving average record: 0.20710
#
# * Models saved *
#
# New historical moving average record: 0.20716
#
# * Models saved *
#
# New historical moving average record: 0.20720
#
# * Models saved *
#
# New historical moving average record: 0.20723
#
# * Models saved *
#
# New historical moving average record: 0.20724
#
# * Models saved *
#
# New historical moving average record: 0.20732
#
# * Models saved *
#
# New historical moving average record: 0.20746
#
# * Models saved *
#
# New historical moving average record: 0.20754
#
# * Models saved *
#
# New historical moving average record: 0.20759
#
# Episode * 10000 * Worker * False * Moving Avg Reward is ==> 0.20757 * Last Reward was ==> 0.25676
# * Models saved *
#
# New historical moving average record: 0.20776
#
# * Models saved *
#
# New historical moving average record: 0.20779
#
# * Models saved *
#
# New historical moving average record: 0.20780
#
# * Models saved *
#
# New historical moving average record: 0.20798
#
# * Models saved *
#
# New historical moving average record: 0.20809
#
# * Models saved *
#
# New historical moving average record: 0.20811
#
# * Models saved *
#
# New historical moving average record: 0.20821
#
# * Models saved *
#
# New historical moving average record: 0.20827
#
# Episode * 10100 * Worker * False * Moving Avg Reward is ==> 0.20806 * Last Reward was ==> 0.18584
# * Models saved *
#
# New historical moving average record: 0.20837
#
# * Models saved *
#
# New historical moving average record: 0.20845
#
# * Models saved *
#
# New historical moving average record: 0.20851
#
# Episode * 10200 * Worker * False * Moving Avg Reward is ==> 0.20833 * Last Reward was ==> 0.21744
# * Models saved *
#
# New historical moving average record: 0.20854
#
# * Models saved *
#
# New historical moving average record: 0.20859
#
# * Models saved *
#
# New historical moving average record: 0.20862
#
# * Models saved *
#
# New historical moving average record: 0.20863
#
# * Models saved *
#
# New historical moving average record: 0.20868
#
# * Models saved *
#
# New historical moving average record: 0.20877
#
# * Models saved *
#
# New historical moving average record: 0.20902
#
# All episodes are returning positive profits.Agent solved environment at the episode 10274
# All episodes are returning positive profits.Agent solved environment at the episode 10274

# %% [markdown]
# ### Test the results
# * Runs a set of episodes with unseen data
# * Stores the results in a csv file for later consulting

# %%
success = 0
n_tests = 10000

scores = []
targets = []
portfolio_target_ratios = []
initial_investments = []

for i in trange(n_tests):
    state = agent.env.reset(visualize=False,mode="test")
    step = 0
    score = 0
    reward = 0
    done = False
    
    targets.append((agent.env.episode_target-agent.env.initial_investment)/agent.env.initial_investment)
    initial_investments.append(agent.env.initial_investment)

    while not done:
        agent.env.render()
        #state = np.expand_dims(state, axis=0)
        action, action_onehot, prediction = agent.act(state)
        # Retrieve new state, reward, and whether the state is terminal
        next_state, reward, done, info = agent.env.step(action)
        #print(action, reward, agent.env.portfolio_value)
        # Memorize (state, action, reward) for training
        #self.buffer.remember(np.expand_dims(state, axis=0), action_onehot, reward)
        # Update current state
        if done :
            if agent.env.portfolio_value > agent.env.initial_investment:
                success +=1

        step+=1
        state = next_state
        score += reward
    
    # Track scores and ratios
    scores.append(score)
    portfolio_target_ratios.append(info["portfolio_value"]/info["episode_target"] -1)
    
    
test_results_dataframe = pd.DataFrame([[
    n_tests,
    str(round(np.mean(scores)*100,3))+'%',
    str(round(np.mean(targets)*100,3))+'%',
    str(round(np.mean(portfolio_target_ratios)*100,3))+'%',
    str(round(min(scores)*100,3))+'%',
    str(round(max(scores)*100,3))+'%',
    str(round((success/n_tests)*100,3)) +'%'
]],
    columns=[
        '# Blind tests',
        '% Average portfolio return', 
        '% Desired portfolio return', 
        'Portfolio/Target rate',
        '% Historical minimum return',
        '% Historical maximum return', 
        '% Episodes concluded with positive outcome'
    ]
)



test_results_dataframe.T
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
agent.results_writer.store_test_results(agent,test_results_dataframe)

# %% [markdown]
# ### Visual test
# * Runs a set of episodes with unseen data
# * See the evolution in real time

# %%
success = 0
n_tests = 2

scores = []
targets = []


for i in trange(n_tests):
    state = agent.env.reset(visualize=True,mode="test")
    step = 0
    score = 0
    reward = 0
    done = False
    targets.append((agent.env.episode_target-agent.env.initial_investment)/agent.env.initial_investment)
    initial_portfolio = agent.env.portfolio_value

    while not done:
        agent.env.render()
        #state = np.expand_dims(state, axis=0)
        action, action_onehot, prediction = agent.act(state)
        # Retrieve new state, reward, and whether the state is terminal
        next_state, reward, done, _ = agent.env.step(action)
        #print(action, reward, agent.env.portfolio_value)
        # Memorize (state, action, reward) for training
        #self.buffer.remember(np.expand_dims(state, axis=0), action_onehot, reward)
        # Update current state
        if done :
            if agent.env.portfolio_value > agent.env.initial_investment:
                success +=1

        step+=1
        state = next_state
        score += reward
    
    #print(score,initial_portfolio, agent.env.portfolio_value)
    scores.append(score)

agent.env.close()
