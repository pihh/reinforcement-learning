# %%
import shutup
shutup.please()

import gym
import src.environments.continuous.stock_trading  

import numpy as np
import pandas as pd 

from tqdm.notebook import trange, tqdm

# %%
env = gym.make('StockTradingEnvironment-v0', use_technical_indicators= [
    "macd",
    "boll_ub",
    "boll_lb",
    "rsi_30",
    "cci_30",
    "dx_30",
    "close_30_sma",
    "close_60_sma",
])

# %%
from src.agents.actor_critic.a2c import A2CAgent

# %%
def environment():
    env = gym.make('StockTradingEnvironment-v0',
                   use_technical_indicators= [
        "macd",
        "boll_ub",
        "boll_lb",
        "rsi_30",
        "cci_30",
        "dx_30",
        "close_30_sma",
        "close_60_sma",
    ])
    
    env.success_threshold =0.25 # 5%
    return env

# %%
agent=A2CAgent(environment, epochs=1, actor_learning_rate=0.000025,critic_learning_rate=0.000025,policy="CNN")
agent.load()
environment().success_threshold
# Out:
# * Models successfully loaded *
# 0.1

# %%
agent.hash
# Out:
# 'ed75666dd5e47547b3de000d534a9270'

# %%
agent.env.mode = "train"
agent.learning_log.episodes = 0
agent.learn(
    timesteps=-1, 
    log_every=100,
    success_threshold_lookback=1000,
    success_strict=True,
)
# Out:
# Episode * 100 * Worker * False * Moving Avg Reward is ==> 0.09500 * Last Reward was ==> 0.10003
# Episode * 200 * Worker * False * Moving Avg Reward is ==> 0.10298 * Last Reward was ==> 0.13642
# Episode * 300 * Worker * False * Moving Avg Reward is ==> 0.10887 * Last Reward was ==> 0.10106
# Episode * 400 * Worker * False * Moving Avg Reward is ==> 0.11054 * Last Reward was ==> 0.08282
# Episode * 500 * Worker * False * Moving Avg Reward is ==> 0.11119 * Last Reward was ==> 0.01286
# Episode * 600 * Worker * False * Moving Avg Reward is ==> 0.11180 * Last Reward was ==> 0.02853
# Episode * 700 * Worker * False * Moving Avg Reward is ==> 0.11410 * Last Reward was ==> 0.17304
# Episode * 800 * Worker * False * Moving Avg Reward is ==> 0.11530 * Last Reward was ==> 0.05952
# Episode * 900 * Worker * False * Moving Avg Reward is ==> 0.11649 * Last Reward was ==> 0.03653
# Episode * 1000 * Worker * False * Moving Avg Reward is ==> 0.11767 * Last Reward was ==> 0.13483
# * Models saved *
#
# New historical moving average record: 0.11767
#
# Agent solved environment at the episode 1000
# Agent solved environment at the episode 1000

# %%
success = 0
n_tests = 10000

scores = []
targets = []

for i in trange(n_tests):
    state = agent.env.reset(visualize=False,mode="test")
    step = 0
    score = 0
    reward = 0
    done = False
    targets.append((agent.env.episode_target-agent.env.initial_investment)/agent.env.initial_investment)

    while not done:
        agent.env.render()
        #state = np.expand_dims(state, axis=0)
        action, action_onehot, prediction = agent.act(state)
        # Retrieve new state, reward, and whether the state is terminal
        next_state, reward, done, _ = agent.env.step(action)
        #print(action, reward, agent.env.portfolio_value)
        # Memorize (state, action, reward) for training
        #self.buffer.remember(np.expand_dims(state, axis=0), action_onehot, reward)
        # Update current state
        if done :
            if agent.env.portfolio_value > agent.env.initial_investment:
                success +=1

        step+=1
        state = next_state
        score += reward
    
    #print(score,initial_portfolio, agent.env.portfolio_value)
    scores.append(score)
    
test_results_dataframe = pd.DataFrame([[
    n_tests,
    str(np.mean(scores)*100)+'%',
    str(np.mean(targets)*100)+'%',
    str(min(scores)*100)+'%',
    str(max(scores)*100)+'%',
    str((success/n_tests)*100) +'%'
]],
    columns=[
        '# Blind tests',
        '% Average portfolio return', 
        '% Desired portfolio return', 
        '% Historical minimum return',
        '% Historical maximum return', 
        '% Episode concluded with positive outcome'
    ]
)

# print(np.mean(scores))
# print(min(scores))
# print(max(scores))
# print(success)

test_results_dataframe.T
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [8], in <cell line: 7>()
#      18 action, action_onehot, prediction = agent.act(state)
#      19 # Retrieve new state, reward, and whether the state is terminal
# ---> 20 next_state, reward, done, _ = agent.env.step(action)
#      21 #print(action, reward, agent.env.portfolio_value)
#      22 # Memorize (state, action, reward) for training
#      23 #self.buffer.remember(np.expand_dims(state, axis=0), action_onehot, reward)
#      24 # Update current state
#      25 if done :
#
# File ~\anaconda3\envs\ai_4\lib\site-packages\gym\wrappers\order_enforcing.py:13, in OrderEnforcing.step(self, action)
#      11 def step(self, action):
#      12     assert self._has_reset, "Cannot call env.step() before calling reset()"
# ---> 13     observation, reward, done, info = self.env.step(action)
#      14     return observation, reward, done, info
#
# File ~\Development\GIT\tmp\reinforcement-learning\src\environments\continuous\stock_trading\v0.py:740, in StockTradingEnvironment.step(self, action)
#     728     pass
#     730 #if done and self.current_step < self.window_size -1:
#     731
#     732 # if self.current_step == self.window_size -1:
#    (...)
#     738
#     739 # Get the next state
# --> 740 self._next_state()
#     742 # Update stepper
#     743 self.episode_step += 1
#
# File ~\Development\GIT\tmp\reinforcement-learning\src\environments\continuous\stock_trading\v0.py:582, in StockTradingEnvironment._next_state(self)
#     571 self.market_history.append(self.df_norm.iloc[i])
#     573 # # News history tracks news
#     574 # self.news_history.append(self.df_normalized.loc[i][self.news_history_params])
#     575
#    (...)
#     580 # self.state = self._state()
#     581 # return self.state
# --> 582 self._state()
#
# File ~\Development\GIT\tmp\reinforcement-learning\src\environments\continuous\stock_trading\v0.py:549, in StockTradingEnvironment._state(self)
#     547 def _state(self):
#     548     #return np.concatenate((self.orders_history,self.portfolio_history, self.market_history,self.news_history,self.indicators_history), axis=1)
# --> 549     state = np.concatenate((
#     550         self.orders_history,
#     551         self.portfolio_history,
#     552         self.market_history)
#     553         ,axis=1)
#     555     self.state = state
#
# File <__array_function__ internals>:180, in concatenate(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
agent.results_writer.store_test_results(agent,test_results_dataframe)

# %%
# from datetime import datetime

# test_results_dataframe.to_csv(agent.writer_log_directory+'/results__'+datetime.now().strftime("%Y%m%d-%H%M%S")+'.csv')

# %%
success = 0
n_tests = 2

scores = []
targets = []


for i in trange(n_tests):
    state = agent.env.reset(visualize=True,mode="test")
    step = 0
    score = 0
    reward = 0
    done = False
    targets.append((agent.env.episode_target-agent.env.initial_investment)/agent.env.initial_investment)
    initial_portfolio = agent.env.portfolio_value

    while not done:
        agent.env.render()
        #state = np.expand_dims(state, axis=0)
        action, action_onehot, prediction = agent.act(state)
        # Retrieve new state, reward, and whether the state is terminal
        next_state, reward, done, _ = agent.env.step(action)
        #print(action, reward, agent.env.portfolio_value)
        # Memorize (state, action, reward) for training
        #self.buffer.remember(np.expand_dims(state, axis=0), action_onehot, reward)
        # Update current state
        if done :
            if agent.env.portfolio_value > agent.env.initial_investment:
                success +=1

        step+=1
        state = next_state
        score += reward
    
    #print(score,initial_portfolio, agent.env.portfolio_value)
    scores.append(score)

agent.env.close()
