# %%
import shutup
shutup.please()

import gym
import src.environments.continuous.stock_trading

# %%
env = gym.make('StockTradingEnvironment-v0', use_technical_indicators= [
    "macd",
    "boll_ub",
    "boll_lb",
    "rsi_30",
    "cci_30",
    "dx_30",
    "close_30_sma",
    "close_60_sma",
])

# %%
env.train_dataframe_id_range,env.test_dataframe_id_range
# Out:
# ([0, 315], [316, 395])

# %%
state = env.reset()

# %%
state[-1]
# Out:
# array([0, 0, 0, 1, 1, 0, 1, -0.0040013543984981, -0.0093431998768237,
#        -0.0106915254585928, 0.0135235442811936, 0.90477903826617, 'aapl',
#        0.0, 0.1889999961853027, 0.053274611978171, -14121.237147626907,
#        4059.085734839907, 2994.391713029398, 0.3629973452186618,
#        -0.6282169505814849, 0.6099054425688929, 3653.449072577907,
#        3815.733795548032, 0.0, 1.0, 0.0, 0.0, 0.045, 0.887, 0.0675,
#        0.3967, 0.5033333333333334, 0.17], dtype=object)

# %%
next_state = env.step([1])
next_state[0][-1]

# %%
next_state = env.step([1])
