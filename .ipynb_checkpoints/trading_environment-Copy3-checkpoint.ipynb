# %%
import shutup
shutup.please()

import gym
import src.environments.continuous.stock_trading  

import numpy as np
import pandas as pd

# %%
env = gym.make('StockTradingEnvironment-v0', use_technical_indicators= [
    "macd",
    "boll_ub",
    "boll_lb",
    "rsi_30",
    "cci_30",
    "dx_30",
    "close_30_sma",
    "close_60_sma",
])

# %%
pd.read_csv('src/environments/continuous/stock_trading/datasets/67b906a1ca1d5e7e03dd20f0c89fd03c/targets.csv').targets.iloc[0]
# Out:
# 7.01746749877929

# %%
env.train_dataframe_id_range,env.test_dataframe_id_range
# Out:
# ([0, 315], [316, 395])

# %%
env.load_dataset_by_index(0)
env.df
# Out:
#                  open       high        low      close     volume  day  \
# date
# 2018-01-08  43.587502  43.902500  43.482498  41.573772   82271200    0
# 2018-01-09  43.637501  43.764999  43.352501  41.569000   86336000    1
# 2018-01-11  43.647499  43.872501  43.622501  41.795528   74670800    3
# 2018-01-12  44.044998  44.340000  43.912498  42.227123  101672400    4
# 2018-01-16  44.474998  44.847500  44.035000  42.012512  118263600    1
# ...               ...        ...        ...        ...        ...  ...
# 2018-04-30  40.532501  41.814999  40.459999  39.566917  169709600    0
# 2018-05-01  41.602501  42.299999  41.317501  40.486298  214277600    1
# 2018-05-02  43.807499  44.437500  43.450001  42.274780  266157600    2
# 2018-05-03  43.970001  44.375000  43.610001  42.351402  136272800    3
# 2018-05-04  44.562500  46.062500  44.542500  44.012989  224805200    4
#
#                vix  turbulence      macd    boll_ub  ...  neg_title  \
# date                                                 ...
# 2018-01-08  0.0952    0.061082 -0.003477  41.870444  ...   0.000000
# 2018-01-09  0.1008    0.060920 -0.004579  41.805620  ...   0.000000
# 2018-01-11  0.0988    0.061166  0.003795  41.864027  ...   0.244000
# 2018-01-12  0.1016    0.071771  0.027654  42.256032  ...   0.000000
# 2018-01-16  0.1166    0.177656  0.032756  42.292433  ...   0.000000
# ...            ...         ...       ...        ...  ...        ...
# 2018-04-30  0.1593    0.219233 -0.531165  43.128501  ...   0.000000
# 2018-05-01  0.1549    0.087350 -0.454444  43.132534  ...   0.000000
# 2018-05-02  0.1597    0.129608 -0.246744  43.287283  ...   0.040364
# 2018-05-03  0.1590    0.045915 -0.075106  43.422290  ...   0.080706
# 2018-05-04  0.1477    0.068189  0.192563  43.958449  ...   0.092333
#
#             neu_title  pos_title  compound_title  neg_body  neu_body  \
# date
# 2018-01-08   1.000000   0.000000        0.000000  0.008000  0.934000
# 2018-01-09   0.946800   0.053200        0.088080  0.026400  0.919000
# 2018-01-11   0.756000   0.000000       -0.296525  0.041000  0.863750
# 2018-01-12   1.000000   0.000000        0.000000  0.126000  0.874000
# 2018-01-16   0.931667   0.068333        0.067433  0.030000  0.849333
# ...               ...        ...             ...       ...       ...
# 2018-04-30   1.000000   0.000000        0.000000  0.022500  0.877500
# 2018-05-01   1.000000   0.000000        0.000000  0.000000  0.962000
# 2018-05-02   0.826455   0.133182        0.110127  0.063545  0.853364
# 2018-05-03   0.836706   0.082588        0.003965  0.077765  0.838176
# 2018-05-04   0.907667   0.000000       -0.116867  0.066333  0.829000
#
#             pos_body  compound_body      aapl  fear greed
# date
# 2018-01-08  0.058000       0.963700  0.395833        0.75
# 2018-01-09  0.055000       0.684980  0.397083        0.75
# 2018-01-11  0.095250       0.636025  0.379167        0.77
# 2018-01-12  0.000000      -0.893400  0.371667        0.79
# 2018-01-16  0.120667       0.729800  0.378333        0.75
# ...              ...            ...       ...         ...
# 2018-04-30  0.100500       0.939450  0.418333        0.42
# 2018-05-01  0.038000       0.381800  0.450417        0.38
# 2018-05-02  0.083091       0.339791  0.431250        0.39
# 2018-05-03  0.084235       0.158376  0.411667        0.32
# 2018-05-04  0.104333      -0.184567  0.415833        0.40
#
# [76 rows x 26 columns]

# %%
env.success_threshold
# Out:
# 0.029911279488266853

# %%
import pandas as pd
episode_targets = []
for i in range(env.n_dataframes):
    env.load_dataset_by_index(i)
    raw_slice = env.df 
    episode_targets.append([
                    env.get_episode_target(raw_slice),
                    raw_slice.iloc[env.lookback-1].open,
                    raw_slice.iloc[env.lookback-1].low,
                    raw_slice.iloc[env.lookback-1].high,
                    raw_slice.iloc[env.lookback-1].close,
                    raw_slice.iloc[env.lookback-1].volume,
                ])




pd.DataFrame(episode_targets,columns=['targets','open','low','high','close','volume']).to_csv(env.df_path+'/targets.csv', index=False)

# %%
episode_columns = ['targets','close','open','high','low','volume']

#pd.DataFrame([[1,2],[1,2]],columns=['a','b'])
#np.array(episode_targets).shape ,=['targets','close','open','high','low','volume']).
pd.DataFrame(episode_targets,columns=episode_columns)
# Out:
#        targets      close       open       high        low       volume
# 0     7.017467  44.325001  44.205002  44.860001  42.215191  130756400.0
# 1     7.335903  44.312500  43.299999  44.325001  41.542770  204420400.0
# 2     7.548981  43.627499  42.632500  43.737499  40.801189  166116000.0
# 3     7.862625  42.540001  41.767502  42.540001  40.050072  202561600.0
# 4     8.504280  41.382500  41.174999  41.842499  39.814007  184192800.0
# ..         ...        ...        ...        ...        ...          ...
# 390  19.386944  54.432499  54.389999  55.032501  53.860348   84632400.0
# 391  19.453281  54.990002  54.779999  55.205002  54.056297   73274800.0
# 392  19.984016  55.264999  54.860001  55.712502  54.563301  101360000.0
# 393  18.982254  55.502499  55.092499  55.939999  54.119972   88242400.0
# 394  19.159805  55.345001  54.367500  55.639999  53.328846  221652400.0
#
# [395 rows x 6 columns]

# %%
state = env.reset()

# %%
state
# Out:
# array([[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          1.00000000e+00,  1.00000000e+00,  0.00000000e+00,
#          1.00000000e+00,  1.52385764e-02, -2.27076613e-03,
#         -3.09399628e-02, -1.87701579e-02, -2.79929071e-02,
#          0.00000000e+00,  2.47000008e-01,  1.50728053e-01,
#         -8.89224214e+02, -2.97667223e+03, -2.70287454e+03,
#          4.78589161e-01, -6.99975520e-01,  3.75323863e-01,
#         -2.84218697e+03, -2.81702353e+03,  4.48750000e-02,
#          8.64250000e-01,  9.08750000e-02,  3.68375000e-02,
#          5.21250000e-02,  8.69625000e-01,  7.81250000e-02,
#          3.62050000e-01,  4.32916667e-01,  7.00000000e-02],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          1.00000000e+00,  1.00000000e+00,  0.00000000e+00,
#          1.00000000e+00, -8.31387057e-03, -5.37538357e-03,
#         -1.88235379e-02, -1.59235437e-02,  5.82888417e-01,
#          1.00000000e+00,  2.41599998e-01,  9.75490863e-02,
#         -7.46769833e+02, -3.51269208e+03, -3.20492400e+03,
#          5.01058756e-01, -4.36152617e-01,  2.53728742e-01,
#         -3.35312555e+03, -3.31935974e+03,  9.24000000e-02,
#          9.07600000e-01,  0.00000000e+00, -1.29720000e-01,
#          6.46000000e-02,  8.53000000e-01,  8.24000000e-02,
#          2.38200000e-01,  4.17916667e-01,  7.00000000e-02],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          1.00000000e+00,  1.00000000e+00,  0.00000000e+00,
#          1.00000000e+00, -2.19676516e-02, -1.27101231e-02,
#          1.03011410e-02,  2.18980437e-02, -2.70484172e-01,
#          7.50000000e-01,  2.42199993e-01,  1.10707856e-01,
#         -2.67152618e+02,  2.55740741e+03,  2.33782141e+03,
#          5.21460804e-01, -2.08802636e-01,  1.58742470e-01,
#          2.44105185e+03,  2.41196157e+03,  1.36200000e-01,
#          7.11200000e-01,  1.52700000e-01, -2.08000000e-03,
#          5.65000000e-02,  8.43100000e-01,  1.00500000e-01,
#          3.87790000e-01,  4.01250000e-01,  9.00000000e-02],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          1.00000000e+00,  1.00000000e+00,  0.00000000e+00,
#          1.00000000e+00,  3.13672993e-02,  4.38967851e-03,
#         -7.45242964e-04, -3.43017421e-02,  5.56570143e-02,
#          5.00000000e-01,  2.52299995e-01,  1.89341026e-01,
#         -1.13906576e+02, -1.63446205e+03, -1.49424628e+03,
#          4.94695444e-01, -3.27898967e-01,  1.58742470e-01,
#         -1.55990333e+03, -1.53755592e+03,  9.28000000e-02,
#          7.91000000e-01,  1.16200000e-01,  6.13400000e-02,
#          2.40000000e-02,  8.93200000e-01,  8.28000000e-02,
#          8.24860000e-01,  4.07083333e-01,  6.00000000e-02],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          1.00000000e+00,  1.00000000e+00,  0.00000000e+00,
#          1.00000000e+00, -1.80171599e-02, -4.92481241e-04,
#         -1.93660612e-02,  9.42681993e-03,  3.46473512e-01,
#          2.50000000e-01,  2.07099991e-01,  2.43503383e-01,
#         -2.69628090e+02,  5.93979907e+03,  5.45839259e+03,
#          5.42251099e-01, -1.61813241e-01,  1.90596558e-01,
#          5.68118194e+03,  5.58390661e+03,  1.32166667e-01,
#          8.30666667e-01,  3.71666667e-02, -1.54350000e-01,
#          6.58333333e-02,  8.71000000e-01,  6.26666667e-02,
#         -1.51150000e-01,  4.19583333e-01,  1.20000000e-01],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          1.00000000e+00,  1.00000000e+00,  0.00000000e+00,
#          1.00000000e+00,  7.93357675e-03,  9.49112427e-03,
#          6.94480898e-03,  6.10985890e-03, -1.29587922e-01,
#          0.00000000e+00,  1.96399994e-01,  6.79492373e-02,
#         -1.89524841e+03,  9.16350229e+03,  8.42048437e+03,
#          5.30369596e-01, -9.95666166e-02,  8.92639219e-02,
#          8.76689373e+03,  8.59330550e+03,  0.00000000e+00,
#          8.42000000e-01,  1.58000000e-01,  2.32633333e-01,
#          3.63333333e-02,  8.93333333e-01,  7.00000000e-02,
#          8.44033333e-01,  4.10416667e-01,  1.60000000e-01],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          1.00000000e+00,  1.00000000e+00,  0.00000000e+00,
#          1.00000000e+00,  9.18006737e-04,  6.91721569e-03,
#          2.07980877e-02,  1.52301576e-02,  1.52664258e-02,
#          1.00000000e+00,  1.98899994e-01,  4.01853673e-01,
#         -3.37829378e+02,  3.67611951e+03,  3.37824317e+03,
#          5.22653906e-01, -2.31620548e-01,  1.56338791e-01,
#          3.51577663e+03,  3.43935597e+03,  0.00000000e+00,
#          9.20333333e-01,  7.96666667e-02,  9.86666667e-02,
#          3.96666667e-02,  8.65666667e-01,  9.46666667e-02,
#          7.23266667e-01,  4.62083333e-01,  1.40000000e-01],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          1.00000000e+00,  1.00000000e+00,  0.00000000e+00,
#          1.00000000e+00, -1.99730202e-02, -1.30254847e-02,
#         -2.89048803e-02, -2.33736497e-02,  4.23671861e-01,
#          7.50000000e-01,  2.00599995e-01,  4.98579657e-02,
#         -9.89004090e+01, -2.39607904e+03, -2.19880711e+03,
#          5.03284712e-01, -5.09442717e-01,  2.06649936e-01,
#         -2.29154760e+03, -2.23663436e+03,  0.00000000e+00,
#          1.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          4.40000000e-02,  9.11500000e-01,  4.45000000e-02,
#         -1.13550000e-01,  4.33333333e-01,  1.20000000e-01],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          1.00000000e+00,  1.00000000e+00,  0.00000000e+00,
#          1.00000000e+00,  1.53930959e-02, -1.56960444e-03,
#          1.19025738e-02, -4.32133023e-03, -2.15823739e-01,
#          5.00000000e-01,  1.73999996e-01,  2.68908846e-01,
#          3.13818519e+03, -1.29475427e+04, -1.19281252e+04,
#          5.36343882e-01, -1.23078806e-01,  4.44199888e-02,
#         -1.24079273e+04, -1.20773809e+04,  3.50000000e-02,
#          9.15600000e-01,  4.94000000e-02,  1.80400000e-02,
#          6.42000000e-02,  8.63600000e-01,  7.18000000e-02,
#          2.57060000e-01,  4.31250000e-01,  1.40000000e-01],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          1.00000000e+00,  1.00000000e+00,  0.00000000e+00,
#          1.00000000e+00, -1.00832472e-02,  5.22924606e-03,
#         -2.34735470e-03,  2.20371769e-02, -5.21905752e-02,
#          2.50000000e-01,  1.76200008e-01,  6.60476865e-02,
#          1.53509477e+02,  2.53948521e+03,  2.33536608e+03,
#          5.42743011e-01, -1.72531819e-01,  4.44199888e-02,
#          2.43517654e+03,  2.36302144e+03,  0.00000000e+00,
#          8.33000000e-01,  1.67000000e-01,  2.92125000e-01,
#          3.76250000e-02,  8.68000000e-01,  9.43750000e-02,
#          6.86250000e-01,  4.47083333e-01,  1.30000000e-01]])

# %%
next_state = env.step([1])
next_state
# Out:
# (array([[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           1.00000000e+00,  1.00000000e+00,  0.00000000e+00,
#           1.00000000e+00, -8.31387057e-03, -5.37538357e-03,
#          -1.88235379e-02, -1.59235437e-02,  5.82888417e-01,
#           1.00000000e+00,  2.41599998e-01,  9.75490863e-02,
#          -7.46769833e+02, -3.51269208e+03, -3.20492400e+03,
#           5.01058756e-01, -4.36152617e-01,  2.53728742e-01,
#          -3.35312555e+03, -3.31935974e+03,  9.24000000e-02,
#           9.07600000e-01,  0.00000000e+00, -1.29720000e-01,
#           6.46000000e-02,  8.53000000e-01,  8.24000000e-02,
#           2.38200000e-01,  4.17916667e-01,  7.00000000e-02],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           1.00000000e+00,  1.00000000e+00,  0.00000000e+00,
#           1.00000000e+00, -2.19676516e-02, -1.27101231e-02,
#           1.03011410e-02,  2.18980437e-02, -2.70484172e-01,
#           7.50000000e-01,  2.42199993e-01,  1.10707856e-01,
#          -2.67152618e+02,  2.55740741e+03,  2.33782141e+03,
#           5.21460804e-01, -2.08802636e-01,  1.58742470e-01,
#           2.44105185e+03,  2.41196157e+03,  1.36200000e-01,
#           7.11200000e-01,  1.52700000e-01, -2.08000000e-03,
#           5.65000000e-02,  8.43100000e-01,  1.00500000e-01,
#           3.87790000e-01,  4.01250000e-01,  9.00000000e-02],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           1.00000000e+00,  1.00000000e+00,  0.00000000e+00,
#           1.00000000e+00,  3.13672993e-02,  4.38967851e-03,
#          -7.45242964e-04, -3.43017421e-02,  5.56570143e-02,
#           5.00000000e-01,  2.52299995e-01,  1.89341026e-01,
#          -1.13906576e+02, -1.63446205e+03, -1.49424628e+03,
#           4.94695444e-01, -3.27898967e-01,  1.58742470e-01,
#          -1.55990333e+03, -1.53755592e+03,  9.28000000e-02,
#           7.91000000e-01,  1.16200000e-01,  6.13400000e-02,
#           2.40000000e-02,  8.93200000e-01,  8.28000000e-02,
#           8.24860000e-01,  4.07083333e-01,  6.00000000e-02],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           1.00000000e+00,  1.00000000e+00,  0.00000000e+00,
#           1.00000000e+00, -1.80171599e-02, -4.92481241e-04,
#          -1.93660612e-02,  9.42681993e-03,  3.46473512e-01,
#           2.50000000e-01,  2.07099991e-01,  2.43503383e-01,
#          -2.69628090e+02,  5.93979907e+03,  5.45839259e+03,
#           5.42251099e-01, -1.61813241e-01,  1.90596558e-01,
#           5.68118194e+03,  5.58390661e+03,  1.32166667e-01,
#           8.30666667e-01,  3.71666667e-02, -1.54350000e-01,
#           6.58333333e-02,  8.71000000e-01,  6.26666667e-02,
#          -1.51150000e-01,  4.19583333e-01,  1.20000000e-01],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           1.00000000e+00,  1.00000000e+00,  0.00000000e+00,
#           1.00000000e+00,  7.93357675e-03,  9.49112427e-03,
#           6.94480898e-03,  6.10985890e-03, -1.29587922e-01,
#           0.00000000e+00,  1.96399994e-01,  6.79492373e-02,
#          -1.89524841e+03,  9.16350229e+03,  8.42048437e+03,
#           5.30369596e-01, -9.95666166e-02,  8.92639219e-02,
#           8.76689373e+03,  8.59330550e+03,  0.00000000e+00,
#           8.42000000e-01,  1.58000000e-01,  2.32633333e-01,
#           3.63333333e-02,  8.93333333e-01,  7.00000000e-02,
#           8.44033333e-01,  4.10416667e-01,  1.60000000e-01],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           1.00000000e+00,  1.00000000e+00,  0.00000000e+00,
#           1.00000000e+00,  9.18006737e-04,  6.91721569e-03,
#           2.07980877e-02,  1.52301576e-02,  1.52664258e-02,
#           1.00000000e+00,  1.98899994e-01,  4.01853673e-01,
#          -3.37829378e+02,  3.67611951e+03,  3.37824317e+03,
#           5.22653906e-01, -2.31620548e-01,  1.56338791e-01,
#           3.51577663e+03,  3.43935597e+03,  0.00000000e+00,
#           9.20333333e-01,  7.96666667e-02,  9.86666667e-02,
#           3.96666667e-02,  8.65666667e-01,  9.46666667e-02,
#           7.23266667e-01,  4.62083333e-01,  1.40000000e-01],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           1.00000000e+00,  1.00000000e+00,  0.00000000e+00,
#           1.00000000e+00, -1.99730202e-02, -1.30254847e-02,
#          -2.89048803e-02, -2.33736497e-02,  4.23671861e-01,
#           7.50000000e-01,  2.00599995e-01,  4.98579657e-02,
#          -9.89004090e+01, -2.39607904e+03, -2.19880711e+03,
#           5.03284712e-01, -5.09442717e-01,  2.06649936e-01,
#          -2.29154760e+03, -2.23663436e+03,  0.00000000e+00,
#           1.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           4.40000000e-02,  9.11500000e-01,  4.45000000e-02,
#          -1.13550000e-01,  4.33333333e-01,  1.20000000e-01],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           1.00000000e+00,  1.00000000e+00,  0.00000000e+00,
#           1.00000000e+00,  1.53930959e-02, -1.56960444e-03,
#           1.19025738e-02, -4.32133023e-03, -2.15823739e-01,
#           5.00000000e-01,  1.73999996e-01,  2.68908846e-01,
#           3.13818519e+03, -1.29475427e+04, -1.19281252e+04,
#           5.36343882e-01, -1.23078806e-01,  4.44199888e-02,
#          -1.24079273e+04, -1.20773809e+04,  3.50000000e-02,
#           9.15600000e-01,  4.94000000e-02,  1.80400000e-02,
#           6.42000000e-02,  8.63600000e-01,  7.18000000e-02,
#           2.57060000e-01,  4.31250000e-01,  1.40000000e-01],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           1.00000000e+00,  1.00000000e+00,  0.00000000e+00,
#           1.00000000e+00, -1.00832472e-02,  5.22924606e-03,
#          -2.34735470e-03,  2.20371769e-02, -5.21905752e-02,
#           2.50000000e-01,  1.76200008e-01,  6.60476865e-02,
#           1.53509477e+02,  2.53948521e+03,  2.33536608e+03,
#           5.42743011e-01, -1.72531819e-01,  4.44199888e-02,
#           2.43517654e+03,  2.36302144e+03,  0.00000000e+00,
#           8.33000000e-01,  1.67000000e-01,  2.92125000e-01,
#           3.76250000e-02,  8.68000000e-01,  9.43750000e-02,
#           6.86250000e-01,  4.47083333e-01,  1.30000000e-01],
#         [ 1.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           1.00000000e+00,  1.00000000e+00,  0.00000000e+00,
#           1.00000000e+00,  1.52385764e-02, -2.27076613e-03,
#          -3.09399628e-02, -1.87701579e-02, -2.79929071e-02,
#           0.00000000e+00,  2.47000008e-01,  1.50728053e-01,
#          -8.89224214e+02, -2.97667223e+03, -2.70287454e+03,
#           4.78589161e-01, -6.99975520e-01,  3.75323863e-01,
#          -2.84218697e+03, -2.81702353e+03,  4.48750000e-02,
#           8.64250000e-01,  9.08750000e-02,  3.68375000e-02,
#           5.21250000e-02,  8.69625000e-01,  7.81250000e-02,
#           3.62050000e-01,  4.32916667e-01,  7.00000000e-02]]),
#  0.0,
#  False,
#  {})

# %%
next_state[0][0] == state[1]
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True])

# %%
# env.reset()
# for i in range(100):
#     next_state, reward, done, _ = env.step(0)
#     print(i, reward,done)#,next_state[-1])
#     if done:
#         break

# %%
len(env.df),env.window_size, env.lookback, env.window_size+ env.lookback
# Out:
# (76, 66, 10, 76)

# %%
# prices = [5,2,1,7,0,6,3]

# """
# # mins = min de inicio até i inclusive 
#     0 - 5
#     1 - 2
#     2 - 2
#     3 - 2
# # maxs = max de i até fim inclusive
#     0 - 6
#     1 - 6
#     2 - 6
#     3 - 3
# """

# mins = [] #[5,2,2,2]
# maxs = [] #[6,6,6,3]

# ### MINS
# # i = 0 -> prices [0 -> 1] [0:1]
# # mins.append(min(prices[0:1]))
# ### MAXS
# # i = 0 -> prices[0:]
# # i = 1 -> prices[1:]
# # prices[3:]

# for i in range(len(prices)):
#     mins.append(min(prices[0:i+1]))
#     maxs.append(max(prices[i:]))
    
# #mins,maxs
# global_max_single_trade_profit = 0
# for i in range(len(prices)):
#     _min = mins[i]
#     _max = maxs[i]
    
#     print('At {} could have bought at {} and sold at {} so it had {} profit'.format(
#         i,
#         _min,
#         _max,
#         _max-_min
#     ))
#     local_max_single_trade_profit = _max-_min
#     if local_max_single_trade_profit > global_max_single_trade_profit:
#         global_max_single_trade_profit = local_max_single_trade_profit

# print()
# print('Best case scenario would have a profit of {}'.format(global_max_single_trade_profit))

# %%
# for i in range(len(prices)):
#     mins.append(min(prices[0:i+1]))
#     maxs.append(max(prices[i:]))
    
# #mins,maxs
# global_max_single_trade_profit = 0
# for i in range(len(prices)):
#     _min = mins[i]
#     _max = maxs[i]
    
#     print('At {} could have bought at {} and sold at {} so it had {} profit'.format(
#         i,
#         _min,
#         _max,
#         _max-_min
#     ))
#     local_max_single_trade_profit = _max-_min
#     if local_max_single_trade_profit > global_max_single_trade_profit:
#         global_max_single_trade_profit = local_max_single_trade_profit

# print()
# print('Best case scenario would have a profit of {}'.format(global_max_single_trade_profit))

# %%
# prices = env.df.close.values

# mins = [] 
# maxs = [] 

# for i in range(len(prices)):
#     mins.append(min(prices[0:i+1]))
#     maxs.append(max(prices[i:]))
# #     
# #mins,maxs
# global_max_single_trade_profit = 0
# for i in range(len(prices)):
#     _min = mins[i]
#     _max = maxs[i]
    
#     print('At {} could have bought at {} and sold at {} so it had {} profit'.format(
#         i,
#         _min,
#         _max,
#         _max-_min
#     ))
#     local_max_single_trade_profit = _max-_min
#     if local_max_single_trade_profit > global_max_single_trade_profit:
#         global_max_single_trade_profit = local_max_single_trade_profit

# print()
# print('Best case scenario would have a profit of {}'.format(global_max_single_trade_profit))

# %%
#prices * (0.5)
#env.fees['BUY']

# %%
# env.n_dataframes

# %%
# targets = []
# for i in range(env.n_dataframes):
#     env.load_dataset_by_index(i)
#     target = env.calculate_episode_target(env.df)
#     targets.append(target)
    
# targets

# %%
# import pandas as pd
# pd.DataFrame(targets,columns=['targets']).to_csv(env.df_path+'/targets.csv', index=False)

# %%
#pd.read_csv(env.df_path+'/targets.csv')

# %%
from src.agents.actor_critic.a2c import A2CAgent

# %%
def environment():
    env = gym.make('StockTradingEnvironment-v0',
                   use_technical_indicators= [
        "macd",
        "boll_ub",
        "boll_lb",
        "rsi_30",
        "cci_30",
        "dx_30",
        "close_30_sma",
        "close_60_sma",
    ])
    
    env.success_threshold =0.05 # 5%
    return env

# %%
agent=A2CAgent(environment, epochs=1, actor_learning_rate=0.000025,critic_learning_rate=0.000025)
agent.load()
environment().success_threshold
# Out:
# Failed to load weights.
# 0.05

# %%
agent.learning_log.episodes
# Out:
# 0

# %%
agent.env.mode = "train"
agent.learning_log.episodes = 0
agent.learn(
    timesteps=-1, 
    log_every=1000,
    success_threshold_lookback=1000,
    success_strict=True,
    
)
# Out:
# Episode * 1000 * Worker * False * Moving Avg Reward is ==> 0.01827 * Last Reward was ==> -0.01564
#
# New historical moving average record: 0.01827
# Saving models
#
#
# New historical moving average record: 0.01830
# Saving models
#
#
# New historical moving average record: 0.01833
# Saving models
#
#
# New historical moving average record: 0.01849
# Saving models
#
#
# New historical moving average record: 0.01854
# Saving models
#
#
# New historical moving average record: 0.01856
# Saving models
#
#
# New historical moving average record: 0.01859
# Saving models
#
#
# New historical moving average record: 0.01859
# Saving models
#
#
# New historical moving average record: 0.01862
# Saving models
#
#
# New historical moving average record: 0.01862
# Saving models
#
#
# New historical moving average record: 0.01865
# Saving models
#
#
# New historical moving average record: 0.01875
# Saving models
#
#
# New historical moving average record: 0.01876
# Saving models
#
#
# New historical moving average record: 0.01883
# Saving models
#
#
# New historical moving average record: 0.01885
# Saving models
#
#
# New historical moving average record: 0.01890
# Saving models
#
#
# New historical moving average record: 0.01893
# Saving models
#
#
# New historical moving average record: 0.01909
# Saving models
#
#
# New historical moving average record: 0.01925
# Saving models
#
#
# New historical moving average record: 0.01931
# Saving models
#
#
# New historical moving average record: 0.01942
# Saving models
#
#
# New historical moving average record: 0.01942
# Saving models
#
#
# New historical moving average record: 0.01943
# Saving models
#
#
# New historical moving average record: 0.01946
# Saving models
#
#
# New historical moving average record: 0.01951
# Saving models
#
#
# New historical moving average record: 0.01964
# Saving models
#
#
# New historical moving average record: 0.01978
# Saving models
#
#
# New historical moving average record: 0.01985
# Saving models
#
#
# New historical moving average record: 0.01985
# Saving models
#
#
# New historical moving average record: 0.01993
# Saving models
#
#
# New historical moving average record: 0.01995
# Saving models
#
#
# New historical moving average record: 0.02001
# Saving models
#
#
# New historical moving average record: 0.02002
# Saving models
#
#
# New historical moving average record: 0.02012
# Saving models
#
#
# New historical moving average record: 0.02015
# Saving models
#
#
# New historical moving average record: 0.02023
# Saving models
#
#
# New historical moving average record: 0.02036
# Saving models
#
#
# New historical moving average record: 0.02043
# Saving models
#
#
# New historical moving average record: 0.02052
# Saving models
#
#
# New historical moving average record: 0.02055
# Saving models
#
#
# New historical moving average record: 0.02063
# Saving models
#
#
# New historical moving average record: 0.02077
# Saving models
#
#
# New historical moving average record: 0.02080
# Saving models
#
#
# New historical moving average record: 0.02086
# Saving models
#
#
# New historical moving average record: 0.02089
# Saving models
#
#
# New historical moving average record: 0.02089
# Saving models
#
#
# New historical moving average record: 0.02091
# Saving models
#
#
# New historical moving average record: 0.02099
# Saving models
#
#
# New historical moving average record: 0.02099
# Saving models
#
#
# New historical moving average record: 0.02101
# Saving models
#
#
# New historical moving average record: 0.02109
# Saving models
#
#
# New historical moving average record: 0.02112
# Saving models
#
#
# New historical moving average record: 0.02116
# Saving models
#
#
# New historical moving average record: 0.02123
# Saving models
#
#
# New historical moving average record: 0.02127
# Saving models
#
#
# New historical moving average record: 0.02135
# Saving models
#
#
# New historical moving average record: 0.02139
# Saving models
#
#
# New historical moving average record: 0.02141
# Saving models
#
#
# New historical moving average record: 0.02142
# Saving models
#
#
# New historical moving average record: 0.02144
# Saving models
#
#
# New historical moving average record: 0.02148
# Saving models
#
#
# New historical moving average record: 0.02152
# Saving models
#
#
# New historical moving average record: 0.02161
# Saving models
#
#
# New historical moving average record: 0.02164
# Saving models
#
#
# New historical moving average record: 0.02164
# Saving models
#
#
# New historical moving average record: 0.02168
# Saving models
#
#
# New historical moving average record: 0.02174
# Saving models
#
#
# New historical moving average record: 0.02177
# Saving models
#
#
# New historical moving average record: 0.02179
# Saving models
#
#
# New historical moving average record: 0.02179
# Saving models
#
#
# New historical moving average record: 0.02183
# Saving models
#
#
# New historical moving average record: 0.02186
# Saving models
#
#
# New historical moving average record: 0.02208
# Saving models
#
#
# New historical moving average record: 0.02215
# Saving models
#
#
# New historical moving average record: 0.02223
# Saving models
#
#
# New historical moving average record: 0.02233
# Saving models
#
#
# New historical moving average record: 0.02239
# Saving models
#
#
# New historical moving average record: 0.02239
# Saving models
#
#
# New historical moving average record: 0.02245
# Saving models
#
#
# New historical moving average record: 0.02252
# Saving models
#
#
# New historical moving average record: 0.02256
# Saving models
#
#
# New historical moving average record: 0.02265
# Saving models
#
#
# New historical moving average record: 0.02266
# Saving models
#
#
# New historical moving average record: 0.02266
# Saving models
#
#
# New historical moving average record: 0.02267
# Saving models
#
#
# New historical moving average record: 0.02270
# Saving models
#
#
# New historical moving average record: 0.02273
# Saving models
#
#
# New historical moving average record: 0.02275
# Saving models
#
#
# New historical moving average record: 0.02278
# Saving models
#
#
# New historical moving average record: 0.02283
# Saving models
#
#
# New historical moving average record: 0.02286
# Saving models
#
#
# New historical moving average record: 0.02291
# Saving models
#
#
# New historical moving average record: 0.02292
# Saving models
#
#
# New historical moving average record: 0.02293
# Saving models
#
#
# New historical moving average record: 0.02296
# Saving models
#
#
# New historical moving average record: 0.02308
# Saving models
#
#
# New historical moving average record: 0.02312
# Saving models
#
#
# New historical moving average record: 0.02314
# Saving models
#
#
# New historical moving average record: 0.02315
# Saving models
#
#
# New historical moving average record: 0.02317
# Saving models
#
#
# New historical moving average record: 0.02322
# Saving models
#
#
# New historical moving average record: 0.02325
# Saving models
#
#
# New historical moving average record: 0.02340
# Saving models
#
#
# New historical moving average record: 0.02342
# Saving models
#
#
# New historical moving average record: 0.02350
# Saving models
#
#
# New historical moving average record: 0.02356
# Saving models
#
#
# New historical moving average record: 0.02359
# Saving models
#
#
# New historical moving average record: 0.02361
# Saving models
#
#
# New historical moving average record: 0.02361
# Saving models
#
#
# New historical moving average record: 0.02361
# Saving models
#
#
# New historical moving average record: 0.02364
# Saving models
#
#
# New historical moving average record: 0.02376
# Saving models
#
#
# New historical moving average record: 0.02392
# Saving models
#
#
# New historical moving average record: 0.02396
# Saving models
#
#
# New historical moving average record: 0.02405
# Saving models
#
#
# New historical moving average record: 0.02408
# Saving models
#
#
# New historical moving average record: 0.02414
# Saving models
#
#
# New historical moving average record: 0.02416
# Saving models
#
#
# New historical moving average record: 0.02419
# Saving models
#
#
# New historical moving average record: 0.02420
# Saving models
#
#
# New historical moving average record: 0.02421
# Saving models
#
#
# New historical moving average record: 0.02422
# Saving models
#
#
# New historical moving average record: 0.02425
# Saving models
#
#
# New historical moving average record: 0.02428
# Saving models
#
#
# New historical moving average record: 0.02431
# Saving models
#
#
# New historical moving average record: 0.02436
# Saving models
#
#
# New historical moving average record: 0.02436
# Saving models
#
#
# New historical moving average record: 0.02439
# Saving models
#
#
# New historical moving average record: 0.02441
# Saving models
#
#
# New historical moving average record: 0.02444
# Saving models
#
#
# New historical moving average record: 0.02453
# Saving models
# New historical moving average record: 0.02458
# Saving models
#
#
# New historical moving average record: 0.02459
# Saving models
#
#
# New historical moving average record: 0.02460
# Saving models
#
#
# New historical moving average record: 0.02468
# Saving models
#
#
# New historical moving average record: 0.02470
# Saving models
#
#
# New historical moving average record: 0.02471
# Saving models
#
#
# New historical moving average record: 0.02471
# Saving models
#
#
# New historical moving average record: 0.02473
# Saving models
#
#
# New historical moving average record: 0.02474
# Saving models
#
#
# New historical moving average record: 0.02478
# Saving models
#
#
# New historical moving average record: 0.02479
# Saving models
#
#
# New historical moving average record: 0.02482
# Saving models
#
#
# New historical moving average record: 0.02490
# Saving models
#
#
# New historical moving average record: 0.02494
# Saving models
#
#
# New historical moving average record: 0.02498
# Saving models
#
#
# New historical moving average record: 0.02507
# Saving models
#
#
# New historical moving average record: 0.02518
# Saving models
#
#
# New historical moving average record: 0.02520
# Saving models
#
#
# New historical moving average record: 0.02529
# Saving models
#
#
# New historical moving average record: 0.02532
# Saving models
#
#
# New historical moving average record: 0.02536
# Saving models
#
#
# New historical moving average record: 0.02536
# Saving models
#
#
# New historical moving average record: 0.02540
# Saving models
#
#
# New historical moving average record: 0.02542
# Saving models
#
#
# New historical moving average record: 0.02545
# Saving models
#
#
# New historical moving average record: 0.02559
# Saving models
#
#
# New historical moving average record: 0.02560
# Saving models
#
#
# New historical moving average record: 0.02567
# Saving models
#
#
# New historical moving average record: 0.02578
# Saving models
#
#
# New historical moving average record: 0.02590
# Saving models
#
#
# New historical moving average record: 0.02598
# Saving models
#
#
# New historical moving average record: 0.02602
# Saving models
#
#
# New historical moving average record: 0.02604
# Saving models
#
#
# New historical moving average record: 0.02604
# Saving models
#
#
# New historical moving average record: 0.02611
# Saving models
#
#
# New historical moving average record: 0.02616
# Saving models
#
#
# New historical moving average record: 0.02618
# Saving models
#
#
# New historical moving average record: 0.02622
# Saving models
#
#
# New historical moving average record: 0.02626
# Saving models
#
# Episode * 2000 * Worker * False * Moving Avg Reward is ==> 0.02603 * Last Reward was ==> -0.05233
#
# New historical moving average record: 0.02628
# Saving models
#
#
# New historical moving average record: 0.02632
# Saving models
#
#
# New historical moving average record: 0.02640
# Saving models
#
#
# New historical moving average record: 0.02651
# Saving models
#
#
# New historical moving average record: 0.02653
# Saving models
#
#
# New historical moving average record: 0.02656
# Saving models
#
#
# New historical moving average record: 0.02661
# Saving models
#
#
# New historical moving average record: 0.02668
# Saving models
#
#
# New historical moving average record: 0.02671
# Saving models
#
#
# New historical moving average record: 0.02671
# Saving models
#
#
# New historical moving average record: 0.02675
# Saving models
#
#
# New historical moving average record: 0.02690
# Saving models
#
#
# New historical moving average record: 0.02697
# Saving models
#
#
# New historical moving average record: 0.02700
# Saving models
#
#
# New historical moving average record: 0.02708
# Saving models
#
#
# New historical moving average record: 0.02716
# Saving models
#
#
# New historical moving average record: 0.02720
# Saving models
#
#
# New historical moving average record: 0.02732
# Saving models
#
#
# New historical moving average record: 0.02736
# Saving models
#
#
# New historical moving average record: 0.02738
# Saving models
#
#
# New historical moving average record: 0.02742
# Saving models
#
#
# New historical moving average record: 0.02743
# Saving models
#
#
# New historical moving average record: 0.02744
# Saving models
#
#
# New historical moving average record: 0.02749
# Saving models
#
# Episode * 3000 * Worker * False * Moving Avg Reward is ==> 0.01938 * Last Reward was ==> -0.07032
# Episode * 4000 * Worker * False * Moving Avg Reward is ==> 0.01559 * Last Reward was ==> 0.00233
# Episode * 5000 * Worker * False * Moving Avg Reward is ==> 0.01802 * Last Reward was ==> 0.06598
# Episode * 6000 * Worker * False * Moving Avg Reward is ==> 0.01690 * Last Reward was ==> 0.02743
# Episode * 7000 * Worker * False * Moving Avg Reward is ==> 0.01372 * Last Reward was ==> 0.02790
# Episode * 8000 * Worker * False * Moving Avg Reward is ==> 0.00596 * Last Reward was ==> 0.03856
# Episode * 9000 * Worker * False * Moving Avg Reward is ==> 0.00622 * Last Reward was ==> 0.00782
# Episode * 10000 * Worker * False * Moving Avg Reward is ==> 0.00429 * Last Reward was ==> 0.06960
# Episode * 11000 * Worker * False * Moving Avg Reward is ==> 0.00402 * Last Reward was ==> 0.03568
# Episode * 12000 * Worker * False * Moving Avg Reward is ==> 0.00155 * Last Reward was ==> 0.02451
# Episode * 13000 * Worker * False * Moving Avg Reward is ==> 0.00150 * Last Reward was ==> 0.12276
# Episode * 14000 * Worker * False * Moving Avg Reward is ==> 0.01342 * Last Reward was ==> 0.02181
# Episode * 15000 * Worker * False * Moving Avg Reward is ==> 0.00290 * Last Reward was ==> 0.02728
# Episode * 16000 * Worker * False * Moving Avg Reward is ==> 0.00920 * Last Reward was ==> 0.02509
# Episode * 17000 * Worker * False * Moving Avg Reward is ==> 0.00613 * Last Reward was ==> 0.01675
# Episode * 18000 * Worker * False * Moving Avg Reward is ==> 0.00814 * Last Reward was ==> 0.03917
# Episode * 19000 * Worker * False * Moving Avg Reward is ==> 0.00929 * Last Reward was ==> 0.07874
# Episode * 20000 * Worker * False * Moving Avg Reward is ==> 0.01065 * Last Reward was ==> -0.05120
# Episode * 21000 * Worker * False * Moving Avg Reward is ==> 0.00832 * Last Reward was ==> 0.15584
# Episode * 22000 * Worker * False * Moving Avg Reward is ==> 0.00489 * Last Reward was ==> -0.08191
# Episode * 23000 * Worker * False * Moving Avg Reward is ==> 0.00049 * Last Reward was ==> 0.00063
# Episode * 24000 * Worker * False * Moving Avg Reward is ==> 0.00364 * Last Reward was ==> 0.16578
# Episode * 25000 * Worker * False * Moving Avg Reward is ==> 0.00611 * Last Reward was ==> 0.07188
# Episode * 26000 * Worker * False * Moving Avg Reward is ==> 0.00269 * Last Reward was ==> 0.00310
# Episode * 27000 * Worker * False * Moving Avg Reward is ==> -0.00555 * Last Reward was ==> 0.00619
# Episode * 28000 * Worker * False * Moving Avg Reward is ==> 0.00658 * Last Reward was ==> 0.13197
# Episode * 29000 * Worker * False * Moving Avg Reward is ==> 0.00278 * Last Reward was ==> 0.04101
# Episode * 30000 * Worker * False * Moving Avg Reward is ==> 0.00265 * Last Reward was ==> -0.00333
# Episode * 31000 * Worker * False * Moving Avg Reward is ==> -0.00258 * Last Reward was ==> 0.01510
# Episode * 32000 * Worker * False * Moving Avg Reward is ==> 0.00178 * Last Reward was ==> 0.03396
# Episode * 33000 * Worker * False * Moving Avg Reward is ==> -0.01227 * Last Reward was ==> 0.09536
# Episode * 34000 * Worker * False * Moving Avg Reward is ==> -0.00446 * Last Reward was ==> 0.01774
# Episode * 35000 * Worker * False * Moving Avg Reward is ==> -0.00887 * Last Reward was ==> 0.02687
# Episode * 36000 * Worker * False * Moving Avg Reward is ==> -0.00590 * Last Reward was ==> 0.04385
# Episode * 37000 * Worker * False * Moving Avg Reward is ==> -0.00731 * Last Reward was ==> 0.03107
# Episode * 38000 * Worker * False * Moving Avg Reward is ==> -0.00647 * Last Reward was ==> 0.02619
# Episode * 39000 * Worker * False * Moving Avg Reward is ==> -0.00638 * Last Reward was ==> 0.02338
# Episode * 40000 * Worker * False * Moving Avg Reward is ==> -0.01177 * Last Reward was ==> -0.22336
# Episode * 41000 * Worker * False * Moving Avg Reward is ==> -0.00873 * Last Reward was ==> 0.05657
# Episode * 42000 * Worker * False * Moving Avg Reward is ==> -0.00540 * Last Reward was ==> -0.19578
# Episode * 43000 * Worker * False * Moving Avg Reward is ==> -0.00269 * Last Reward was ==> 0.01732
# Episode * 44000 * Worker * False * Moving Avg Reward is ==> -0.00887 * Last Reward was ==> -0.04040
# Episode * 45000 * Worker * False * Moving Avg Reward is ==> -0.00719 * Last Reward was ==> -0.01130
# Episode * 46000 * Worker * False * Moving Avg Reward is ==> -0.00226 * Last Reward was ==> -0.18572
# Episode * 47000 * Worker * False * Moving Avg Reward is ==> -0.00870 * Last Reward was ==> 0.04306
# Episode * 48000 * Worker * False * Moving Avg Reward is ==> -0.00549 * Last Reward was ==> 0.01343
# Episode * 49000 * Worker * False * Moving Avg Reward is ==> -0.00661 * Last Reward was ==> 0.02881
# Episode * 50000 * Worker * False * Moving Avg Reward is ==> -0.00565 * Last Reward was ==> -0.08812
# Episode * 51000 * Worker * False * Moving Avg Reward is ==> -0.00539 * Last Reward was ==> 0.03029
# Episode * 52000 * Worker * False * Moving Avg Reward is ==> -0.00962 * Last Reward was ==> 0.06441
# Episode * 53000 * Worker * False * Moving Avg Reward is ==> -0.00441 * Last Reward was ==> 0.01362
# Episode * 54000 * Worker * False * Moving Avg Reward is ==> -0.00755 * Last Reward was ==> 0.02267
# Episode * 55000 * Worker * False * Moving Avg Reward is ==> -0.00859 * Last Reward was ==> 0.03400
# Episode * 56000 * Worker * False * Moving Avg Reward is ==> -0.00694 * Last Reward was ==> 0.05605
# Episode * 57000 * Worker * False * Moving Avg Reward is ==> -0.00921 * Last Reward was ==> 0.03611
# Episode * 58000 * Worker * False * Moving Avg Reward is ==> -0.00703 * Last Reward was ==> 0.04131
# Episode * 59000 * Worker * False * Moving Avg Reward is ==> -0.00317 * Last Reward was ==> 0.03022
# Episode * 60000 * Worker * False * Moving Avg Reward is ==> -0.00847 * Last Reward was ==> 0.05613
# Episode * 61000 * Worker * False * Moving Avg Reward is ==> -0.00504 * Last Reward was ==> -0.02865
# Episode * 62000 * Worker * False * Moving Avg Reward is ==> -0.00368 * Last Reward was ==> 0.01732
# Episode * 63000 * Worker * False * Moving Avg Reward is ==> -0.00555 * Last Reward was ==> 0.02086
# Episode * 64000 * Worker * False * Moving Avg Reward is ==> -0.00606 * Last Reward was ==> 0.01434
# Episode * 65000 * Worker * False * Moving Avg Reward is ==> -0.00612 * Last Reward was ==> 0.03009
# Episode * 66000 * Worker * False * Moving Avg Reward is ==> -0.00936 * Last Reward was ==> 0.02939
# Episode * 67000 * Worker * False * Moving Avg Reward is ==> -0.01023 * Last Reward was ==> -0.00925
# Episode * 68000 * Worker * False * Moving Avg Reward is ==> -0.01167 * Last Reward was ==> -0.19015
# Episode * 69000 * Worker * False * Moving Avg Reward is ==> -0.00704 * Last Reward was ==> 0.01234
# Episode * 70000 * Worker * False * Moving Avg Reward is ==> -0.00775 * Last Reward was ==> 0.04357
# Episode * 71000 * Worker * False * Moving Avg Reward is ==> -0.00881 * Last Reward was ==> 0.01774
# Episode * 72000 * Worker * False * Moving Avg Reward is ==> -0.00616 * Last Reward was ==> 0.01425
# Episode * 73000 * Worker * False * Moving Avg Reward is ==> -0.00329 * Last Reward was ==> 0.02760
# Episode * 74000 * Worker * False * Moving Avg Reward is ==> -0.01228 * Last Reward was ==> 0.03616
# Episode * 75000 * Worker * False * Moving Avg Reward is ==> -0.00354 * Last Reward was ==> 0.05653
# Episode * 76000 * Worker * False * Moving Avg Reward is ==> -0.00412 * Last Reward was ==> 0.02128
# Episode * 77000 * Worker * False * Moving Avg Reward is ==> -0.00330 * Last Reward was ==> -0.13788
# Episode * 78000 * Worker * False * Moving Avg Reward is ==> -0.00444 * Last Reward was ==> 0.04463
# Episode * 79000 * Worker * False * Moving Avg Reward is ==> -0.00835 * Last Reward was ==> 0.03321
# Episode * 80000 * Worker * False * Moving Avg Reward is ==> -0.00575 * Last Reward was ==> -0.13381
# Episode * 81000 * Worker * False * Moving Avg Reward is ==> -0.00433 * Last Reward was ==> 0.03599
# Episode * 82000 * Worker * False * Moving Avg Reward is ==> -0.00471 * Last Reward was ==> 0.03856
# Episode * 83000 * Worker * False * Moving Avg Reward is ==> -0.00721 * Last Reward was ==> 0.04131
# Episode * 84000 * Worker * False * Moving Avg Reward is ==> -0.00281 * Last Reward was ==> -0.13807
# Episode * 85000 * Worker * False * Moving Avg Reward is ==> -0.00865 * Last Reward was ==> -0.00975
# Episode * 86000 * Worker * False * Moving Avg Reward is ==> -0.00684 * Last Reward was ==> -0.12681
# Episode * 87000 * Worker * False * Moving Avg Reward is ==> -0.00602 * Last Reward was ==> 0.02760
# Episode * 88000 * Worker * False * Moving Avg Reward is ==> -0.00523 * Last Reward was ==> -0.09152
# Episode * 89000 * Worker * False * Moving Avg Reward is ==> -0.00467 * Last Reward was ==> -0.09860
# Episode * 90000 * Worker * False * Moving Avg Reward is ==> -0.00407 * Last Reward was ==> 0.04145
# Episode * 91000 * Worker * False * Moving Avg Reward is ==> -0.00963 * Last Reward was ==> 0.03856
# Episode * 92000 * Worker * False * Moving Avg Reward is ==> -0.00735 * Last Reward was ==> 0.02818
# Episode * 93000 * Worker * False * Moving Avg Reward is ==> -0.00304 * Last Reward was ==> 0.03770
# Episode * 94000 * Worker * False * Moving Avg Reward is ==> -0.00530 * Last Reward was ==> -0.05829
# Episode * 95000 * Worker * False * Moving Avg Reward is ==> -0.00625 * Last Reward was ==> -0.10856
# Episode * 96000 * Worker * False * Moving Avg Reward is ==> -0.00716 * Last Reward was ==> 0.01549
# Episode * 97000 * Worker * False * Moving Avg Reward is ==> -0.00430 * Last Reward was ==> 0.12163
# Episode * 98000 * Worker * False * Moving Avg Reward is ==> -0.00146 * Last Reward was ==> -0.11786
# Episode * 99000 * Worker * False * Moving Avg Reward is ==> -0.01005 * Last Reward was ==> 0.03103
# Episode * 100000 * Worker * False * Moving Avg Reward is ==> -0.00444 * Last Reward was ==> 0.01734
# Episode * 101000 * Worker * False * Moving Avg Reward is ==> -0.00640 * Last Reward was ==> 0.02135
# Episode * 102000 * Worker * False * Moving Avg Reward is ==> -0.00313 * Last Reward was ==> 0.04209
# Episode * 103000 * Worker * False * Moving Avg Reward is ==> -0.00542 * Last Reward was ==> 0.04728
# Episode * 104000 * Worker * False * Moving Avg Reward is ==> -0.00590 * Last Reward was ==> -0.20332
# Episode * 105000 * Worker * False * Moving Avg Reward is ==> -0.00453 * Last Reward was ==> 0.02760
# Episode * 106000 * Worker * False * Moving Avg Reward is ==> -0.00631 * Last Reward was ==> -0.06917
# Episode * 107000 * Worker * False * Moving Avg Reward is ==> -0.00991 * Last Reward was ==> 0.03599
# Episode * 108000 * Worker * False * Moving Avg Reward is ==> -0.00712 * Last Reward was ==> 0.03611
# Episode * 109000 * Worker * False * Moving Avg Reward is ==> -0.00582 * Last Reward was ==> -0.10856
# Episode * 110000 * Worker * False * Moving Avg Reward is ==> -0.00336 * Last Reward was ==> 0.03400
# Episode * 111000 * Worker * False * Moving Avg Reward is ==> -0.00897 * Last Reward was ==> -0.09082
# Episode * 112000 * Worker * False * Moving Avg Reward is ==> -0.00124 * Last Reward was ==> -0.02865
# Episode * 113000 * Worker * False * Moving Avg Reward is ==> -0.00741 * Last Reward was ==> -0.08191
# Episode * 114000 * Worker * False * Moving Avg Reward is ==> -0.00268 * Last Reward was ==> 0.07276
# Episode * 115000 * Worker * False * Moving Avg Reward is ==> -0.00119 * Last Reward was ==> 0.03856
# Episode * 116000 * Worker * False * Moving Avg Reward is ==> 0.00430 * Last Reward was ==> 0.03729
# Episode * 117000 * Worker * False * Moving Avg Reward is ==> -0.00033 * Last Reward was ==> 0.04317
# Episode * 118000 * Worker * False * Moving Avg Reward is ==> -0.00699 * Last Reward was ==> -0.20063
# Episode * 119000 * Worker * False * Moving Avg Reward is ==> -0.00844 * Last Reward was ==> 0.03052
# Episode * 120000 * Worker * False * Moving Avg Reward is ==> -0.00253 * Last Reward was ==> -0.05300
# Episode * 121000 * Worker * False * Moving Avg Reward is ==> -0.00295 * Last Reward was ==> -0.00722
# Episode * 122000 * Worker * False * Moving Avg Reward is ==> -0.00252 * Last Reward was ==> 0.03158
# Episode * 123000 * Worker * False * Moving Avg Reward is ==> -0.00227 * Last Reward was ==> -0.01221
# Episode * 124000 * Worker * False * Moving Avg Reward is ==> -0.00489 * Last Reward was ==> 0.04157
# Episode * 125000 * Worker * False * Moving Avg Reward is ==> -0.00598 * Last Reward was ==> 0.01014
# Episode * 126000 * Worker * False * Moving Avg Reward is ==> -0.00422 * Last Reward was ==> 0.04157
# Episode * 127000 * Worker * False * Moving Avg Reward is ==> -0.00235 * Last Reward was ==> 0.01459
# Episode * 128000 * Worker * False * Moving Avg Reward is ==> -0.00719 * Last Reward was ==> -0.12236
# Episode * 129000 * Worker * False * Moving Avg Reward is ==> -0.00617 * Last Reward was ==> -0.10389
# Episode * 130000 * Worker * False * Moving Avg Reward is ==> -0.00346 * Last Reward was ==> 0.01704
# Episode * 131000 * Worker * False * Moving Avg Reward is ==> -0.00117 * Last Reward was ==> 0.01376
# Episode * 132000 * Worker * False * Moving Avg Reward is ==> -0.00121 * Last Reward was ==> 0.03353
# Episode * 133000 * Worker * False * Moving Avg Reward is ==> 0.00206 * Last Reward was ==> 0.03770
# Episode * 134000 * Worker * False * Moving Avg Reward is ==> 0.00776 * Last Reward was ==> -0.12919
# Episode * 135000 * Worker * False * Moving Avg Reward is ==> 0.00534 * Last Reward was ==> 0.13108
# Episode * 136000 * Worker * False * Moving Avg Reward is ==> 0.00237 * Last Reward was ==> 0.03672
# Episode * 137000 * Worker * False * Moving Avg Reward is ==> 0.00636 * Last Reward was ==> -0.01267
# Episode * 138000 * Worker * False * Moving Avg Reward is ==> 0.00056 * Last Reward was ==> -0.19389
# Episode * 139000 * Worker * False * Moving Avg Reward is ==> -0.00346 * Last Reward was ==> 0.03008
# Episode * 140000 * Worker * False * Moving Avg Reward is ==> -0.00571 * Last Reward was ==> 0.03135
# Episode * 141000 * Worker * False * Moving Avg Reward is ==> -0.00149 * Last Reward was ==> 0.02389
# Episode * 142000 * Worker * False * Moving Avg Reward is ==> -0.00145 * Last Reward was ==> 0.07396
# Episode * 143000 * Worker * False * Moving Avg Reward is ==> -0.00124 * Last Reward was ==> 0.01327
# Episode * 144000 * Worker * False * Moving Avg Reward is ==> -0.00135 * Last Reward was ==> 0.01632
# Episode * 145000 * Worker * False * Moving Avg Reward is ==> 0.00325 * Last Reward was ==> 0.04248
# Episode * 146000 * Worker * False * Moving Avg Reward is ==> -0.00637 * Last Reward was ==> -0.00269
# Episode * 147000 * Worker * False * Moving Avg Reward is ==> 0.00236 * Last Reward was ==> 0.14785
# Episode * 148000 * Worker * False * Moving Avg Reward is ==> -0.00242 * Last Reward was ==> -0.14930
# Episode * 149000 * Worker * False * Moving Avg Reward is ==> 0.00367 * Last Reward was ==> 0.02624
# Episode * 150000 * Worker * False * Moving Avg Reward is ==> 0.00304 * Last Reward was ==> 0.02351
# Episode * 151000 * Worker * False * Moving Avg Reward is ==> -0.00298 * Last Reward was ==> -0.19658
# Episode * 152000 * Worker * False * Moving Avg Reward is ==> 0.00177 * Last Reward was ==> -0.12946
# Episode * 153000 * Worker * False * Moving Avg Reward is ==> 0.00115 * Last Reward was ==> 0.02679
# Episode * 154000 * Worker * False * Moving Avg Reward is ==> -0.00826 * Last Reward was ==> 0.05717
# Episode * 155000 * Worker * False * Moving Avg Reward is ==> -0.00309 * Last Reward was ==> -0.11835
# Episode * 156000 * Worker * False * Moving Avg Reward is ==> -0.00471 * Last Reward was ==> -0.00863
# Episode * 157000 * Worker * False * Moving Avg Reward is ==> -0.00688 * Last Reward was ==> 0.03435
# Episode * 158000 * Worker * False * Moving Avg Reward is ==> -0.00233 * Last Reward was ==> 0.06779
# Episode * 159000 * Worker * False * Moving Avg Reward is ==> -0.00050 * Last Reward was ==> 0.01483
# Episode * 160000 * Worker * False * Moving Avg Reward is ==> 0.00047 * Last Reward was ==> 0.02300
# Episode * 161000 * Worker * False * Moving Avg Reward is ==> -0.00026 * Last Reward was ==> -0.02363
# Episode * 162000 * Worker * False * Moving Avg Reward is ==> -0.00328 * Last Reward was ==> 0.04555
# Episode * 163000 * Worker * False * Moving Avg Reward is ==> -0.00523 * Last Reward was ==> 0.03386
# Episode * 164000 * Worker * False * Moving Avg Reward is ==> -0.00538 * Last Reward was ==> 0.05614
# Episode * 165000 * Worker * False * Moving Avg Reward is ==> -0.00658 * Last Reward was ==> -0.02416
# Episode * 166000 * Worker * False * Moving Avg Reward is ==> -0.00511 * Last Reward was ==> -0.22933
# Episode * 167000 * Worker * False * Moving Avg Reward is ==> 0.00223 * Last Reward was ==> -0.03082
# Episode * 168000 * Worker * False * Moving Avg Reward is ==> -0.00483 * Last Reward was ==> 0.05839
# Episode * 169000 * Worker * False * Moving Avg Reward is ==> -0.00527 * Last Reward was ==> -0.06754
# Episode * 170000 * Worker * False * Moving Avg Reward is ==> -0.00090 * Last Reward was ==> 0.00108
# Episode * 171000 * Worker * False * Moving Avg Reward is ==> -0.00365 * Last Reward was ==> -0.14595
# Episode * 172000 * Worker * False * Moving Avg Reward is ==> -0.00458 * Last Reward was ==> 0.07845
# Episode * 173000 * Worker * False * Moving Avg Reward is ==> -0.00313 * Last Reward was ==> -0.04643
# Episode * 174000 * Worker * False * Moving Avg Reward is ==> -0.00129 * Last Reward was ==> -0.09180
# Episode * 175000 * Worker * False * Moving Avg Reward is ==> -0.00268 * Last Reward was ==> -0.12085
# Episode * 176000 * Worker * False * Moving Avg Reward is ==> -0.00457 * Last Reward was ==> 0.05827
# Episode * 177000 * Worker * False * Moving Avg Reward is ==> -0.00387 * Last Reward was ==> 0.01370
# Episode * 178000 * Worker * False * Moving Avg Reward is ==> -0.00488 * Last Reward was ==> -0.05151
# Episode * 179000 * Worker * False * Moving Avg Reward is ==> -0.00174 * Last Reward was ==> 0.04289
# Episode * 180000 * Worker * False * Moving Avg Reward is ==> -0.00793 * Last Reward was ==> 0.02089
# Episode * 181000 * Worker * False * Moving Avg Reward is ==> 0.00144 * Last Reward was ==> 0.03705
# Episode * 182000 * Worker * False * Moving Avg Reward is ==> 0.00180 * Last Reward was ==> 0.00304
# Episode * 183000 * Worker * False * Moving Avg Reward is ==> -0.00229 * Last Reward was ==> 0.03830
# Episode * 184000 * Worker * False * Moving Avg Reward is ==> -0.00829 * Last Reward was ==> 0.05355
# Episode * 185000 * Worker * False * Moving Avg Reward is ==> -0.00316 * Last Reward was ==> 0.05929
# Episode * 186000 * Worker * False * Moving Avg Reward is ==> -0.00327 * Last Reward was ==> 0.04148
# Episode * 187000 * Worker * False * Moving Avg Reward is ==> 0.00000 * Last Reward was ==> -0.10236
# Episode * 188000 * Worker * False * Moving Avg Reward is ==> 0.00197 * Last Reward was ==> 0.13519
# Episode * 189000 * Worker * False * Moving Avg Reward is ==> -0.00205 * Last Reward was ==> -0.00674
# Episode * 190000 * Worker * False * Moving Avg Reward is ==> -0.00333 * Last Reward was ==> 0.09100
# Episode * 191000 * Worker * False * Moving Avg Reward is ==> -0.00192 * Last Reward was ==> 0.05614
# Episode * 192000 * Worker * False * Moving Avg Reward is ==> -0.00081 * Last Reward was ==> 0.02224
# Episode * 193000 * Worker * False * Moving Avg Reward is ==> -0.00412 * Last Reward was ==> 0.02936
# Episode * 194000 * Worker * False * Moving Avg Reward is ==> -0.00436 * Last Reward was ==> 0.07770
# Episode * 195000 * Worker * False * Moving Avg Reward is ==> -0.00305 * Last Reward was ==> 0.04675
# Episode * 196000 * Worker * False * Moving Avg Reward is ==> 0.00088 * Last Reward was ==> -0.20726
# Episode * 197000 * Worker * False * Moving Avg Reward is ==> -0.00126 * Last Reward was ==> -0.09180
# Episode * 198000 * Worker * False * Moving Avg Reward is ==> -0.00435 * Last Reward was ==> -0.23475
# Episode * 199000 * Worker * False * Moving Avg Reward is ==> -0.00250 * Last Reward was ==> 0.05827
# Episode * 200000 * Worker * False * Moving Avg Reward is ==> -0.00083 * Last Reward was ==> 0.02264
# Episode * 201000 * Worker * False * Moving Avg Reward is ==> -0.00241 * Last Reward was ==> 0.03429
# Episode * 202000 * Worker * False * Moving Avg Reward is ==> -0.00368 * Last Reward was ==> -0.10632
# Episode * 203000 * Worker * False * Moving Avg Reward is ==> -0.00131 * Last Reward was ==> 0.01251
# Episode * 204000 * Worker * False * Moving Avg Reward is ==> -0.00088 * Last Reward was ==> 0.02914
# Episode * 205000 * Worker * False * Moving Avg Reward is ==> -0.00366 * Last Reward was ==> 0.07632
# Episode * 206000 * Worker * False * Moving Avg Reward is ==> 0.00096 * Last Reward was ==> 0.08136
# Episode * 207000 * Worker * False * Moving Avg Reward is ==> -0.00071 * Last Reward was ==> 0.13825
# Episode * 208000 * Worker * False * Moving Avg Reward is ==> -0.00516 * Last Reward was ==> 0.08649
# Episode * 209000 * Worker * False * Moving Avg Reward is ==> 0.00205 * Last Reward was ==> 0.08649
# Episode * 210000 * Worker * False * Moving Avg Reward is ==> -0.00094 * Last Reward was ==> 0.04688
# Episode * 211000 * Worker * False * Moving Avg Reward is ==> -0.00380 * Last Reward was ==> 0.12509
# Episode * 212000 * Worker * False * Moving Avg Reward is ==> -0.00387 * Last Reward was ==> 0.03382
# Episode * 213000 * Worker * False * Moving Avg Reward is ==> -0.00059 * Last Reward was ==> 0.04384
# Episode * 214000 * Worker * False * Moving Avg Reward is ==> 0.00153 * Last Reward was ==> -0.01237
# Episode * 215000 * Worker * False * Moving Avg Reward is ==> -0.00174 * Last Reward was ==> 0.05311
# Episode * 216000 * Worker * False * Moving Avg Reward is ==> -0.00380 * Last Reward was ==> -0.09692
# Episode * 217000 * Worker * False * Moving Avg Reward is ==> -0.00607 * Last Reward was ==> -0.13662
# Episode * 218000 * Worker * False * Moving Avg Reward is ==> -0.00531 * Last Reward was ==> 0.00900
# Episode * 219000 * Worker * False * Moving Avg Reward is ==> 0.00398 * Last Reward was ==> 0.01096
# Episode * 220000 * Worker * False * Moving Avg Reward is ==> -0.00339 * Last Reward was ==> 0.07501
# Episode * 221000 * Worker * False * Moving Avg Reward is ==> -0.00194 * Last Reward was ==> -0.10236
# Episode * 222000 * Worker * False * Moving Avg Reward is ==> -0.00003 * Last Reward was ==> 0.12586
# Episode * 223000 * Worker * False * Moving Avg Reward is ==> -0.00367 * Last Reward was ==> 0.02679
# Episode * 224000 * Worker * False * Moving Avg Reward is ==> 0.00063 * Last Reward was ==> 0.01829
# Episode * 225000 * Worker * False * Moving Avg Reward is ==> -0.00395 * Last Reward was ==> -0.03385
# Episode * 226000 * Worker * False * Moving Avg Reward is ==> -0.00661 * Last Reward was ==> -0.13802
# Episode * 227000 * Worker * False * Moving Avg Reward is ==> -0.00835 * Last Reward was ==> 0.01322
# Episode * 228000 * Worker * False * Moving Avg Reward is ==> -0.00116 * Last Reward was ==> -0.09692
# Episode * 229000 * Worker * False * Moving Avg Reward is ==> -0.00156 * Last Reward was ==> -0.00674
# Episode * 230000 * Worker * False * Moving Avg Reward is ==> -0.00821 * Last Reward was ==> 0.01808
# Episode * 231000 * Worker * False * Moving Avg Reward is ==> -0.00572 * Last Reward was ==> -0.19559
# Episode * 232000 * Worker * False * Moving Avg Reward is ==> -0.00023 * Last Reward was ==> 0.04758
# Episode * 233000 * Worker * False * Moving Avg Reward is ==> -0.00173 * Last Reward was ==> 0.04420
# Episode * 234000 * Worker * False * Moving Avg Reward is ==> -0.00337 * Last Reward was ==> 0.00084
# Episode * 235000 * Worker * False * Moving Avg Reward is ==> 0.00246 * Last Reward was ==> -0.09180
# Episode * 236000 * Worker * False * Moving Avg Reward is ==> -0.00552 * Last Reward was ==> 0.06038
# Episode * 237000 * Worker * False * Moving Avg Reward is ==> 0.00047 * Last Reward was ==> 0.02300
# Episode * 238000 * Worker * False * Moving Avg Reward is ==> -0.00455 * Last Reward was ==> 0.02177
# Episode * 239000 * Worker * False * Moving Avg Reward is ==> -0.00766 * Last Reward was ==> 0.13825
# Episode * 240000 * Worker * False * Moving Avg Reward is ==> -0.00439 * Last Reward was ==> 0.01453
# Episode * 241000 * Worker * False * Moving Avg Reward is ==> -0.00597 * Last Reward was ==> 0.00858

# %%
agent.env.mode = "test"
scores = []
success = 0

for i in range(100):
    state = agent.env.reset()
    score = 0
    reward = 0
    done = False
    initial_portfolio = agent.env.portfolio_value
    step = 0
    while not done:
                
        #state = np.expand_dims(state, axis=0)
        action, action_onehot, prediction = agent.act(state)
        # Retrieve new state, reward, and whether the state is terminal
        next_state, reward, done, _ = agent.env.step(action)
        #print(action, reward, agent.env.portfolio_value)
        # Memorize (state, action, reward) for training
        #self.buffer.remember(np.expand_dims(state, axis=0), action_onehot, reward)
        # Update current state
        if done :
            if step < 65:
                success +=1
        step+=1
        state = next_state
        score += reward
    
    #print(score,initial_portfolio, agent.env.portfolio_value)
    scores.append(score)
    
print(np.mean(scores))
print(min(scores))
print(max(scores))
print(success)
